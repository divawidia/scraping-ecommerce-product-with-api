# %%
import requests
import pandas as pd

# %%
url = "https://gql.tokopedia.com/graphql/ShopProducts"

querystring = {
    "etalaseId": "etalase", 
    "page": "1", 
    "perPage": "80",
    "sid":"2126488", 
    "sort": "11",
    "user_cityId": "176",
    "user_districtId": "2274",
    "user_lat": "",
    "user_long": ""}

payload = ""
headers = {
        'authority': 'gql.tokopedia.com',
        'accept': '*/*',
        'accept-encoding':'gzip, deflate, br',
        'accept-language':'en-US,en;q=0.9,id;q=0.8,ja;q=0.7',
        'content-type': 'application/json',
        'cookie': '_gcl_au=1.1.435086370.1661918253; DID=cdd106062b250090c81baca129ab757a52429f2a588e1437b783e6bcfa80e3f9d760cc3735292f1d41aa4af6fa49b6c7; DID_JS=Y2RkMTA2MDYyYjI1MDA5MGM4MWJhY2ExMjlhYjc1N2E1MjQyOWYyYTU4OGUxNDM3Yjc4M2U2YmNmYTgwZTNmOWQ3NjBjYzM3MzUyOTJmMWQ0MWFhNGFmNmZhNDliNmM347DEQpj8HBSa+/TImW+5JCeuQeRkm5NMpJWZG3hSuFU=; _UUID_NONLOGIN_=88aa6392627dfe3d5ef605c5426a24e7; _UUID_CAS_=28fbc622-cf35-45de-9432-7adfd4a31d7c; _jxx=0cf5a050-28e1-11ed-82cc-d9794eebe228; _jx=0cf5a050-28e1-11ed-82cc-d9794eebe228; __auc=9c046f5b182f20c333bde6c34e7; _fbp=fb.1.1661918274750.1516274203; hfv_banner=true; _SID_Tokopedia_=LnRQMndITydZnvruKSOF1Okg10x_30y9pAx_48z873_2l_hEJtb0lBV9ZZ2SMWbNkdr09pas-TUnJDQmFAw8rCreCPLYY8QHRvvLa9-bI4l-R8bRzuz6HgCzIUpm4QTM; g_yolo_production=1; l=1; tuid=13438843; uidh=5A015SQcjQfQwBqfXdQzNVhc5KAC2gTu5nc8QFi/x+A=; FPF=1; uide=zSRLDpas4m77Pt2jpNYOvNsR+NRJt7gRyOfKwfsdbMyOFkqn; aus=1; cto_bundle=uJc2PV9SMkYyNSUyQjB5RFBXTW9aeTJ5RnVuY2RRa21PcXVIOHp1b0dDYXg5JTJCOFBKVExUc3BuUTIxSHV3ZHg3UnR2elZtZlZaa2FaZFJvYzFNeSUyRnZ1ODRPMFF6akprWUc0ZzZraVZWNTBpRTl6QUh5MlE0S0lQejRyamg5eFkwNGhnajBMNDN2RFp2R0RDS0pEUmNlZjJHQiUyQm5sQSUzRCUzRA; _CASE_=...; bm_sz=4EC882F7F9CA685ADFA32D278DD7E798~~4601414~4605507; ak_bmsc=55353C436B92C645D90D15CD21D3308D~000000000000000000000000000000~...; _gid=GA1.2.1223926664.1669254800; _jxxs=1669254799-0cf5a050-28e1-11ed-82cc-d9794eebe228; _jxs=1669254799-0cf5a050-28e1-11ed-82cc-d9794eebe228; __asc=833c8da4184a756ef7e0d9c9557; _dc_gtm_UA-9801603-1=1; _abck=04370785DA6C9C926DE3DDD9DA73A390~0~...~-1~-1~-1; bm_sv=798C7ED40F5A906B74C8B73BAEE10A57~~1; _ga=GA1.2.1035263622.1661918253; _dc_gtm_UA-126956641-6=1; webauthn-session=d8288f95-2a6b-4e37-981d-77205156f037; _gat_UA-9801603-1=1; _ga_70947XW48P=GS1.1.1669254799.53.1.1669255598.19.0.0',
        'origin': 'https://www.tokopedia.com',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.56',
    }
response = requests.request(
    "POST", url, headers=headers, params=querystring)

data = response.json()
# product_list = []
# # data

# for index in range(0, data['data']['paging']['total_item'], 40):
#     querystring_product = {"promoTab": "false", "excludeProductList": "false",
#                    "start":f"{index}", "intent": "false", "multiCategory": "true", "showFacet": "false"}
#     response_product = requests.request("GET", url, data=payload, headers=headers, params=querystring_product)
#     data_product = response_product.json()

#     for product in data_product["data"]["products"]:
#         product_list.append(product)

# %%
data
# Out:
# [{'errors': [{'message': 'Request not allowed', 'extensions': {'code': 406}}]}]

# %%
df = pd.json_normalize(data)
df
# Out:
#                                               errors
# 0  [{'message': 'Request not allowed', 'extension...

# %%
url_review = "https://www.blibli.com/backend/product-review/public-reviews"

result_review = []

for i in range(0, len(product_list)):
    query_params_review = {
        "page":"1",
        "itemPerPage":"30",
        "productSku":f"{product_list[i]['sku']}"
    }
    headers_review = {
        'authority': 'www.blibli.com',
        'accept': 'application/json, text/plain, */*',
        'accept-language':'en-US,en;q=0.9,id;q=0.8,ja;q=0.7',
        'cache-control':'no-cache',
        'cookie': 'Blibli-Device-Id=U.cb41c6ad-3ec3-413b-839f-6ccc5cef84d0; Blibli-Device-Id-Signature=a3add4c1e749d43595ebfc088de7674634e06db5; _gcl_au=1.1.119481478.1662825687; __gtm_med=popads_cpc; __gtm_src=propeller_ads; __bwa_user_id=657116261.U.6479625894511464.1662825687; _vwo_uuid_v2=D2BADB50769B5030869041F9800073B9B|8d3132207c7774ddf328c43ecacd82b4; _fbp=fb.1.1662825687909.1013520868; _tt_enable_cookie=1; _ttp=d7e905ff-7712-4c32-b238-de66f8387bf5; _vis_opt_s=1%7C; _vis_opt_test_cookie=1; _vwo_uuid=D2BADB50769B5030869041F9800073B9B; __gtm_cam=homepage_smartcpm; cebs=1; Blibli-Is-Member=false; Blibli-Is-Remember=false; Blibli-User-Id=c285e445-8329-48d9-9eff-3b3927c4f96a; Blibli-Session-Id=3325b78c-a3a3-4e67-ba44-c09d9b0b4859; Blibli-Signature=bd1048ea8813b09047c5d789a234b1abaff6ddcc; moe_uuid=34b40e3a-d664-4d16-9fb7-79544db6c0d4; _vis_opt_exp_223_exclude=1; JSESSIONID=0C4BE506C57C87DC083457F68DE0388D; _gid=GA1.2.542517985.1669123993; _vwo_ds=3%3Aa_0%2Ct_0%3A0%241662825685%3A50.27817927%3A%3A7_0%2C6_0%2C5_0%2C4_0%2C3_0%2C2_0%3A215_0%2C214_0%2C213_0%2C211_0%2C210_0%2C209_0%2C208_0%2C139_0%2C3_0%2C2_0%3A0; _abck=9438609A1CC0C976A7C5F0965FDCF94B~0~...~-1~-1~-1; bm_sz=505F53A70AAB8E35AF604FCCE22FD8AA~~3290693~4604741; ak_bmsc=B2B52A64E36F4CC36CFF44AD2F4D91BC~000000000000000000000000000000~...; cto_bundle=d14Nl19ENWxHSXJOdXZVVXk1S3ZRb0x6U2U2ZHVtMjdLUFdNTGpsUUt3bkEyZzN5VVNwaE5aazVkTSUyQlAwaVM4NlV0RU1JNXh4N3FGNjhoSEN0U24xSWs0VmE2aGZ0RyUyRnVhdGVsQVlOQVpCVTBhdXJ4Z1pwcXpBWW9vbnJsJTJCWE93TGE4UkU2eUZTQm1IWDI2WHJDNVFCNWslMkZuZyUzRCUzRA; _ga=GA1.2.1032891258.1662825687; _dc_gtm_UA-21718848-13=1; __bwa_session_utm_campaign=; __bwa_session_utm_medium=; __bwa_session_utm_source=MERCHANT_PAGE; __bwa_session_utm_content=; __bwa_session_utm_term=; __bwa_session_campaign_type=campaign-tags; __bwa_session_id=723337755.S.6651441420746517.1669206602; __bwa_user_session_sequence=61; cebsp=122; _ga_G3ZP2F3MW9=GS1.1.1669205947.32.1.1669206607.55.0.0; bm_sv=34CBD18A2F1C41467F57FF4261F29A62~~1; _ce.s=v~b7660bf9a491e6fb6dc76f40c3afc212ddedcda9~vpv~0~v11.rlc~1669205948305~ir~1~gtrk.la~latmiomb; __bwa_session_action_sequence=3; _vwo_sn=6380077%3A21',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    }
    response_review = requests.request("GET", url=url_review, headers=headers_review, params=query_params_review).json()

    product = product_list[i]

    try:
        if response_review["paging"]["total_page"] > 1:
            for page in range(1, response_review["paging"]["total_page"]+1):
                querystring_review2 = {"page":f"{page}","itemPerPage":"30","productSku":f"{product_list[i]['sku']}"}

                response_review2 = requests.request("GET", url=url_review, headers=headers_review, params=querystring_review2)
                
                data_review2 = response_review2.json()

                for a in data_review2["data"]:
                    a.update({"product":product})
                    result_review.append(a)
        else:
            for a in response_review["data"]:
                a.update({"product":product})
                result_review.append(a)

        print("Scraping product no. "+str(i)+" sku: " + product_list[i]['sku'] + " review done")
    except Exception as e:
        print(response_review)
        print(e)
# Out:
# Scraping product no. 0 sku: SOO-60052-00009 review done
# Scraping product no. 1 sku: SOO-60052-00023 review done
# Scraping product no. 2 sku: SOO-60052-00025 review done
# Scraping product no. 3 sku: SOO-60052-00039 review done
# Scraping product no. 4 sku: SOO-60052-00026 review done
# Scraping product no. 5 sku: SOO-60052-00028 review done
# Scraping product no. 6 sku: SOO-60052-00010 review done
# Scraping product no. 7 sku: SOO-60052-00029 review done
# Scraping product no. 8 sku: SOO-60052-00168 review done
# Scraping product no. 9 sku: SOO-60052-00141 review done
# Scraping product no. 10 sku: SOO-60052-00003 review done
# Scraping product no. 11 sku: SOO-60052-00166 review done
# Scraping product no. 12 sku: SOO-60052-00004 review done
# Scraping product no. 13 sku: SOO-60052-00011 review done
# Scraping product no. 14 sku: SOO-60052-00233 review done
# Scraping product no. 15 sku: SOO-60052-00027 review done
# Scraping product no. 16 sku: SOO-60052-00035 review done
# ...

# %%
df_review = pd.json_normalize(result_review)
df_review
# Out:
#                                         id             name  rating  \
# 0     73a68739-1237-49f1-821f-6261cb90c5fc              Aro       5
# 1     75702197-fba0-4200-a0f0-52dd7c8c332c          MUHAMAD       5
# 2     2a91401f-8e11-4b90-8027-7605a8b89ba3             Dewi       5
# 3     5c94e856-63aa-40c5-be9d-8931160c049d            V***a       5
# 4     3d98c992-e2c9-454c-aa1a-a957f7ac5764  iv***@gmail.com       5
# ...                                    ...              ...     ...
# 8348  c5025d0d-a0d3-48ed-827e-11ce51f6cacc            F***a       5
# 8349  40b76884-0c7b-4f71-ad22-93d237b1ad45            Dolar       5
# 8350  236dc7b3-5a93-43fb-8e1f-2bac06cfcc46            G***a       5
# 8351  86009efb-3533-476f-bfdc-fba46fe8f399            Retno       5
# 8352  893e13a5-337b-4856-b471-4f292ad587df            N***a       5
#
#         createdDate    updatedDate  likes  showPriority  verifiedBuyer  \
# 0     1668487909680  1668487909680      0             2           True
# ...

# %%
from pymongo import MongoClient

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['blibliProductReview'] 
collection = db['somethinc']

# %%
collection.insert_many(result_review)

# %%
data = collection.find()

df = pd.json_normalize(data)
df
# Out:
#                            _id                                    id  \
# 0     637e18d68ccf7446afd010e3  73a68739-1237-49f1-821f-6261cb90c5fc
# 1     637e18d68ccf7446afd010e4  75702197-fba0-4200-a0f0-52dd7c8c332c
# 2     637e18d68ccf7446afd010e5  2a91401f-8e11-4b90-8027-7605a8b89ba3
# 3     637e18d68ccf7446afd010e6  5c94e856-63aa-40c5-be9d-8931160c049d
# 4     637e18d68ccf7446afd010e7  3d98c992-e2c9-454c-aa1a-a957f7ac5764
# ...                        ...                                   ...
# 8348  637e18d68ccf7446afd0317f  c5025d0d-a0d3-48ed-827e-11ce51f6cacc
# 8349  637e18d68ccf7446afd03180  40b76884-0c7b-4f71-ad22-93d237b1ad45
# 8350  637e18d68ccf7446afd03181  236dc7b3-5a93-43fb-8e1f-2bac06cfcc46
# 8351  637e18d68ccf7446afd03182  86009efb-3533-476f-bfdc-fba46fe8f399
# 8352  637e18d68ccf7446afd03183  893e13a5-337b-4856-b471-4f292ad587df
#
#                  name  rating    createdDate    updatedDate  likes  \
# 0                 Aro       5  1668487909680  1668487909680      0
# ...
