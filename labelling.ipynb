# %%
from pymongo import MongoClient
import pandas as pd
import re
import numpy as np

# %%
localhost = "mongodb://localhost:27017"
mongodb_atlas = "mongodb+srv://user:pass123@productreviewecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
client = MongoClient(localhost)

# %%
db_blibli = client['blibli'] 
collection_blibli = db_blibli['polytron']

# %%
# from bukalapak
db_bukalapak = client['bukalapak'] 
collection_bukalapak = db_bukalapak['polytron']

# %%
db_zalora = client['zalora'] 
collection_zalora = db_zalora['910']

# %%
db_shopee = client['shopee'] 
collection_shopee = db_shopee['polytron']

# %%
db_jdid = client['jdidProductReview'] 
collection_jdid = db_jdid['910']

# %%
db_tokopedia = client['tokopedia'] 
collection_tokopedia = db_tokopedia['polytron']

# %% [markdown]
# **Convert MongoDB Data to DataFrame**

# %%
data_bukalapak = collection_bukalapak.find()

df_bukalapak = pd.json_normalize(data_bukalapak)
df_bukalapak = pd.DataFrame(df_bukalapak[['review.content', 'created_at', 'product.name', 'product.specs.merek']])
df_bukalapak['created_at'] = pd.to_datetime(df_bukalapak['created_at'])
df_bukalapak.rename(columns = {'review.content':'review', 'created_at':'review_date', 'product.name':'product_name', 'product.specs.merek':'product_brand'}, inplace = True)
df_bukalapak

# %%
data_blili = collection_blibli.find()

df_blibli = pd.json_normalize(data_blili)
df_blibli = pd.DataFrame(df_blibli[['content', 'createdDate', 'product.name', 'product.brand']])
df_blibli['createdDate'] = pd.to_datetime(df_blibli['createdDate'], unit='ms')
df_blibli.rename(columns = {'content':'review', 'createdDate':'review_date', 'product.name':'product_name', 'product.brand':'product_brand'}, inplace = True)
df_blibli
# Out:
#                                                  review  \
# 0                                                   NaN
# 1     Produknya berbunyi keras, untuk air panas dan ...
# 2                                                mantap
# 3
# 4                             barang ok. pengiriman ok.
# ...                                                 ...
# 3219  bilang dong kalo pake ekspedisi. bli bli tolon...
# 3220                                                NaN
# 3221             top markotoooooppppp...👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍
# 3222
# 3223  barang ok bet..produk polytron gk ush diraguka...
#
#                  review_date  \
# 0    2022-02-23 01:42:48.823
# 1    2021-11-06 02:13:42.100
# 2    2021-07-16 12:30:20.258
# 3    2021-04-04 14:59:55.617
# 4    2021-01-21 06:31:47.572
# ...                      ...
# 3219 2020-08-19 12:10:35.478
# 3220 2022-08-11 14:19:41.595
# 3221 2022-10-25 07:18:13.497
# 3222 2022-08-30 00:35:57.362
# 3223 2022-04-01 12:52:04.448
#
#                                            product_name product_brand
# 0     POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 1     POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 2     POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 3     POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 4     POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# ...                                                 ...           ...
# 3219            POLYTRON Cinemax LED TV 43" PLD 43TS153      POLYTRON
# 3220  Dispenser Galon Bawah Polytron PWC 778 WUV den...      POLYTRON
# 3221          POLYTRON Smart TV 4K UHD HDR PLD 55UV5920      POLYTRON
# 3222        POLYTRON Digital LED TV 40 inch PLD 40V8953      POLYTRON
# 3223       POLYTRON Belleza 1 pintu 150 liter PRA 15MOW      POLYTRON
#
# [3224 rows x 4 columns]

# %%
data_zalora = collection_zalora.find()

df_zalora = pd.json_normalize(data_zalora)
df_zalora = df_zalora.to_dict('records')
df_zalora = pd.json_normalize(df_zalora, 'comments', ['product.meta.name', 'product.meta.brand'])
df_zalora = pd.DataFrame(df_zalora[['text', 'created_at', 'product.meta.name', 'product.meta.brand']])
df_zalora.rename(columns = {'text':'review', 'created_at':'review_date','product.meta.name':'product_name', 'product.meta.brand':'product_brand'}, inplace = True)
df_zalora
# Out:
#                                                review          review_date  \
# 0   di plastik kiriman ada tulisan free socks tp d...  2022-05-12 16:51:23
# 1                                             Terbaik  2021-05-18 08:39:04
# 2                             produk bagus dan sesuai  2022-10-19 08:56:36
# 3             warna yang datang tidak sesuai pesanan.  2021-05-19 06:29:49
# 4   mantap pokonya, lokal pride keren parah😅 cmn p...  2021-06-10 14:36:01
# 5                                       terbaik...👍👍👍  2022-01-13 13:22:52
# 6                                              mantap  2021-11-16 01:30:15
# 7   Sepatu ini terasa nyaman di kaki dan gak panas...  2022-01-17 13:33:29
# 8                                         reccomended  2021-06-12 12:30:11
# 9                                                nice  2022-10-29 15:19:09
# 10                                             mantap  2022-02-27 05:08:35
# 11                           kualitas sesuai harga...  2022-11-15 10:42:23
# 12                                   bagus dan nyaman  2021-08-05 12:17:17
#
#                                          product_name product_brand
# 0   910 Nineten Geist Ekiden Sepatu Running - Hita...           910
# 1   910 Nineten Geist Ekiden Sepatu Running - Hita...           910
# 2   910 Nineten Kizuna Sepatu Lari - Biru/Merah/Ku...           910
# 3   910 Nineten Yuza Sepatu Trail Running - Hijau ...           910
# 4   910 Nineten Geist Ekiden Sepatu Running - Hita...           910
# 5   910 Nineten Haze 1.5 Sepatu Lari -Hitam/Abu/Merah           910
# 6   910 Nineten Haze 1.5 Sepatu Lari - Biru Dongke...           910
# 7   910 Nineten Geist Ekiden Sepatu Running - Hita...           910
# 8   910 Nineten Geist Ekiden Sepatu Running - Hita...           910
# 9   910 Nineten Haze Metaspeed Sepatu Lari - Biru-...           910
# 10  910 Nineten Haze Vision Sepatu Lari - Biru Tua...           910
# 11  910 Nineten Yuza Riot-Sepatu Trail-Hijau-Teal/...           910
# 12  910 Nineten Bundling Fuka Quarter Kaos Kaki Pa...           910

# %%
data_tokopedia = collection_tokopedia.find()

df_tokopedia = pd.json_normalize(data_tokopedia)
df_tokopedia = pd.DataFrame(df_tokopedia[['message', 'reviewCreateTime', 'product.name']])
df_tokopedia['reviewCreateTime'] = pd.to_datetime(df_tokopedia['reviewCreateTime'], unit='s')
df_tokopedia.rename(columns = {'message':'review', 'reviewCreateTime':'review_date','product.name':'product_name'}, inplace = True)
df_tokopedia
# Out:
#                                                   review         review_date  \
# 0                       barang ok punya sesuai deskripsi 2022-11-16 16:28:38
# 1      Kulkasnya sih berfungsi tapi saya masih menung... 2022-10-23 12:15:13
# 2                                           Terima kasih 2022-10-09 22:03:04
# 3                 Saya chat tidak di respon tapi di read 2022-10-07 06:30:43
# 4      Produk bagus, order sabtu, hari selasa sampe. ... 2022-09-03 01:55:18
# ...                                                  ...                 ...
# 12002  barang oke banget.. produk halus, layar oke bg... 2019-01-07 11:10:00
# 12003         mantap barangnya nyampe nya cepet perfecto 2019-07-18 19:06:29
# 12004  Brang bgus....sesuai yg d gmbar.dan buat penge... 2019-06-07 18:11:54
# 12005  Pruloduknya dipaket kan dengan tapi Dan tdk ad... 2019-09-01 11:28:42
# 12006                                                    2019-03-18 13:53:51
#
#                                             product_name
# 0      Kulkas POLYTRON Belleza JUMBO Inverter 2 Pintu...
# 1      Kulkas POLYTRON Belleza JUMBO Inverter 2 Pintu...
# 2      Kulkas POLYTRON Belleza JUMBO Inverter 2 Pintu...
# 3      Kulkas POLYTRON Belleza JUMBO Inverter 2 Pintu...
# 4      Kulkas POLYTRON Belleza JUMBO Inverter 2 Pintu...
# ...                                                  ...
# 12002               POLYTRON Candybar C289 - Layar Besar
# 12003     POLYTRON Candybar C204 - Garansi Resmi 1 tahun
# 12004     POLYTRON Candybar C204 - Garansi Resmi 1 tahun
# 12005     Polytron Candybar C24g - Garansi resmi 1 Tahun
# 12006               POLYTRON Candybar C201 - Cuci Gudang
#
# [12007 rows x 3 columns]

# %%
data_jdid = collection_jdid.find()

df_jdid = pd.json_normalize(data_jdid, 'commentChildrens', [['product','skuName']])
df_jdid['commentDate'] = pd.to_datetime(df_jdid['commentDate'], unit='ms')
df_jdid = pd.DataFrame(df_jdid[['content', 'commentDate', 'product.skuName']])
df_jdid.rename(columns = {'content':'review', 'commentDate':'review_date','product.skuName':'product_name'}, inplace = True)
df_jdid

# %%
data_shopee = collection_shopee.find()

df_shopee = pd.json_normalize(data_shopee, 'product_items', ['comment', 'ctime'])
df_shopee = pd.DataFrame(df_shopee[['comment', 'ctime', 'name']])
df_shopee['ctime'] = pd.to_datetime(df_shopee['ctime'], unit='s')
df_shopee.rename(columns = {'comment':'review', 'ctime':'review_date','name':'product_name'}, inplace = True)
df_shopee
# Out:
#                                                   review         review_date  \
# 0      Fitur Terbaik:Polytron ok\nSepadan dengan Harg... 2022-11-22 11:22:15
# 1      Semoga awet . akhirnya sampe juga yang ditungg... 2021-12-12 06:02:34
# 2      Sepadan dengan Harga:yah sesuai, apalagi kl ad... 2022-12-04 13:24:36
# 3      Fitur Terbaik:pengiriman cepat,dua hari sampai... 2022-11-03 08:06:58
# 4      Pengiriman cpt, udah tv digital gambarnya bers... 2022-10-21 15:39:52
# ...                                                  ...                 ...
# 10003                                                    2022-08-01 02:05:15
# 10004                                                    2022-02-15 23:50:28
# 10005                                                    2022-01-11 14:03:23
# 10006  Barang sudah diterima dengan baik\nDiantar den... 2022-10-13 08:34:47
# 10007                                                    2022-09-22 22:28:54
#
#                                             product_name
# 0      POLYTRON Cinemax Digital LED TV 32 inch PLD 32...
# 1      POLYTRON Cinemax Digital LED TV 32 inch PLD 32...
# 2      POLYTRON Cinemax Digital LED TV 32 inch PLD 32...
# 3      POLYTRON Cinemax Digital LED TV 32 inch PLD 32...
# 4      POLYTRON Cinemax Digital LED TV 32 inch PLD 32...
# ...                                                  ...
# 10003  POLYTRON Mesin Cuci Front Loading inverter 100...
# 10004  Mesin cuci bukaan depan polytron wonderwash PF...
# 10005  Mesin cuci bukaan depan polytron wonderwash PF...
# 10006            POLYTRON Multimedia Speaker PMA 9320 /W
# 10007            POLYTRON Multimedia Speaker PMA 9320 /W
#
# [10008 rows x 3 columns]

# %%
df_review = pd.concat([df_blibli, df_tokopedia, df_shopee], ignore_index=True)
df_review
# Out:
#                                                   review  \
# 0                                                    NaN
# 1      Produknya berbunyi keras, untuk air panas dan ...
# 2                                                 mantap
# 3
# 4                              barang ok. pengiriman ok.
# ...                                                  ...
# 25234
# 25235
# 25236
# 25237  Barang sudah diterima dengan baik\nDiantar den...
# 25238
#
#                   review_date  \
# 0     2022-02-23 01:42:48.823
# 1     2021-11-06 02:13:42.100
# 2     2021-07-16 12:30:20.258
# 3     2021-04-04 14:59:55.617
# 4     2021-01-21 06:31:47.572
# ...                       ...
# 25234 2022-08-01 02:05:15.000
# 25235 2022-02-15 23:50:28.000
# 25236 2022-01-11 14:03:23.000
# 25237 2022-10-13 08:34:47.000
# 25238 2022-09-22 22:28:54.000
#
#                                             product_name product_brand
# 0      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 1      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 2      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 3      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 4      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# ...                                                  ...           ...
# 25234  POLYTRON Mesin Cuci Front Loading inverter 100...           NaN
# 25235  Mesin cuci bukaan depan polytron wonderwash PF...           NaN
# 25236  Mesin cuci bukaan depan polytron wonderwash PF...           NaN
# 25237            POLYTRON Multimedia Speaker PMA 9320 /W           NaN
# 25238            POLYTRON Multimedia Speaker PMA 9320 /W           NaN
#
# [25239 rows x 4 columns]

# %%
df_review = pd.concat([df_blibli, df_bukalapak, df_zalora, df_jdid, df_tokopedia, df_shopee], ignore_index=True)
df_review
# Out:
#                                                   review  \
# 0                                                    NaN
# 1
# 2                                                    NaN
# 3                                             keren kali
# 4
# ...                                                  ...
# 53540  Paket diterima dengan aman dan selamat, respon...
# 53541  Ini keren banget di buat prioritas\nDan sudah ...
# 53542
# 53543
# 53544
#
#                       review_date  \
# 0      2022-11-21 07:38:27.070000
# 1      2022-11-15 02:30:16.483000
# 2      2022-10-28 08:21:37.291000
# 3      2022-10-07 12:56:40.869000
# 4      2022-10-07 08:10:58.027000
# ...                           ...
# 53540         2022-07-31 02:49:20
# 53541         2022-05-02 18:29:53
# 53542         2022-07-21 09:26:08
# 53543         2022-02-20 02:59:04
# 53544         2022-03-22 00:16:17
#
#                                             product_name product_brand
# 0      910 Nineten Hatomi Kaos Kaki Socks Quarter - P...           910
# 1      910 Nineten Hatomi Kaos Kaki Socks Quarter - P...           910
# 2      910 Nineten Hatomi Kaos Kaki Socks Quarter - P...           910
# 3      910 Nineten Hatomi Kaos Kaki Socks Quarter - P...           910
# 4      910 Nineten Hatomi Kaos Kaki Socks Quarter - P...           910
# ...                                                  ...           ...
# 53540  910 Nineten Bundling Package Haze 1.5 (Sepatu+...           NaN
# 53541  910 Nineten Bundling Package Haze 1.5 (Sepatu+...           NaN
# 53542  910 Nineten Bundling Package Geist Ekiden (Sep...           NaN
# 53543  910 Nineten Bundling Package Geist Ekiden (Sep...           NaN
# 53544  910 Nineten Bundling Package Geist Ekiden (Sep...           NaN
#
# [53545 rows x 4 columns]

# %%
df_review = df_review.dropna(how='all',subset=['review'])
df_review
# Out:
#                                                   review  \
# 1      Produknya berbunyi keras, untuk air panas dan ...
# 2                                                 mantap
# 3
# 4                              barang ok. pengiriman ok.
# 5      gak berfungsi produck nya.....gak dapet sinyal...
# ...                                                  ...
# 25234
# 25235
# 25236
# 25237  Barang sudah diterima dengan baik\nDiantar den...
# 25238
#
#                   review_date  \
# 1     2021-11-06 02:13:42.100
# 2     2021-07-16 12:30:20.258
# 3     2021-04-04 14:59:55.617
# 4     2021-01-21 06:31:47.572
# 5     2022-11-16 10:38:07.174
# ...                       ...
# 25234 2022-08-01 02:05:15.000
# 25235 2022-02-15 23:50:28.000
# 25236 2022-01-11 14:03:23.000
# 25237 2022-10-13 08:34:47.000
# 25238 2022-09-22 22:28:54.000
#
#                                             product_name product_brand
# 1      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 2      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 3      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 4      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 5              Set Top Box Digital DVB - T2 [ PDV 700T2]      POLYTRON
# ...                                                  ...           ...
# 25234  POLYTRON Mesin Cuci Front Loading inverter 100...           NaN
# 25235  Mesin cuci bukaan depan polytron wonderwash PF...           NaN
# 25236  Mesin cuci bukaan depan polytron wonderwash PF...           NaN
# 25237            POLYTRON Multimedia Speaker PMA 9320 /W           NaN
# 25238            POLYTRON Multimedia Speaker PMA 9320 /W           NaN
#
# [25072 rows x 4 columns]

# %%
df_review = df_review[df_review.review != ""]
df_review
# Out:
#                                                   review  \
# 1      Produknya berbunyi keras, untuk air panas dan ...
# 2                                                 mantap
# 4                              barang ok. pengiriman ok.
# 5      gak berfungsi produck nya.....gak dapet sinyal...
# 6           agak lama pengirimannya..namun barang ori...
# ...                                                  ...
# 25227  Pengiriman cepet, produk dalam keadaan baik da...
# 25228  Kenapa milih produk Polytron , terus terang ka...
# 25230  Fitur Terbaik:Baik\nSepadan dengan Harga:Yup\n...
# 25231  produk bagus  ternyata karet bagian belakang h...
# 25237  Barang sudah diterima dengan baik\nDiantar den...
#
#                   review_date  \
# 1     2021-11-06 02:13:42.100
# 2     2021-07-16 12:30:20.258
# 4     2021-01-21 06:31:47.572
# 5     2022-11-16 10:38:07.174
# 6     2022-11-15 04:09:14.525
# ...                       ...
# 25227 2022-05-11 09:34:17.000
# 25228 2022-01-19 09:19:35.000
# 25230 2022-09-16 05:30:23.000
# 25231 2021-12-19 07:15:15.000
# 25237 2022-10-13 08:34:47.000
#
#                                             product_name product_brand
# 1      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 2      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 4      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      POLYTRON
# 5              Set Top Box Digital DVB - T2 [ PDV 700T2]      POLYTRON
# 6              Set Top Box Digital DVB - T2 [ PDV 700T2]      POLYTRON
# ...                                                  ...           ...
# 25227  Mesin cuci bukaan depan polytron wonderwash PF...           NaN
# 25228  Mesin cuci bukaan depan polytron wonderwash PF...           NaN
# 25230  POLYTRON Mesin Cuci Front Loading inverter 100...           NaN
# 25231  Mesin cuci bukaan depan polytron wonderwash PF...           NaN
# 25237            POLYTRON Multimedia Speaker PMA 9320 /W           NaN
#
# [17684 rows x 4 columns]

# %%
df_review['product_brand'] = 'polytron'
df_review
# Out:
# C:\Users\wiart\AppData\Local\Temp/ipykernel_11948/848936752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_review['product_brand'] = 'polytron'
#                                                   review  \
# 1      Produknya berbunyi keras, untuk air panas dan ...
# 2                                                 mantap
# 4                              barang ok. pengiriman ok.
# 5      gak berfungsi produck nya.....gak dapet sinyal...
# 6           agak lama pengirimannya..namun barang ori...
# ...                                                  ...
# 25227  Pengiriman cepet, produk dalam keadaan baik da...
# 25228  Kenapa milih produk Polytron , terus terang ka...
# 25230  Fitur Terbaik:Baik\nSepadan dengan Harga:Yup\n...
# 25231  produk bagus  ternyata karet bagian belakang h...
# 25237  Barang sudah diterima dengan baik\nDiantar den...
#
#                   review_date  \
# 1     2021-11-06 02:13:42.100
# 2     2021-07-16 12:30:20.258
# 4     2021-01-21 06:31:47.572
# 5     2022-11-16 10:38:07.174
# 6     2022-11-15 04:09:14.525
# ...                       ...
# 25227 2022-05-11 09:34:17.000
# 25228 2022-01-19 09:19:35.000
# 25230 2022-09-16 05:30:23.000
# 25231 2021-12-19 07:15:15.000
# 25237 2022-10-13 08:34:47.000
#
#                                             product_name product_brand
# 1      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 2      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 4      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 5              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# 6              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# ...                                                  ...           ...
# 25227  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25228  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25230  POLYTRON Mesin Cuci Front Loading inverter 100...      polytron
# 25231  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25237            POLYTRON Multimedia Speaker PMA 9320 /W      polytron
#
# [17684 rows x 4 columns]

# %%
df_review.to_csv('polytron.csv', index=False)

# %%
# !pip install cleantext
# !pip install demoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cleantext
#   Downloading cleantext-1.1.4-py3-none-any.whl (4.9 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from cleantext) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk->cleantext) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk->cleantext) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->cleantext) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->cleantext) (7.1.2)
# Installing collected packages: cleantext
# Successfully installed cleantext-1.1.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting demoji
#   Downloading demoji-1.1.0-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.2 MB/s
# Installing collected packages: demoji
# Successfully installed demoji-1.1.0

# %%
import cleantext
import demoji

# %%
def bersihkan_review(text):
    text = cleantext.clean(
        text, 
        extra_spaces=True, 
        numbers=True, 
        lowercase=True,
        reg='[^\w\s]',
        reg_replace=' '
    )
    text = re.sub('\n', ' ', text)
    text = re.sub('&amp;', 'dan', text)
    remove_emoji = demoji.findall(text)

    for item in remove_emoji.keys():
        text = text.replace(item, '')

    return text

# %%
df_review['review_bersih'] = df_review['review'].apply(lambda review: bersihkan_review(review))
df_review
# Out:
# C:\Users\wiart\AppData\Local\Temp/ipykernel_11948/3208101927.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_review['review_bersih'] = df_review['review'].apply(lambda review: bersihkan_review(review))
#                                                   review  \
# 1      Produknya berbunyi keras, untuk air panas dan ...
# 2                                                 mantap
# 4                              barang ok. pengiriman ok.
# 5      gak berfungsi produck nya.....gak dapet sinyal...
# 6           agak lama pengirimannya..namun barang ori...
# ...                                                  ...
# 25227  Pengiriman cepet, produk dalam keadaan baik da...
# 25228  Kenapa milih produk Polytron , terus terang ka...
# 25230  Fitur Terbaik:Baik\nSepadan dengan Harga:Yup\n...
# 25231  produk bagus  ternyata karet bagian belakang h...
# 25237  Barang sudah diterima dengan baik\nDiantar den...
#
#                   review_date  \
# 1     2021-11-06 02:13:42.100
# 2     2021-07-16 12:30:20.258
# 4     2021-01-21 06:31:47.572
# 5     2022-11-16 10:38:07.174
# 6     2022-11-15 04:09:14.525
# ...                       ...
# 25227 2022-05-11 09:34:17.000
# 25228 2022-01-19 09:19:35.000
# 25230 2022-09-16 05:30:23.000
# 25231 2021-12-19 07:15:15.000
# 25237 2022-10-13 08:34:47.000
#
#                                             product_name product_brand  \
# 1      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 2      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 4      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 5              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# 6              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# ...                                                  ...           ...
# 25227  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25228  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25230  POLYTRON Mesin Cuci Front Loading inverter 100...      polytron
# 25231  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25237            POLYTRON Multimedia Speaker PMA 9320 /W      polytron
#
#                                            review_bersih
# 1      produknya berbunyi keras untuk air panas dan a...
# 2                                                 mantap
# 4                                barang ok pengiriman ok
# 5      gak berfungsi produck nya gak dapet sinyal apa...
# 6               agak lama pengirimannya namun barang ori
# ...                                                  ...
# 25227  pengiriman cepet produk dalam keadaan baik dan...
# 25228  kenapa milih produk polytron terus terang kare...
# 25230  fitur terbaik baik sepadan dengan harga yup  b...
# 25231  produk bagus ternyata karet bagian belakang ha...
# 25237  barang sudah diterima dengan baik diantar deng...
#
# [17684 rows x 5 columns]

# %%
# normalization
import re
import string
import csv

reader = csv.reader(open('slang_word.csv', 'r'))
d = {}
for row in reader:
    k,v= row
    d[k] = v
    #print d[k]
pat = re.compile(r"\b(%s)\b" % "|".join(d))
for i in range(len(df_review)):
    text = df_review['review_bersih'].iloc[i]
    text = pat.sub(lambda m: d.get(m.group()), text)
    #print text
    df_review['review_bersih'].iloc[i]=text
df_review
# Out:
# c:\Users\wiart\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                                                   review  \
# 1      Produknya berbunyi keras, untuk air panas dan ...
# 2                                                 mantap
# 4                              barang ok. pengiriman ok.
# 5      gak berfungsi produck nya.....gak dapet sinyal...
# 6           agak lama pengirimannya..namun barang ori...
# ...                                                  ...
# 25227  Pengiriman cepet, produk dalam keadaan baik da...
# 25228  Kenapa milih produk Polytron , terus terang ka...
# 25230  Fitur Terbaik:Baik\nSepadan dengan Harga:Yup\n...
# 25231  produk bagus  ternyata karet bagian belakang h...
# 25237  Barang sudah diterima dengan baik\nDiantar den...
#
#                   review_date  \
# 1     2021-11-06 02:13:42.100
# 2     2021-07-16 12:30:20.258
# 4     2021-01-21 06:31:47.572
# 5     2022-11-16 10:38:07.174
# 6     2022-11-15 04:09:14.525
# ...                       ...
# 25227 2022-05-11 09:34:17.000
# 25228 2022-01-19 09:19:35.000
# 25230 2022-09-16 05:30:23.000
# 25231 2021-12-19 07:15:15.000
# 25237 2022-10-13 08:34:47.000
#
#                                             product_name product_brand  \
# 1      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 2      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 4      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 5              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# 6              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# ...                                                  ...           ...
# 25227  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25228  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25230  POLYTRON Mesin Cuci Front Loading inverter 100...      polytron
# 25231  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25237            POLYTRON Multimedia Speaker PMA 9320 /W      polytron
#
#                                            review_bersih
# 1      produknya berbunyi keras untuk air panas dan a...
# 2                                                 mantap
# 4                                barang ok pengiriman ok
# 5      tidak berfungsi produck nya tidak dapat sinyal...
# 6         cukup lama pengirimannya namun barang orisinal
# ...                                                  ...
# 25227  pengiriman cepat produk dalam keadaan baik dan...
# 25228  kenapa memilih produk polytron terus terang ka...
# 25230  fitur terbaik baik sepadan dengan harga iya  b...
# 25231  produk bagus ternyata karet bagian belakang ha...
# 25237  barang sudah diterima dengan baik diantar deng...
#
# [17684 rows x 5 columns]

# %%
# !pip install sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 5.1 MB/s
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
 
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

# %%
review = []
for index, row in df_review.iterrows():
    review.append(stopword.remove(row["review_bersih"]))
    
df_review["hasil_stopword"] = review
df_review
# Out:
# C:\Users\wiart\AppData\Local\Temp/ipykernel_11948/377695539.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_review["hasil_stopword"] = review
#                                                   review  \
# 1      Produknya berbunyi keras, untuk air panas dan ...
# 2                                                 mantap
# 4                              barang ok. pengiriman ok.
# 5      gak berfungsi produck nya.....gak dapet sinyal...
# 6           agak lama pengirimannya..namun barang ori...
# ...                                                  ...
# 25227  Pengiriman cepet, produk dalam keadaan baik da...
# 25228  Kenapa milih produk Polytron , terus terang ka...
# 25230  Fitur Terbaik:Baik\nSepadan dengan Harga:Yup\n...
# 25231  produk bagus  ternyata karet bagian belakang h...
# 25237  Barang sudah diterima dengan baik\nDiantar den...
#
#                   review_date  \
# 1     2021-11-06 02:13:42.100
# 2     2021-07-16 12:30:20.258
# 4     2021-01-21 06:31:47.572
# 5     2022-11-16 10:38:07.174
# 6     2022-11-15 04:09:14.525
# ...                       ...
# 25227 2022-05-11 09:34:17.000
# 25228 2022-01-19 09:19:35.000
# 25230 2022-09-16 05:30:23.000
# 25231 2021-12-19 07:15:15.000
# 25237 2022-10-13 08:34:47.000
#
#                                             product_name product_brand  \
# 1      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 2      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 4      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 5              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# 6              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# ...                                                  ...           ...
# 25227  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25228  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25230  POLYTRON Mesin Cuci Front Loading inverter 100...      polytron
# 25231  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25237            POLYTRON Multimedia Speaker PMA 9320 /W      polytron
#
#                                            review_bersih  \
# 1      produknya berbunyi keras untuk air panas dan a...
# 2                                                 mantap
# 4                                barang ok pengiriman ok
# 5      tidak berfungsi produck nya tidak dapat sinyal...
# 6         cukup lama pengirimannya namun barang orisinal
# ...                                                  ...
# 25227  pengiriman cepat produk dalam keadaan baik dan...
# 25228  kenapa memilih produk polytron terus terang ka...
# 25230  fitur terbaik baik sepadan dengan harga iya  b...
# 25231  produk bagus ternyata karet bagian belakang ha...
# 25237  barang sudah diterima dengan baik diantar deng...
#
#                                           hasil_stopword
# 1      produknya berbunyi keras air panas air dingin ...
# 2                                                 mantap
# 4                                      barang pengiriman
# 5      berfungsi produck nya dapat sinyal harus beli ...
# 6               cukup lama pengirimannya barang orisinal
# ...                                                  ...
# 25227  pengiriman cepat produk keadaan baik berfungsi...
# 25228  memilih produk polytron terus terang afrer sal...
# 25230  fitur terbaik baik sepadan harga iya  berfungs...
# 25231  produk bagus ternyata karet bagian belakang di...
# 25237  barang diterima baik diantar mobil box jadi am...
#
# [17684 rows x 6 columns]

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
review = []
for index, row in df_review.iterrows():
    review.append(stemmer.stem(row["hasil_stopword"]))
    
df_review["hasil_stemming"] = review
df_review
# Out:
# C:\Users\wiart\AppData\Local\Temp/ipykernel_11948/1039093134.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_review["hasil_stemming"] = review
#                                                   review  \
# 1      Produknya berbunyi keras, untuk air panas dan ...
# 2                                                 mantap
# 4                              barang ok. pengiriman ok.
# 5      gak berfungsi produck nya.....gak dapet sinyal...
# 6           agak lama pengirimannya..namun barang ori...
# ...                                                  ...
# 25227  Pengiriman cepet, produk dalam keadaan baik da...
# 25228  Kenapa milih produk Polytron , terus terang ka...
# 25230  Fitur Terbaik:Baik\nSepadan dengan Harga:Yup\n...
# 25231  produk bagus  ternyata karet bagian belakang h...
# 25237  Barang sudah diterima dengan baik\nDiantar den...
#
#                   review_date  \
# 1     2021-11-06 02:13:42.100
# 2     2021-07-16 12:30:20.258
# 4     2021-01-21 06:31:47.572
# 5     2022-11-16 10:38:07.174
# 6     2022-11-15 04:09:14.525
# ...                       ...
# 25227 2022-05-11 09:34:17.000
# 25228 2022-01-19 09:19:35.000
# 25230 2022-09-16 05:30:23.000
# 25231 2021-12-19 07:15:15.000
# 25237 2022-10-13 08:34:47.000
#
#                                             product_name product_brand  \
# 1      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 2      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 4      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 5              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# 6              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# ...                                                  ...           ...
# 25227  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25228  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25230  POLYTRON Mesin Cuci Front Loading inverter 100...      polytron
# 25231  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25237            POLYTRON Multimedia Speaker PMA 9320 /W      polytron
#
#                                            review_bersih  \
# 1      produknya berbunyi keras untuk air panas dan a...
# 2                                                 mantap
# 4                                barang ok pengiriman ok
# 5      tidak berfungsi produck nya tidak dapat sinyal...
# 6         cukup lama pengirimannya namun barang orisinal
# ...                                                  ...
# 25227  pengiriman cepat produk dalam keadaan baik dan...
# 25228  kenapa memilih produk polytron terus terang ka...
# 25230  fitur terbaik baik sepadan dengan harga iya  b...
# 25231  produk bagus ternyata karet bagian belakang ha...
# 25237  barang sudah diterima dengan baik diantar deng...
#
#                                           hasil_stopword  \
# 1      produknya berbunyi keras air panas air dingin ...
# 2                                                 mantap
# 4                                      barang pengiriman
# 5      berfungsi produck nya dapat sinyal harus beli ...
# 6               cukup lama pengirimannya barang orisinal
# ...                                                  ...
# 25227  pengiriman cepat produk keadaan baik berfungsi...
# 25228  memilih produk polytron terus terang afrer sal...
# 25230  fitur terbaik baik sepadan harga iya  berfungs...
# 25231  produk bagus ternyata karet bagian belakang di...
# 25237  barang diterima baik diantar mobil box jadi am...
#
#                                           hasil_stemming
# 1            produk bunyi keras air panas air dingin oke
# 2                                                 mantap
# 4                                           barang kirim
# 5      fungsi produck nya dapat sinyal harus beli ant...
# 6                       cukup lama kirim barang orisinal
# ...                                                  ...
# 25227  kirim cepat produk ada baik fungsi sesuai desk...
# 25228  pilih produk polytron terus terang afrer sales...
# 25230  fitur baik baik padan harga iya fungsi mana mesti
# 25231  produk bagus nyata karet bagi belakang lepas t...
# 25237  barang terima baik antar mobil box jadi aman k...
#
# [17684 rows x 7 columns]

# %%
df_review.drop(df_review.columns[[4,5]], axis = 1, inplace=True)

df_review
# Out:
# c:\Users\wiart\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                                   review  \
# 1      Produknya berbunyi keras, untuk air panas dan ...
# 2                                                 mantap
# 4                              barang ok. pengiriman ok.
# 5      gak berfungsi produck nya.....gak dapet sinyal...
# 6           agak lama pengirimannya..namun barang ori...
# ...                                                  ...
# 25227  Pengiriman cepet, produk dalam keadaan baik da...
# 25228  Kenapa milih produk Polytron , terus terang ka...
# 25230  Fitur Terbaik:Baik\nSepadan dengan Harga:Yup\n...
# 25231  produk bagus  ternyata karet bagian belakang h...
# 25237  Barang sudah diterima dengan baik\nDiantar den...
#
#                   review_date  \
# 1     2021-11-06 02:13:42.100
# 2     2021-07-16 12:30:20.258
# 4     2021-01-21 06:31:47.572
# 5     2022-11-16 10:38:07.174
# 6     2022-11-15 04:09:14.525
# ...                       ...
# 25227 2022-05-11 09:34:17.000
# 25228 2022-01-19 09:19:35.000
# 25230 2022-09-16 05:30:23.000
# 25231 2021-12-19 07:15:15.000
# 25237 2022-10-13 08:34:47.000
#
#                                             product_name product_brand  \
# 1      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 2      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 4      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 5              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# 6              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# ...                                                  ...           ...
# 25227  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25228  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25230  POLYTRON Mesin Cuci Front Loading inverter 100...      polytron
# 25231  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25237            POLYTRON Multimedia Speaker PMA 9320 /W      polytron
#
#                                           hasil_stemming
# 1            produk bunyi keras air panas air dingin oke
# 2                                                 mantap
# 4                                           barang kirim
# 5      fungsi produck nya dapat sinyal harus beli ant...
# 6                       cukup lama kirim barang orisinal
# ...                                                  ...
# 25227  kirim cepat produk ada baik fungsi sesuai desk...
# 25228  pilih produk polytron terus terang afrer sales...
# 25230  fitur baik baik padan harga iya fungsi mana mesti
# 25231  produk bagus nyata karet bagi belakang lepas t...
# 25237  barang terima baik antar mobil box jadi aman k...
#
# [17684 rows x 5 columns]

# %%
df_review.rename(columns = {'hasil_stemming':'review_bersih'}, inplace = True)
df_review
# Out:
# c:\Users\wiart\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                                                   review  \
# 1      Produknya berbunyi keras, untuk air panas dan ...
# 2                                                 mantap
# 4                              barang ok. pengiriman ok.
# 5      gak berfungsi produck nya.....gak dapet sinyal...
# 6           agak lama pengirimannya..namun barang ori...
# ...                                                  ...
# 25227  Pengiriman cepet, produk dalam keadaan baik da...
# 25228  Kenapa milih produk Polytron , terus terang ka...
# 25230  Fitur Terbaik:Baik\nSepadan dengan Harga:Yup\n...
# 25231  produk bagus  ternyata karet bagian belakang h...
# 25237  Barang sudah diterima dengan baik\nDiantar den...
#
#                   review_date  \
# 1     2021-11-06 02:13:42.100
# 2     2021-07-16 12:30:20.258
# 4     2021-01-21 06:31:47.572
# 5     2022-11-16 10:38:07.174
# 6     2022-11-15 04:09:14.525
# ...                       ...
# 25227 2022-05-11 09:34:17.000
# 25228 2022-01-19 09:19:35.000
# 25230 2022-09-16 05:30:23.000
# 25231 2021-12-19 07:15:15.000
# 25237 2022-10-13 08:34:47.000
#
#                                             product_name product_brand  \
# 1      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 2      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 4      POLYTRON Hydra Bottom Loading Gallon Hybrid Di...      polytron
# 5              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# 6              Set Top Box Digital DVB - T2 [ PDV 700T2]      polytron
# ...                                                  ...           ...
# 25227  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25228  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25230  POLYTRON Mesin Cuci Front Loading inverter 100...      polytron
# 25231  Mesin cuci bukaan depan polytron wonderwash PF...      polytron
# 25237            POLYTRON Multimedia Speaker PMA 9320 /W      polytron
#
#                                            review_bersih
# 1            produk bunyi keras air panas air dingin oke
# 2                                                 mantap
# 4                                           barang kirim
# 5      fungsi produck nya dapat sinyal harus beli ant...
# 6                       cukup lama kirim barang orisinal
# ...                                                  ...
# 25227  kirim cepat produk ada baik fungsi sesuai desk...
# 25228  pilih produk polytron terus terang afrer sales...
# 25230  fitur baik baik padan harga iya fungsi mana mesti
# 25231  produk bagus nyata karet bagi belakang lepas t...
# 25237  barang terima baik antar mobil box jadi aman k...
#
# [17684 rows x 5 columns]

# %%
df_review = df_review.to_dict('records')

# %%
db_review_bersih = client['reviewBersih'] 
collection_review_bersih = db_review_bersih['polytron']

# %%
collection_review_bersih.insert_many(df_review)

# %%
# from nltk.tokenize import word_tokenize

# df_content['review_token']=df_content['content'].apply(word_tokenize)
# df_content

# %%
# df_content['review_string'] = df_content['review_token'].apply(lambda x: ' '.join([item for item in x if len(item)>1]))
# df_content
