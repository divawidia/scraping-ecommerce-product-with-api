# %%
import requests
import pandas as pd

# %%
store_id = "3072108"

# %%
url = "https://gql.tokopedia.com/graphql/ShopProducts"
page = 1
product_list = []

while True:
    payload = [{
        'operationName': "ShopProducts",
        'variables': {
            "etalaseId": "etalase", 
            "page": page, 
            "perPage": 200,
            "sid":f"{store_id}", 
            "sort": 11,
            "user_cityId": "176",
            "user_districtId": "2274",
            "user_lat": "",
            "user_long": ""
        },
        'query': 'query ShopProducts($sid: String!, $page: Int, $perPage: Int, $keyword: String, $etalaseId: String, $sort: Int, $user_districtId: String, $user_cityId: String, $user_lat: String, $user_long: String) {\n  GetShopProduct(shopID: $sid, filter: {page: $page, perPage: $perPage, fkeyword: $keyword, fmenu: $etalaseId, sort: $sort, user_districtId: $user_districtId, user_cityId: $user_cityId, user_lat: $user_lat, user_long: $user_long}) {\n    status\n    errors\n    links {\n      prev\n      next\n      __typename\n    }\n    data {\n      name\n      product_url\n      product_id\n      price {\n        text_idr\n        __typename\n      }\n      primary_image {\n        original\n        thumbnail\n        resize300\n        __typename\n      }\n      flags {\n        isSold\n        isPreorder\n        isWholesale\n        isWishlist\n        __typename\n      }\n      campaign {\n        discounted_percentage\n        original_price_fmt\n        start_date\n        end_date\n        __typename\n      }\n      label {\n        color_hex\n        content\n        __typename\n      }\n      label_groups {\n        position\n        title\n        type\n        url\n        __typename\n      }\n      badge {\n        title\n        image_url\n        __typename\n      }\n      stats {\n        reviewCount\n        rating\n        __typename\n      }\n      category {\n        id\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n'
    }]

    response = requests.post(url, json=payload)

    data = response.json()

    for product in data[0]['data']['GetShopProduct']['data']:
        product_list.append(product)
    
    if data[0]['data']['GetShopProduct']['links']['next'] == '':
        break

    page += 1

# %%
df = pd.json_normalize(product_list)
df
# Out:
#                                                  name  \
# 0   Advan Tab Sketsa 2 4GB / 64GB 10" Tiger T310 A...
# 1   Advan Tab VX 8GB / 128GB 10.4 inch Tiger T618 ...
# 2   Advan Nasaplus 2GB 16GB Smartphone Android10 Q...
# 3   Advan Telkomsel Orbit Star A1 Modem Router 4G ...
# 4   Telkomsel Orbit Data 150GB Advan CPE Router Mo...
# ..                                                ...
# 67  Advan StartGo Z01-C Kabel Data Charger USB Typ...
# 68  Advan StartGo B01C-C Kabel Data USB Type C to ...
# 69  Advan StartGo Z02C-CK Kabel Data USB Type C Fa...
# 70  Advan StartGo B01-3 Kabel Data USB 3 in 1 Type...
# 71  Advan StartGo B01-L Kabel Data iPhone USB Ligh...
#
#                                           product_url  product_id label  \
# 0   https://www.tokopedia.com/advan-official/advan...  2765473026    []
# 1   https://www.tokopedia.com/advan-official/advan...  2306149620    []
# 2   https://www.tokopedia.com/advan-official/advan...  1276659296    []
# 3   https://www.tokopedia.com/advan-official/advan...  2221660507    []
# 4   https://www.tokopedia.com/advan-official/telko...  1988362437    []
# ..                                                ...         ...   ...
# 67  https://www.tokopedia.com/advan-official/advan...  3650449743    []
# 68  https://www.tokopedia.com/advan-official/advan...  3666415067    []
# 69  https://www.tokopedia.com/advan-official/advan...  3843453206    []
# 70  https://www.tokopedia.com/advan-official/advan...  3667880698    []
# 71  https://www.tokopedia.com/advan-official/advan...  3650585140    []
#
#                                          label_groups  \
# 0   [{'position': 'integrity', 'title': 'Terjual 1...
# 1   [{'position': 'integrity', 'title': 'Terjual 7...
# 2   [{'position': 'integrity', 'title': 'Terjual 7...
# 3   [{'position': 'integrity', 'title': 'Terjual 5...
# 4   [{'position': 'integrity', 'title': 'Terjual 2...
# ..                                                ...
# 67  [{'position': 'status', 'title': 'Stok Habis',...
# 68  [{'position': 'status', 'title': 'Stok Habis',...
# 69  [{'position': 'status', 'title': 'Stok Habis',...
# 70  [{'position': 'status', 'title': 'Stok Habis',...
# 71  [{'position': 'status', 'title': 'Stok Habis',...
#
#                                                 badge             __typename  \
# 0   [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 1   [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 2   [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 3   [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 4   [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# ..                                                ...                    ...
# 67  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 68  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 69  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 70  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 71  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
#
#    price.text_idr  price.__typename  \
# 0    Rp 2.599.000  ProductListPrice
# 1    Rp 3.399.000  ProductListPrice
# 2      Rp 845.000  ProductListPrice
# 3      Rp 529.000  ProductListPrice
# 4      Rp 679.000  ProductListPrice
# ..            ...               ...
# 67      Rp 34.900  ProductListPrice
# 68      Rp 79.000  ProductListPrice
# 69      Rp 83.900  ProductListPrice
# 70      Rp 99.000  ProductListPrice
# 71      Rp 83.900  ProductListPrice
#
#                                primary_image.original  ...  \
# 0   https://images.tokopedia.net/img/cache/300-squ...  ...
# 1   https://images.tokopedia.net/img/cache/300-squ...  ...
# 2   https://images.tokopedia.net/img/cache/300-squ...  ...
# 3   https://images.tokopedia.net/img/cache/300-squ...  ...
# 4   https://images.tokopedia.net/img/cache/300-squ...  ...
# ..                                                ...  ...
# 67  https://images.tokopedia.net/img/cache/300-squ...  ...
# 68  https://images.tokopedia.net/img/cache/300-squ...  ...
# 69  https://images.tokopedia.net/img/cache/300-squ...  ...
# 70  https://images.tokopedia.net/img/cache/300-squ...  ...
# 71  https://images.tokopedia.net/img/cache/300-squ...  ...
#
#    campaign.discounted_percentage campaign.original_price_fmt  \
# 0                              38                Rp 4.199.000
# 1                              35                Rp 5.249.000
# 2                              15                  Rp 999.000
# 3                              22                  Rp 679.000
# 4                              24                  Rp 899.000
# ..                            ...                         ...
# 67                              0
# 68                              0
# 69                              0
# 70                              0
# 71                              0
#
#      campaign.start_date     campaign.end_date        campaign.__typename  \
# 0   2022-12-01T09:11:04Z  2022-12-12T23:59:00Z  ProductDetailCampaignType
# 1   2022-12-01T09:11:04Z  2022-12-12T23:59:00Z  ProductDetailCampaignType
# 2   2022-12-01T09:11:04Z  2022-12-12T23:59:00Z  ProductDetailCampaignType
# 3   2022-12-03T18:00:00Z  2022-12-03T19:59:00Z  ProductDetailCampaignType
# 4   2022-12-01T09:11:04Z  2022-12-12T23:59:00Z  ProductDetailCampaignType
# ..                   ...                   ...                        ...
# 67                                              ProductDetailCampaignType
# 68                                              ProductDetailCampaignType
# 69                                              ProductDetailCampaignType
# 70                                              ProductDetailCampaignType
# 71                                              ProductDetailCampaignType
#
#     stats.reviewCount  stats.rating  stats.__typename category.id  \
# 0                 831            98  ProductListStats           0
# 1                 589            97  ProductListStats           0
# 2                 466            97  ProductListStats           0
# 3                 277            98  ProductListStats           0
# 4                 201            96  ProductListStats           0
# ..                ...           ...               ...         ...
# 67                  6           100  ProductListStats           0
# 68                  4           100  ProductListStats           0
# 69                  3           100  ProductListStats           0
# 70                  3           100  ProductListStats           0
# 71                  1           100  ProductListStats           0
#
#     category.__typename
# 0   ProductListCategory
# 1   ProductListCategory
# 2   ProductListCategory
# 3   ProductListCategory
# 4   ProductListCategory
# ..                  ...
# 67  ProductListCategory
# 68  ProductListCategory
# 69  ProductListCategory
# 70  ProductListCategory
# 71  ProductListCategory
#
# [72 rows x 28 columns]

# %%
url_review = "https://gql.tokopedia.com/graphql/productReviewList"
result_review = []

for i in range(0, len(product_list)):
    product = product_list[i]
    page_review = 1

    while True:
        payload_review = [{
            'operationName': "productReviewList",
            'variables': {
                "filterBy": "", 
                "limit": 500, 
                "page": page_review,
                "productID":f"{product_list[i]['product_id']}", 
                "sortBy": 'create_time desc'
            },
            'query': 'query productReviewList($productID: String!, $page: Int!, $limit: Int!, $sortBy: String, $filterBy: String) {\n  productrevGetProductReviewList(productID: $productID, page: $page, limit: $limit, sortBy: $sortBy, filterBy: $filterBy) {\n    productID\n    list {\n      id: feedbackID\n      variantName\n      message\n      productRating\n      reviewCreateTime\n      reviewCreateTimestamp\n      isReportable\n      isAnonymous\n      imageAttachments {\n        attachmentID\n        imageThumbnailUrl\n        imageUrl\n        __typename\n      }\n      videoAttachments {\n        attachmentID\n        videoUrl\n        __typename\n      }\n      reviewResponse {\n        message\n        createTime\n        __typename\n      }\n      user {\n        userID\n        fullName\n        image\n        url\n        __typename\n      }\n      likeDislike {\n        totalLike\n        likeStatus\n        __typename\n      }\n      stats {\n        key\n        formatted\n        count\n        __typename\n      }\n      badRatingReasonFmt\n      __typename\n    }\n    shop {\n      shopID\n      name\n      url\n      image\n      __typename\n    }\n    hasNext\n    totalReviews\n    __typename\n  }\n}\n'
        }]

        response_review = requests.post(url_review, json=payload_review)

        data_review = response_review.json()

        for review in data_review[0]['data']['productrevGetProductReviewList']['list']:
            review.update({"product":product})
            result_review.append(review)

        print("Scraped product no. "+str(i)+" id: " + product_list[i]['product_id'] + " review page:"+str(page_review))
        
        if data_review[0]['data']['productrevGetProductReviewList']['hasNext'] == False:
            break

        page_review += 1
    print("Scraping product no. "+str(i)+" id: " + product_list[i]['product_id'] + " review done")
# Out:
# Scraping product no. 0 id: 2765473026 review done
# Scraping product no. 1 id: 2306149620 review done
# Scraping product no. 2 id: 1276659296 review done
# Scraping product no. 3 id: 2221660507 review done
# Scraping product no. 4 id: 1988362437 review done
# Scraping product no. 5 id: 4352172223 review done
# Scraping product no. 6 id: 3952449911 review done
# Scraping product no. 7 id: 4210439616 review done
# Scraping product no. 8 id: 2657725412 review done
# Scraping product no. 9 id: 5237080469 review done
# Scraping product no. 10 id: 2657737945 review done
# Scraping product no. 11 id: 3623840794 review done
# Scraping product no. 12 id: 2899438354 review done
# Scraping product no. 13 id: 3587870168 review done
# Scraping product no. 14 id: 4959982041 review done
# Scraping product no. 15 id: 7035351588 review done
# Scraping product no. 16 id: 6218832934 review done
# Scraping product no. 17 id: 4652959692 review done
# Scraping product no. 18 id: 6810677417 review done
# Scraping product no. 19 id: 3623769437 review done
# Scraping product no. 20 id: 6222258522 review done
# Scraping product no. 21 id: 3886960115 review done
# Scraping product no. 22 id: 5624489159 review done
# Scraping product no. 23 id: 4652885296 review done
# Scraping product no. 24 id: 3936302552 review done
# Scraping product no. 25 id: 6929639138 review done
# Scraping product no. 26 id: 3937589463 review done
# Scraping product no. 27 id: 1566244440 review done
# Scraping product no. 28 id: 1574674115 review done
# Scraping product no. 29 id: 1184279759 review done
# Scraping product no. 30 id: 1958307699 review done
# Scraping product no. 31 id: 1591637929 review done
# Scraping product no. 32 id: 1184228468 review done
# Scraping product no. 33 id: 1948384056 review done
# Scraping product no. 34 id: 1442173971 review done
# Scraping product no. 35 id: 842501562 review done
# Scraping product no. 36 id: 1184286720 review done
# Scraping product no. 37 id: 2100948695 review done
# Scraping product no. 38 id: 1070918296 review done
# Scraping product no. 39 id: 1206419736 review done
# Scraping product no. 40 id: 1184223320 review done
# Scraping product no. 41 id: 1027644276 review done
# Scraping product no. 42 id: 480756264 review done
# Scraping product no. 43 id: 2030389538 review done
# Scraping product no. 44 id: 400100068 review done
# Scraping product no. 45 id: 1410385118 review done
# Scraping product no. 46 id: 1288960449 review done
# Scraping product no. 47 id: 2988367095 review done
# Scraping product no. 48 id: 1184267065 review done
# Scraping product no. 49 id: 1184236023 review done
# Scraping product no. 50 id: 3221246785 review done
# Scraping product no. 51 id: 1410416213 review done
# Scraping product no. 52 id: 870484807 review done
# Scraping product no. 53 id: 1330846238 review done
# Scraping product no. 54 id: 1184274686 review done
# Scraping product no. 55 id: 4688905276 review done
# Scraping product no. 56 id: 3589785854 review done
# Scraping product no. 57 id: 671218585 review done
# Scraping product no. 58 id: 1184294623 review done
# Scraping product no. 59 id: 618743913 review done
# Scraping product no. 60 id: 4802212625 review done
# Scraping product no. 61 id: 1114285932 review done
# Scraping product no. 62 id: 512204322 review done
# Scraping product no. 63 id: 3843421183 review done
# Scraping product no. 64 id: 2521156543 review done
# Scraping product no. 65 id: 3588474901 review done
# Scraping product no. 66 id: 1079401849 review done
# Scraping product no. 67 id: 3650449743 review done
# Scraping product no. 68 id: 3666415067 review done
# Scraping product no. 69 id: 3843453206 review done
# Scraping product no. 70 id: 3667880698 review done
# Scraping product no. 71 id: 3650585140 review done

# %%
df_review = pd.json_normalize(result_review)
df_review
# Out:
#              id variantName  \
# 0     803787899
# 1     803130507
# 2     803025545
# 3     802909423
# 4     802438387
# ...         ...         ...
# 3335  685918355       Putih
# 3336  667615471       Putih
# 3337  727472465        Ungu
# 3338  688767213        Gold
# 3339  667681451        Gold
#
#                                                 message  productRating  \
# 0     Barang sampai dengan selamat. bungkusnya baik,...              5
# 1     respon seller cepet dan pengiriman cepat,baran...              5
# 2     Barang sampai dengan baik, tersegel rapi, dan ...              5
# 3                  lumayan ringkas sbg pengganti laptop              5
# 4     barang sudah diterima dengan lengkap, baik dan...              5
# ...                                                 ...            ...
# 3335                                                                 5
# 3336  paketnya oke sekali, nyampe tangan saya dengan...              5
# 3337  kabel data sepertinya kuat terlihat dari kuali...              5
# 3338         terima kasih, barang oke, pengiriman cepat              5
# 3339  terima kasih, barang sesuai dengan deskripsi d...              5
#
#      reviewCreateTime reviewCreateTimestamp  isReportable  isAnonymous  \
# 0          1670068683              Hari ini         False         True
# 1          1669982987           1 hari lalu         False        False
# 2          1669973294           1 hari lalu         False        False
# 3          1669941287           1 hari lalu         False        False
# 4          1669897093           2 hari lalu         False        False
# ...               ...                   ...           ...          ...
# 3335       1654438073          6 bulan lalu         False        False
# 3336       1652284489          6 bulan lalu         False        False
# 3337       1659617102          4 bulan lalu         False        False
# 3338       1654769391          5 bulan lalu         False        False
# 3339       1652289072          6 bulan lalu         False        False
#
#                                        imageAttachments videoAttachments  ...  \
# 0                                                    []               []  ...
# 1                                                    []               []  ...
# 2                                                    []               []  ...
# 3                                                    []               []  ...
# 4                                                    []               []  ...
# ...                                                 ...              ...  ...
# 3335  [{'attachmentID': '76121856', 'imageThumbnailU...               []  ...
# 3336  [{'attachmentID': '73520985', 'imageThumbnailU...               []  ...
# 3337                                                 []               []  ...
# 3338                                                 []               []  ...
# 3339                                                 []               []  ...
#
#      product.campaign.__typename product.label  \
# 0      ProductDetailCampaignType            []
# 1      ProductDetailCampaignType            []
# 2      ProductDetailCampaignType            []
# 3      ProductDetailCampaignType            []
# 4      ProductDetailCampaignType            []
# ...                          ...           ...
# 3335   ProductDetailCampaignType            []
# 3336   ProductDetailCampaignType            []
# 3337   ProductDetailCampaignType            []
# 3338   ProductDetailCampaignType            []
# 3339   ProductDetailCampaignType            []
#
#                                    product.label_groups  \
# 0     [{'position': 'integrity', 'title': 'Terjual 1...
# 1     [{'position': 'integrity', 'title': 'Terjual 1...
# 2     [{'position': 'integrity', 'title': 'Terjual 1...
# 3     [{'position': 'integrity', 'title': 'Terjual 1...
# 4     [{'position': 'integrity', 'title': 'Terjual 1...
# ...                                                 ...
# 3335  [{'position': 'status', 'title': 'Stok Habis',...
# 3336  [{'position': 'status', 'title': 'Stok Habis',...
# 3337  [{'position': 'status', 'title': 'Stok Habis',...
# 3338  [{'position': 'status', 'title': 'Stok Habis',...
# 3339  [{'position': 'status', 'title': 'Stok Habis',...
#
#                                           product.badge  \
# 0     [{'title': 'Official Store', 'image_url': 'htt...
# 1     [{'title': 'Official Store', 'image_url': 'htt...
# 2     [{'title': 'Official Store', 'image_url': 'htt...
# 3     [{'title': 'Official Store', 'image_url': 'htt...
# 4     [{'title': 'Official Store', 'image_url': 'htt...
# ...                                                 ...
# 3335  [{'title': 'Official Store', 'image_url': 'htt...
# 3336  [{'title': 'Official Store', 'image_url': 'htt...
# 3337  [{'title': 'Official Store', 'image_url': 'htt...
# 3338  [{'title': 'Official Store', 'image_url': 'htt...
# 3339  [{'title': 'Official Store', 'image_url': 'htt...
#
#      product.stats.reviewCount product.stats.rating product.stats.__typename  \
# 0                          831                   98         ProductListStats
# 1                          831                   98         ProductListStats
# 2                          831                   98         ProductListStats
# 3                          831                   98         ProductListStats
# 4                          831                   98         ProductListStats
# ...                        ...                  ...                      ...
# 3335                         6                  100         ProductListStats
# 3336                         6                  100         ProductListStats
# 3337                         4                  100         ProductListStats
# 3338                         3                  100         ProductListStats
# 3339                         3                  100         ProductListStats
#
#      product.category.id product.category.__typename     product.__typename
# 0                      0         ProductListCategory  ShopProductListDetail
# 1                      0         ProductListCategory  ShopProductListDetail
# 2                      0         ProductListCategory  ShopProductListDetail
# 3                      0         ProductListCategory  ShopProductListDetail
# 4                      0         ProductListCategory  ShopProductListDetail
# ...                  ...                         ...                    ...
# 3335                   0         ProductListCategory  ShopProductListDetail
# 3336                   0         ProductListCategory  ShopProductListDetail
# 3337                   0         ProductListCategory  ShopProductListDetail
# 3338                   0         ProductListCategory  ShopProductListDetail
# 3339                   0         ProductListCategory  ShopProductListDetail
#
# [3340 rows x 52 columns]

# %%
from pymongo import MongoClient

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
localhost = "mongodb://localhost:27017"

# %%
client = MongoClient(localhost)
db = client['tokopedia'] 
collection = db['advan']

# %%
collection.insert_many(result_review)

# %%
data = collection.find()

df = pd.json_normalize(data)
df
# Out:
#                            _id                                    id  \
# 0     637e18d68ccf7446afd010e3  73a68739-1237-49f1-821f-6261cb90c5fc
# 1     637e18d68ccf7446afd010e4  75702197-fba0-4200-a0f0-52dd7c8c332c
# 2     637e18d68ccf7446afd010e5  2a91401f-8e11-4b90-8027-7605a8b89ba3
# 3     637e18d68ccf7446afd010e6  5c94e856-63aa-40c5-be9d-8931160c049d
# 4     637e18d68ccf7446afd010e7  3d98c992-e2c9-454c-aa1a-a957f7ac5764
# ...                        ...                                   ...
# 8348  637e18d68ccf7446afd0317f  c5025d0d-a0d3-48ed-827e-11ce51f6cacc
# 8349  637e18d68ccf7446afd03180  40b76884-0c7b-4f71-ad22-93d237b1ad45
# 8350  637e18d68ccf7446afd03181  236dc7b3-5a93-43fb-8e1f-2bac06cfcc46
# 8351  637e18d68ccf7446afd03182  86009efb-3533-476f-bfdc-fba46fe8f399
# 8352  637e18d68ccf7446afd03183  893e13a5-337b-4856-b471-4f292ad587df
#
#                  name  rating    createdDate    updatedDate  likes  \
# 0                 Aro       5  1668487909680  1668487909680      0
# 1             MUHAMAD       5  1668437644933  1668437644943      0
# 2                Dewi       5  1668379161516  1668379161516      0
# 3               V***a       5  1668228006469  1668228006479      0
# 4     iv***@gmail.com       5  1668162659023  1668162659032      0
# ...               ...     ...            ...            ...    ...
# 8348            F***a       5  1624382386487  1624382386584      0
# 8349            Dolar       5  1616256165498  1624382386585      0
# 8350            G***a       5  1613015902079  1624382386585      0
# 8351            Retno       5  1610624999957  1624382386585      0
# 8352            N***a       5  1609178240861  1624382386585      0
#
#       showPriority  verifiedBuyer  edited  ... product.soldRangeCount.en  \
# 0                2           True   False  ...                     1,9 k
# 1                2           True   False  ...                     1,9 k
# 2                2           True   False  ...                     1,9 k
# 3                2           True   False  ...                     1,9 k
# 4                2           True   False  ...                     1,9 k
# ...            ...            ...     ...  ...                       ...
# 8348             3           True   False  ...                        45
# 8349             4           True   False  ...                        45
# 8350             3           True   False  ...                        45
# 8351             3           True   False  ...                        45
# 8352             3           True   False  ...                        45
#
#      product.soldRangeCount.id                  product.categoryIdHierarchy  \
# 0                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# 1                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# 2                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# 3                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# 4                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# ...                        ...                                          ...
# 8348                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
# 8349                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
# 8350                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
# 8351                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
# 8352                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
#
#       product.cartLogisticOptions product.merchantVoucherMessage  \
# 0                              []           No voucher available
# 1                              []           No voucher available
# 2                              []           No voucher available
# 3                              []           No voucher available
# 4                              []           No voucher available
# ...                           ...                            ...
# 8348                           []           No voucher available
# 8349                           []           No voucher available
# 8350                           []           No voucher available
# 8351                           []           No voucher available
# 8352                           []           No voucher available
#
#       product.preorder  product.official  \
# 0                False              True
# 1                False              True
# 2                False              True
# 3                False              True
# 4                False              True
# ...                ...               ...
# 8348             False              True
# 8349             False              True
# 8350             False              True
# 8351             False              True
# 8352             False              True
#
#                                                 content title  \
# 0                                                   NaN   NaN
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# ...                                                 ...   ...
# 8348                                     Very pigmented   NaN
# 8349
# 8350  so pretty... warnanya pigmented banget, hargan...   NaN
# 8351    good seller. trusted. barang sampai dengan aman
# 8352            Bagus bgt. Pigmented dan warnanya ok ok   NaN
#
#      product.price.strikeThroughPriceDisplay
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 8348                                     NaN
# 8349                                     NaN
# 8350                                     NaN
# 8351                                     NaN
# 8352                                     NaN
#
# [8353 rows x 65 columns]
