# %%
import requests
import pandas as pd

# %%
store_id = "6364291"

# %%
url = "https://gql.tokopedia.com/graphql/ShopProducts"
page = 1
product_list = []

while True:
    payload = [{
        'operationName': "ShopProducts",
        'variables': {
            "etalaseId": "etalase", 
            "page": page, 
            "perPage": 200,
            "sid":f"{store_id}", 
            "sort": 11,
            "user_cityId": "176",
            "user_districtId": "2274",
            "user_lat": "",
            "user_long": ""
        },
        'query': 'query ShopProducts($sid: String!, $page: Int, $perPage: Int, $keyword: String, $etalaseId: String, $sort: Int, $user_districtId: String, $user_cityId: String, $user_lat: String, $user_long: String) {\n  GetShopProduct(shopID: $sid, filter: {page: $page, perPage: $perPage, fkeyword: $keyword, fmenu: $etalaseId, sort: $sort, user_districtId: $user_districtId, user_cityId: $user_cityId, user_lat: $user_lat, user_long: $user_long}) {\n    status\n    errors\n    links {\n      prev\n      next\n      __typename\n    }\n    data {\n      name\n      product_url\n      product_id\n      price {\n        text_idr\n        __typename\n      }\n      primary_image {\n        original\n        thumbnail\n        resize300\n        __typename\n      }\n      flags {\n        isSold\n        isPreorder\n        isWholesale\n        isWishlist\n        __typename\n      }\n      campaign {\n        discounted_percentage\n        original_price_fmt\n        start_date\n        end_date\n        __typename\n      }\n      label {\n        color_hex\n        content\n        __typename\n      }\n      label_groups {\n        position\n        title\n        type\n        url\n        __typename\n      }\n      badge {\n        title\n        image_url\n        __typename\n      }\n      stats {\n        reviewCount\n        rating\n        __typename\n      }\n      category {\n        id\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n'
    }]

    response = requests.post(url, json=payload)

    data = response.json()

    for product in data[0]['data']['GetShopProduct']['data']:
        product_list.append(product)
    
    if data[0]['data']['GetShopProduct']['links']['next'] == '':
        break

    page += 1

# %%
df = pd.json_normalize(product_list)
df
# Out:
#                                                  name  \
# 0          Miyako Magic Warmer Plus MCM-508 SBC 1.8 L
# 1           Miyako Magic Warmer Plus MCM-606 B 0.63 L
# 2                   Miyako Rice Cooker PSG-607 0.63 L
# 3                            Miyako Setrika EI-1008 M
# 4              Miyako Magic Warmer Plus MCM-612 1.2 L
# ..                                                ...
# 130          Miyako Water Dispenser WD-19PX Super Hot
# 131  Miyako Water Dispenser Extra Hot Normal WD-18 EX
# 132                 Miyako Kompor Gas KG-11c 1 Tungku
# 133                          Miyako Regulator RM-201M
# 134             Miyako Regulator RMS-207M Selang 1.8M
#
#                                            product_url product_id label  \
# 0    https://www.tokopedia.com/miyako/miyako-magic-...  527324623    []
# 1    https://www.tokopedia.com/miyako/miyako-magic-...  527324830    []
# 2    https://www.tokopedia.com/miyako/miyako-rice-c...  527324858    []
# 3    https://www.tokopedia.com/miyako/miyako-setrik...  527324948    []
# 4    https://www.tokopedia.com/miyako/miyako-magic-...  527324851    []
# ..                                                 ...        ...   ...
# 130  https://www.tokopedia.com/miyako/miyako-water-...  543508768    []
# 131  https://www.tokopedia.com/miyako/miyako-water-...  526961756    []
# 132  https://www.tokopedia.com/miyako/miyako-kompor...  527564411    []
# 133  https://www.tokopedia.com/miyako/miyako-regula...  527459174    []
# 134  https://www.tokopedia.com/miyako/miyako-regula...  527459151    []
#
#                                           label_groups  \
# 0    [{'position': 'integrity', 'title': 'Terjual 5...
# 1    [{'position': 'integrity', 'title': 'Terjual 5...
# 2    [{'position': 'integrity', 'title': 'Terjual 2...
# 3    [{'position': 'integrity', 'title': 'Terjual 2...
# 4    [{'position': 'integrity', 'title': 'Terjual 2...
# ..                                                 ...
# 130  [{'position': 'status', 'title': 'Stok Habis',...
# 131  [{'position': 'status', 'title': 'Stok Habis',...
# 132  [{'position': 'status', 'title': 'Stok Habis',...
# 133  [{'position': 'status', 'title': 'Stok Habis',...
# 134  [{'position': 'status', 'title': 'Stok Habis',...
#
#                                                  badge             __typename  \
# 0    [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 1    [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 2    [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 3    [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 4    [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# ..                                                 ...                    ...
# 130  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 131  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 132  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 133  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 134  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
#
#     price.text_idr  price.__typename  \
# 0       Rp 260.920  ProductListPrice
# 1       Rp 220.010  ProductListPrice
# 2       Rp 180.760  ProductListPrice
# 3       Rp 123.770  ProductListPrice
# 4       Rp 233.510  ProductListPrice
# ..             ...               ...
# 130     Rp 245.310  ProductListPrice
# 131     Rp 245.310  ProductListPrice
# 132     Rp 137.700  ProductListPrice
# 133      Rp 49.299  ProductListPrice
# 134      Rp 59.500  ProductListPrice
#
#                                 primary_image.original  ...  \
# 0    https://images.tokopedia.net/img/cache/300-squ...  ...
# 1    https://images.tokopedia.net/img/cache/300-squ...  ...
# 2    https://images.tokopedia.net/img/cache/300-squ...  ...
# 3    https://images.tokopedia.net/img/cache/300-squ...  ...
# 4    https://images.tokopedia.net/img/cache/300-squ...  ...
# ..                                                 ...  ...
# 130  https://images.tokopedia.net/img/cache/300-squ...  ...
# 131  https://images.tokopedia.net/img/cache/300-squ...  ...
# 132  https://images.tokopedia.net/img/cache/300-squ...  ...
# 133  https://images.tokopedia.net/img/cache/300-squ...  ...
# 134  https://images.tokopedia.net/img/cache/300-squ...  ...
#
#     campaign.discounted_percentage campaign.original_price_fmt  \
# 0                               13                  Rp 298.590
# 1                               15                  Rp 259.740
# 2                               10                  Rp 200.799
# 3                                0
# 4                               15                  Rp 274.170
# ..                             ...                         ...
# 130                              0
# 131                              0
# 132                              0
# 133                              0
# 134                              0
#
#       campaign.start_date     campaign.end_date        campaign.__typename  \
# 0    2022-12-02T12:01:00Z  2022-12-02T23:59:00Z  ProductDetailCampaignType
# 1    2022-12-02T12:01:00Z  2022-12-02T23:59:00Z  ProductDetailCampaignType
# 2    2022-12-02T12:01:00Z  2022-12-02T23:59:00Z  ProductDetailCampaignType
# 3                                                ProductDetailCampaignType
# 4    2022-12-02T12:01:00Z  2022-12-02T23:59:00Z  ProductDetailCampaignType
# ..                    ...                   ...                        ...
# 130                                              ProductDetailCampaignType
# 131                                              ProductDetailCampaignType
# 132                                              ProductDetailCampaignType
# 133                                              ProductDetailCampaignType
# 134                                              ProductDetailCampaignType
#
#      stats.reviewCount  stats.rating  stats.__typename category.id  \
# 0                  369            97  ProductListStats           0
# 1                  296            97  ProductListStats           0
# 2                  233            97  ProductListStats           0
# 3                  176            96  ProductListStats           0
# 4                  172            96  ProductListStats           0
# ..                 ...           ...               ...         ...
# 130                  1           100  ProductListStats           0
# 131                  1           100  ProductListStats           0
# 132                  0             0  ProductListStats           0
# 133                  0             0  ProductListStats           0
# 134                  0             0  ProductListStats           0
#
#      category.__typename
# 0    ProductListCategory
# 1    ProductListCategory
# 2    ProductListCategory
# 3    ProductListCategory
# 4    ProductListCategory
# ..                   ...
# 130  ProductListCategory
# 131  ProductListCategory
# 132  ProductListCategory
# 133  ProductListCategory
# 134  ProductListCategory
#
# [135 rows x 28 columns]

# %%
url_review = "https://gql.tokopedia.com/graphql/productReviewList"
page_review = 1
result_review = []

for i in range(0, len(product_list)):
    product = product_list[i]

    while True:
        payload_review = [{
            'operationName': "productReviewList",
            'variables': {
                "filterBy": "", 
                "limit": 500, 
                "page": page_review,
                "productID":f"{product_list[i]['product_id']}", 
                "sortBy": 'create_time desc'
            },
            'query': 'query productReviewList($productID: String!, $page: Int!, $limit: Int!, $sortBy: String, $filterBy: String) {\n  productrevGetProductReviewList(productID: $productID, page: $page, limit: $limit, sortBy: $sortBy, filterBy: $filterBy) {\n    productID\n    list {\n      id: feedbackID\n      variantName\n      message\n      productRating\n      reviewCreateTime\n      reviewCreateTimestamp\n      isReportable\n      isAnonymous\n      imageAttachments {\n        attachmentID\n        imageThumbnailUrl\n        imageUrl\n        __typename\n      }\n      videoAttachments {\n        attachmentID\n        videoUrl\n        __typename\n      }\n      reviewResponse {\n        message\n        createTime\n        __typename\n      }\n      user {\n        userID\n        fullName\n        image\n        url\n        __typename\n      }\n      likeDislike {\n        totalLike\n        likeStatus\n        __typename\n      }\n      stats {\n        key\n        formatted\n        count\n        __typename\n      }\n      badRatingReasonFmt\n      __typename\n    }\n    shop {\n      shopID\n      name\n      url\n      image\n      __typename\n    }\n    hasNext\n    totalReviews\n    __typename\n  }\n}\n'
        }]

        response_review = requests.post(url_review, json=payload_review)

        data_review = response_review.json()

        for review in data_review[0]['data']['productrevGetProductReviewList']['list']:
            review.update({"product":product})
            result_review.append(review)
        
        if data_review[0]['data']['productrevGetProductReviewList']['hasNext'] == False:
            break

        page_review += 1
    print("Scraping product no. "+str(i)+" id: " + product_list[i]['product_id'] + " review done")
# Out:
# Scraping product no. 0 id: 527324623 review done
# Scraping product no. 1 id: 527324830 review done
# Scraping product no. 2 id: 527324858 review done
# Scraping product no. 3 id: 527324948 review done
# Scraping product no. 4 id: 527324851 review done
# Scraping product no. 5 id: 527324762 review done
# Scraping product no. 6 id: 1789810656 review done
# Scraping product no. 7 id: 526964780 review done
# Scraping product no. 8 id: 526964805 review done
# Scraping product no. 9 id: 527324963 review done
# Scraping product no. 10 id: 527324794 review done
# Scraping product no. 11 id: 527324916 review done
# Scraping product no. 12 id: 6986907027 review done
# Scraping product no. 13 id: 611331306 review done
# Scraping product no. 14 id: 756496785 review done
# Scraping product no. 15 id: 527458923 review done
# Scraping product no. 16 id: 6921909438 review done
# Scraping product no. 17 id: 527459101 review done
# Scraping product no. 18 id: 526961744 review done
# Scraping product no. 19 id: 527458932 review done
# Scraping product no. 20 id: 549559978 review done
# Scraping product no. 21 id: 527368662 review done
# Scraping product no. 22 id: 527324840 review done
# Scraping product no. 23 id: 526921320 review done
# Scraping product no. 24 id: 527459139 review done
# Scraping product no. 25 id: 526947243 review done
# Scraping product no. 26 id: 526947228 review done
# Scraping product no. 27 id: 527324668 review done
# Scraping product no. 28 id: 526906039 review done
# Scraping product no. 29 id: 526947252 review done
# Scraping product no. 30 id: 526964763 review done
# Scraping product no. 31 id: 741750321 review done
# Scraping product no. 32 id: 1283858308 review done
# Scraping product no. 33 id: 527324602 review done
# Scraping product no. 34 id: 526964750 review done
# Scraping product no. 35 id: 526918873 review done
# Scraping product no. 36 id: 527324719 review done
# Scraping product no. 37 id: 526961831 review done
# Scraping product no. 38 id: 526961741 review done
# Scraping product no. 39 id: 527324566 review done
# Scraping product no. 40 id: 6126833036 review done
# Scraping product no. 41 id: 527559964 review done
# Scraping product no. 42 id: 538363054 review done
# Scraping product no. 43 id: 527324776 review done
# Scraping product no. 44 id: 526911612 review done
# Scraping product no. 45 id: 526935126 review done
# Scraping product no. 46 id: 6127133756 review done
# Scraping product no. 47 id: 526930132 review done
# Scraping product no. 48 id: 850313443 review done
# Scraping product no. 49 id: 531380703 review done
# Scraping product no. 50 id: 527459006 review done
# Scraping product no. 51 id: 527324588 review done
# Scraping product no. 52 id: 527324576 review done
# Scraping product no. 53 id: 6002080896 review done
# Scraping product no. 54 id: 1024193064 review done
# Scraping product no. 55 id: 527458959 review done
# Scraping product no. 56 id: 527324683 review done
# Scraping product no. 57 id: 526947292 review done
# Scraping product no. 58 id: 6126723174 review done
# Scraping product no. 59 id: 527438519 review done
# Scraping product no. 60 id: 527324745 review done
# Scraping product no. 61 id: 526961819 review done
# Scraping product no. 62 id: 540600784 review done
# Scraping product no. 63 id: 527458995 review done
# Scraping product no. 64 id: 527324706 review done
# Scraping product no. 65 id: 527324614 review done
# Scraping product no. 66 id: 526964893 review done
# Scraping product no. 67 id: 526961801 review done
# Scraping product no. 68 id: 526961797 review done
# Scraping product no. 69 id: 526932427 review done
# Scraping product no. 70 id: 527459193 review done
# Scraping product no. 71 id: 526961811 review done
# Scraping product no. 72 id: 533335323 review done
# Scraping product no. 73 id: 527561680 review done
# Scraping product no. 74 id: 527368652 review done
# Scraping product no. 75 id: 527368623 review done
# Scraping product no. 76 id: 526964711 review done
# Scraping product no. 77 id: 531377637 review done
# Scraping product no. 78 id: 526924065 review done
# Scraping product no. 79 id: 4828991447 review done
# Scraping product no. 80 id: 527324821 review done
# Scraping product no. 81 id: 527324632 review done
# Scraping product no. 82 id: 526947216 review done
# Scraping product no. 83 id: 526926228 review done
# Scraping product no. 84 id: 527324694 review done
# Scraping product no. 85 id: 850315835 review done
# Scraping product no. 86 id: 632974422 review done
# Scraping product no. 87 id: 527458942 review done
# Scraping product no. 88 id: 526947257 review done
# Scraping product no. 89 id: 549528938 review done
# Scraping product no. 90 id: 527459201 review done
# Scraping product no. 91 id: 526961845 review done
# Scraping product no. 92 id: 526927821 review done
# Scraping product no. 93 id: 6994132372 review done
# Scraping product no. 94 id: 6993600743 review done
# Scraping product no. 95 id: 6989658702 review done
# Scraping product no. 96 id: 6989624250 review done
# Scraping product no. 97 id: 6989594396 review done
# Scraping product no. 98 id: 6989556223 review done
# Scraping product no. 99 id: 6989520898 review done
# Scraping product no. 100 id: 6989479205 review done
# Scraping product no. 101 id: 6989423248 review done
# Scraping product no. 102 id: 526961738 review done
# Scraping product no. 103 id: 527557843 review done
# Scraping product no. 104 id: 526961772 review done
# Scraping product no. 105 id: 6150658095 review done
# Scraping product no. 106 id: 526964728 review done
# Scraping product no. 107 id: 6002182166 review done
# Scraping product no. 108 id: 527458883 review done
# Scraping product no. 109 id: 527458909 review done
# Scraping product no. 110 id: 549924304 review done
# Scraping product no. 111 id: 527324895 review done
# Scraping product no. 112 id: 527324979 review done
# Scraping product no. 113 id: 527458895 review done
# Scraping product no. 114 id: 527458861 review done
# Scraping product no. 115 id: 527459354 review done
# Scraping product no. 116 id: 539429668 review done
# Scraping product no. 117 id: 527447154 review done
# Scraping product no. 118 id: 527324652 review done
# Scraping product no. 119 id: 526964739 review done
# Scraping product no. 120 id: 1784598031 review done
# Scraping product no. 121 id: 549536753 review done
# Scraping product no. 122 id: 527459257 review done
# Scraping product no. 123 id: 527459121 review done
# Scraping product no. 124 id: 527324805 review done
# Scraping product no. 125 id: 526961785 review done
# Scraping product no. 126 id: 850290863 review done
# Scraping product no. 127 id: 527459287 review done
# Scraping product no. 128 id: 527458828 review done
# Scraping product no. 129 id: 527324675 review done
# Scraping product no. 130 id: 543508768 review done
# Scraping product no. 131 id: 526961756 review done
# Scraping product no. 132 id: 527564411 review done
# Scraping product no. 133 id: 527459174 review done
# Scraping product no. 134 id: 527459151 review done

# %%
df_review = pd.json_normalize(result_review)
df_review
# Out:
#              id variantName  \
# 0     801207971
# 1     798881998
# 2     798107484
# 3     782049117
# 4     781924917
# ...         ...         ...
# 1064  167835827
# 1065  207510527
# 1066  197344839
# 1067  197344854
# 1068  214184736
#
#                                                 message  productRating  \
# 0     barang penyok. lain kali harus lebih teliti la...              1
# 1     Kualitas barang bagus, berfungsi dengan baik, ...              5
# 2                 Produk sesuai order, pengiroman cepat              5
# 3                                                                    5
# 4                                                                    5
# ...                                                 ...            ...
# 1064  produk sangat berkualitas tetapi pengiriman ag...              5
# 1065                          Produk yang asli Original              5
# 1066  Produk berkualitas, harga kompetitif, pakai ek...              5
# 1067  Produk berkualitas, harga kompetitif, pakai ek...              5
# 1068            Barang sampai dgn selamat...terimakasih              5
#
#      reviewCreateTime    reviewCreateTimestamp  isReportable  isAnonymous  \
# 0          1669734747              3 hari lalu         False         True
# 1          1669384004            1 minggu lalu         False        False
# 2          1669274687            1 minggu lalu         False        False
# 3          1666994001             1 bulan lalu         False        False
# 4          1666982538             1 bulan lalu         False         True
# ...               ...                      ...           ...          ...
# 1064       1573220482  Lebih dari 1 tahun lalu         False        False
# 1065       1590080693  Lebih dari 1 tahun lalu         False         True
# 1066       1587250145  Lebih dari 1 tahun lalu         False        False
# 1067       1587250151  Lebih dari 1 tahun lalu         False        False
# 1068       1592070898  Lebih dari 1 tahun lalu         False        False
#
#                                        imageAttachments  \
# 0     [{'attachmentID': '92116598', 'imageThumbnailU...
# 1                                                    []
# 2     [{'attachmentID': '91714988', 'imageThumbnailU...
# 3                                                    []
# 4     [{'attachmentID': '89559331', 'imageThumbnailU...
# ...                                                 ...
# 1064                                                 []
# 1065                                                 []
# 1066                                                 []
# 1067                                                 []
# 1068                                                 []
#
#                                        videoAttachments  ...  \
# 0                                                    []  ...
# 1                                                    []  ...
# 2                                                    []  ...
# 3     [{'attachmentID': '89577102', 'videoUrl': 'htt...  ...
# 4                                                    []  ...
# ...                                                 ...  ...
# 1064                                                 []  ...
# 1065                                                 []  ...
# 1066                                                 []  ...
# 1067                                                 []  ...
# 1068                                                 []  ...
#
#      product.campaign.__typename product.label  \
# 0      ProductDetailCampaignType            []
# 1      ProductDetailCampaignType            []
# 2      ProductDetailCampaignType            []
# 3      ProductDetailCampaignType            []
# 4      ProductDetailCampaignType            []
# ...                          ...           ...
# 1064   ProductDetailCampaignType            []
# 1065   ProductDetailCampaignType            []
# 1066   ProductDetailCampaignType            []
# 1067   ProductDetailCampaignType            []
# 1068   ProductDetailCampaignType            []
#
#                                    product.label_groups  \
# 0     [{'position': 'integrity', 'title': 'Terjual 5...
# 1     [{'position': 'integrity', 'title': 'Terjual 5...
# 2     [{'position': 'integrity', 'title': 'Terjual 5...
# 3     [{'position': 'integrity', 'title': 'Terjual 5...
# 4     [{'position': 'integrity', 'title': 'Terjual 5...
# ...                                                 ...
# 1064  [{'position': 'status', 'title': 'Stok Habis',...
# 1065  [{'position': 'status', 'title': 'Stok Habis',...
# 1066  [{'position': 'status', 'title': 'Stok Habis',...
# 1067  [{'position': 'status', 'title': 'Stok Habis',...
# 1068  [{'position': 'status', 'title': 'Stok Habis',...
#
#                                           product.badge  \
# 0     [{'title': 'Official Store', 'image_url': 'htt...
# 1     [{'title': 'Official Store', 'image_url': 'htt...
# 2     [{'title': 'Official Store', 'image_url': 'htt...
# 3     [{'title': 'Official Store', 'image_url': 'htt...
# 4     [{'title': 'Official Store', 'image_url': 'htt...
# ...                                                 ...
# 1064  [{'title': 'Official Store', 'image_url': 'htt...
# 1065  [{'title': 'Official Store', 'image_url': 'htt...
# 1066  [{'title': 'Official Store', 'image_url': 'htt...
# 1067  [{'title': 'Official Store', 'image_url': 'htt...
# 1068  [{'title': 'Official Store', 'image_url': 'htt...
#
#      product.stats.reviewCount product.stats.rating product.stats.__typename  \
# 0                          369                   97         ProductListStats
# 1                          369                   97         ProductListStats
# 2                          369                   97         ProductListStats
# 3                          369                   97         ProductListStats
# 4                          369                   97         ProductListStats
# ...                        ...                  ...                      ...
# 1064                         3                  100         ProductListStats
# 1065                         3                  100         ProductListStats
# 1066                         3                  100         ProductListStats
# 1067                         2                   90         ProductListStats
# 1068                         2                  100         ProductListStats
#
#      product.category.id product.category.__typename     product.__typename
# 0                      0         ProductListCategory  ShopProductListDetail
# 1                      0         ProductListCategory  ShopProductListDetail
# 2                      0         ProductListCategory  ShopProductListDetail
# 3                      0         ProductListCategory  ShopProductListDetail
# 4                      0         ProductListCategory  ShopProductListDetail
# ...                  ...                         ...                    ...
# 1064                   0         ProductListCategory  ShopProductListDetail
# 1065                   0         ProductListCategory  ShopProductListDetail
# 1066                   0         ProductListCategory  ShopProductListDetail
# 1067                   0         ProductListCategory  ShopProductListDetail
# 1068                   0         ProductListCategory  ShopProductListDetail
#
# [1069 rows x 52 columns]

# %%
from pymongo import MongoClient

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['tokopediaProductReview'] 
collection = db['miyako']

# %%
collection.insert_many(result_review)

# %%
data = collection.find()

df = pd.json_normalize(data)
df
# Out:
#                            _id                                    id  \
# 0     637e18d68ccf7446afd010e3  73a68739-1237-49f1-821f-6261cb90c5fc
# 1     637e18d68ccf7446afd010e4  75702197-fba0-4200-a0f0-52dd7c8c332c
# 2     637e18d68ccf7446afd010e5  2a91401f-8e11-4b90-8027-7605a8b89ba3
# 3     637e18d68ccf7446afd010e6  5c94e856-63aa-40c5-be9d-8931160c049d
# 4     637e18d68ccf7446afd010e7  3d98c992-e2c9-454c-aa1a-a957f7ac5764
# ...                        ...                                   ...
# 8348  637e18d68ccf7446afd0317f  c5025d0d-a0d3-48ed-827e-11ce51f6cacc
# 8349  637e18d68ccf7446afd03180  40b76884-0c7b-4f71-ad22-93d237b1ad45
# 8350  637e18d68ccf7446afd03181  236dc7b3-5a93-43fb-8e1f-2bac06cfcc46
# 8351  637e18d68ccf7446afd03182  86009efb-3533-476f-bfdc-fba46fe8f399
# 8352  637e18d68ccf7446afd03183  893e13a5-337b-4856-b471-4f292ad587df
#
#                  name  rating    createdDate    updatedDate  likes  \
# 0                 Aro       5  1668487909680  1668487909680      0
# 1             MUHAMAD       5  1668437644933  1668437644943      0
# 2                Dewi       5  1668379161516  1668379161516      0
# 3               V***a       5  1668228006469  1668228006479      0
# 4     iv***@gmail.com       5  1668162659023  1668162659032      0
# ...               ...     ...            ...            ...    ...
# 8348            F***a       5  1624382386487  1624382386584      0
# 8349            Dolar       5  1616256165498  1624382386585      0
# 8350            G***a       5  1613015902079  1624382386585      0
# 8351            Retno       5  1610624999957  1624382386585      0
# 8352            N***a       5  1609178240861  1624382386585      0
#
#       showPriority  verifiedBuyer  edited  ... product.soldRangeCount.en  \
# 0                2           True   False  ...                     1,9 k
# 1                2           True   False  ...                     1,9 k
# 2                2           True   False  ...                     1,9 k
# 3                2           True   False  ...                     1,9 k
# 4                2           True   False  ...                     1,9 k
# ...            ...            ...     ...  ...                       ...
# 8348             3           True   False  ...                        45
# 8349             4           True   False  ...                        45
# 8350             3           True   False  ...                        45
# 8351             3           True   False  ...                        45
# 8352             3           True   False  ...                        45
#
#      product.soldRangeCount.id                  product.categoryIdHierarchy  \
# 0                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# 1                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# 2                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# 3                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# 4                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# ...                        ...                                          ...
# 8348                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
# 8349                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
# 8350                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
# 8351                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
# 8352                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
#
#       product.cartLogisticOptions product.merchantVoucherMessage  \
# 0                              []           No voucher available
# 1                              []           No voucher available
# 2                              []           No voucher available
# 3                              []           No voucher available
# 4                              []           No voucher available
# ...                           ...                            ...
# 8348                           []           No voucher available
# 8349                           []           No voucher available
# 8350                           []           No voucher available
# 8351                           []           No voucher available
# 8352                           []           No voucher available
#
#       product.preorder  product.official  \
# 0                False              True
# 1                False              True
# 2                False              True
# 3                False              True
# 4                False              True
# ...                ...               ...
# 8348             False              True
# 8349             False              True
# 8350             False              True
# 8351             False              True
# 8352             False              True
#
#                                                 content title  \
# 0                                                   NaN   NaN
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# ...                                                 ...   ...
# 8348                                     Very pigmented   NaN
# 8349
# 8350  so pretty... warnanya pigmented banget, hargan...   NaN
# 8351    good seller. trusted. barang sampai dengan aman
# 8352            Bagus bgt. Pigmented dan warnanya ok ok   NaN
#
#      product.price.strikeThroughPriceDisplay
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 8348                                     NaN
# 8349                                     NaN
# 8350                                     NaN
# 8351                                     NaN
# 8352                                     NaN
#
# [8353 rows x 65 columns]
