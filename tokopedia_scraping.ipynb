# %%
import requests
import pandas as pd
from pymongo import MongoClient

# %% [markdown]
# **Get Product from The Store**

# %%
store_id = "3708434"
url = "https://gql.tokopedia.com/graphql/ShopProducts"
page = 1
product_list = []
store_id = "3708434"

while True:
    payload = [{
        'operationName': "ShopProducts",
        'variables': {
            "etalaseId": "etalase", 
            "page": page, 
            "perPage": 200,
            "sid":f"{store_id}", 
            "sort": 11,
            "user_cityId": "176",
            "user_districtId": "2274",
            "user_lat": "",
            "user_long": ""
        },
        'query': 'query ShopProducts($sid: String!, $page: Int, $perPage: Int, $keyword: String, $etalaseId: String, $sort: Int, $user_districtId: String, $user_cityId: String, $user_lat: String, $user_long: String) {\n  GetShopProduct(shopID: $sid, filter: {page: $page, perPage: $perPage, fkeyword: $keyword, fmenu: $etalaseId, sort: $sort, user_districtId: $user_districtId, user_cityId: $user_cityId, user_lat: $user_lat, user_long: $user_long}) {\n    status\n    errors\n    links {\n      prev\n      next\n      __typename\n    }\n    data {\n      name\n      product_url\n      product_id\n      price {\n        text_idr\n        __typename\n      }\n      primary_image {\n        original\n        thumbnail\n        resize300\n        __typename\n      }\n      flags {\n        isSold\n        isPreorder\n        isWholesale\n        isWishlist\n        __typename\n      }\n      campaign {\n        discounted_percentage\n        original_price_fmt\n        start_date\n        end_date\n        __typename\n      }\n      label {\n        color_hex\n        content\n        __typename\n      }\n      label_groups {\n        position\n        title\n        type\n        url\n        __typename\n      }\n      badge {\n        title\n        image_url\n        __typename\n      }\n      stats {\n        reviewCount\n        rating\n        __typename\n      }\n      category {\n        id\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n'
    }]

    response = requests.post(url, json=payload)

    data = response.json()

    for product in data[0]['data']['GetShopProduct']['data']:
        product_list.append(product)
    
    if data[0]['data']['GetShopProduct']['links']['next'] == '':
        break

    page += 1

# %% [markdown]
# **Get Product from Search Query**

# %%
url = "https://gql.tokopedia.com/graphql/SearchProductQueryV4"
product_list = []
brand = 'indomie'
category = '1394'
price_min = '1100000'

payload = [{
    'operationName': "SearchProductQueryV4",
    'variables': {
        "params":f"device=desktop&ob=5&q={brand}&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&st=product&start=0&topads_bucket=true&unique_id=88aa6392627dfe3d5ef605c5426a24e7&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=0&variants="
        # "params":f"device=desktop&ob=5&q={brand}&related=true&rows=60&safe_search=false&sc={category}&scheme=https&shipping=&source=search&st=product&start=0&topads_bucket=true&unique_id=88aa6392627dfe3d5ef605c5426a24e7&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=0&variants="
        # "params":f"device=desktop&ob=5&pmin={price_min}&q={brand}&related=true&rows=60&safe_search=false&sc={category}&scheme=https&shipping=&source=search&st=product&start=0&topads_bucket=true&unique_id=88aa6392627dfe3d5ef605c5426a24e7&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=0&variants="
    },
    'query': "query SearchProductQueryV4($params: String!) {\n  ace_search_product_v4(params: $params) {\n    header {\n      totalData\n      totalDataText\n      processTime\n      responseCode\n      errorMessage\n      additionalParams\n      keywordProcess\n      componentId\n      __typename\n    }\n    data {\n      banner {\n        position\n        text\n        imageUrl\n        url\n        componentId\n        trackingOption\n        __typename\n      }\n      backendFilters\n      isQuerySafe\n      ticker {\n        text\n        query\n        typeId\n        componentId\n        trackingOption\n        __typename\n      }\n      redirection {\n        redirectUrl\n        departmentId\n        __typename\n      }\n      related {\n        position\n        trackingOption\n        relatedKeyword\n        otherRelated {\n          keyword\n          url\n          product {\n            id\n            name\n            price\n            imageUrl\n            rating\n            countReview\n            url\n            priceStr\n            wishlist\n            shop {\n              city\n              isOfficial\n              isPowerBadge\n              __typename\n            }\n            ads {\n              adsId: id\n              productClickUrl\n              productWishlistUrl\n              shopClickUrl\n              productViewUrl\n              __typename\n            }\n            badges {\n              title\n              imageUrl\n              show\n              __typename\n            }\n            ratingAverage\n            labelGroups {\n              position\n              type\n              title\n              url\n              __typename\n            }\n            componentId\n            __typename\n          }\n          componentId\n          __typename\n        }\n        __typename\n      }\n      suggestion {\n        currentKeyword\n        suggestion\n        suggestionCount\n        instead\n        insteadCount\n        query\n        text\n        componentId\n        trackingOption\n        __typename\n      }\n      products {\n        id\n        name\n        ads {\n          adsId: id\n          productClickUrl\n          productWishlistUrl\n          productViewUrl\n          __typename\n        }\n        badges {\n          title\n          imageUrl\n          show\n          __typename\n        }\n        category: departmentId\n        categoryBreadcrumb\n        categoryId\n        categoryName\n        countReview\n        customVideoURL\n        discountPercentage\n        gaKey\n        imageUrl\n        labelGroups {\n          position\n          title\n          type\n          url\n          __typename\n        }\n        originalPrice\n        price\n        priceRange\n        rating\n        ratingAverage\n        shop {\n          shopId: id\n          name\n          url\n          city\n          isOfficial\n          isPowerBadge\n          __typename\n        }\n        url\n        wishlist\n        sourceEngine: source_engine\n        __typename\n      }\n      violation {\n        headerText\n        descriptionText\n        imageURL\n        ctaURL\n        ctaApplink\n        buttonText\n        buttonType\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
}]

response = requests.post(url, json=payload)

data = response.json()

for index in range(0, 6000, 60):
    payload = [{
        'operationName': "SearchProductQueryV4",
        'variables': {
            "params":f"device=desktop&ob=5&q={brand}&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&st=product&start={index}&topads_bucket=true&unique_id=88aa6392627dfe3d5ef605c5426a24e7&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=0&variants="
            # "params":f"device=desktop&ob=5&q={brand}&related=true&rows=60&safe_search=false&sc={category}&scheme=https&shipping=&source=search&st=product&start=0&topads_bucket=true&unique_id=88aa6392627dfe3d5ef605c5426a24e7&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=0&variants="
            # "params":f"device=desktop&ob=5&pmin={price_min}&q={brand}&related=true&rows=60&safe_search=false&sc={category}&scheme=https&shipping=&source=search&st=product&start=0&topads_bucket=true&unique_id=88aa6392627dfe3d5ef605c5426a24e7&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=0&variants="
        },
        'query': "query SearchProductQueryV4($params: String!) {\n  ace_search_product_v4(params: $params) {\n    header {\n      totalData\n      totalDataText\n      processTime\n      responseCode\n      errorMessage\n      additionalParams\n      keywordProcess\n      componentId\n      __typename\n    }\n    data {\n      banner {\n        position\n        text\n        imageUrl\n        url\n        componentId\n        trackingOption\n        __typename\n      }\n      backendFilters\n      isQuerySafe\n      ticker {\n        text\n        query\n        typeId\n        componentId\n        trackingOption\n        __typename\n      }\n      redirection {\n        redirectUrl\n        departmentId\n        __typename\n      }\n      related {\n        position\n        trackingOption\n        relatedKeyword\n        otherRelated {\n          keyword\n          url\n          product {\n            id\n            name\n            price\n            imageUrl\n            rating\n            countReview\n            url\n            priceStr\n            wishlist\n            shop {\n              city\n              isOfficial\n              isPowerBadge\n              __typename\n            }\n            ads {\n              adsId: id\n              productClickUrl\n              productWishlistUrl\n              shopClickUrl\n              productViewUrl\n              __typename\n            }\n            badges {\n              title\n              imageUrl\n              show\n              __typename\n            }\n            ratingAverage\n            labelGroups {\n              position\n              type\n              title\n              url\n              __typename\n            }\n            componentId\n            __typename\n          }\n          componentId\n          __typename\n        }\n        __typename\n      }\n      suggestion {\n        currentKeyword\n        suggestion\n        suggestionCount\n        instead\n        insteadCount\n        query\n        text\n        componentId\n        trackingOption\n        __typename\n      }\n      products {\n        id\n        name\n        ads {\n          adsId: id\n          productClickUrl\n          productWishlistUrl\n          productViewUrl\n          __typename\n        }\n        badges {\n          title\n          imageUrl\n          show\n          __typename\n        }\n        category: departmentId\n        categoryBreadcrumb\n        categoryId\n        categoryName\n        countReview\n        customVideoURL\n        discountPercentage\n        gaKey\n        imageUrl\n        labelGroups {\n          position\n          title\n          type\n          url\n          __typename\n        }\n        originalPrice\n        price\n        priceRange\n        rating\n        ratingAverage\n        shop {\n          shopId: id\n          name\n          url\n          city\n          isOfficial\n          isPowerBadge\n          __typename\n        }\n        url\n        wishlist\n        sourceEngine: source_engine\n        __typename\n      }\n      violation {\n        headerText\n        descriptionText\n        imageURL\n        ctaURL\n        ctaApplink\n        buttonText\n        buttonType\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
    }]

    response = requests.post(url, json=payload)

    data = response.json()
    for product in data[0]['data']['ace_search_product_v4']['data']['products']:
        product_list.append(product)
    print(str(index))
# Out:
# 0
# 60
# 120
# 180
# 240
# 300
# 360
# 420
# 480
# 540
# 600
# 660
# 720
# 780
# 840
# 900
# 960
# 1020
# 1080
# 1140
# 1200
# 1260
# 1320
# 1380
# 1440
# 1500
# 1560
# 1620
# 1680
# 1740
# 1800
# 1860
# 1920
# 1980
# 2040
# 2100
# 2160
# 2220
# 2280
# 2340
# 2400
# 2460
# 2520
# 2580
# 2640
# 2700
# 2760
# 2820
# 2880
# 2940
# 3000
# 3060
# 3120
# 3180
# 3240
# 3300
# 3360
# 3420
# 3480
# 3540
# 3600
# 3660
# 3720
# 3780
# 3840
# 3900
# 3960
# 4020
# 4080
# 4140
# 4200
# 4260
# 4320
# 4380
# 4440
# 4500
# 4560
# 4620
# 4680
# 4740
# 4800
# 4860
# 4920
# 4980
# 5040
# 5100
# 5160
# 5220
# 5280
# 5340
# 5400
# 5460
# 5520
# 5580
# 5640
# 5700
# 5760
# 5820
# 5880
# 5940

# %%
df = pd.json_normalize(product_list)
df
# Out:
#               id                                               name  \
# 0     2806598274         Indomie Mie Instan [40 pcs / karton] 1 dus
# 1      448842257                    10 Pcs - Indomie Goreng Spesial
# 2     2124673719                        Paket Bundling Indomie Kuah
# 3      447322637                     5 Pcs - Indomie Goreng Spesial
# 4     2124669767                      Paket Bundling Indomie Goreng
# ...          ...                                                ...
# 5995   920807576                     Indomie rasa ayam bawang 1 pcs
# 5996  1075028704  HARGA EKONOMIS 10 BUNGKUSS !!! - INDOMIE MIE K...
# 5997  1959611401                     indomie rasa ayam bawang 69 gr
# 5998  2201828882       Mie Instan Indomie Ayam Geprek 85 gr (5 bks)
# 5999  2845391978                          Indomie Goreng Mie Instan
#
#                                                  badges  category  \
# 0     [{'title': 'Power Merchant Pro Badge', 'imageU...      2738
# ...

# %%
df.drop_duplicates(subset=['id'], keep="first")
df
# Out:
#               id                                               name  \
# 0     2806598274         Indomie Mie Instan [40 pcs / karton] 1 dus
# 1      448842257                    10 Pcs - Indomie Goreng Spesial
# 2     2124673719                        Paket Bundling Indomie Kuah
# 3      447322637                     5 Pcs - Indomie Goreng Spesial
# 4     2124669767                      Paket Bundling Indomie Goreng
# ...          ...                                                ...
# 5995   920807576                     Indomie rasa ayam bawang 1 pcs
# 5996  1075028704  HARGA EKONOMIS 10 BUNGKUSS !!! - INDOMIE MIE K...
# 5997  1959611401                     indomie rasa ayam bawang 69 gr
# 5998  2201828882       Mie Instan Indomie Ayam Geprek 85 gr (5 bks)
# 5999  2845391978                          Indomie Goreng Mie Instan
#
#                                                  badges  category  \
# 0     [{'title': 'Power Merchant Pro Badge', 'imageU...      2738
# ...

# %%
df = df[df["name"].str.contains("Distro|distro|XL|Nike|nike|NIKE|Air|air|AIR|model|MODEL|Model|NEVADA|HUSH") == False]
df

# %%
url_review = "https://gql.tokopedia.com/graphql/productReviewList"
result_review = []

for i in range(0, len(product_list)):
    product = product_list[i]
    page_review = 1
    
    if product_list[i]['countReview'] == 0:
        print("Product no. "+str(i)+" id: " + str(product_list[i]['id']) + " tidak ada review")
        continue
    else:
        while True:
            payload_review = [{
                'operationName': "productReviewList",
                'variables': {
                    "filterBy": "", 
                    "limit": 500, 
                    "page": page_review,
                    "productID":f"{product_list[i]['id']}", 
                    "sortBy": 'create_time desc'
                },
                'query': 'query productReviewList($productID: String!, $page: Int!, $limit: Int!, $sortBy: String, $filterBy: String) {\n  productrevGetProductReviewList(productID: $productID, page: $page, limit: $limit, sortBy: $sortBy, filterBy: $filterBy) {\n    productID\n    list {\n      id: feedbackID\n      variantName\n      message\n      productRating\n      reviewCreateTime\n      reviewCreateTimestamp\n      isReportable\n      isAnonymous\n      imageAttachments {\n        attachmentID\n        imageThumbnailUrl\n        imageUrl\n        __typename\n      }\n      videoAttachments {\n        attachmentID\n        videoUrl\n        __typename\n      }\n      reviewResponse {\n        message\n        createTime\n        __typename\n      }\n      user {\n        userID\n        fullName\n        image\n        url\n        __typename\n      }\n      likeDislike {\n        totalLike\n        likeStatus\n        __typename\n      }\n      stats {\n        key\n        formatted\n        count\n        __typename\n      }\n      badRatingReasonFmt\n      __typename\n    }\n    shop {\n      shopID\n      name\n      url\n      image\n      __typename\n    }\n    hasNext\n    totalReviews\n    __typename\n  }\n}\n'
            }]

            response_review = requests.post(url_review, json=payload_review)

            data_review = response_review.json()

            for review in data_review[0]['data']['productrevGetProductReviewList']['list']:
                review.update({"product":product})
                result_review.append(review)

            print("Scraping product no. "+str(i)+" id: " + str(product_list[i]['id']) + " review page:"+str(page_review))
            
            if data_review[0]['data']['productrevGetProductReviewList']['hasNext'] == False:
                break

            page_review += 1
        print("Scraping product no. "+str(i)+" id: " + str(product_list[i]['id']) + " review done")
# Out:
# Scraping product no. 0 id: 2806598274 review page:1
# Scraping product no. 0 id: 2806598274 review page:2
# Scraping product no. 0 id: 2806598274 review page:3
# Scraping product no. 0 id: 2806598274 review page:4
# Scraping product no. 0 id: 2806598274 review page:5
# Scraping product no. 0 id: 2806598274 review done
# Scraping product no. 1 id: 448842257 review page:1
# Scraping product no. 1 id: 448842257 review page:2
# Scraping product no. 1 id: 448842257 review done
# Scraping product no. 2 id: 2124673719 review page:1
# Scraping product no. 2 id: 2124673719 review page:2
# Scraping product no. 2 id: 2124673719 review done
# Scraping product no. 3 id: 447322637 review page:1
# Scraping product no. 3 id: 447322637 review page:2
# Scraping product no. 3 id: 447322637 review done
# Scraping product no. 4 id: 2124669767 review page:1
# Scraping product no. 4 id: 2124669767 review page:2
# Scraping product no. 4 id: 2124669767 review done
# ...

# %%
df_review = pd.DataFrame(result_review)
df_review
# Out:
#               id     variantName  \
# 0      849227654  Ayam Bawang AB
# 1      849227309  Ayam Bawang AB
# 2      848249729  Goreng Rendang
# 3      847105680  Ayam Bawang AB
# 4      845247917   Kebab Rendang
# ...          ...             ...
# 83325  844739373
# 83326  734364476
# 83327  353335207
# 83328  518846920
# 83329  773205498
#
#                                                  message  productRating  \
# 0                barang realfick kurir baik dan ramah tq              5
# 1      mantap seler gercep, barang cepat sampai kurir...              5
# 2      packing rapi cepat sampai nya dan\n sesuai pro...              5
# 3      Respon seller cepat.., pengemasan aman.., dan ...              5
# 4                             pengiriman cepat dan aman.              5
# ...                                                  ...            ...
# 83325                                     sesuai pesanan              5
# ...

# %%
df_review.to_json(path_or_buf="review_carvil.json")

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
localhost = "mongodb://localhost:27017"

# %%
client = MongoClient(localhost)
db = client['tokopedia2'] 
collection = db['indomie']

# %%
collection.insert_many(result_review)
