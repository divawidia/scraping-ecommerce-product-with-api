# %%
import requests
import pandas as pd

# %%
store_id = "1114391"

# %%
url = "https://gql.tokopedia.com/graphql/ShopProducts"
page = 1
product_list = []

while True:
    payload = [{
        'operationName': "ShopProducts",
        'variables': {
            "etalaseId": "etalase", 
            "page": page, 
            "perPage": 200,
            "sid":f"{store_id}", 
            "sort": 11,
            "user_cityId": "176",
            "user_districtId": "2274",
            "user_lat": "",
            "user_long": ""
        },
        'query': 'query ShopProducts($sid: String!, $page: Int, $perPage: Int, $keyword: String, $etalaseId: String, $sort: Int, $user_districtId: String, $user_cityId: String, $user_lat: String, $user_long: String) {\n  GetShopProduct(shopID: $sid, filter: {page: $page, perPage: $perPage, fkeyword: $keyword, fmenu: $etalaseId, sort: $sort, user_districtId: $user_districtId, user_cityId: $user_cityId, user_lat: $user_lat, user_long: $user_long}) {\n    status\n    errors\n    links {\n      prev\n      next\n      __typename\n    }\n    data {\n      name\n      product_url\n      product_id\n      price {\n        text_idr\n        __typename\n      }\n      primary_image {\n        original\n        thumbnail\n        resize300\n        __typename\n      }\n      flags {\n        isSold\n        isPreorder\n        isWholesale\n        isWishlist\n        __typename\n      }\n      campaign {\n        discounted_percentage\n        original_price_fmt\n        start_date\n        end_date\n        __typename\n      }\n      label {\n        color_hex\n        content\n        __typename\n      }\n      label_groups {\n        position\n        title\n        type\n        url\n        __typename\n      }\n      badge {\n        title\n        image_url\n        __typename\n      }\n      stats {\n        reviewCount\n        rating\n        __typename\n      }\n      category {\n        id\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n'
    }]

    response = requests.post(url, json=payload)

    data = response.json()

    for product in data[0]['data']['GetShopProduct']['data']:
        product_list.append(product)
    
    if data[0]['data']['GetShopProduct']['links']['next'] == '':
        break

    page += 1

# %%
df = pd.json_normalize(product_list)
df
# Out:
#                                                   name  \
# 0    910 Nineten Nichirin Kaos Kaki Pendek Socks An...
# 1      910 Nineten Socks FUKA Quarter Hitam/Putih/Biru
# 2    910 Nineten Nichirin Kaos Kaki Socks Quarter -...
# 3    910 Nineten Nichirin Kaos Kaki Pendek Socks An...
# 4    910 Nineten Socks FUKA Quarter Putih/Abu Muda/...
# ..                                                 ...
# 239  910 Nineten Kazari Sepatu Lari Unisex - Hitam/...
# 240   Bundling Sepatu Ryu Swift + Azumi Pullover Hodie
# 241           Bundling Sepatu Ryu Swift + Rejion Ultra
# 242          Bundling Sepatu Ryu Swift + T-Shirt Fruro
# 243         910 Sandal Rejion Fix Strap - Biru Dongker
#
#                                            product_url  product_id label  \
# 0    https://www.tokopedia.com/910ninetenshoes/910-...   970526230    []
# 1    https://www.tokopedia.com/910ninetenshoes/910-...  1740845088    []
# 2    https://www.tokopedia.com/910ninetenshoes/910-...   970555659    []
# 3    https://www.tokopedia.com/910ninetenshoes/910-...  1134145572    []
# 4    https://www.tokopedia.com/910ninetenshoes/910-...  1740833839    []
# ..                                                 ...         ...   ...
# 239  https://www.tokopedia.com/910ninetenshoes/910-...   623153918    []
# 240  https://www.tokopedia.com/910ninetenshoes/bund...  6830389352    []
# 241  https://www.tokopedia.com/910ninetenshoes/bund...  6830220325    []
# 242  https://www.tokopedia.com/910ninetenshoes/bund...  6994255922    []
# 243  https://www.tokopedia.com/910ninetenshoes/910-...   641982670    []
#
#                                           label_groups  \
# 0    [{'position': 'integrity', 'title': 'Terjual 5...
# 1    [{'position': 'integrity', 'title': 'Terjual 4...
# 2    [{'position': 'integrity', 'title': 'Terjual 4...
# 3    [{'position': 'integrity', 'title': 'Terjual 3...
# 4    [{'position': 'integrity', 'title': 'Terjual 2...
# ..                                                 ...
# 239  [{'position': 'status', 'title': 'Stok Habis',...
# 240  [{'position': 'status', 'title': 'Stok Habis',...
# 241  [{'position': 'status', 'title': 'Stok Habis',...
# 242  [{'position': 'status', 'title': 'Stok Habis',...
# 243  [{'position': 'status', 'title': 'Stok Habis',...
#
#                                                  badge             __typename  \
# 0    [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 1    [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 2    [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 3    [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 4    [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# ..                                                 ...                    ...
# 239  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 240  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 241  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 242  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
# 243  [{'title': 'Official Store', 'image_url': 'htt...  ShopProductListDetail
#
#     price.text_idr  price.__typename  \
# 0        Rp 16.900  ProductListPrice
# 1        Rp 18.900  ProductListPrice
# 2        Rp 18.900  ProductListPrice
# 3        Rp 16.900  ProductListPrice
# 4        Rp 18.900  ProductListPrice
# ..             ...               ...
# 239     Rp 299.900  ProductListPrice
# 240     Rp 699.800  ProductListPrice
# 241     Rp 569.800  ProductListPrice
# 242     Rp 524.800  ProductListPrice
# 243     Rp 149.000  ProductListPrice
#
#                                 primary_image.original  ...  \
# 0    https://images.tokopedia.net/img/cache/300-squ...  ...
# 1    https://images.tokopedia.net/img/cache/300-squ...  ...
# 2    https://images.tokopedia.net/img/cache/300-squ...  ...
# 3    https://images.tokopedia.net/img/cache/300-squ...  ...
# 4    https://images.tokopedia.net/img/cache/300-squ...  ...
# ..                                                 ...  ...
# 239  https://images.tokopedia.net/img/cache/300-squ...  ...
# 240  https://images.tokopedia.net/img/cache/300-squ...  ...
# 241  https://images.tokopedia.net/img/cache/300-squ...  ...
# 242  https://images.tokopedia.net/img/cache/300-squ...  ...
# 243  https://images.tokopedia.net/img/cache/300-squ...  ...
#
#     campaign.discounted_percentage campaign.original_price_fmt  \
# 0                               58                   Rp 39.900
# 1                               62                   Rp 50.000
# 2                               62                   Rp 49.900
# 3                               58                   Rp 39.900
# 4                               62                   Rp 50.000
# ..                             ...                         ...
# 239                              0
# 240                              0
# 241                              0
# 242                              0
# 243                              0
#
#       campaign.start_date     campaign.end_date        campaign.__typename  \
# 0    2022-08-05T17:00:03Z  2023-08-05T17:00:03Z  ProductDetailCampaignType
# 1    2022-08-25T16:54:57Z  2023-08-25T16:54:57Z  ProductDetailCampaignType
# 2    2022-02-08T14:35:08Z  2023-02-08T14:27:08Z  ProductDetailCampaignType
# 3    2022-02-08T14:35:08Z  2023-02-08T14:27:08Z  ProductDetailCampaignType
# 4    2022-08-25T16:54:57Z  2023-08-25T16:54:57Z  ProductDetailCampaignType
# ..                    ...                   ...                        ...
# 239                                              ProductDetailCampaignType
# 240                                              ProductDetailCampaignType
# 241                                              ProductDetailCampaignType
# 242                                              ProductDetailCampaignType
# 243                                              ProductDetailCampaignType
#
#      stats.reviewCount  stats.rating  stats.__typename category.id  \
# 0                 3098            98  ProductListStats           0
# 1                 2545            97  ProductListStats           0
# 2                 2527            98  ProductListStats           0
# 3                 1983            97  ProductListStats           0
# 4                 1519            96  ProductListStats           0
# ..                 ...           ...               ...         ...
# 239                  2           100  ProductListStats           0
# 240                  1            80  ProductListStats           0
# 241                  1           100  ProductListStats           0
# 242                  0             0  ProductListStats           0
# 243                  0             0  ProductListStats           0
#
#      category.__typename
# 0    ProductListCategory
# 1    ProductListCategory
# 2    ProductListCategory
# 3    ProductListCategory
# 4    ProductListCategory
# ..                   ...
# 239  ProductListCategory
# 240  ProductListCategory
# 241  ProductListCategory
# 242  ProductListCategory
# 243  ProductListCategory
#
# [244 rows x 28 columns]

# %%
url_review = "https://gql.tokopedia.com/graphql/productReviewList"
page_review = 1
result_review = []

for i in range(0, len(product_list)):
    product = product_list[i]

    while True:
        payload_review = [{
            'operationName': "productReviewList",
            'variables': {
                "filterBy": "", 
                "limit": 500, 
                "page": page_review,
                "productID":f"{product_list[i]['product_id']}", 
                "sortBy": 'create_time desc'
            },
            'query': 'query productReviewList($productID: String!, $page: Int!, $limit: Int!, $sortBy: String, $filterBy: String) {\n  productrevGetProductReviewList(productID: $productID, page: $page, limit: $limit, sortBy: $sortBy, filterBy: $filterBy) {\n    productID\n    list {\n      id: feedbackID\n      variantName\n      message\n      productRating\n      reviewCreateTime\n      reviewCreateTimestamp\n      isReportable\n      isAnonymous\n      imageAttachments {\n        attachmentID\n        imageThumbnailUrl\n        imageUrl\n        __typename\n      }\n      videoAttachments {\n        attachmentID\n        videoUrl\n        __typename\n      }\n      reviewResponse {\n        message\n        createTime\n        __typename\n      }\n      user {\n        userID\n        fullName\n        image\n        url\n        __typename\n      }\n      likeDislike {\n        totalLike\n        likeStatus\n        __typename\n      }\n      stats {\n        key\n        formatted\n        count\n        __typename\n      }\n      badRatingReasonFmt\n      __typename\n    }\n    shop {\n      shopID\n      name\n      url\n      image\n      __typename\n    }\n    hasNext\n    totalReviews\n    __typename\n  }\n}\n'
        }]

        response_review = requests.post(url_review, json=payload_review)

        data_review = response_review.json()

        for review in data_review[0]['data']['productrevGetProductReviewList']['list']:
            review.update({"product":product})
            result_review.append(review)
        
        if data_review[0]['data']['productrevGetProductReviewList']['hasNext'] == False:
            break

        page_review += 1
    print("Scraping product no. "+str(i)+" id: " + product_list[i]['product_id'] + " review done")
# Out:
# Scraping product no. 0 id: 970526230 review done
# Scraping product no. 1 id: 1740845088 review done
# Scraping product no. 2 id: 970555659 review done
# Scraping product no. 3 id: 1134145572 review done
# Scraping product no. 4 id: 1740833839 review done
# Scraping product no. 5 id: 2907476721 review done
# Scraping product no. 6 id: 2698923470 review done
# Scraping product no. 7 id: 1317398339 review done
# Scraping product no. 8 id: 1948834995 review done
# Scraping product no. 9 id: 1429339590 review done
# Scraping product no. 10 id: 757174295 review done
# Scraping product no. 11 id: 1822976370 review done
# Scraping product no. 12 id: 2434847170 review done
# Scraping product no. 13 id: 2156774880 review done
# Scraping product no. 14 id: 1771126742 review done
# Scraping product no. 15 id: 1482570836 review done
# Scraping product no. 16 id: 2908041032 review done
# Scraping product no. 17 id: 1292832392 review done
# Scraping product no. 18 id: 2079708275 review done
# Scraping product no. 19 id: 2907727560 review done
# Scraping product no. 20 id: 2150555065 review done
# Scraping product no. 21 id: 2434835114 review done
# Scraping product no. 22 id: 2150546771 review done
# Scraping product no. 23 id: 2907799386 review done
# Scraping product no. 24 id: 3271739279 review done
# Scraping product no. 25 id: 2908056315 review done
# Scraping product no. 26 id: 1536844553 review done
# Scraping product no. 27 id: 1676537868 review done
# Scraping product no. 28 id: 2908118903 review done
# Scraping product no. 29 id: 2644215422 review done
# Scraping product no. 30 id: 6737082875 review done
# Scraping product no. 31 id: 3401118448 review done
# Scraping product no. 32 id: 4881128692 review done
# Scraping product no. 33 id: 2907809939 review done
# Scraping product no. 34 id: 1482553404 review done
# Scraping product no. 35 id: 3271779016 review done
# Scraping product no. 36 id: 6924244925 review done
# Scraping product no. 37 id: 6515187468 review done
# Scraping product no. 38 id: 3378588039 review done
# Scraping product no. 39 id: 6489023024 review done
# Scraping product no. 40 id: 4881150310 review done
# Scraping product no. 41 id: 3970783958 review done
# Scraping product no. 42 id: 4047738982 review done
# Scraping product no. 43 id: 2907992184 review done
# Scraping product no. 44 id: 4718796388 review done
# Scraping product no. 45 id: 6737136909 review done
# Scraping product no. 46 id: 5672722136 review done
# Scraping product no. 47 id: 6489076319 review done
# Scraping product no. 48 id: 5672758341 review done
# Scraping product no. 49 id: 2766325950 review done
# Scraping product no. 50 id: 6737157777 review done
# Scraping product no. 51 id: 6737067402 review done
# Scraping product no. 52 id: 6123786296 review done
# Scraping product no. 53 id: 2320275821 review done
# Scraping product no. 54 id: 4029797654 review done
# Scraping product no. 55 id: 2320316487 review done
# Scraping product no. 56 id: 6737352956 review done
# Scraping product no. 57 id: 3262702021 review done
# Scraping product no. 58 id: 6830305044 review done
# Scraping product no. 59 id: 6737267156 review done
# Scraping product no. 60 id: 4061660345 review done
# Scraping product no. 61 id: 6515453185 review done
# Scraping product no. 62 id: 7041665771 review done
# Scraping product no. 63 id: 7030988681 review done
# Scraping product no. 64 id: 7041672093 review done
# Scraping product no. 65 id: 7031010907 review done
# Scraping product no. 66 id: 6737334698 review done
# Scraping product no. 67 id: 6737285554 review done
# Scraping product no. 68 id: 6515249095 review done
# Scraping product no. 69 id: 4029844332 review done
# Scraping product no. 70 id: 1738448998 review done
# Scraping product no. 71 id: 7048399455 review done
# Scraping product no. 72 id: 7048386812 review done
# Scraping product no. 73 id: 7048342114 review done
# Scraping product no. 74 id: 7048307686 review done
# Scraping product no. 75 id: 6830332353 review done
# Scraping product no. 76 id: 4180003448 review done
# Scraping product no. 77 id: 1263887710 review done
# Scraping product no. 78 id: 1263893054 review done
# Scraping product no. 79 id: 970536663 review done
# Scraping product no. 80 id: 1184674014 review done
# Scraping product no. 81 id: 2699002951 review done
# Scraping product no. 82 id: 2698937668 review done
# Scraping product no. 83 id: 2698907735 review done
# Scraping product no. 84 id: 2309894869 review done
# Scraping product no. 85 id: 2699025552 review done
# Scraping product no. 86 id: 2907524876 review done
# Scraping product no. 87 id: 706341528 review done
# Scraping product no. 88 id: 2907463811 review done
# Scraping product no. 89 id: 1584813106 review done
# Scraping product no. 90 id: 2435769676 review done
# Scraping product no. 91 id: 1415694107 review done
# Scraping product no. 92 id: 2907537226 review done
# Scraping product no. 93 id: 1292849999 review done
# Scraping product no. 94 id: 2435759437 review done
# Scraping product no. 95 id: 2119950527 review done
# Scraping product no. 96 id: 2343739052 review done
# Scraping product no. 97 id: 2907447335 review done
# Scraping product no. 98 id: 2907741567 review done
# Scraping product no. 99 id: 2907717878 review done
# Scraping product no. 100 id: 2644105839 review done
# Scraping product no. 101 id: 2042366350 review done
# Scraping product no. 102 id: 1771133193 review done
# Scraping product no. 103 id: 2644126819 review done
# Scraping product no. 104 id: 2908088894 review done
# Scraping product no. 105 id: 1927880963 review done
# Scraping product no. 106 id: 1699935942 review done
# Scraping product no. 107 id: 1927887140 review done
# Scraping product no. 108 id: 706335954 review done
# Scraping product no. 109 id: 2089672185 review done
# Scraping product no. 110 id: 2907705211 review done
# Scraping product no. 111 id: 1968784204 review done
# Scraping product no. 112 id: 706344034 review done
# Scraping product no. 113 id: 1559497868 review done
# Scraping product no. 114 id: 2907762729 review done
# Scraping product no. 115 id: 1736985660 review done
# Scraping product no. 116 id: 2070350945 review done
# Scraping product no. 117 id: 3673047481 review done
# Scraping product no. 118 id: 1603085867 review done
# Scraping product no. 119 id: 866497950 review done
# Scraping product no. 120 id: 662253311 review done
# Scraping product no. 121 id: 1666700925 review done
# Scraping product no. 122 id: 1940191190 review done
# Scraping product no. 123 id: 1666695428 review done
# Scraping product no. 124 id: 5042182345 review done
# Scraping product no. 125 id: 1771072947 review done
# Scraping product no. 126 id: 2070359012 review done
# Scraping product no. 127 id: 1784468842 review done
# Scraping product no. 128 id: 595626626 review done
# Scraping product no. 129 id: 1546702753 review done
# Scraping product no. 130 id: 1765163728 review done
# Scraping product no. 131 id: 4718829348 review done
# Scraping product no. 132 id: 603886868 review done
# Scraping product no. 133 id: 5042002979 review done
# Scraping product no. 134 id: 2119979103 review done
# Scraping product no. 135 id: 1584744434 review done
# Scraping product no. 136 id: 706339056 review done
# Scraping product no. 137 id: 757168288 review done
# Scraping product no. 138 id: 2644225260 review done
# Scraping product no. 139 id: 632193006 review done
# Scraping product no. 140 id: 595629521 review done
# Scraping product no. 141 id: 866499247 review done
# Scraping product no. 142 id: 756576045 review done
# Scraping product no. 143 id: 757164112 review done
# Scraping product no. 144 id: 2089656839 review done
# Scraping product no. 145 id: 2907827957 review done
# Scraping product no. 146 id: 1268104637 review done
# Scraping product no. 147 id: 1268096606 review done
# Scraping product no. 148 id: 796213966 review done
# Scraping product no. 149 id: 1940196146 review done
# Scraping product no. 150 id: 1699946062 review done
# Scraping product no. 151 id: 5236606589 review done
# Scraping product no. 152 id: 757158225 review done
# Scraping product no. 153 id: 736077530 review done
# Scraping product no. 154 id: 2434874442 review done
# Scraping product no. 155 id: 1771058919 review done
# Scraping product no. 156 id: 1546673174 review done
# Scraping product no. 157 id: 1425167544 review done
# Scraping product no. 158 id: 5672924566 review done
# Scraping product no. 159 id: 796236465 review done
# Scraping product no. 160 id: 783359052 review done
# Scraping product no. 161 id: 1700110219 review done
# Scraping product no. 162 id: 756569894 review done
# Scraping product no. 163 id: 1737022709 review done
# Scraping product no. 164 id: 3378607109 review done
# Scraping product no. 165 id: 632135514 review done
# Scraping product no. 166 id: 603975986 review done
# Scraping product no. 167 id: 6924257357 review done
# Scraping product no. 168 id: 757160856 review done
# Scraping product no. 169 id: 727719708 review done
# Scraping product no. 170 id: 1823892802 review done
# Scraping product no. 171 id: 592272265 review done
# Scraping product no. 172 id: 757169518 review done
# Scraping product no. 173 id: 562230118 review done
# Scraping product no. 174 id: 2434882233 review done
# Scraping product no. 175 id: 1591838791 review done
# Scraping product no. 176 id: 1700099165 review done
# Scraping product no. 177 id: 1189682059 review done
# Scraping product no. 178 id: 6123868423 review done
# Scraping product no. 179 id: 2101130715 review done
# Scraping product no. 180 id: 757166814 review done
# Scraping product no. 181 id: 727719186 review done
# Scraping product no. 182 id: 6310045478 review done
# Scraping product no. 183 id: 1583173010 review done
# Scraping product no. 184 id: 651635972 review done
# Scraping product no. 185 id: 6123844972 review done
# Scraping product no. 186 id: 641983083 review done
# Scraping product no. 187 id: 662791139 review done
# Scraping product no. 188 id: 1125431489 review done
# Scraping product no. 189 id: 3454554565 review done
# Scraping product no. 190 id: 4173993261 review done
# Scraping product no. 191 id: 1565736443 review done
# Scraping product no. 192 id: 429787674 review done
# Scraping product no. 193 id: 757162272 review done
# Scraping product no. 194 id: 4294221594 review done
# Scraping product no. 195 id: 1738431231 review done
# Scraping product no. 196 id: 1238535153 review done
# Scraping product no. 197 id: 1565738869 review done
# Scraping product no. 198 id: 796226499 review done
# Scraping product no. 199 id: 757170468 review done
# Scraping product no. 200 id: 6515641967 review done
# Scraping product no. 201 id: 1738440447 review done
# Scraping product no. 202 id: 1547247796 review done
# Scraping product no. 203 id: 592274883 review done
# Scraping product no. 204 id: 6515150124 review done
# Scraping product no. 205 id: 647070750 review done
# Scraping product no. 206 id: 595631897 review done
# Scraping product no. 207 id: 581505454 review done
# Scraping product no. 208 id: 1591839366 review done
# Scraping product no. 209 id: 603885860 review done
# Scraping product no. 210 id: 2457219330 review done
# Scraping product no. 211 id: 1228849586 review done
# Scraping product no. 212 id: 1569026531 review done
# Scraping product no. 213 id: 2471390744 review done
# Scraping product no. 214 id: 1591838173 review done
# Scraping product no. 215 id: 1223707184 review done
# Scraping product no. 216 id: 603887916 review done
# Scraping product no. 217 id: 1228853465 review done
# Scraping product no. 218 id: 641984716 review done
# Scraping product no. 219 id: 595631029 review done
# Scraping product no. 220 id: 1657844929 review done
# Scraping product no. 221 id: 641984327 review done
# Scraping product no. 222 id: 595624911 review done
# Scraping product no. 223 id: 2087707362 review done
# Scraping product no. 224 id: 1862181251 review done
# Scraping product no. 225 id: 1486964966 review done
# Scraping product no. 226 id: 429791326 review done
# Scraping product no. 227 id: 1923388884 review done
# Scraping product no. 228 id: 623152987 review done
# Scraping product no. 229 id: 6830235917 review done
# Scraping product no. 230 id: 2054798347 review done
# Scraping product no. 231 id: 1238510324 review done
# Scraping product no. 232 id: 2087726782 review done
# Scraping product no. 233 id: 1569023430 review done
# Scraping product no. 234 id: 427147496 review done
# Scraping product no. 235 id: 6994213778 review done
# Scraping product no. 236 id: 2618292662 review done
# Scraping product no. 237 id: 1547122159 review done
# Scraping product no. 238 id: 1359668982 review done
# Scraping product no. 239 id: 623153918 review done
# Scraping product no. 240 id: 6830389352 review done
# Scraping product no. 241 id: 6830220325 review done
# Scraping product no. 242 id: 6994255922 review done
# Scraping product no. 243 id: 641982670 review done

# %%
df_review = pd.json_normalize(result_review)
df_review
# Out:
#              id variantName  \
# 0     802422239
# 1     800763404
# 2     797983688
# 3     795678911
# 4     786485872
# ...         ...         ...
# 2196  307790714
# 2197  303766407
# 2198  289832098
# 2199  289004797
# 2200  270773344
#
#                                                 message  productRating  \
# 0                                                                    5
# 1                               kok tipis ya...sekarang              2
# 2     sdh sampai ..ini yg kesekian x nya saya beli ....              5
# 3                        tipis\nKarena murah mungkin ya              5
# 4                                                Mantul              5
# ...                                                 ...            ...
# 2196             barang sudah sampai gan, terima kasih               5
# 2197                                              okehh              5
# 2198           Sesuai deskripsi dan produk original 910              5
# 2199                                              bagus              5
# 2200                               bareng tebal,ok juga              5
#
#      reviewCreateTime    reviewCreateTimestamp  isReportable  isAnonymous  \
# 0          1669895707              2 hari lalu         False         True
# 1          1669663931              5 hari lalu         False        False
# 2          1669236275            1 minggu lalu         False        False
# 3          1668878387            2 minggu lalu         False        False
# 4          1667581137            4 minggu lalu         False        False
# ...               ...                      ...           ...          ...
# 2196       1610549982  Lebih dari 1 tahun lalu         False        False
# 2197       1609944908  Lebih dari 1 tahun lalu         False        False
# 2198       1607703617  Lebih dari 1 tahun lalu         False        False
# 2199       1607595545  Lebih dari 1 tahun lalu         False        False
# 2200       1604573589  Lebih dari 1 tahun lalu         False        False
#
#                                        imageAttachments videoAttachments  ...  \
# 0     [{'attachmentID': '92279485', 'imageThumbnailU...               []  ...
# 1                                                    []               []  ...
# 2     [{'attachmentID': '91700515', 'imageThumbnailU...               []  ...
# 3                                                    []               []  ...
# 4                                                    []               []  ...
# ...                                                 ...              ...  ...
# 2196                                                 []               []  ...
# 2197  [{'attachmentID': '28216781', 'imageThumbnailU...               []  ...
# 2198                                                 []               []  ...
# 2199                                                 []               []  ...
# 2200                                                 []               []  ...
#
#      product.campaign.__typename product.label  \
# 0      ProductDetailCampaignType            []
# 1      ProductDetailCampaignType            []
# 2      ProductDetailCampaignType            []
# 3      ProductDetailCampaignType            []
# 4      ProductDetailCampaignType            []
# ...                          ...           ...
# 2196   ProductDetailCampaignType            []
# 2197   ProductDetailCampaignType            []
# 2198   ProductDetailCampaignType            []
# 2199   ProductDetailCampaignType            []
# 2200   ProductDetailCampaignType            []
#
#                                    product.label_groups  \
# 0     [{'position': 'integrity', 'title': 'Terjual 5...
# 1     [{'position': 'integrity', 'title': 'Terjual 5...
# 2     [{'position': 'integrity', 'title': 'Terjual 5...
# 3     [{'position': 'integrity', 'title': 'Terjual 5...
# 4     [{'position': 'integrity', 'title': 'Terjual 5...
# ...                                                 ...
# 2196  [{'position': 'status', 'title': 'Stok Habis',...
# 2197  [{'position': 'status', 'title': 'Stok Habis',...
# 2198  [{'position': 'status', 'title': 'Stok Habis',...
# 2199  [{'position': 'status', 'title': 'Stok Habis',...
# 2200  [{'position': 'status', 'title': 'Stok Habis',...
#
#                                           product.badge  \
# 0     [{'title': 'Official Store', 'image_url': 'htt...
# 1     [{'title': 'Official Store', 'image_url': 'htt...
# 2     [{'title': 'Official Store', 'image_url': 'htt...
# 3     [{'title': 'Official Store', 'image_url': 'htt...
# 4     [{'title': 'Official Store', 'image_url': 'htt...
# ...                                                 ...
# 2196  [{'title': 'Official Store', 'image_url': 'htt...
# 2197  [{'title': 'Official Store', 'image_url': 'htt...
# 2198  [{'title': 'Official Store', 'image_url': 'htt...
# 2199  [{'title': 'Official Store', 'image_url': 'htt...
# 2200  [{'title': 'Official Store', 'image_url': 'htt...
#
#      product.stats.reviewCount product.stats.rating product.stats.__typename  \
# 0                         3098                   98         ProductListStats
# 1                         3098                   98         ProductListStats
# 2                         3098                   98         ProductListStats
# 3                         3098                   98         ProductListStats
# 4                         3098                   98         ProductListStats
# ...                        ...                  ...                      ...
# 2196                      5084                   97         ProductListStats
# 2197                      5084                   97         ProductListStats
# 2198                      5084                   97         ProductListStats
# 2199                      5084                   97         ProductListStats
# 2200                      5084                   97         ProductListStats
#
#      product.category.id product.category.__typename     product.__typename
# 0                      0         ProductListCategory  ShopProductListDetail
# 1                      0         ProductListCategory  ShopProductListDetail
# 2                      0         ProductListCategory  ShopProductListDetail
# 3                      0         ProductListCategory  ShopProductListDetail
# 4                      0         ProductListCategory  ShopProductListDetail
# ...                  ...                         ...                    ...
# 2196                   0         ProductListCategory  ShopProductListDetail
# 2197                   0         ProductListCategory  ShopProductListDetail
# 2198                   0         ProductListCategory  ShopProductListDetail
# 2199                   0         ProductListCategory  ShopProductListDetail
# 2200                   0         ProductListCategory  ShopProductListDetail
#
# [2201 rows x 52 columns]

# %%
from pymongo import MongoClient

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
localhost = "mongodb://localhost:27017"

# %%
client = MongoClient(localhost)
db = client['tokopedia'] 
collection = db['910']

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['tokopediaProductReview'] 
collection = db['miyako']

# %%
collection.insert_many(result_review)

# %%
data = collection.find()

df = pd.json_normalize(data)
df
# Out:
#                            _id                                    id  \
# 0     637e18d68ccf7446afd010e3  73a68739-1237-49f1-821f-6261cb90c5fc
# 1     637e18d68ccf7446afd010e4  75702197-fba0-4200-a0f0-52dd7c8c332c
# 2     637e18d68ccf7446afd010e5  2a91401f-8e11-4b90-8027-7605a8b89ba3
# 3     637e18d68ccf7446afd010e6  5c94e856-63aa-40c5-be9d-8931160c049d
# 4     637e18d68ccf7446afd010e7  3d98c992-e2c9-454c-aa1a-a957f7ac5764
# ...                        ...                                   ...
# 8348  637e18d68ccf7446afd0317f  c5025d0d-a0d3-48ed-827e-11ce51f6cacc
# 8349  637e18d68ccf7446afd03180  40b76884-0c7b-4f71-ad22-93d237b1ad45
# 8350  637e18d68ccf7446afd03181  236dc7b3-5a93-43fb-8e1f-2bac06cfcc46
# 8351  637e18d68ccf7446afd03182  86009efb-3533-476f-bfdc-fba46fe8f399
# 8352  637e18d68ccf7446afd03183  893e13a5-337b-4856-b471-4f292ad587df
#
#                  name  rating    createdDate    updatedDate  likes  \
# 0                 Aro       5  1668487909680  1668487909680      0
# 1             MUHAMAD       5  1668437644933  1668437644943      0
# 2                Dewi       5  1668379161516  1668379161516      0
# 3               V***a       5  1668228006469  1668228006479      0
# 4     iv***@gmail.com       5  1668162659023  1668162659032      0
# ...               ...     ...            ...            ...    ...
# 8348            F***a       5  1624382386487  1624382386584      0
# 8349            Dolar       5  1616256165498  1624382386585      0
# 8350            G***a       5  1613015902079  1624382386585      0
# 8351            Retno       5  1610624999957  1624382386585      0
# 8352            N***a       5  1609178240861  1624382386585      0
#
#       showPriority  verifiedBuyer  edited  ... product.soldRangeCount.en  \
# 0                2           True   False  ...                     1,9 k
# 1                2           True   False  ...                     1,9 k
# 2                2           True   False  ...                     1,9 k
# 3                2           True   False  ...                     1,9 k
# 4                2           True   False  ...                     1,9 k
# ...            ...            ...     ...  ...                       ...
# 8348             3           True   False  ...                        45
# 8349             4           True   False  ...                        45
# 8350             3           True   False  ...                        45
# 8351             3           True   False  ...                        45
# 8352             3           True   False  ...                        45
#
#      product.soldRangeCount.id                  product.categoryIdHierarchy  \
# 0                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# 1                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# 2                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# 3                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# 4                       1,9 rb  [53203, PE-1000098, PE-1000201, SC-1000005]
# ...                        ...                                          ...
# 8348                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
# 8349                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
# 8350                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
# 8351                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
# 8352                        45  [53203, MA-1000015, RI-1000006, EY-1000001]
#
#       product.cartLogisticOptions product.merchantVoucherMessage  \
# 0                              []           No voucher available
# 1                              []           No voucher available
# 2                              []           No voucher available
# 3                              []           No voucher available
# 4                              []           No voucher available
# ...                           ...                            ...
# 8348                           []           No voucher available
# 8349                           []           No voucher available
# 8350                           []           No voucher available
# 8351                           []           No voucher available
# 8352                           []           No voucher available
#
#       product.preorder  product.official  \
# 0                False              True
# 1                False              True
# 2                False              True
# 3                False              True
# 4                False              True
# ...                ...               ...
# 8348             False              True
# 8349             False              True
# 8350             False              True
# 8351             False              True
# 8352             False              True
#
#                                                 content title  \
# 0                                                   NaN   NaN
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# ...                                                 ...   ...
# 8348                                     Very pigmented   NaN
# 8349
# 8350  so pretty... warnanya pigmented banget, hargan...   NaN
# 8351    good seller. trusted. barang sampai dengan aman
# 8352            Bagus bgt. Pigmented dan warnanya ok ok   NaN
#
#      product.price.strikeThroughPriceDisplay
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 8348                                     NaN
# 8349                                     NaN
# 8350                                     NaN
# 8351                                     NaN
# 8352                                     NaN
#
# [8353 rows x 65 columns]
