# %%
import requests
import pandas as pd
from pymongo import MongoClient

# %%
store_id = "86817902"

# %%
url = "https://shopee.co.id/api/v4/shop/search_items"

querystring = {
    "filter_sold_out":"1",
    "limit":"100",
    "offset":"0",
    "order":"desc",
    "shopid":f"{store_id}",
    "sort_by":"pop",
    "use_case":"4"
}

payload = ""
headers = {
        'authority': 'shopee.co.id',
        'accept': '*/*',
        'accept-encoding':'gzip, deflate, br',
        'accept-language':'en-US,en;q=0.9,id;q=0.8,ja;q=0.7',
        'cookie': '__LOCALE__null=ID; _gcl_au=1.1.25966848.1662450885; csrftoken=8Qs3cIItKMOm32ijJfpHIQsyhuB16wXF; REC_T_ID=2c5bbe52-2db9-11ed-a70a-b47af1499c50; SPC_F=S6e8zBu7JvGYL9fRdFwNdSnTqTyIZDbX; REC_T_ID=2c5e81b4-2db9-11ed-8680-7ec556a0edb3; _fbp=fb.2.1662450886480.1740229127; _QPWSDCXHZQA=e658f935-658f-4916-a174-98f35939b136; _tt_enable_cookie=1; _ttp=52b24f8e-1fb9-43b7-958b-2d70f9867fdf; G_ENABLED_IDPS=google; SPC_CLIENTID=UzZlOHpCdTdKdkdZbpzbvkmbybnbthea; _ga_CGXK257VSB=GS1.1.1663580710.1.0.1663580710.60.0.0; SPC_U=-; SPC_EC=-; SPC_IA=-1; SPC_T_ID="9VDb5zUpQqub2x5zBx2xMpQVF1qJl/YbOaa8z9oUWKv/i6kw8uwzPj3VvlWCT0RAz15X9+54WE7o1fgtpVw3w4lgrC+Xs7zmYNBhHxVufB0="; SPC_T_IV="swXjMq/Knt/saekFNKvhqQ=="; SPC_T_ID=9VDb5zUpQqub2x5zBx2xMpQVF1qJl/YbOaa8z9oUWKv/i6kw8uwzPj3VvlWCT0RAz15X9+54WE7o1fgtpVw3w4lgrC+Xs7zmYNBhHxVufB0=; SPC_T_IV=swXjMq/Knt/saekFNKvhqQ==; SPC_R_T_ID=9VDb5zUpQqub2x5zBx2xMpQVF1qJl/YbOaa8z9oUWKv/i6kw8uwzPj3VvlWCT0RAz15X9+54WE7o1fgtpVw3w4lgrC+Xs7zmYNBhHxVufB0=; SPC_R_T_IV=swXjMq/Knt/saekFNKvhqQ==; _med=refer; SPC_SI=4yKGYwAAAABCUFZGYTc1aIKXWwAAAAAAS2EwYlQ0emc=; _gid=GA1.3.1714972316.1669958743; AMP_TOKEN=$NOT_FOUND; _ga_SW6D8G0HXK=GS1.1.1669992620.40.1.1669993445.5.0.0; _ga=GA1.1.1338607349.1662450890; _dc_gtm_UA-61904553-8=1; shopee_webUnique_ccd=eqy0oBYK/WperNtiIoRuqQ==|XDTYIcfuOYyUTjpZA+SBG43QNVhRk/4jvuv9BJqhx1oUoC17wEKtL/UsloYIozB354AmHYJgHGz/yNv1+uKQkvdxHwPyxvcqSkPt|PXIV1K81ru6ciOFL|06|3; ds=c604b817f1d9d9bdf4bb3d6105e2d9c5; cto_bundle=yITfY19XdDluZ1Vza3psTkxqYUpqQnM3MU0zbmtTeXJYcHRmdjJIRnQ1bTFiMjh2MDV3RVpJM3JDemFQbE11NkxsM002YzdaYkV2QXhONG1pajNZRVVSOFhURkxIc3c5MThlcWtKcXo0S0dpYTc0Y1RRbUJPSWtTTTBnVDFXRWlFOTB6T3haa214M2tMMVYwa1pEbXY0R3YzNlElM0QlM0Q',
        'if-none-match-': '55b03-1611d614b4a7259b2ee90e88c8146174',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    }
response = requests.request(
    "GET", url, headers=headers, params=querystring)

data = response.json()
product_list = []

for offset in range(0, data['total_count'], 100):
    querystring = {
        "filter_sold_out":"1",
        "limit":"100",
        "offset":f"{offset}",
        "order":"desc",
        "shopid":f"{store_id}",
        "sort_by":"pop",
        "use_case":"4"
    }
    response = requests.request(
    "GET", url, headers=headers, params=querystring)

    data = response.json()

    for product in data["items"]:
        product_list.append(product)

# %%
df = pd.json_normalize(product_list)
df
# Out:
#           itemid    shopid  item_basic.itemid  item_basic.shopid  \
# 0     2940054992  86817902         2940054992           86817902
# 1     5627405947  86817902         5627405947           86817902
# 2    13937760334  86817902        13937760334           86817902
# 3     6551334114  86817902         6551334114           86817902
# 4     5027404447  86817902         5027404447           86817902
# ..           ...       ...                ...                ...
# 252   5405776722  86817902         5405776722           86817902
# 253   5261385728  86817902         5261385728           86817902
# 254   4005768360  86817902         4005768360           86817902
# 255   2978471512  86817902         2978471512           86817902
# 256   2814946919  86817902         2814946919           86817902
#
#                                        item_basic.name  \
# 0        910 Nineten Socks FUKA QUARTER Hitam/abu/biru
# 1                         910 Nineten Socks Abu/Oranye
# ...

# %%
url_review = "https://shopee.co.id/api/v2/item/get_ratings"

result_review = []

for i in range(0, len(product_list)):
    querystring_review = {
        "filter":"0",
        "flag":"1",
        "itemid":f"{product_list[i]['itemid']}",
        "limit":"50",
        "offset":"0",
        "shopid":f"{product_list[i]['shopid']}",
        "type":"0"
    }
    headers_review = {
        'authority': 'shopee.co.id',
        'accept': '*/*',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language':'en-US,en;q=0.9,id;q=0.8,ja;q=0.7',
        'if-none-match-': '55b03-5d3a1cd914f17cf4a6796de72977d3ba',
        'cookie': '__LOCALE__null=ID; _gcl_au=1.1.25966848.1662450885; csrftoken=8Qs3cIItKMOm32ijJfpHIQsyhuB16wXF; REC_T_ID=2c5bbe52-2db9-11ed-a70a-b47af1499c50; SPC_F=S6e8zBu7JvGYL9fRdFwNdSnTqTyIZDbX; REC_T_ID=2c5e81b4-2db9-11ed-8680-7ec556a0edb3; _fbp=fb.2.1662450886480.1740229127; _QPWSDCXHZQA=e658f935-658f-4916-a174-98f35939b136; _tt_enable_cookie=1; _ttp=52b24f8e-1fb9-43b7-958b-2d70f9867fdf; G_ENABLED_IDPS=google; SPC_CLIENTID=UzZlOHpCdTdKdkdZbpzbvkmbybnbthea; _ga_CGXK257VSB=GS1.1.1663580710.1.0.1663580710.60.0.0; SPC_U=-; SPC_EC=-; SPC_IA=-1; SPC_T_ID="9VDb5zUpQqub2x5zBx2xMpQVF1qJl/YbOaa8z9oUWKv/i6kw8uwzPj3VvlWCT0RAz15X9+54WE7o1fgtpVw3w4lgrC+Xs7zmYNBhHxVufB0="; SPC_T_IV="swXjMq/Knt/saekFNKvhqQ=="; SPC_T_ID=9VDb5zUpQqub2x5zBx2xMpQVF1qJl/YbOaa8z9oUWKv/i6kw8uwzPj3VvlWCT0RAz15X9+54WE7o1fgtpVw3w4lgrC+Xs7zmYNBhHxVufB0=; SPC_T_IV=swXjMq/Knt/saekFNKvhqQ==; SPC_R_T_ID=9VDb5zUpQqub2x5zBx2xMpQVF1qJl/YbOaa8z9oUWKv/i6kw8uwzPj3VvlWCT0RAz15X9+54WE7o1fgtpVw3w4lgrC+Xs7zmYNBhHxVufB0=; SPC_R_T_IV=swXjMq/Knt/saekFNKvhqQ==; _med=refer; SPC_SI=4yKGYwAAAABCUFZGYTc1aIKXWwAAAAAAS2EwYlQ0emc=; _gid=GA1.3.1714972316.1669958743; _ga=GA1.1.1338607349.1662450890; cto_bundle=yITfY19XdDluZ1Vza3psTkxqYUpqQnM3MU0zbmtTeXJYcHRmdjJIRnQ1bTFiMjh2MDV3RVpJM3JDemFQbE11NkxsM002YzdaYkV2QXhONG1pajNZRVVSOFhURkxIc3c5MThlcWtKcXo0S0dpYTc0Y1RRbUJPSWtTTTBnVDFXRWlFOTB6T3haa214M2tMMVYwa1pEbXY0R3YzNlElM0QlM0Q; _ga_SW6D8G0HXK=GS1.1.1670023016.41.0.1670023016.60.0.0; shopee_webUnique_ccd=qxrEEB4dwt42L8uUGfh1jQ==|XDTZIcfuOYyUTjpZA+SBG43QNVhRk/4jvuv9BJqhx1oUoC17wEKtL/UsloYIozB354AmHYJgHGz/yNv08+ubkvN3Fwr4z/cqSkPt|PXIV1K81ru6ciOFL|06|3; ds=2bb2fda8c932d31fb6fcf13361b19b40',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.56',
    }
    response_review = requests.request("GET", url=url_review, headers=headers_review, params=querystring_review,verify=False).json()

    for offset in range(0, response_review["data"]["item_rating_summary"]['rating_total'], 50):
        querystring_review2 = {
            "filter":"0",
            "flag":"1",
            "itemid":f"{product_list[i]['itemid']}",
            "limit":"50",
            "offset":f"{offset}",
            "shopid":f"{product_list[i]['shopid']}",
            "type":"0"
        }

        response_review2 = requests.request("GET", url=url_review, headers=headers_review, params=querystring_review2,verify=False)
        
        data_review = response_review2.json()
        try:
            for review in data_review['data']['ratings']:
                result_review.append(review)
        except Exception as e:
            print("scrape review product no. "+str(i)+" id: " + str(product_list[i]['itemid']) + " stoped at offset: "+str(offset))
            print(e)
        print("scraped review product no. "+str(i)+" id: " + str(product_list[i]['itemid']) + " offset: "+str(offset))
    print("Scraping product no. "+str(i)+" id: " + str(product_list[i]['itemid']) + " review done")
# Out:
# scraped review product no. 0 id: 2940054992 offset: 0
# scraped review product no. 0 id: 2940054992 offset: 50
# scraped review product no. 0 id: 2940054992 offset: 100
# scraped review product no. 0 id: 2940054992 offset: 150
# scraped review product no. 0 id: 2940054992 offset: 200
# scraped review product no. 0 id: 2940054992 offset: 250
# scraped review product no. 0 id: 2940054992 offset: 300
# scraped review product no. 0 id: 2940054992 offset: 350
# scraped review product no. 0 id: 2940054992 offset: 400
# scraped review product no. 0 id: 2940054992 offset: 450
# scraped review product no. 0 id: 2940054992 offset: 500
# scraped review product no. 0 id: 2940054992 offset: 550
# scraped review product no. 0 id: 2940054992 offset: 600
# scraped review product no. 0 id: 2940054992 offset: 650
# scraped review product no. 0 id: 2940054992 offset: 700
# scraped review product no. 0 id: 2940054992 offset: 750
# scraped review product no. 0 id: 2940054992 offset: 800
# ...

# %%
url_review = "https://shopee.co.id/api/v2/item/get_ratings"

querystring_review = {
    "filter":"0",
    "flag":"1",
    "itemid":"5224704572",
    "limit":"50",
    "offset":"3000",
    "shopid":"32427818",
    "type":"0"
}

headers_review = {
    'authority': 'shopee.co.id',
    'accept': '*/*',
    'accept-encoding':'gzip, deflate, br',
    'accept-language':'en-US,en;q=0.9,id;q=0.8,ja;q=0.7',
    'cookie': '__LOCALE__null=ID; _gcl_au=1.1.25966848.1662450885; csrftoken=8Qs3cIItKMOm32ijJfpHIQsyhuB16wXF; REC_T_ID=2c5bbe52-2db9-11ed-a70a-b47af1499c50; SPC_F=S6e8zBu7JvGYL9fRdFwNdSnTqTyIZDbX; REC_T_ID=2c5e81b4-2db9-11ed-8680-7ec556a0edb3; _fbp=fb.2.1662450886480.1740229127; _QPWSDCXHZQA=e658f935-658f-4916-a174-98f35939b136; _tt_enable_cookie=1; _ttp=52b24f8e-1fb9-43b7-958b-2d70f9867fdf; G_ENABLED_IDPS=google; SPC_CLIENTID=UzZlOHpCdTdKdkdZbpzbvkmbybnbthea; _ga_CGXK257VSB=GS1.1.1663580710.1.0.1663580710.60.0.0; SPC_U=-; SPC_EC=-; SPC_IA=-1; SPC_T_ID="9VDb5zUpQqub2x5zBx2xMpQVF1qJl/YbOaa8z9oUWKv/i6kw8uwzPj3VvlWCT0RAz15X9+54WE7o1fgtpVw3w4lgrC+Xs7zmYNBhHxVufB0="; SPC_T_IV="swXjMq/Knt/saekFNKvhqQ=="; SPC_T_ID=9VDb5zUpQqub2x5zBx2xMpQVF1qJl/YbOaa8z9oUWKv/i6kw8uwzPj3VvlWCT0RAz15X9+54WE7o1fgtpVw3w4lgrC+Xs7zmYNBhHxVufB0=; SPC_T_IV=swXjMq/Knt/saekFNKvhqQ==; SPC_R_T_ID=9VDb5zUpQqub2x5zBx2xMpQVF1qJl/YbOaa8z9oUWKv/i6kw8uwzPj3VvlWCT0RAz15X9+54WE7o1fgtpVw3w4lgrC+Xs7zmYNBhHxVufB0=; SPC_R_T_IV=swXjMq/Knt/saekFNKvhqQ==; _med=refer; SPC_SI=4yKGYwAAAABCUFZGYTc1aIKXWwAAAAAAS2EwYlQ0emc=; _gid=GA1.3.1714972316.1669958743; AMP_TOKEN=$NOT_FOUND; shopee_webUnique_ccd=ooRQVQrq2ZxjBmW+7nKhEw==|XDXaIcfuOYyUTjpZA+SBG43QNVhRk/4jvuv9BJqhx1oUoC17wEKtL/UsloYIozB354AmHYJgHGz/yNv1+uKel/dyEQD0z/cqSkPt|PXIV1K81ru6ciOFL|06|3; ds=4fcaad5e6d0b82323dab27dea84f9436; _ga=GA1.1.1338607349.1662450890; _ga_SW6D8G0HXK=GS1.1.1669976139.37.1.1669976482.48.0.0; cto_bundle=_rprFl9wS3BYeWg1WjRpRW9MMFBtYXVvYURoVFJIZWFOTWQ3WlJsNldFM25tSFpqOCUyRjZ0bnVJY0tjV2RUczRnWnhoN1RWNVlCaFJ2RUVRaHA5TGFIRXJXJTJCJTJGRzJUNVBBaiUyQmxWSlY3VEE0SXV1RUdpJTJCQzRlQiUyRiUyQmZiWVQlMkYzTVZiOGEwT3lLTzNCTnVHaTBYb21KSno5OGxUUUlRJTNEJTNE',
    'if-none-match-': '55b03-b73d95a10fed044947106eb7e402db1a',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.56',
}
response_review = requests.request("GET", url=url_review, headers=headers_review, params=querystring_review, verify=False).json()
# Out:
# c:\Users\wiart\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\packages\urllib3\connectionpool.py:834: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/security.html
#   warnings.warn((

# %%
response_review
# Out:
# {'data': {'ratings': [{'orderid': 120942004186566,
#     'itemid': 5224704572,
#     'cmtid': 9973493555,
#     'ctime': 1667554399,
#     'rating': 1,
#     'userid': 347285500,
#     'shopid': 32427818,
#     'comment': '',
#     'rating_star': 5,
#     'status': 2,
#     'mtime': 1667554399,
#     'editable': 1,
#     'opt': 2,
#     'filter': 0,
#     'mentioned': [],
#     'is_hidden': False,
#     'author_username': 'isti_mewah',
#     'author_portrait': 'e8ef3caefd74548388f4b8904c48a3f6',
#     'author_shopid': 347265925,
#     'anonymous': False,
#     'images': None,
#     'videos': [],
#     'product_items': [{'itemid': 5224704572,
#       'shopid': 32427818,
#       'name': 'Roughneck H007 Black Forest Camouflage Hoodie',
#       'image': 'bcdd027ae310404704faa1d644357020',
#       'is_snapshot': 1,
#       'snapshotid': 3960071931,
#       'modelid': 15673277041,
#       'model_name': 'M',
#       'options': ['M']}],
#     'delete_reason': None,
# ...

# %%
df2 = pd.json_normalize(response_review['data']['ratings'])
df2
# Out:
#            orderid      itemid       cmtid       ctime  rating     userid  \
# 0  118127386264805  5224704572  9700277421  1664561471       1  360098354
# 1  116923434215802  5224704572  9607179150  1663607627       1  587047662
# 2   98375640595793  5224704572  7656339391  1646410148       1  537183107
# 3   90339896358874  5224704572  6611741063  1637047142       1  291657991
# 4   93015461372432  5224704572  6954569464  1639822257       1  318861188
# 5  120331409221957  5224704572  9917035955  1666881542       1  700565223
# 6  118410363259845  5224704572  9732926589  1664943913       1  399322319
# 7   84371316107996  5224704572  5902570537  1630993700       1  134772328
# 8  108213146541776  5224704572  8688439260  1655338496       1  655506323
# 9   84834752368693  5224704572  5997021544  1631699116       1  216078038
#
#      shopid                                            comment  rating_star  \
# 0  32427818  Tampilan:good\nWarna:bagus\n\nPengiriman cepat...            5
# ...

# %%
df_review = pd.json_normalize(result_review)
df_review
# Out:
#                orderid      itemid       cmtid       ctime  rating     userid  \
# 0      119038724288891  2940054992  9791279826  1665571615       1   28353962
# 1       88370691425413  2940054992  6385888460  1635065900       1  335657601
# 2       92942911372491  2940054992  6983645425  1640056203       1  265734914
# 3       93668298553070  2940054992  7016240658  1640308717       1  224368979
# 4      105029684337551  2940054992  8280310866  1651753943       1  241030082
# ...                ...         ...         ...         ...     ...        ...
# 11657   70693275230115  7451334014  4414214641  1617111292       1   37223638
# 11658   60526473480652  7451334014  3547502821  1607265472       1   93887458
# 11659   57256612094564  7451334014  3274808521  1603893686       1  254004873
# 11660   60270447638074  7451334014  3521260371  1606949880       1   11104698
# 11661   64931816183139  7451334014  3914224752  1611390931       1   22869024
#
# ...

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productreviewecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['shopeeProductReview'] 
collection = db['roughneck']

# %%
collection.insert_many(result_review)
