# %%
import requests
import pandas as pd
from pymongo import MongoClient
import time
import random

# %%
store = "aerostreet"
url = 'https://www.lazada.co.id/'+store+'/'

query_params = {
    'ajax':'true',
    'from':'wangpu',
    'langFlag':'id',
    'page':'1',
    'pageTypeId':'2',
    'q':'All-Products'
}

headers = {
    'authority': 'www.lazada.co.id',
    'accept': 'application/json, text/plain, */*',
    'cookie': 'miidlaz=miidgi499a1gcf8kjp9cn3j; t_fv=1662664726435; t_uid=Br1Uy7Lfc7KMdFzYA514tADQx66FD0nE; lzd_cid=a360fd78-3649-423d-b46a-75b9ebea8e2c; _tb_token_=fa9e5eb358e5b; cna=FS6hGwn853YCAbb9hCYYob4b; lzd_sid=101ae28026be828dd07d0b40a2652fbe; exlaz=c_lzd_byr:mm_150030223_51150528_2010300519!id1256005:clkgi4c2i1gfghfhhc57f8::; lzd_click_id=clkgi4c2i1gfghfhhc57f8; _bl_uid=26lj5a5z18OuzX4FFtqy8hLtUeUX; _gcl_au=1.1.1060732676.1667526349; _fbp=fb.2.1667526370430.628345689; hng=ID|id-ID|IDR|360; hng.sig=to18pG508Hzz7EPB_okhuQu8kDUP3TDmLlnu4IbIOY8; cto_axid=Bs29sS62NxbyiAGA_4cJjK7HzJmmqpNW; AMCVS_126E248D54200F960A4C98C6@AdobeOrg=1; _ga=GA1.3.1291115222.1668214893; pdp_login=false; __wpkreporterwid_=2280956e-9961-4ab4-baae-02b566e582a3; xlly_s=1; AMCV_126E248D54200F960A4C98C6@AdobeOrg=-1124106680|MCIDTS|19329|MCMID|02304393368715373353663002851187300535|MCAAMLH-1670593146|3|MCAAMB-1670593146|6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y|MCOPTOUT-1669995546s|NONE|MCSYNCSOP|411-19336|vVersion|5.2.0; _m_h5_tk=50b37daf3ec0b37bd73e91d1207ee866_1670045229275; _m_h5_tk_enc=0cab84c2ea61e5d3236e17f917acb855; _gid=GA1.3.842524240.1670036259; EGG_SESS=S_Gs1wHo9OvRHCMp98md7GDpNU5jJZoCY5jZRSOKtnVZvkRt0BL5JtAdJNhJZDQleJ6Y6RAO8-aQidk_TN-zbpKPuYdbeuR8ZyKZfkSwkY0N6n-fcqQgzUKXyzVZ-6-WuKrOyy4RIJz19NmqYiSn9snyLwSZsaj2jcgzeZIL9hQ=; t_sid=vrxNqJZYtLzaCdcAmnUGSRbxyksHcp5m; utm_channel=NA; _uetsid=ae6c8910724611ed8c86c9b8f3010614; _uetvid=74edc1a05be211ed8e3e8582a563d421; cto_bundle=yW0upl9VSGVQVk1lJTJCdFRhQUswRiUyRnFVeVl3TUdGNEdOOEF4NGdXdk5TNlpUTEYwMUlJS2szWVYlMkJiN2ZMZTZqMk82ZWRoaDZITWxWQlBZcFBvdiUyQjNuZVlKNHUlMkJtTVlzRWVHTEJXZGluUlRMMTd0N1hvZGhUakg2MmpCTDE1Zk5aMTc5UDBUYzhxRDdRJTJCVHFURyUyRkkwajk2Smh4USUzRCUzRA; _gat_UA-29801013-1=1; tfstk=cpOPBdxoUbhPIXfIB_1e_RCSs0vRa8OH1YQdEDmXO64SEbW5bs4zvZ4nL3KUukXl.; l=eBgcOsoITPk65kpXBO5wKurza77tCIOf1sPzaNbMiIncC6UliopEgN-QmhwAxLxRRJXcid8e4rVzUu9T0Fau-ykjov_GbQ79JPHDBef..; isg=BHt7HHranAikQqAsHX9WdCKYCl_l0I_Sh9EW1G05Mnh-zJiu9qICI4hK5mSCbOfK',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    'x-csrf-token': 'fa9e5eb358e5b',
    'x-requested-with': 'XMLHttpRequest'
}

product_list = []

data = requests.request("GET", url, headers=headers, params=query_params).json()

for page in range(1, round(int(data['mainInfo']['totalResults'])/40)+2):
    query_params_productlist = {
        'ajax':'true',
        'from':'wangpu',
        'langFlag':'id',
        'page':f'{page}',
        'pageTypeId':'2',
        'q':'All-Products'
    }

    productlist = requests.request("GET", url, headers=headers, params=query_params_productlist).json()
    try:
        for product in productlist['mods']['listItems']:
            product_list.append(product)
    except KeyError as e:
        break
    print("Scraping product list page: "+str(page)+" done")
# Out:
# Scraping product list page: 1 done
# Scraping product list page: 2 done
# Scraping product list page: 3 done
# Scraping product list page: 4 done
# Scraping product list page: 5 done
# Scraping product list page: 6 done
# Scraping product list page: 7 done
# Scraping product list page: 8 done
# Scraping product list page: 9 done
# Scraping product list page: 10 done
# Scraping product list page: 11 done
# Scraping product list page: 12 done
# Scraping product list page: 13 done
# Scraping product list page: 14 done
# Scraping product list page: 15 done
# Scraping product list page: 16 done
# Scraping product list page: 17 done
# Scraping product list page: 18 done
# Scraping product list page: 19 done
# Scraping product list page: 20 done
# Scraping product list page: 21 done
# Scraping product list page: 22 done
# Scraping product list page: 23 done

# %%
df = pd.DataFrame(product_list)
df
# Out:
#                                                   name         nid  \
# 0    Aerostreet 37-44 Jhosse Low Hitam - Sepatu Sne...  4531244640
# 1     Aerostreet Windbreaker Jaxton Jacket Olive IAAAA  6219224359
# 2    Aerostreet T Shirt Pop Art Navy T-Shirt Tshirt...  6870982341
# 3             Aerostreet Bomber Jacket Ezio Navy HAAAA  6233940942
# 4    Aerostreet Coach Jacket Riding Scooter Hitam J...  5854038855
# ..                                                 ...         ...
# 913  Aerostreet 37-40 Enzo Abu Toska - Sepatu Sneak...  1120696440
# 914  Aerostreet 37-44 Comfy Krem - Sepatu Slip On P...  6923254791
# 915  Aerostreet 39-42 Leopard Putih - Sepatu Sneake...  3742596745
# 916  Aerostreet 37-40 Motion+ Abu Muda Fushia - Sep...  3192740868
# 917  Aerostreet 36-40 Comfy Toska Pastel - Sepatu S...  5563618371
#
#                                                  icons  \
# 0    [{'domClass': 'VZbE7j', 'alias': 'VZbE7j', 'ty...
# 1    [{'domClass': 'VZbE7j', 'alias': 'VZbE7j', 'ty...
# 2    [{'domClass': 'VZbE7j', 'alias': 'VZbE7j', 'ty...
# 3    [{'domClass': 'VZbE7j', 'alias': 'VZbE7j', 'ty...
# 4    [{'domClass': 'VZbE7j', 'alias': 'VZbE7j', 'ty...
# ..                                                 ...
# 913  [{'domClass': 'VZbE7j', 'alias': 'VZbE7j', 'ty...
# 914  [{'domClass': 'out_of_stock_id', 'alias': 'out...
# 915  [{'domClass': 'VZbE7j', 'alias': 'VZbE7j', 'ty...
# 916  [{'domClass': 'VZbE7j', 'alias': 'VZbE7j', 'ty...
# 917  [{'domClass': 'out_of_stock_id', 'alias': 'out...
#
#                                               utLogMap  \
# 0    {'srp_name': 'lazadaInShopSrp', 'x_object_type...
# 1    {'srp_name': 'lazadaInShopSrp', 'x_object_type...
# 2    {'srp_name': 'lazadaInShopSrp', 'x_object_type...
# 3    {'srp_name': 'lazadaInShopSrp', 'x_object_type...
# 4    {'srp_name': 'lazadaInShopSrp', 'x_object_type...
# ..                                                 ...
# 913  {'srp_name': 'lazadaInShopSrp', 'x_object_type...
# 914  {'srp_name': 'lazadaInShopSrp', 'x_object_type...
# 915  {'srp_name': 'lazadaInShopSrp', 'x_object_type...
# 916  {'srp_name': 'lazadaInShopSrp', 'x_object_type...
# 917  {'srp_name': 'lazadaInShopSrp', 'x_object_type...
#
#                                                  image originalPrice  \
# 0    https://id-test-11.slatic.net/p/86f12e3ef2fe2e...     279800.00
# 1    https://id-test-11.slatic.net/p/0fd2244192edde...     299800.00
# 2    https://id-test-11.slatic.net/p/9d6de410362d3b...     119800.00
# 3    https://id-test-11.slatic.net/p/2fc9f5289e6865...     379800.00
# 4    https://id-test-11.slatic.net/p/659348fbdac217...     299800.00
# ..                                                 ...           ...
# 913  https://id-test-11.slatic.net/p/b5077071120cce...           NaN
# 914  https://id-test-11.slatic.net/p/958211bb76cb76...     239800.00
# 915  https://id-test-11.slatic.net/p/c4313c77d8a357...           NaN
# 916  https://id-test-11.slatic.net/p/9bb169e49b7428...           NaN
# 917  https://id-test-11.slatic.net/p/83e49014663533...     239800.00
#
#     originalPriceShow      price promotionId  priceShow  ...      itemId  \
# 0           Rp279.800  139900.00        null  Rp139.900  ...  4531244640
# 1           Rp299.800  149900.00        null  Rp149.900  ...  6219224359
# 2           Rp119.800   59900.00        null   Rp59.900  ...  6870982341
# 3           Rp379.800  189900.00        null  Rp189.900  ...  6233940942
# 4           Rp299.800  119900.00        null  Rp119.900  ...  5854038855
# ..                ...        ...         ...        ...  ...         ...
# 913               NaN  166500.00        null  Rp166.500  ...  1120696440
# 914         Rp239.800  119900.00        null  Rp119.900  ...  6923254791
# 915               NaN  199800.00        null  Rp199.800  ...  3742596745
# 916               NaN  166500.00        null  Rp166.500  ...  3192740868
# 917         Rp239.800  119900.00        null  Rp119.900  ...  5563618371
#
#            skuId inStock isAD addToCart showFeedBack longImageDisplayable  \
# 0     7799144951    True    0     False        False                False
# 1    11820486503    True    0     False        False                False
# 2    13020404522    True    0     False        False                False
# 3    11847382899    True    0     False        False                False
# 4    11315488171    True    0     False        False                False
# ..           ...     ...  ...       ...          ...                  ...
# 913   1764106831    True    0     False        False                False
# 914  13119430116   False    0     False        False                False
# 915   6215220213    True    0     False        False                False
# 916   5589038654    True    0     False        False                False
# 917  11018576756   False    0     False        False                False
#
#     isSponsored                                            itemUrl  \
# 0         False  //www.lazada.co.id/products/aerostreet-37-44-j...
# 1         False  //www.lazada.co.id/products/aerostreet-windbre...
# 2         False  //www.lazada.co.id/products/aerostreet-t-shirt...
# 3         False  //www.lazada.co.id/products/aerostreet-bomber-...
# 4         False  //www.lazada.co.id/products/aerostreet-coach-j...
# ..          ...                                                ...
# 913       False  //www.lazada.co.id/products/aerostreet-37-40-e...
# 914       False  //www.lazada.co.id/products/aerostreet-37-44-c...
# 915       False  //www.lazada.co.id/products/aerostreet-39-42-l...
# 916       False  //www.lazada.co.id/products/aerostreet-37-40-m...
# 917       False  //www.lazada.co.id/products/aerostreet-36-40-c...
#
#                                            querystring
# 0    search=1&source=search&request_id=cc8b16707183...
# 1    search=1&source=search&request_id=cc8b16707183...
# 2    search=1&source=search&request_id=cc8b16707183...
# 3    search=1&source=search&request_id=cc8b16707183...
# 4    search=1&source=search&request_id=cc8b16707183...
# ..                                                 ...
# 913  search=1&source=search&request_id=11194928a6ef...
# 914  search=1&source=search&request_id=11194928a6ef...
# 915  search=1&source=search&request_id=11194928a6ef...
# 916  search=1&source=search&request_id=11194928a6ef...
# 917  search=1&source=search&request_id=11194928a6ef...
#
# [918 rows x 40 columns]

# %%
review_list = []
index = 0

# %%
url_review = 'https://my.lazada.co.id/pdp/review/getReviewList'

while index < len(product_list):
    product = product_list[index]
    query_params_review = {
        'itemId':f'{product_list[index]["itemId"]}',
        'pageSize':'50',
        'filter':'0',
        'sort':'1',
        'pageNo':'1'
    }

    headers_review = {
        'authority': 'my.lazada.co.id',
        'accept': 'application/json, text/plain, */*',
        'cookie': 'client_type=desktop; miidlaz=miidgi499a1gcf8kjp9cn3j; t_fv=1662664726435; t_uid=Br1Uy7Lfc7KMdFzYA514tADQx66FD0nE; lzd_cid=a360fd78-3649-423d-b46a-75b9ebea8e2c; _tb_token_=fa9e5eb358e5b; cna=FS6hGwn853YCAbb9hCYYob4b; exlaz=c_lzd_byr:mm_150030223_51150528_2010300519!id1256005:clkgi4c2i1gfghfhhc57f8::; lzd_click_id=clkgi4c2i1gfghfhhc57f8; _gcl_au=1.1.1060732676.1667526349; _fbp=fb.2.1667526370430.628345689; cto_axid=Bs29sS62NxbyiAGA_4cJjK7HzJmmqpNW; AMCVS_126E248D54200F960A4C98C6@AdobeOrg=1; _ga=GA1.3.1291115222.1668214893; pdp_login=false; hng=ID|id-ID|IDR|360; hng.sig=to18pG508Hzz7EPB_okhuQu8kDUP3TDmLlnu4IbIOY8; AMCV_126E248D54200F960A4C98C6@AdobeOrg=-1124106680|MCIDTS|19335|MCMID|02304393368715373353663002851187300535|MCAAMLH-1671103203|3|MCAAMB-1671103203|6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y|MCOPTOUT-1670505603s|NONE|MCSYNCSOP|411-19336|vVersion|5.2.0; xlly_s=1; lzd_uid=400015212140; lzd_sid=1b5c5fcc72453b1b3f0d037d4c29a1e1; sgcookie=E100Q7yzaDw1v3qda4ztrCLX5f0TlvfIboXNbTDGFFoobgyhjfwIkomKgr/2WXue9XnTa+5uOwHo89ZCEf5AF6hHqURdObFcL/lSfYCMx9M0/pQ=; lzd_uti={"fpd":"9999-99-99","lpd":"9999-99-99","cnt":"0"}; _m_h5_tk=bcb65296fa5613234e452488baffcfa4_1670507417905; _m_h5_tk_enc=32d735ecbd788f7a947abd77c021bd5e; _uetsid=424b22c076ea11edb32e9da469ab5d42; _uetvid=74edc1a05be211ed8e3e8582a563d421; cto_bundle=AIhgql9vb1VuUHNFSndmNFY4YUh4Q3pFaEtodXZFJTJGJTJGUEdPRXh3JTJCeWdOWWUxWlNvJTJGa3Z2TUdCM0dWVGd5a0JQVnNKTHNjMkNOamI3UHkyRUlYTWtBWXJranNCNkJwVDhBY25sVFlKJTJCekpxSWhJUkNRMndQb204OVg2JTJCS0ZtNEFNeXZ4UWVJTXhGcDJKM1lmZ0NuN1NRU1BrQmclM0QlM0Q; _gid=GA1.3.745083133.1670498494; x5sec=7b22617365727665722d6c617a6164613b32223a226235306236306563376135393930373733346531353735356439353536316532434e716879357747454b6e36394c504e325a2b5569414561446a51774d4441784e5449784d6a45304d4473784d5071752f37734451414d3d227d; tfstk=c9RRBOtuHmmuGXihg_Hc8TgSkwelC7DRxmja9C3jtc_gTypBiI1cwCAOmTNcWGS-k; l=fBgcOsoITPk65wC9BO5alurza77TWCRfCsPzaNbMiIEGC6vWWc9i1d-QmEwICMKRRJXlNZ894rVzUu9T2ek7JyM6_X1zHAVWzgDDBe4h7vZd.; isg=BERERVPn-6UKkU9hTsKRoSEdFcI2XWjHJLS5WV7hK43RieFTg2yjV4ljySlR7KAf',
        'origin': 'https://www.lazada.co.id',
        'referer': 'https://www.lazada.co.id/',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-site',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
        'x-csrf-token': 'fa9e5eb358e5b',
        'x-requested-with': 'XMLHttpRequest'
    }

    response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
    
    # cek apakah ada key rgv587_flag di hasil response_review buat deteksi apakah terkena warning spam
    key = 'rgv587_flag'
    key2 = 'ret'
    if key in response_review:
        print("delay scraping product no: "+str(index)+"...")
        time.sleep(random.uniform(60, 70))
        continue
    elif key2 in response_review:
        print("delay scraping product no: "+str(index)+"...")
        time.sleep(random.uniform(60, 70))
        continue
    else:
        try : 
            for page in range(1, response_review['model']['paging']['totalPages']+1):
                query_params_review = {
                    'itemId':f'{product_list[index]["itemId"]}',
                    'pageSize':'50',
                    'filter':'0',
                    'sort':'1',
                    'pageNo':f'{page}'
                }

                response_reviews = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
                try:
                    for review in response_reviews['model']['items']:
                        review.update({"product" : product})
                        review_list.append(review)

                    print("Scraping product no. "+str(index)+" id: " + product_list[index]['itemId'] + " review page: "+str(page)+" done")
                except KeyError as e:
                    print(e)
        except TypeError as e:
            print("Scraping product no. "+str(index)+" id: " + product_list[index]['itemId'] + " review done")
        # time.sleep(random.uniform(20, 30))
        index += 1
# Out:
# Scraping product no. 723 id: 1907228783 review page: 1 done
# Scraping product no. 724 id: 6016620556 review page: 1 done
# Scraping product no. 725 id: 5854604466 review page: 1 done
# Scraping product no. 726 id: 5858494906 review page: 1 done
# Scraping product no. 727 id: 6192194748 review page: 1 done
# Scraping product no. 728 id: 5850914116 review page: 1 done
# Scraping product no. 729 id: 6685612991 review page: 1 done
# Scraping product no. 730 id: 1908998791 review page: 1 done
# Scraping product no. 731 id: 2976270532 review page: 1 done
# Scraping product no. 731 id: 2976270532 review page: 2 done
# Scraping product no. 731 id: 2976270532 review page: 3 done
# Scraping product no. 731 id: 2976270532 review page: 4 done
# Scraping product no. 731 id: 2976270532 review page: 5 done
# Scraping product no. 732 id: 6016504936 review page: 1 done
# Scraping product no. 733 id: 5858932922 review page: 1 done
# Scraping product no. 734 id: 4108580534 review page: 1 done
# Scraping product no. 734 id: 4108580534 review page: 2 done
# Scraping product no. 735 id: 3194552487 review page: 1 done
# Scraping product no. 736 id: 6846484052 review page: 1 done
# Scraping product no. 737 id: 5043044508 review page: 1 done
# Scraping product no. 738 id: 4108654601 review page: 1 done
# Scraping product no. 739 id: 7060506164 review page: 1 done
# Scraping product no. 740 id: 1906852298 review page: 1 done
# Scraping product no. 741 id: 1874108388 review page: 1 done
# Scraping product no. 741 id: 1874108388 review page: 2 done
# Scraping product no. 742 id: 6685400998 review page: 1 done
# Scraping product no. 743 id: 1907724187 review page: 1 done
# Scraping product no. 743 id: 1907724187 review page: 2 done
# Scraping product no. 744 id: 1908698225 review page: 1 done
# Scraping product no. 745 id: 1108272696 review page: 1 done
# Scraping product no. 746 id: 4494062137 review page: 1 done
# Scraping product no. 746 id: 4494062137 review page: 2 done
# Scraping product no. 746 id: 4494062137 review page: 3 done
# Scraping product no. 747 id: 1907768783 review page: 1 done
# Scraping product no. 748 id: 1909218267 review page: 1 done
# Scraping product no. 748 id: 1909218267 review page: 2 done
# Scraping product no. 749 id: 4834446585 review page: 1 done
# Scraping product no. 749 id: 4834446585 review page: 2 done
# Scraping product no. 749 id: 4834446585 review page: 3 done
# Scraping product no. 749 id: 4834446585 review page: 4 done
# Scraping product no. 749 id: 4834446585 review page: 5 done
# Scraping product no. 749 id: 4834446585 review page: 6 done
# Scraping product no. 749 id: 4834446585 review page: 7 done
# Scraping product no. 750 id: 6157840037 review page: 1 done
# Scraping product no. 751 id: 5850782595 review page: 1 done
# Scraping product no. 752 id: 4725954259 review page: 1 done
# Scraping product no. 753 id: 1906692674 review page: 1 done
# Scraping product no. 754 id: 6192308815 review page: 1 done
# Scraping product no. 755 id: 3412602129 review page: 1 done
# Scraping product no. 755 id: 3412602129 review page: 2 done
# Scraping product no. 756 id: 3199446388 review page: 1 done
# Scraping product no. 757 id: 5854156352 review page: 1 done
# Scraping product no. 758 id: 3201250656 review page: 1 done
# Scraping product no. 759 id: 6158228359 review page: 1 done
# Scraping product no. 760 id: 1391606665 review page: 1 done
# Scraping product no. 760 id: 1391606665 review page: 2 done
# Scraping product no. 761 id: 1874882990 review page: 1 done
# Scraping product no. 762 id: 1874862907 review page: 1 done
# Scraping product no. 762 id: 1874862907 review page: 2 done
# Scraping product no. 762 id: 1874862907 review page: 3 done
# Scraping product no. 762 id: 1874862907 review page: 4 done
# delay scraping product no: 763...

# %%
df_review = pd.DataFrame(review_list)
df_review
# Out:
#            reviewRateId      reviewType       buyerId   buyerName buyerEmail  \
# 0      1094669288944640  PRODUCT_REVIEW  400082877047       meffa       None
# 1      1094056771344640  PRODUCT_REVIEW  400327476778     heriadi       None
# 2      1093803876944640  PRODUCT_REVIEW      19509991   ratono F.       None
# 3      1093411872144640  PRODUCT_REVIEW  400672794983  Marpuah M.       None
# 4      1093098423744640  PRODUCT_REVIEW      21469143     agus S.       None
# ...                 ...             ...           ...         ...        ...
# 20715   578642032400148  PRODUCT_REVIEW  400230468962      Eko A.       None
# 20716   577244445800148  PRODUCT_REVIEW  400140867332      syalim       None
# 20717   577907066200148  PRODUCT_REVIEW  400068738551     Aina T.       None
# 20718   568578666900148  PRODUCT_REVIEW  400219908044       0***1       None
# 20719   561058273300148  PRODUCT_REVIEW  400214856899       0***2       None
#
#       realBuyerName  isAnonymous tradeOrderId source  clientType  ...  \
# 0              None        False         None   None  androidApp  ...
# 1              None        False         None   None  androidApp  ...
# 2              None        False         None   None  androidApp  ...
# 3              None        False         None   None  androidApp  ...
# 4              None        False         None   None  androidApp  ...
# ...             ...          ...          ...    ...         ...  ...
# 20715          None        False         None   None  androidApp  ...
# 20716          None        False         None   None  androidApp  ...
# 20717          None        False         None   None  androidApp  ...
# 20718          None        False         None   None  androidApp  ...
# 20719          None        False         None   None  androidApp  ...
#
#        isCompleted videoId isVideoReady videoCoverUrl  \
# 0                1     NaN         None          None
# 1                1     NaN         None          None
# 2                1     NaN         None          None
# 3                1     NaN         None          None
# 4                1     NaN         None          None
# ...            ...     ...          ...           ...
# 20715            1     NaN         None          None
# 20716            1     NaN         None          None
# 20717            1     NaN         None          None
# 20718            1     NaN         None          None
# 20719            0     NaN         None          None
#
#                                                   avatar canDownloadImage  \
# 0                                                                    None
# 1                                                                    None
# 2      https://lzd-live-id-member.oss-ap-southeast-1....             None
# 3      https://graph.facebook.com/118139774224697/pic...             None
# 4      https://lh5.googleusercontent.com/-Ty_w18aJI6k...             None
# ...                                                  ...              ...
# 20715                                               None             None
# 20716                                               None             None
# 20717                                               None             None
# 20718                                               None             None
# 20719                                               None             None
#
#          targetId targetType  \
# 0      4531244640       item
# 1      4531244640       item
# 2      4531244640       item
# 3      4531244640       item
# 4      4531244640       item
# ...           ...        ...
# 20715  1378700148       item
# 20716  1378700148       item
# 20717  1378700148       item
# 20718  1378700148       item
# 20719  1378700148       item
#
#                                                  product  \
# 0      {'name': 'Aerostreet 37-44 Jhosse Low Hitam - ...
# 1      {'name': 'Aerostreet 37-44 Jhosse Low Hitam - ...
# 2      {'name': 'Aerostreet 37-44 Jhosse Low Hitam - ...
# 3      {'name': 'Aerostreet 37-44 Jhosse Low Hitam - ...
# 4      {'name': 'Aerostreet 37-44 Jhosse Low Hitam - ...
# ...                                                  ...
# 20715  {'name': 'Aerostreet 37-42 Brushpen Black Whit...
# 20716  {'name': 'Aerostreet 37-42 Brushpen Black Whit...
# 20717  {'name': 'Aerostreet 37-42 Brushpen Black Whit...
# 20718  {'name': 'Aerostreet 37-42 Brushpen Black Whit...
# 20719  {'name': 'Aerostreet 37-42 Brushpen Black Whit...
#
#                             _id
# 0      6391fcf036af721fd7b1767b
# 1      6391fcf036af721fd7b1767c
# 2      6391fcf036af721fd7b1767d
# 3      6391fcf036af721fd7b1767e
# 4      6391fcf036af721fd7b1767f
# ...                         ...
# 20715                       NaN
# 20716                       NaN
# 20717                       NaN
# 20718                       NaN
# 20719                       NaN
#
# [20720 rows x 74 columns]

# %%
localhost = "mongodb://localhost:27017"

# %%
client = MongoClient(localhost)
db = client['lazada'] 
collection = db['aerostreet']

# %%
collection.insert_many(review_list)
