# %%
import requests
import pandas as pd
from pymongo import MongoClient
import random
import time

# %%
keyword = "rexus"
brandId = "138"

# %%
url = 'https://color.jd.id/jdid_pc_website/search_pc/1.0'

query_params = {
    'keyword':f'{keyword}',
    'pvid':'407cfaff7ca347c19e928ed16261f669', 
    'brandId':f'{brandId}',
    'page':'1',
    'pagesize':'60'
}

headers = {
    'authority': 'color.jd.id',
    'accept': '*/*',
    'cookie': 'mba_muid=166860068555036447537; _deviceId=cbeb6b66-d448-4b21-aab0-611c512b955d; eptCountry=%7B%22id%22%3A%2262%22%7D; _gcl_au=1.1.799070587.1668600687; GarudaShop=Other Page; _fbp=fb.1.1668600717483.1200734578; address_flag=true; stateId=10100000; cityId=10100004; areaId=10100033; townId=10100209; regional_full=10100000:DKI%20Jakarta|10100004:Kota%20Jakarta%20Selatan|10100033:Setia%20Budi|10100209:Karet%20Kuningan; moe_uuid=ea3dfb1c-f3b2-4cf7-bf83-a9b39eac502a; USER_DATA=%7B%22attributes%22%3A%5B%5D%2C%22subscribedToOldSdk%22%3Afalse%2C%22deviceUuid%22%3A%22ea3dfb1c-f3b2-4cf7-bf83-a9b39eac502a%22%2C%22deviceAdded%22%3Atrue%7D; shshshfpa=a7fce101-466d-8ca7-109c-9b3d3a896bc0-1668672773; site=undefined; shshshfpb=iyCjL7701bdt0nv0hai9Xjg; x_api_device_token=38e0fb2e-3091-4227-883f-a1f9a0dc17e3; _gia_s_local_fingerprint=6465bf402a49e4ecc47d679c1b8c8438; _gia_s_e_joint={"eid":"FK2TYVRWIWHAB363FQW42A3QEJI4YCS3VSHNIR5IH6ZE7WLUAXZSH2ALRJOCGX64HCHW5X2OESC2VIW6WGNMRI43ZU","ma":"","im":"","os":"Android 6.x","ip":"182.253.132.113","ia":"","uu":"","at":"6"}; TrackID=1thqAgyJR7lnAMleDW1k0d4xCVQr13iO1iaLtj9v3CmOgkTquX4CkYwNmLZmvMubaoFq_yg7TzPOm2Ck_bN3s3Q; pinId=2l-AJG5YkWyr6ERWVo1rrbKS7MJkIcs6; pin=jdid_deglekwqxwlc; unick=jdid_eqtGCmjycoit; me=05429cefa54876c1fac907b8fde611ef; jmp=5b1dbe1e2e8d757935d0ef70227f6cc1e9e5294b5fef3506fd199b439ac6992f; _tp=""; logining=1; _pst=jdid_deglekwqxwlc; __jdv=63461492|accounts.google.com|-|organic|notset|1668674909535; regional_pin=jdid_deglekwqxwlc; _gid=GA1.2.1340604156.1668861183; vc=8861187672; __jda=63461492.166860068555036447537.1668600685.1668701149.1668861187.10; __jdc=63461492; __jd_ab=10; _searchHistory=official%2520store%2Cpolytton%2Caerostreet%2Cset%2520top%2520box%2CAdvan%2Csanken%2Cnike; _gat_UA-69994851-3=1; _dc_gtm_UA-69994851-3=1; shshshfp=65c1eef4af192a35c9cfea0224cd40b2; shshshsID=9b9527a912ec2b799fd3581ebac1d4cd_4_1668861499325; _dc_gtm_UA-69994851-1=1; 3AB9D23F7A4B3C9B=FK2TYVRWIWHAB363FQW42A3QEJI4YCS3VSHNIR5IH6ZE7WLUAXZSH2ALRJOCGX64HCHW5X2OESC2VIW6WGNMRI43ZU; lighting-id=...; RT="z=1&dm=jd.id&si=cwt9r2ru0yo&ss=lanwv15e&sl=b&tt=mnr&ld=6r18&ul=6s27&hd=6s9f"; _tk=U1gi7ubab111h41vv5lsfjrm5l90; m-search-ab=idsearchrevision-new-10_100; _browser_id=58823322-0e98-4a26-9e83-4d227f09c5f7; cto_bundle=vKSIFl9KRSUyQmVJMTFKazF5T3ltSURMQkdMdDEzbTVJek5vY0JBd1B3cUVmUDhGUFdhbmRjODNYSlV4aXYwN3VNeUZrTWlndjZaNjc4TEh6V1QlMkZkSFh0MnQzSEs5RnNRR3NpNWRMYW5IRktuaDNpdVdQME1SNzRRQiUyQnBhTGpTdktpSXpMNQ; __jdb=63461492.23.166860068555036447537|10.1668861187; mba_sid=16688611875602784285884544071.7; _ga_VZMC86167F=GS1.1.1668861183.10.1.1668861537.45.0.0; _ga=GA1.2.221065702.1668600688',
    'lang': 'id',
    'origin': 'https://www.jd.id',
    'referer': 'https://www.jd.id/',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    'x-api-timestamp': '1668679359139'
}

product_list = []

data = requests.request("GET", url, headers=headers, params=query_params).json()

for page in range(1, data['data']['head']['Summary']['Page']['PageCount']+1):
    query_params_productlist = {
        'keyword':f'{keyword}',
        'pvid':'407cfaff7ca347c19e928ed16261f669', 
        'brandId':f'{brandId}',
        'page':f'{page}',
        'pagesize':'60'
    }

    product_response = requests.request("GET", url, headers=headers, params=query_params_productlist).json()
    for product in product_response['data']['paragraphs']:
        product_list.append(product)

    print("Scraping product list page: "+str(page)+" done")
# Out:
# Scraping product list page: 1 done
# Scraping product list page: 2 done
# Scraping product list page: 3 done
# Scraping product list page: 4 done
# Scraping product list page: 5 done
# Scraping product list page: 6 done
# Scraping product list page: 7 done
# Scraping product list page: 8 done
# Scraping product list page: 9 done
# Scraping product list page: 10 done
# Scraping product list page: 11 done
# Scraping product list page: 12 done
# Scraping product list page: 13 done
# Scraping product list page: 14 done
# Scraping product list page: 15 done
# Scraping product list page: 16 done
# Scraping product list page: 17 done
# Scraping product list page: 18 done
# Scraping product list page: 19 done
# Scraping product list page: 20 done
# Scraping product list page: 21 done

# %%
url = 'https://color.jd.id/shop_decoration_ina/search/2.0'

query_params = {
    'pageSize':'50',
    'mergeSku':'true', 
    'venderId':f'{vender_id}',
    'pageNo':'1',
    'orderBy':'1',
    'catLevel':'-1',
    'filters':'{}',
    '_token':f'{token}'
}

headers = {
    'authority': 'color.jd.id',
    'accept': '*/*',
    'cookie': 'mba_muid=166860068555036447537; _deviceId=cbeb6b66-d448-4b21-aab0-611c512b955d; eptCountry=%7B%22id%22%3A%2262%22%7D; _gcl_au=1.1.799070587.1668600687; GarudaShop=Other Page; _fbp=fb.1.1668600717483.1200734578; address_flag=true; stateId=10100000; cityId=10100004; areaId=10100033; townId=10100209; regional_full=10100000:DKI%20Jakarta|10100004:Kota%20Jakarta%20Selatan|10100033:Setia%20Budi|10100209:Karet%20Kuningan; moe_uuid=ea3dfb1c-f3b2-4cf7-bf83-a9b39eac502a; USER_DATA=%7B%22attributes%22%3A%5B%5D%2C%22subscribedToOldSdk%22%3Afalse%2C%22deviceUuid%22%3A%22ea3dfb1c-f3b2-4cf7-bf83-a9b39eac502a%22%2C%22deviceAdded%22%3Atrue%7D; shshshfpa=a7fce101-466d-8ca7-109c-9b3d3a896bc0-1668672773; site=undefined; shshshfpb=iyCjL7701bdt0nv0hai9Xjg; x_api_device_token=38e0fb2e-3091-4227-883f-a1f9a0dc17e3; _gia_s_local_fingerprint=6465bf402a49e4ecc47d679c1b8c8438; _gia_s_e_joint={"eid":"FK2TYVRWIWHAB363FQW42A3QEJI4YCS3VSHNIR5IH6ZE7WLUAXZSH2ALRJOCGX64HCHW5X2OESC2VIW6WGNMRI43ZU","ma":"","im":"","os":"Android 6.x","ip":"182.253.132.113","ia":"","uu":"","at":"6"}; TrackID=1thqAgyJR7lnAMleDW1k0d4xCVQr13iO1iaLtj9v3CmOgkTquX4CkYwNmLZmvMubaoFq_yg7TzPOm2Ck_bN3s3Q; pinId=2l-AJG5YkWyr6ERWVo1rrbKS7MJkIcs6; pin=jdid_deglekwqxwlc; unick=jdid_eqtGCmjycoit; me=05429cefa54876c1fac907b8fde611ef; jmp=5b1dbe1e2e8d757935d0ef70227f6cc1e9e5294b5fef3506fd199b439ac6992f; _tp=""; logining=1; _pst=jdid_deglekwqxwlc; __jdv=63461492|accounts.google.com|-|organic|notset|1668674909535; regional_pin=jdid_deglekwqxwlc; _gid=GA1.2.1340604156.1668861183; vc=8861187672; __jda=63461492.166860068555036447537.1668600685.1668701149.1668861187.10; __jdc=63461492; __jd_ab=10; _searchHistory=official%2520store%2Cpolytton%2Caerostreet%2Cset%2520top%2520box%2CAdvan%2Csanken%2Cnike; _gat_UA-69994851-3=1; _dc_gtm_UA-69994851-3=1; shshshfp=65c1eef4af192a35c9cfea0224cd40b2; shshshsID=9b9527a912ec2b799fd3581ebac1d4cd_4_1668861499325; _dc_gtm_UA-69994851-1=1; 3AB9D23F7A4B3C9B=FK2TYVRWIWHAB363FQW42A3QEJI4YCS3VSHNIR5IH6ZE7WLUAXZSH2ALRJOCGX64HCHW5X2OESC2VIW6WGNMRI43ZU; lighting-id=...; RT="z=1&dm=jd.id&si=cwt9r2ru0yo&ss=lanwv15e&sl=b&tt=mnr&ld=6r18&ul=6s27&hd=6s9f"; _tk=U1gi7ubab111h41vv5lsfjrm5l90; m-search-ab=idsearchrevision-new-10_100; _browser_id=58823322-0e98-4a26-9e83-4d227f09c5f7; cto_bundle=vKSIFl9KRSUyQmVJMTFKazF5T3ltSURMQkdMdDEzbTVJek5vY0JBd1B3cUVmUDhGUFdhbmRjODNYSlV4aXYwN3VNeUZrTWlndjZaNjc4TEh6V1QlMkZkSFh0MnQzSEs5RnNRR3NpNWRMYW5IRktuaDNpdVdQME1SNzRRQiUyQnBhTGpTdktpSXpMNQ; __jdb=63461492.23.166860068555036447537|10.1668861187; mba_sid=16688611875602784285884544071.7; _ga_VZMC86167F=GS1.1.1668861183.10.1.1668861537.45.0.0; _ga=GA1.2.221065702.1668600688',
    'lang': 'id',
    'origin': 'https://www.jd.id',
    'referer': 'https://www.jd.id/',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    'x-api-timestamp': '1668679359139'
}

product_list = []

data = requests.request("POST", url, headers=headers, params=query_params).json()

for i in range(1, data['data']['pageCount']+1):
    query_params_productlist = {
        'pageSize':'50',
        'mergeSku':'true', 
        'venderId':f'{vender_id}',
        'pageNo':f'{i}',
        'orderBy':'1',
        'catLevel':'-1',
        'filters':'{}',
        '_token':f'{token}'
    }

    product_response = requests.request("POST", url, headers=headers, params=query_params_productlist).json()
    for product in product_response['data']['skuList']:
        product_list.append(product)

    print("Scraping product list page: "+str(i)+" done")
# Out:
# Scraping product list page: 1 done
# Scraping product list page: 2 done

# %%
df = pd.json_normalize(product_list)
df
# Out:
#                                               SlaveWare bean_ratio brand_id  \
# 0     [{'Content': {'color': 'Hitam', 'crosstype': '...      0.001      138
# 1     [{'Content': {'color': 'Hitam', 'crosstype': '...        NaN      138
# 2                                                   NaN      0.001      138
# 3     [{'Content': {'color': 'Baby Pink', 'crosstype...        NaN      138
# 4     [{'Content': {'color': 'Hitam', 'crosstype': '...        NaN      138
# ...                                                 ...        ...      ...
# 1254  [{'Content': {'color': 'Perak', 'crosstype': '...        NaN      138
# 1255                                                NaN        NaN      138
# 1256  [{'Content': {'color': 'Hijau', 'crosstype': '...        NaN      138
# 1257                                                NaN        NaN      138
# 1258                                                NaN        NaN      138
#
# ...

# %%
review_list = []
index = 0

# %%
url_review = 'https://color.jd.id/jdid_pc_website/comment_product_page/1.0'

for index in range(index, len(product_list)):
    try:
        query_params_review = {
            'spuId':f'{product_list[index]["spuid"]}',
            'skuId':f'{product_list[index]["skuid"]}',
            'storeId':'',
            'pageSize':'50',
            'pageIndex':'1',
            'tagId':'',
            'commentType':''
        }

        headers_review = {
            'authority': 'color.jd.id',
            'accept': '*/*',
            'cookie': 'mba_muid=166860068555036447537; eptCountry={"id":"62"}; _gcl_au=1.1.799070587.1668600687; GarudaShop=Other Page; _fbp=fb.1.1668600717483.1200734578; address_flag=true; stateId=10100000; cityId=10100004; areaId=10100033; townId=10100209; regional_full=10100000:DKI Jakarta|10100004:Kota Jakarta Selatan|10100033:Setia Budi|10100209:Karet Kuningan; moe_uuid=ea3dfb1c-f3b2-4cf7-bf83-a9b39eac502a; USER_DATA={"attributes":[],"subscribedToOldSdk":false,"deviceUuid":"ea3dfb1c-f3b2-4cf7-bf83-a9b39eac502a","deviceAdded":true}; shshshfpa=a7fce101-466d-8ca7-109c-9b3d3a896bc0-1668672773; site=undefined; shshshfpb=iyCjL7701bdt0nv0hai9Xjg; x_api_device_token=38e0fb2e-3091-4227-883f-a1f9a0dc17e3; _gia_s_local_fingerprint=6465bf402a49e4ecc47d679c1b8c8438; _gia_s_e_joint={"eid":"FK2TYVRWIWHAB363FQW42A3QEJI4YCS3VSHNIR5IH6ZE7WLUAXZSH2ALRJOCGX64HCHW5X2OESC2VIW6WGNMRI43ZU","ma":"","im":"","os":"Android 6.x","ip":"182.253.132.113","ia":"","uu":"","at":"6"}; logining=1; TrackID=1PS7Zdov6S1YEOBCRoW_hA_yzJg7rb09rFwYRTAlEbcacM8fPXzik5ZJB9Hvlp5Xtyud7k1jtEXpm12HZu-VGLA; pinId=F75_dAMyEJadIkMtq60ob9lOVL4SJJY8; me=96240b55f0991d7beba877ce24869687; jmp=be905eb086eb3c36122773d3995fa483917793b2178e1d68a9cfef3f209b7653; __jdc=63461492; _deviceId=a701d8b3-fac5-4fae-a2ea-1d8bf2ce6888; regional_pin=; __jdv=63461492|www.google.com|-|organic|notset|1673132112003; shshshfp=53e4c753cfe90bc2a3737df5c8a17992; 3AB9D23F7A4B3C9B=FK2TYVRWIWHAB363FQW42A3QEJI4YCS3VSHNIR5IH6ZE7WLUAXZSH2ALRJOCGX64HCHW5X2OESC2VIW6WGNMRI43ZU; _gid=GA1.2.879568663.1674196303; __jd_ab=29; _searchHistory=rexus; __jda=63461492.166860068555036447537.1668600685.1674196303.1674217981.30; _dc_gtm_UA-69994851-1=1; __jdb=63461492.3.166860068555036447537|30.1674217981; _browser_id=1674218492376; _ga_VZMC86167F=GS1.1.1674217961.26.1.1674218494.36.0.0; RT="z=1&dm=jd.id&si=tkpug7ulkid&ss=ld45b547&sl=1&tt=cm1&nu=bb4941c8a00a6165c1c8211bac70894a&cl=d5gmb&ld=d5lmw"; cto_bundle=JfbUoV9nMUVBVnk2R2xwNnN3RmlQYTNvckFncElpYnM5RGhQMjVuWEhZOTN5TElramNIckp5VkwyN2M2T09sQmVMZjN3MkNqZ01MRDhHaFhxbUxQNUVwVjB2WndEdWglMkYwWGl1NmE0TjRDNlpJMmJLSXBzRk5wMUtnTTlGRUNtYXJJSVNO; _ga=GA1.2.221065702.1668600688',
            'lang': 'id',
            'origin': 'https://www.jd.id',
            'referer': 'https://www.jd.id/',
            'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
            'sec-ch-ua-mobile': '?0',
            'sec-ch-ua-platform': '"Windows"',
            'sec-fetch-dest': 'empty',
            'sec-fetch-mode': 'cors',
            'sec-fetch-site': 'same-site',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
            'x-api-platform': 'PC',
            'x-api-timestamp': '1668680185752'
        }

        response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
        product = product_list[index]
        for page in range(1, round(response_review['data']['total']/50)+2):
            query_params_review = {
                'spuId':f'{product_list[index]["spuid"]}',
                'skuId':f'{product_list[index]["skuid"]}',
                'storeId':'',
                'pageSize':'50',
                'pageIndex':f'{page}',
                'tagId':'',
                'commentType':''
            }

            response_reviews = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
            for review in response_reviews['data']['items']:
                review.update({"product":product})
                review_list.append(review)
        print("Scraping product no. "+str(index)+" id: " + str(product_list[index]["spuid"]) + " review done")
    except ConnectionError as e:
        print("delay scraping product no: "+str(index)+"...")
        time.sleep(random.uniform(20, 30))
        continue
# Out:
# Scraping product no. 675 id: 630448920 review done
# Scraping product no. 676 id: 634431424 review done
# Scraping product no. 677 id: 669487983 review done
# Scraping product no. 678 id: 640587807 review done
# Scraping product no. 679 id: 640586978 review done
# Scraping product no. 680 id: 640588018 review done
# Scraping product no. 681 id: 640639859 review done
# Scraping product no. 682 id: 671262574 review done
# Scraping product no. 683 id: 675629501 review done
# Scraping product no. 684 id: 675652190 review done
# Scraping product no. 685 id: 644021523 review done
# Scraping product no. 686 id: 704371847 review done
# Scraping product no. 687 id: 619902796 review done
# Scraping product no. 688 id: 623445471 review done
# Scraping product no. 689 id: 646885510 review done
# Scraping product no. 690 id: 646885583 review done
# Scraping product no. 691 id: 647219997 review done
# Scraping product no. 692 id: 654814609 review done
# ...

# %%
df_review = pd.DataFrame(review_list)
df_review
# Out:
#     userNickName                                          userImage country  \
# 0         u****r  amZzL3Q5NC8zNy82NzU2NzMyMjUzLzE4NDU4L2JiMjU2Yz...    None
# 1         t****o  amZzL3QyMi83NS80MzQ1ODcwNTUyLzEwNjUzLzVmYzY5MG...    None
# 2         i****9                                               None    None
# 3         g****a                    nHBfsgAAWwAAAA4AQo7gHwAAMTI.jpg    None
# 4         h****0                                               None    None
# ..           ...                                                ...     ...
# 820       a****i                                               None    None
# 821       s****a                                               None    None
# 822       1****h                    nHBfsgAAxQAAABUAHL8h1gAAItI.jpg    None
# 823       b****y                                               None    None
# 824       j****j                                               None    None
#
#      commentType      skuId  venderId userPin  \
# ...

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
localhost = "mongodb://localhost:27017"

# %%
client = MongoClient(localhost)
db = client['jdid'] 
collection = db['rexus']

# %%
collection.insert_many(review_list)
