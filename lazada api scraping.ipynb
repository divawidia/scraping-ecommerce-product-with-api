# %%
import requests
import pandas as pd
from pymongo import MongoClient

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['lazadaProductReview'] 
collection = db['polytron']

# %%
store = "brodo-footwear"
url = 'https://www.lazada.co.id/'+store+'/'

query_params = {
    'ajax':'true',
    'from':'wangpu',
    'langFlag':'id',
    'page':'1',
    'pageTypeId':'2',
    'q':'All-Products'
}

headers = {
    'authority': 'www.lazada.co.id',
    'accept': 'application/json, text/plain, */*',
    'cookie': 'miidlaz=miidgi499a1gcf8kjp9cn3j; t_fv=1662664726435; t_uid=Br1Uy7Lfc7KMdFzYA514tADQx66FD0nE; lzd_cid=a360fd78-3649-423d-b46a-75b9ebea8e2c; _tb_token_=fa9e5eb358e5b; cna=FS6hGwn853YCAbb9hCYYob4b; lzd_sid=101ae28026be828dd07d0b40a2652fbe; exlaz=c_lzd_byr:mm_150030223_51150528_2010300519!id1256005:clkgi4c2i1gfghfhhc57f8::; lzd_click_id=clkgi4c2i1gfghfhhc57f8; _bl_uid=26lj5a5z18OuzX4FFtqy8hLtUeUX; _gcl_au=1.1.1060732676.1667526349; _fbp=fb.2.1667526370430.628345689; hng=ID|id-ID|IDR|360; hng.sig=to18pG508Hzz7EPB_okhuQu8kDUP3TDmLlnu4IbIOY8; cto_axid=Bs29sS62NxbyiAGA_4cJjK7HzJmmqpNW; AMCVS_126E248D54200F960A4C98C6%40AdobeOrg=1; _ga=GA1.3.1291115222.1668214893; pdp_login=false; __wpkreporterwid_=2280956e-9961-4ab4-baae-02b566e582a3; t_sid=epRQr2A5KypRRofBNUFqUN7OifbGvp0e; utm_channel=NA; _m_h5_tk=108c5ca92d86bf1916e4e552d0b0728b_1669259331149; _m_h5_tk_enc=0ba8a13e67cf7931385042df867168fc; xlly_s=1; AMCV_126E248D54200F960A4C98C6%40AdobeOrg=-1124106680%7CMCIDTS%7C19321%7CMCMID%7C02304393368715373353663002851187300535%7CMCAAMLH-1669853716%7C3%7CMCAAMB-1669853716%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-1669256116s%7CNONE%7CMCSYNCSOP%7C411-19328%7CvVersion%7C5.2.0; _gid=GA1.3.71990634.1669248999; cto_bundle=RQaUb19XWjdWbExIQ2lpc3RHdyUyQldMcUZyNVg1REJTMXE1V3ZlaW1vUndqdkdqcllKaTU1Y2twMFNjbXBiVHJ5Tk8wWnJKT2ZLaEYlMkJuUE1pdSUyRlp5JTJCQXdiNzkwMHBTWnJyb2RzaVNGRDh4MUhpbSUyQiUyRjJraGZNUiUyRkhuaDZiamwwN0NPdkhDbGFLSnYlMkZ4Nmppc2hJUnJGbDhpRDJ3JTNEJTNE; _gat_UA-29801013-1=1; _uetsid=11a1fec06b8d11ed8255dde0f680ef34; _uetvid=74edc1a05be211ed8e3e8582a563d421; tfstk=cDh1B7NNRGjsWdpUB-Te0UgOq3NfZ41Q-6qE5hiyCCJhgog1iQfzVqCu5MN4ky1..; l=eBgcOsoITPk656EfBOfwourza77OSIRAguPzaNbMiOCPOf1p5jh1W6zeaCT9C3GNhs1kR3z0a8y9BeYBqIXkmDLljDtQ3-kmn; isg=BKurfxU-TIyRQJC8TU9mxJKIOs-VwL9CN-HGwR0oh-pBvMsepZBPkkkaFvTSnBc6',
    'referer': 'https://www.lazada.co.id/910/?q=All-Products&from=wangpu&langFlag=id&pageTypeId=2',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    'x-csrf-token': 'fa9e5eb358e5b',
    'x-requested-with': 'XMLHttpRequest'
}

product_list = []

data = requests.request("GET", url, headers=headers, params=query_params).json()

for page in range(1, round(int(data['mainInfo']['totalResults'])/40)+2):
    query_params_productlist = {
        'ajax':'true',
        'from':'wangpu',
        'langFlag':'id',
        'page':f'{page}',
        'pageTypeId':'2',
        'q':'All-Products'
    }

    productlist = requests.request("GET", url, headers=headers, params=query_params_productlist).json()
    for product in productlist['mods']['listItems']:
        product_list.append(product)

# %%
df = pd.DataFrame(product_list)
df
# Out:
#                                                  name         nid  \
# 0                               BRODO - Banda Parfume  6277396553
# 1                  Brodo - Frope Hanging Wallet Black  7021828067
# 2                   BRODO - Sandal Flipper Full Black  5137874261
# 3                         Broslides BRO-DO Full Black  5793314790
# 4                  BRODO - Sandal\tBroslide Neo Black  6372296931
# ..                                                ...         ...
# 921             BRODO - Ikat Pinggang Nast Belt Black  6267590142
# 922        BRODO - Aksesoris Lanyard Skj Tosca Purple  7021838178
# 923   BRODO - Aksesoris Pria Combat Lanyard Choco Tan  1754066607
# 924  BRODO - Aksesoris Pria Combat Lanyard Dark Choco  1754020900
# 925             BRODO - Ikat Pinggang Nast Belt Brown  6267520859
#
#                                                  icons  \
# 0    [{'domClass': 'JzuERf', 'alias': 'JzuERf', 'ty...
# 1    [{'domClass': 'JzuERf', 'alias': 'JzuERf', 'ty...
# ...

# %%
review_list = []

# %%
url_review = 'https://my.lazada.co.id/pdp/review/getReviewList'
index = 1
# for index in range(0, len(product_list)):
query_params_review = {
    'itemId':f'{product_list[index]["itemId"]}',
    'pageSize':'50',
    'filter':'0',
    'sort':'1',
    'pageNo':'1'
}

headers_review = {
    'authority': 'my.lazada.co.id',
    'accept': 'application/json, text/plain, */*',
    'cookie': 'client_type=desktop; miidlaz=miidgi499a1gcf8kjp9cn3j; t_fv=1662664726435; t_uid=Br1Uy7Lfc7KMdFzYA514tADQx66FD0nE; lzd_cid=a360fd78-3649-423d-b46a-75b9ebea8e2c; _tb_token_=fa9e5eb358e5b; cna=FS6hGwn853YCAbb9hCYYob4b; lzd_sid=101ae28026be828dd07d0b40a2652fbe; exlaz=c_lzd_byr:mm_150030223_51150528_2010300519!id1256005:clkgi4c2i1gfghfhhc57f8::; lzd_click_id=clkgi4c2i1gfghfhhc57f8; _gcl_au=1.1.1060732676.1667526349; _fbp=fb.2.1667526370430.628345689; hng=ID|id-ID|IDR|360; hng.sig=to18pG508Hzz7EPB_okhuQu8kDUP3TDmLlnu4IbIOY8; cto_axid=Bs29sS62NxbyiAGA_4cJjK7HzJmmqpNW; AMCVS_126E248D54200F960A4C98C6@AdobeOrg=1; _ga=GA1.3.1291115222.1668214893; pdp_login=false; _m_h5_tk=108c5ca92d86bf1916e4e552d0b0728b_1669259331149; _m_h5_tk_enc=0ba8a13e67cf7931385042df867168fc; xlly_s=1; AMCV_126E248D54200F960A4C98C6@AdobeOrg=-1124106680|MCIDTS|19321|MCMID|02304393368715373353663002851187300535|MCAAMLH-1669853716|3|MCAAMB-1669853716|6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y|MCOPTOUT-1669256116s|NONE|MCSYNCSOP|411-19328|vVersion|5.2.0; _gid=GA1.3.71990634.1669248999; cto_bundle=RQaUb19XWjdWbExIQ2lpc3RHdyUyQldMcUZyNVg1REJTMXE1V3ZlaW1vUndqdkdqcllKaTU1Y2twMFNjbXBiVHJ5Tk8wWnJKT2ZLaEYlMkJuUE1pdSUyRlp5JTJCQXdiNzkwMHBTWnJyb2RzaVNGRDh4MUhpbSUyQiUyRjJraGZNUiUyRkhuaDZiamwwN0NPdkhDbGFLSnYlMkZ4Nmppc2hJUnJGbDhpRDJ3JTNEJTNE; _uetsid=11a1fec06b8d11ed8255dde0f680ef34; _uetvid=74edc1a05be211ed8e3e8582a563d421; t_sid=TfB2GIlfnW6EMdc4lxHlV8MCjxKRl80w; utm_channel=NA; tfstk=c-DVBF0DgKpql5m9J82ZL4bYTPOAaBkidIETiFf-Af6NKMPz8svVWujM_q3N4NVc.; l=eBgcOsoITPk65gzBBO5anurza77tzIObzsPzaNbMiInca1JdZQOhGNCU8M5Dodtj_t5vVe-zo7yzBd3w8r4U-xOZO_yA3HUHXdvwRe1..; isg=BAUFe3DNyvqjKO7CNw0gMhgqFEE_wrlUDUPYnwdrmTyHnicQzBMMJQY8qMpo3tEM',
    'origin': 'https://www.lazada.co.id',
    'referer': 'https://www.lazada.co.id/',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    'x-csrf-token': 'fa9e5eb358e5b',
    'x-requested-with': 'XMLHttpRequest'
}

response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
for review in response_review['model']['items']:
        product = product_list[index]
        review.update({"product" : product})
        review_list.append(review)
# try : 
# for page in range(1, response_review['model']['paging']['totalPages']+1):
#     query_params_review = {
#         'itemId':f'{product_list[index]["itemId"]}',
#         'pageSize':'50',
#         'filter':'0',
#         'sort':'1',
#         'pageNo':f'{page}'
#     }

#     response_reviews = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
#     for review in response_reviews['model']['items']:
#         product = product_list[index]
#         review.update({"product" : product})
#         review_list.append(review)

print("Scraping product no. "+str(index)+" id: " + product_list[index]['itemId'] + " review done")
    # except KeyError as e:
    #     print(response_review)
    #     print(e)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1684/3647337005.py in <module>
#      28
#      29 response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
# ---> 30 for review in response_review['model']['items']:
#      31         product = product_list[index]
#      32         review.update({"product" : product})
#
# KeyError: 'model'

# %%
response_review
# Out:
# {'success': True,
#  'model': {'items': [{'reviewRateId': 1078126319428067,
#     'reviewType': 'PRODUCT_REVIEW',
#     'buyerId': 400357068407,
#     'buyerName': 'Memenugi R.',
#     'buyerEmail': None,
#     'realBuyerName': None,
#     'isAnonymous': False,
#     'tradeOrderId': None,
#     'source': None,
#     'clientType': 'androidApp',
#     'rating': 5,
#     'originalRating': None,
#     'reviewTitle': None,
#     'reviewContent': 'kece sesuai gambar 👍👍',
#     'reviewTime': '3  minggu lalu\r\n',
#     'zonedReviewTime': None,
#     'likeCount': 0,
#     'likeText': None,
#     'isMeLike': None,
#     'helpful': True,
#     'rejected': False,
#     'rejectionReason': None,
#     'resubmissionTooltip': None,
#     'resubmissionMessage': None,
#     'qcReasonId': None,
#     'qcDate': None,
#     'isPurchased': True,
#     'isGuest': False,
#     'sellerId': 80778,
#     'sellerName': None,
#     'boughtDate': '26 Okt 2022',
#     'zonedBoughtDate': None,
# ...

# %%
df_review = pd.json_normalize(review_list)
df_review
# Out:
#        reviewRateId      reviewType       buyerId    buyerName buyerEmail  \
# 0  1078126319428067  PRODUCT_REVIEW  400357068407  Memenugi R.       None
#
#   realBuyerName  isAnonymous tradeOrderId source  clientType  ...  \
# 0          None        False         None   None  androidApp  ...
#
#    product.itemId product.skuId product.inStock product.isAD  \
# 0      7021828067   13277764977            True            0
#
#   product.addToCart product.showFeedBack  product.longImageDisplayable  \
# 0             False                False                         False
#
#   product.isSponsored                                    product.itemUrl  \
# 0               False  //www.lazada.co.id/products/brodo-frope-hangin...
#
#                                  product.querystring
# 0  source=search&mp=1&freeshipping=1&fs_ab=1&fuse...
#
# [1 rows x 123 columns]

# %%
collection.insert_many(review_list)
