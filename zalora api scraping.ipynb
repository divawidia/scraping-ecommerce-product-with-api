# %%
import requests
import pandas as pd
from pymongo import MongoClient

# %%
product_list = []

url = "https://www.zalora.co.id/_c/v1/desktop/zis_list_catalog_products"
seller_id = 8828

query_params = {
    "sort":"popularity",
    "dir":"desc",
    "offset":"0",
    "limit":"300",
    "seller_id":f"{seller_id}",
    "special_price":"false",
    "all_products":"true",
    "new_products":"false",
    "top_sellers":"false",
    "catalogtype":"Main",
    "lang":"id",
    "is_brunei":"false",
    "search_suggest":"false",
    "enable_visual_sort":"true",
    "enable_filter_ads":"true",
    "compact_catalog_desktop":"false",
    "name_search":"false",
    "solr7_support":"false",
    "pick_for_you":"false",
    "learn_to_sort_catalog":"false",
    "enable_similar_term":"true",
    "enable_relevance_classifier":"true",
    "auto_correct":"true"
}

headers = {
    'authority': 'www.zalora.co.id',
    'accept': 'application/json, text/plain, */*',
    'cookie': 'userLanguage=id; browserDetection=eyJ0eXBlIjoiYnJvd3NlciIsIm5hbWUiOiJDaHJvbWUiLCJjc3NDbGFzcyI6ImNocm9tZSIsInZlcnNpb24iOiIxMDcifQ%3D%3D; PHPSESSID_83d0767d2f534a23f21399428e28c076=1f00ae8006799b60f99753474279dee8; zid=478411372.1668672968; rrCookie=zItAGRRlnEuTeo5cEP2K22oCti81zcKo; ANONYMOUS_TRACKING_ID=06318d2b-9591-4f33-bb10-5da92ab4bb4c; is_guest_with_empty_cart=true; 905125419dc9d3c8f422452a786673ba=-; zalora_referer=%7B%22search.brave.com%22%3A%5B%22https%3A%5C%2F%5C%2Fsearch.brave.com%5C%2F%22%5D%7D; optimizelyEndUserId=oeu1668672970006r0.89856154814837; _gid=GA1.3.1877399038.1668672972; ajs_anonymous_id=06318d2b-9591-4f33-bb10-5da92ab4bb4c; ab.storage.deviceId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1=%7B%22g%22%3A%229611eb88-9412-89ef-10ed-e225abefde5e%22%2C%22c%22%3A1668672972721%2C%22l%22%3A1668672972721%7D; _fbp=fb.2.1668672973096.849720760; _gcl_au=1.1.1251577912.1668672973; __rtbh.sid=%7B%22eventType%22%3A%22sid%22%2C%22id%22%3A%22478411372.1668672968%22%7D; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%22iSbKqsW4cEccbmMlfS4d%22%7D; _tt_enable_cookie=1; _ttp=b6ca33dd-fe7d-40a2-b110-b591d4618095; _vz=viz_6375edd01e73b; _vz=; userSegment=men; rr_rcs=eF5jYSlN9jAxTTOwsEw10zU3NUzVNTEzTtG1TEk20jU2NjM0MjI0STQxNuPKLSvJTBEwtLA00TXUNQQAgRcNgQ; viz_sent=1; wpn_https={"status":"denied","last_shown":"Fri, 18 Nov 2022 02:15:41 GMT","shown_count":2}; _abck=3405F0D98681418EEB0DC15FEC1B1121~0~...~-1~-1~-1; bm_sz=C266EB3109FE88AAB9D7B448F43161B5~~3359289~3223862; bm_mi=E4AE6805ADAE5896EDF59870C4287FAE~~1; sessionCount=6; ak_bmsc=2929D0C8E356B20516A4380B126793FA~000000000000000000000000000000~...; _gat=1; _gat_UA-28869185-1=1; cto_bundle=TapxGl9IT3UlMkZPS04wJTJCb3gzeHhVYVVOc3NyclRJQ3pUeFZ4d3A3T0Zha1o3Y29aTyUyRmtWMDMwNGJZRlljVGRWVnd6VmpkcW9Bd2M4ZWxSMENHQWRXdGN1a3kyJTJGNm9Td3NYV2lyRm9zamU4ZG02S1lNdGVvbUsxQzREaDhQaU9rbVR0MENqaXVvbHo3M0lncFNxdjRUOTUxOXlyQSUzRCUzRA; _gali=pdvVisitStore; ab.storage.sessionId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1=%7B%22g%22%3A%228984390f-45b1-0a8f-fa48-b26caf6b1021%22%2C%22e%22%3A1668755237091%2C%22c%22%3A1668750430447%2C%22l%22%3A1668753437091%7D; bm_sv=1DA75E9D7CCD1F41D774A519D85B0E77~~1; _ga_T53WSL6JBT=GS1.1.1668750426.6.1.1668753437.41.0.0; _ga=GA1.3.1421552235.1668672972; pageCount=18; RT="sl=16&ss=1668750425919&tt=57775&obo=2&sh=1668753432433%3D16%3A2%3A57775%2C1668753423083%3D15%3A2%3A53124%2C1668753322190%3D14%3A2%3A47796%2C1668753318840%3D13%3A2%3A43886%2C1668753315706%3D12%3A1%3A43886&dm=zalora.co.id&si=0fc6470b-0f82-45c7-8969-28c6666ca231&bcn=%2F%2F684d0d46.akstat.io%2F&rl=1"',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
}

data = requests.request("GET", url, headers=headers, params=query_params).json()

for offset in range(0, data['response']['numFound'], 300):
    query_params_productlist = {
        "sort":"popularity",
        "dir":"desc",
        "offset":f"{offset}",
        "limit":"300",
        "seller_id":f"{seller_id}",
        "special_price":"false",
        "all_products":"true",
        "new_products":"false",
        "top_sellers":"false",
        "catalogtype":"Main",
        "lang":"id",
        "is_brunei":"false",
        "search_suggest":"false",
        "enable_visual_sort":"true",
        "enable_filter_ads":"true",
        "compact_catalog_desktop":"false",
        "name_search":"false",
        "solr7_support":"false",
        "pick_for_you":"false",
        "learn_to_sort_catalog":"false",
        "enable_similar_term":"true",
        "enable_relevance_classifier":"true",
        "auto_correct":"true"
    }

    productlist = requests.request("GET", url, headers=headers, params=query_params_productlist).json()
    for product in productlist['response']['docs']:
        product_list.append(product)

# %%
df = pd.DataFrame(product_list)
df
# Out:
#                                                 meta  \
# 0  {'sku': 'A4044SH6198AB7GS', 'max_saving_percen...
# 1  {'sku': 'DC347SHD0A1717GS', 'max_saving_percen...
# 2  {'sku': 'A3C43SH89EB507GS', 'max_saving_percen...
#
#                                                 link  \
# 0  converse-chuck-taylor-all-star-shoreline-white...
# 1          converse-chuck-70-plus-black-3771985.html
# 2    converse-chuck-taylor-dainty-black-3200951.html
#
#                                                image  \
# 0  https://dynamic.zacdn.com/UcagckYTYNHj_zCwrvbh...
# 1  https://dynamic.zacdn.com/TcdI6iuRDtxdw6ZiyPOe...
# 2  https://dynamic.zacdn.com/cAMHGQJcI4R_n0enAxRv...
#
#                                        image_gallery  \
# 0  https://dynamic.zacdn.com/V9LjhThvpKGN0cnIvm_w...
# 1  https://dynamic.zacdn.com/BsPM7qOzpY49NesEeFVa...
# 2  https://dynamic.zacdn.com/IJnZrleNenz1BdS1Hb_A...
#
#                                          image_extra  \
# ...

# %%
url_review = 'https://www.zalora.co.id/productreviews/reviews/'
review_list = []

for index in range(0, len(product_list)):
    query_params_review = {
        'sku':f'{product_list[index]["meta"]["sku"]}',
        'token':'',
        'per_page':'40'
    }

    headers_review = {
        'authority': 'www.zalora.co.id',
        'accept': '*/*',
        'cookie': 'userLanguage=id; browserDetection=eyJ0eXBlIjoiYnJvd3NlciIsIm5hbWUiOiJDaHJvbWUiLCJjc3NDbGFzcyI6ImNocm9tZSIsInZlcnNpb24iOiIxMDcifQ%3D%3D; PHPSESSID_83d0767d2f534a23f21399428e28c076=1f00ae8006799b60f99753474279dee8; zid=478411372.1668672968; rrCookie=zItAGRRlnEuTeo5cEP2K22oCti81zcKo; ANONYMOUS_TRACKING_ID=06318d2b-9591-4f33-bb10-5da92ab4bb4c; is_guest_with_empty_cart=true; 905125419dc9d3c8f422452a786673ba=-; zalora_referer=%7B%22search.brave.com%22%3A%5B%22https%3A%5C%2F%5C%2Fsearch.brave.com%5C%2F%22%5D%7D; optimizelyEndUserId=oeu1668672970006r0.89856154814837; _gid=GA1.3.1877399038.1668672972; ajs_anonymous_id=06318d2b-9591-4f33-bb10-5da92ab4bb4c; ab.storage.deviceId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1=%7B%22g%22%3A%229611eb88-9412-89ef-10ed-e225abefde5e%22%2C%22c%22%3A1668672972721%2C%22l%22%3A1668672972721%7D; _fbp=fb.2.1668672973096.849720760; _gcl_au=1.1.1251577912.1668672973; __rtbh.sid=%7B%22eventType%22%3A%22sid%22%2C%22id%22%3A%22478411372.1668672968%22%7D; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%22iSbKqsW4cEccbmMlfS4d%22%7D; _tt_enable_cookie=1; _ttp=b6ca33dd-fe7d-40a2-b110-b591d4618095; _vz=viz_6375edd01e73b; _vz=; userSegment=men; rr_rcs=eF5jYSlN9jAxTTOwsEw10zU3NUzVNTEzTtG1TEk20jU2NjM0MjI0STQxNuPKLSvJTBEwtLA00TXUNQQAgRcNgQ; viz_sent=1; wpn_https={"status":"denied","last_shown":"Fri, 18 Nov 2022 02:15:41 GMT","shown_count":2}; _abck=3405F0D98681418EEB0DC15FEC1B1121~0~...~-1~-1~-1; bm_sz=C266EB3109FE88AAB9D7B448F43161B5~~3359289~3223862; bm_mi=E4AE6805ADAE5896EDF59870C4287FAE~~1; sessionCount=6; ak_bmsc=2929D0C8E356B20516A4380B126793FA~000000000000000000000000000000~...; pageCount=10; _gat=1; ab.storage.sessionId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1=%7B%22g%22%3A%228984390f-45b1-0a8f-fa48-b26caf6b1021%22%2C%22e%22%3A1668753456752%2C%22c%22%3A1668750430447%2C%22l%22%3A1668751656752%7D; _gat_UA-28869185-1=1; _ga_T53WSL6JBT=GS1.1.1668750426.6.1.1668751658.17.0.0; cto_bundle=XIgGsV9WeHk5SUkya2NVRXlLUGQlMkZDYmk1MGRheGhkV1dKcFdKS2FYJTJCZXJuT0txZE5SdkJZb0w1WjklMkYlMkZXeVYlMkJWWWpuTjBSaUxIc0pZUW1JVzZoNkZSU241WGhFSWhGaUxZMnBGNEtNOSUyQlRvWnIzd0VQbXlMRGpxZjVaNXpLb0hxU1ZVNUt0anhGbjVkaWtremdUR29CZXlSTmclM0QlM0Q; bm_sv=1DA75E9D7CCD1F41D774A519D85B0E77~~1; RT="sl=9&ss=1668750425919&tt=37051&obo=0&sh=1668751657285%3D9%3A0%3A37051%2C1668751164496%3D8%3A0%3A34046%2C1668751156559%3D7%3A0%3A30978%2C1668751147091%3D6%3A0%3A27069%2C1668751115723%3D5%3A0%3A22438&dm=zalora.co.id&si=0fc6470b-0f82-45c7-8969-28c6666ca231&bcn=%2F%2F684d0d46.akstat.io%2F&rl=1&ld=1668751657285&nu=https%3A%2F%2Fwww.zalora.co.id%2F&cl=1668751663544"; _ga=GA1.3.1421552235.1668672972',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    }

    response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
    product = product_list[index]
    try:
        for review in response_review['reviews']:
            review.update({"product":product})
            review_list.append(review)

        try:
            while response_review['cursor']['has_next']:
                query_params_review = {
                    'sku':f'{product_list[index]["meta"]["sku"]}',
                    'token':f'{response_review["cursor"]["next"]}',
                    'per_page':'40'
                }

                response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
                
                for review in response_review['reviews']:
                    review.update({"product":product})
                    review_list.append(review)
        except KeyError as e:
            review.update({"product":product})
            review_list.append(review)
            print("Scraping product no. "+str(index)+" sku: " + product_list[index]["meta"]["sku"] + " review done")
    except KeyError as e:
        print("Product no. "+str(index)+" sku :" + product_list[index]["meta"]["sku"] + " has no review")
# Out:
# Scraping product 0 A4044SH6198AB7GS review done
# Product 1 DC347SHD0A1717GS has no review
# Scraping product 2 A3C43SH89EB507GS review done

# %%
df_review = pd.DataFrame(review_list)
df_review
# Out:
#           id   customer_display_name  rating     sales_order_date  \
# 0   32015986                  MARWAN       5  2022-10-02 06:40:38
# 1   31709607  H********************o       5  2022-09-25 01:43:35
# 2   31589168                 o*****r       4  2022-09-21 18:19:12
# 3   30519271       c***************a       5  2022-08-31 05:28:16
# 4   23823309                 R*****a       5  2022-04-25 00:21:20
# 5   25622081                  J****g       5  2022-05-26 03:12:00
# 6   24276909                   M***y       5  2022-04-29 16:27:58
# 7   23631683                   n***n       5  2022-04-20 04:52:34
# 8   19790036              Margaretha       5  2022-02-10 03:48:16
# 9   19508939                 Kambing       5  2022-02-07 04:26:23
# 10  20256588                     J*y       5  2022-02-24 03:46:18
# 11  19427845         I*************a       5  2022-02-07 08:14:08
#
#                                                  tags         submitted_at  \
# ...

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['zaloraProductReview'] 
collection = db['polytron']

# %%
collection.insert_many(review_list)
