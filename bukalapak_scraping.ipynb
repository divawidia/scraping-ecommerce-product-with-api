# %%
import requests
import pandas as pd
from pymongo import MongoClient

# %%
store_id = 382819418
url = "https://api.bukalapak.com/stores/"+store_id+"/products"

product_list = []
# for x in range(0, ):
querystring = {"offset":"0","limit":"12","sort":"bestratingratio","store_id":f"{store_id}","access_token":"TG8jr3sL0DxL0LVxdxh1Wp6ukk--oIVeW4P8PMKJfr0mPw"}
payload = ""
headers = {"cookie": "lskjfewjrh34ghj23brjh234=bGhWVHErVFJGbVdsRkk2NENMWmMzSjU2UmRtaEorQTNIdDJEMEN6ZFVWZC9HcStENXNwNWxHbjhNL3V1cVg5dzVrbCt2MHJyMmpwSXZYTnZsdUpZSWh3anN2cWh0RmJMWDV3T0MzbEVYZW89LS1EWWprTGR1dmozVzJya3ZzZFBPekdnPT0%253D--599d45809b1e2691736b92b5fb28d15da3c97174; visid_incap_2720185=z%2FqeorcNQoGZ6p309xErgxyHdGMAAAAAQUIPAAAAAACKnL0ws4VsHAI1XbIeKiCb; nlbi_2720185=7UuIf%2BjA4gCzO9o1AkoPxgAAAAA4HbAfNdXbfifMSnUtOzb0; incap_ses_218_2720185=pzT7EZy4ekBDzlcuHn4GA8ugdGMAAAAA%2FdT0MQ3ItP6as3Gv1olsEg%3D%3D; incap_ses_959_2720185=bXE%2BFov0mXDpMGI4OA5PDSrFdGMAAAAA9oqzL6yXKZZV6b16CxlfvA%3D%3D"}
response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

data = response.json()
# for product in data["data"]:
#         result.append(product)

for x in range(0, data["meta"]["total"], 50):
    querystring_products = {"offset":f"{x}","limit":"50","sort":"bestratingratio","store_id":f"{store_id}","access_token":"TG8jr3sL0DxL0LVxdxh1Wp6ukk--oIVeW4P8PMKJfr0mPw"}

    payload_products = ""
    headers_products = {"cookie": "lskjfewjrh34ghj23brjh234=bGhWVHErVFJGbVdsRkk2NENMWmMzSjU2UmRtaEorQTNIdDJEMEN6ZFVWZC9HcStENXNwNWxHbjhNL3V1cVg5dzVrbCt2MHJyMmpwSXZYTnZsdUpZSWh3anN2cWh0RmJMWDV3T0MzbEVYZW89LS1EWWprTGR1dmozVzJya3ZzZFBPekdnPT0%253D--599d45809b1e2691736b92b5fb28d15da3c97174; visid_incap_2720185=z%2FqeorcNQoGZ6p309xErgxyHdGMAAAAAQUIPAAAAAACKnL0ws4VsHAI1XbIeKiCb; nlbi_2720185=7UuIf%2BjA4gCzO9o1AkoPxgAAAAA4HbAfNdXbfifMSnUtOzb0; incap_ses_218_2720185=LQ%2BREqqQCynrBQ8uHn4GAyqHdGMAAAAAwLnVHMp%2B4AnxLru2zi2%2B1g%3D%3D"}

    response_products = requests.request("GET", url, data=payload_products, headers=headers_products, params=querystring_products)

    data_products = response_products.json()
    for product in data_products["data"]:
        product_list.append(product)

# %%
df = pd.json_normalize(product_list)
df
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10144/973097881.py in <module>
# ----> 1 df = pd.json_normalize(result[0]['active'])
#       2 df
#
# c:\Users\wiart\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     421         data = list(data)
#     422     else:
# --> 423         raise NotImplementedError
#     424
#     425     # check to see if a simple recursive function is possible to
#
# NotImplementedError:

# %%
url_review = "https://api.bukalapak.com/product-reviews"

review_list = []

for i in range(0, len(product_list)):
    for offset in range(0, product_list[i]['rating']['user_count'], 100):
        querystring_review = {"product_id":f"{product_list[i]['id']}","offset":f"{offset}","limit":"100","aggregates[]":"ratings","access_token":"TG8jr3sL0DxL0LVxdxh1Wp6ukk--oIVeW4P8PMKJfr0mPw"}

        payload_review = ""
        headers_review = {
            "cookie": "lskjfewjrh34ghj23brjh234=bGhWVHErVFJGbVdsRkk2NENMWmMzSjU2UmRtaEorQTNIdDJEMEN6ZFVWZC9HcStENXNwNWxHbjhNL3V1cVg5dzVrbCt2MHJyMmpwSXZYTnZsdUpZSWh3anN2cWh0RmJMWDV3T0MzbEVYZW89LS1EWWprTGR1dmozVzJya3ZzZFBPekdnPT0%253D--599d45809b1e2691736b92b5fb28d15da3c97174; visid_incap_2720185=z%2FqeorcNQoGZ6p309xErgxyHdGMAAAAAQUIPAAAAAACKnL0ws4VsHAI1XbIeKiCb; nlbi_2720185=7UuIf%2BjA4gCzO9o1AkoPxgAAAAA4HbAfNdXbfifMSnUtOzb0; incap_ses_218_2720185=pzT7EZy4ekBDzlcuHn4GA8ugdGMAAAAA%2FdT0MQ3ItP6as3Gv1olsEg%3D%3D; incap_ses_959_2720185=bXE%2BFov0mXDpMGI4OA5PDSrFdGMAAAAA9oqzL6yXKZZV6b16CxlfvA%3D%3D",
            "id": "1234",
            "name": "dipa",
            "age": "22",
            "address": "jimbaran"
        }

        response_review = requests.request("GET", url_review, data=payload_review, headers=headers_review, params=querystring_review)

        data_review = response_review.json()

        for a in data_review["data"]:
            product = product_list[i]
            a.update({"product" : product})
            review_list.append(a)
    
    print("Scraping product no. "+str(i)+" id: " + product_list[i]['id'] + " review done")

# %%
df = pd.json_normalize(data_products)
df
# Out:
#      active  assurance available_countries condition couriers  \
# 0      True      False                  []      Baru       []
# 1      True      False                  []      Baru       []
# 2      True      False                  []      Baru       []
# 3      True      False                  []      Baru       []
# 4      True      False                  []      Baru       []
# ..      ...        ...                 ...       ...      ...
# 602    True      False                  []      Baru       []
# 603    True      False                  []      Baru       []
# 604    True      False                  []      Baru       []
# 605    True      False                  []      Baru       []
# 606    True      False                  []      Baru       []
#
#                created_at default_catalog  \
# 0    2021-03-19T02:58:16Z            None
# 1    2021-02-08T01:56:36Z            None
# 2    2021-06-30T02:26:14Z            None
# 3    2021-01-12T13:20:37Z            None
# 4    2021-04-16T11:13:23Z            None
# ..                    ...             ...
# 602  2021-10-26T07:32:42Z            None
# 603  2021-10-26T07:21:17Z            None
# 604  2021-10-26T07:18:04Z            None
# 605  2021-10-26T06:52:25Z            None
# 606  2021-10-26T06:49:20Z            None
#
#                                            description  digital_product  \
# 0    <p>TIDAK AKAN JEBOL setelah dicuci atau kehuja...            False
# 1    <p>TIDAK AKAN JEBOL setelah dicuci atau kehuja...            False
# 2    <p>Empuk, menambah kenyamanan saat bersepatu k...            False
# 3    <p>Proses vulkanisasi dimana sol luar sepatu d...            False
# 4    <p>TIDAK AKAN JEBOL setelah dicuci atau kehuja...            False
# ..                                                 ...              ...
# 602  <p>Bahan : </p><ul><li>Katun Combed 24s - Extr...            False
# 603  <p>Bahan : </p><ul><li>Katun Combed 24s - Extr...            False
# 604  <p>Bahan : </p><ul><li>Katun Combed 24s - Extr...            False
# 605  <p>Bahan : </p><ul><li>Katun Combed 24s - Extr...            False
# 606  <p>Bahan : </p><ul><li>Katun Combed 24s - Extr...            False
#
#      discount_percentage  ... store.sla.type  store.sla.value  \
# 0                     52  ...         normal                2
# 1                     50  ...         normal                2
# 2                     50  ...         normal                2
# 3                     50  ...         normal                2
# 4                     50  ...         normal                2
# ..                   ...  ...            ...              ...
# 602                    0  ...         normal                2
# 603                    0  ...         normal                2
# 604                    0  ...         normal                2
# 605                    0  ...         normal                2
# 606                    0  ...         normal                2
#
#     store.subscriber_amount  \
# 0                     21632
# 1                     21632
# 2                     21632
# 3                     21632
# 4                     21632
# ..                      ...
# 602                   21632
# 603                   21632
# 604                   21632
# 605                   21632
# 606                   21632
#
#                               store.term_and_condition  \
# 0    <p>Proses pengiriman disesuaikan dengan varian...
# 1    <p>Proses pengiriman disesuaikan dengan varian...
# 2    <p>Proses pengiriman disesuaikan dengan varian...
# 3    <p>Proses pengiriman disesuaikan dengan varian...
# 4    <p>Proses pengiriman disesuaikan dengan varian...
# ..                                                 ...
# 602  <p>Proses pengiriman disesuaikan dengan varian...
# 603  <p>Proses pengiriman disesuaikan dengan varian...
# 604  <p>Proses pengiriman disesuaikan dengan varian...
# 605  <p>Proses pengiriman disesuaikan dengan varian...
# 606  <p>Proses pengiriman disesuaikan dengan varian...
#
#                                   store.url warranty.cheapest  \
# 0    https://www.bukalapak.com/u/aerostreet             False
# 1    https://www.bukalapak.com/u/aerostreet             False
# 2    https://www.bukalapak.com/u/aerostreet             False
# 3    https://www.bukalapak.com/u/aerostreet             False
# 4    https://www.bukalapak.com/u/aerostreet             False
# ..                                      ...               ...
# 602  https://www.bukalapak.com/u/aerostreet             False
# 603  https://www.bukalapak.com/u/aerostreet             False
# 604  https://www.bukalapak.com/u/aerostreet             False
# 605  https://www.bukalapak.com/u/aerostreet             False
# 606  https://www.bukalapak.com/u/aerostreet             False
#
#      discount_subsidy  specs.merek  specs.type specs.tipe
# 0                 NaN          NaN         NaN        NaN
# 1                 NaN          NaN         NaN        NaN
# 2                 NaN          NaN         NaN        NaN
# 3                 NaN          NaN         NaN        NaN
# 4                 NaN          NaN         NaN        NaN
# ..                ...          ...         ...        ...
# 602               NaN          NaN         NaN         []
# 603               NaN          NaN         NaN         []
# 604               NaN          NaN         NaN         []
# 605               NaN          NaN         NaN         []
# 606               NaN          NaN         NaN         []
#
# [607 rows x 108 columns]

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['bukalapakProductReview'] 
collection = db['polytron']

# %%
collection.insert_many(review_list)
