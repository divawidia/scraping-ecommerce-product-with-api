# %%
import requests
import pandas as pd
from pymongo import MongoClient

# %%
seller_id = 10173

# %%
product_list = []

url = "https://www.zalora.co.id/_c/v1/desktop/zis_list_catalog_products"

query_params = {
    "sort":"popularity",
    "dir":"desc",
    "offset":"0",
    "limit":"300",
    "seller_id":f"{seller_id}",
    "special_price":"false",
    "all_products":"true",
    "new_products":"false",
    "top_sellers":"false",
    "catalogtype":"Main",
    "lang":"id",
    "is_brunei":"false",
    "search_suggest":"false",
    "enable_visual_sort":"true",
    "enable_filter_ads":"true",
    "compact_catalog_desktop":"false",
    "name_search":"false",
    "solr7_support":"false",
    "pick_for_you":"false",
    "learn_to_sort_catalog":"false",
    "enable_similar_term":"true",
    "enable_relevance_classifier":"true",
    "auto_correct":"true"
}

headers = {
    'authority': 'www.zalora.co.id',
    'accept': 'application/json, text/plain, */*',
    'cookie': 'userLanguage=id; PHPSESSID_83d0767d2f534a23f21399428e28c076=1f00ae8006799b60f99753474279dee8; zid=478411372.1668672968; rrCookie=zItAGRRlnEuTeo5cEP2K22oCti81zcKo; ANONYMOUS_TRACKING_ID=06318d2b-9591-4f33-bb10-5da92ab4bb4c; is_guest_with_empty_cart=true; 905125419dc9d3c8f422452a786673ba=-; optimizelyEndUserId=oeu1668672970006r0.89856154814837; ajs_anonymous_id=06318d2b-9591-4f33-bb10-5da92ab4bb4c; ab.storage.deviceId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1={"g":"9611eb88-9412-89ef-10ed-e225abefde5e","c":1668672972721,"l":1668672972721}; _fbp=fb.2.1668672973096.849720760; _gcl_au=1.1.1251577912.1668672973; __rtbh.sid={"eventType":"sid","id":"478411372.1668672968"}; __rtbh.lid={"eventType":"lid","id":"iSbKqsW4cEccbmMlfS4d"}; _tt_enable_cookie=1; _ttp=b6ca33dd-fe7d-40a2-b110-b591d4618095; _vz=viz_6375edd01e73b; _vz=; rr_rcs=eF5jYSlN9jAxTTOwsEw10zU3NUzVNTEzTtG1TEk20jU2NjM0MjI0STQxNuPKLSvJTBEwtLA00TXUNQQAgRcNgQ; zalora_referer={"hubb.link":["https:\/\/hubb.link\/"]}; userSegment=men; browserDetection=eyJ0eXBlIjoiYnJvd3NlciIsIm5hbWUiOiJDaHJvbWUiLCJjc3NDbGFzcyI6ImNocm9tZSIsInZlcnNpb24iOiIxMDgifQ==; _abck=3405F0D98681418EEB0DC15FEC1B1121~0~...~-1~-1~-1; bm_sz=91A7FF7F01F84F7B88BAC862A488A4D3~~3228727~4471089; bm_mi=97EE32A8312B4EDF2FE6786BE19AD1AA~~1; _gid=GA1.3.231015447.1670567964; sessionCount=24; ak_bmsc=8472A91CDFA0365D08A65E5C6D021FA8~000000000000000000000000000000~...; wpn_https={"status":"denied","last_shown":"Fri, 09 Dec 2022 06:39:30 GMT","shown_count":1}; viz_sent=1; pageCount=6; RT="dm=zalora.co.id&si=0fc6470b-0f82-45c7-8969-28c6666ca231&ss=1670567961340&sl=6&tt=18844&obo=0&sh=1670568039161=6:0:18844,1670568029297=5:0:15277,1670568011379=4:0:12594,1670567975326=3:0:8627,1670567970083=2:0:6613&rl=1&ld=1670568039161"; _ga=GA1.1.1421552235.1668672972; cto_bundle=AGWA-19TaVJxZVZPYVNodlRORyUyQmhMSkNVZ29rODBETFlvJTJCWFlyR3FPSUtYY0FHWDlHTU9rSG8weXNpaTY3U3JYenk2REFyNSUyRm96ZEFSNW1RSDVaTklFZWRwV3Q2YnByeTVDSVB6ME9jcUQ4UmpYWTZDNmM0JTJCdU50a3lXUyUyQk5XV3Jjc2VDYlJjbnpNa3QlMkZHSXE1Y1BWTEdNQWclM0QlM0Q; ab.storage.sessionId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1={"g":"6da3f7f0-55ff-8c73-8888-c16145850331","e":1670569839924,"c":1670567965022,"l":1670568039924}; bm_sv=4D4B5A9E6E6F502700A226D3AE1F0166~~1; _ga_T53WSL6JBT=GS1.1.1670567966.26.1.1670568048.39.0.0',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
}

data = requests.request("GET", url, headers=headers, params=query_params).json()

for offset in range(0, data['response']['numFound'], 300):
    query_params_productlist = {
        "sort":"popularity",
        "dir":"desc",
        "offset":f"{offset}",
        "limit":"300",
        "seller_id":f"{seller_id}",
        "special_price":"false",
        "all_products":"true",
        "new_products":"false",
        "top_sellers":"false",
        "catalogtype":"Main",
        "lang":"id",
        "is_brunei":"false",
        "search_suggest":"false",
        "enable_visual_sort":"true",
        "enable_filter_ads":"true",
        "compact_catalog_desktop":"false",
        "name_search":"false",
        "solr7_support":"false",
        "pick_for_you":"false",
        "learn_to_sort_catalog":"false",
        "enable_similar_term":"true",
        "enable_relevance_classifier":"true",
        "auto_correct":"true"
    }

    productlist = requests.request("GET", url, headers=headers, params=query_params_productlist).json()
    for product in productlist['response']['docs']:
        product_list.append(product)

    print("Scraping product list offset: "+str(offset)+" done")
# Out:
# Scraping product list offset: 0 done
# Scraping product list offset: 300 done

# %%
df = pd.DataFrame(product_list)
df
# Out:
#                                                   meta  \
# 0    {'sku': '0C99CBE1D76698GS', 'max_saving_percen...
# 1    {'sku': '6F47ABE2F4A7CDGS', 'max_saving_percen...
# 2    {'sku': '618B0BE7C2FCFEGS', 'max_saving_percen...
# 3    {'sku': '30696BE238702BGS', 'max_saving_percen...
# 4    {'sku': '08460BE085585AGS', 'max_saving_percen...
# ..                                                 ...
# 314  {'sku': '471AEBEFE17131GS', 'max_saving_percen...
# 315  {'sku': '5B7CABEA070F05GS', 'max_saving_percen...
# 316  {'sku': '4298DBEF8EF8A1GS', 'max_saving_percen...
# 317  {'sku': '19F6BBEFCE2D72GS', 'max_saving_percen...
# 318  {'sku': '2F70DBE93C8FB5GS', 'max_saving_percen...
#
#                                                   link  \
# 0    somethinc-somethinc-ceramic-skin-saviour-moist...
# 1    somethinc-somethinc-x-han-so-hee-cloud-skin-lo...
# 2    somethinc-somethinc-10-niacinamide-moisture-sa...
# 3    somethinc-somethinc-complete-each-other-toner-...
# ...

# %%
url_review = 'https://www.zalora.co.id/productreviews/reviews/'
review_list = []

for index in range(0, len(product_list)):
    query_params_review = {
        'sku':f'{product_list[index]["meta"]["sku"]}',
        'token':'',
        'per_page':'40'
    }

    headers_review = {
        'authority': 'www.zalora.co.id',
        'accept': '*/*',
        'cookie': 'userLanguage=id; PHPSESSID_83d0767d2f534a23f21399428e28c076=1f00ae8006799b60f99753474279dee8; zid=478411372.1668672968; rrCookie=zItAGRRlnEuTeo5cEP2K22oCti81zcKo; ANONYMOUS_TRACKING_ID=06318d2b-9591-4f33-bb10-5da92ab4bb4c; is_guest_with_empty_cart=true; 905125419dc9d3c8f422452a786673ba=-; optimizelyEndUserId=oeu1668672970006r0.89856154814837; ajs_anonymous_id=06318d2b-9591-4f33-bb10-5da92ab4bb4c; ab.storage.deviceId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1={"g":"9611eb88-9412-89ef-10ed-e225abefde5e","c":1668672972721,"l":1668672972721}; _fbp=fb.2.1668672973096.849720760; _gcl_au=1.1.1251577912.1668672973; __rtbh.sid={"eventType":"sid","id":"478411372.1668672968"}; __rtbh.lid={"eventType":"lid","id":"iSbKqsW4cEccbmMlfS4d"}; _tt_enable_cookie=1; _ttp=b6ca33dd-fe7d-40a2-b110-b591d4618095; _vz=viz_6375edd01e73b; _vz=; rr_rcs=eF5jYSlN9jAxTTOwsEw10zU3NUzVNTEzTtG1TEk20jU2NjM0MjI0STQxNuPKLSvJTBEwtLA00TXUNQQAgRcNgQ; zalora_referer={"hubb.link":["https:\/\/hubb.link\/"]}; userSegment=men; browserDetection=eyJ0eXBlIjoiYnJvd3NlciIsIm5hbWUiOiJDaHJvbWUiLCJjc3NDbGFzcyI6ImNocm9tZSIsInZlcnNpb24iOiIxMDgifQ==; _abck=3405F0D98681418EEB0DC15FEC1B1121~0~...~-1~-1~-1; bm_sz=91A7FF7F01F84F7B88BAC862A488A4D3~~3228727~4471089; bm_mi=97EE32A8312B4EDF2FE6786BE19AD1AA~~1; _gid=GA1.3.231015447.1670567964; sessionCount=24; ak_bmsc=8472A91CDFA0365D08A65E5C6D021FA8~000000000000000000000000000000~...; wpn_https={"status":"denied","last_shown":"Fri, 09 Dec 2022 06:39:30 GMT","shown_count":1}; viz_sent=1; cto_bundle=AGWA-19TaVJxZVZPYVNodlRORyUyQmhMSkNVZ29rODBETFlvJTJCWFlyR3FPSUtYY0FHWDlHTU9rSG8weXNpaTY3U3JYenk2REFyNSUyRm96ZEFSNW1RSDVaTklFZWRwV3Q2YnByeTVDSVB6ME9jcUQ4UmpYWTZDNmM0JTJCdU50a3lXUyUyQk5XV3Jjc2VDYlJjbnpNa3QlMkZHSXE1Y1BWTEdNQWclM0QlM0Q; _ga=GA1.3.1421552235.1668672972; _gat_UA-28869185-1=1; _gali=productReviewsTab; _ga_T53WSL6JBT=GS1.1.1670567966.26.1.1670568636.60.0.0; pageCount=7; bm_sv=4D4B5A9E6E6F502700A226D3AE1F0166~~1; _gat=1; ab.storage.sessionId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1={"g":"6da3f7f0-55ff-8c73-8888-c16145850331","e":1670570438991,"c":1670567965022,"l":1670568638991}; RT="dm=zalora.co.id&si=0fc6470b-0f82-45c7-8969-28c6666ca231&ss=1670567961340&sl=6&tt=18844&obo=0&sh=1670568039161=6:0:18844,1670568029297=5:0:15277,1670568011379=4:0:12594,1670567975326=3:0:8627,1670567970083=2:0:6613&rl=1&nu=https://www.zalora.co.id/&cl=1670568639858"',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    }

    response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
    product = product_list[index]
    try:
        for review in response_review['reviews']:
            review.update({"product":product})
            review_list.append(review)

        try:
            while response_review['cursor']['has_next']:
                query_params_review = {
                    'sku':f'{product_list[index]["meta"]["sku"]}',
                    'token':f'{response_review["cursor"]["next"]}',
                    'per_page':'40'
                }

                response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
                
                for review in response_review['reviews']:
                    review.update({"product":product})
                    review_list.append(review)
        except KeyError as e:
            print("Scraping product no. "+str(index)+" sku: " + product_list[index]["meta"]["sku"] + " review done")
    except KeyError as e:
        print("Product no. "+str(index)+" sku :" + product_list[index]["meta"]["sku"] + " has no review")
# Out:
# Scraping product no. 0 sku: 0C99CBE1D76698GS review done
# Product no. 1 sku :6F47ABE2F4A7CDGS has no review
# Scraping product no. 2 sku: 618B0BE7C2FCFEGS review done
# Scraping product no. 3 sku: 30696BE238702BGS review done
# Product no. 4 sku :08460BE085585AGS has no review
# Product no. 5 sku :32F7EBE9CE572DGS has no review
# Scraping product no. 6 sku: 1A4ADBE53A7493GS review done
# Scraping product no. 7 sku: 2DFCDBE604368FGS review done
# Product no. 8 sku :0887EBE11FD84EGS has no review
# Scraping product no. 9 sku: A3AC9BEC814B0CGS review done
# Scraping product no. 10 sku: 0C033BE7AB489BGS review done
# Scraping product no. 11 sku: 0EEADBE9629B18GS review done
# Scraping product no. 12 sku: 8EDD7BE596E59EGS review done
# Product no. 13 sku :A5949BEEA01520GS has no review
# Scraping product no. 14 sku: F3C70BEB088C66GS review done
# Scraping product no. 15 sku: 70D30BE411751BGS review done
# Scraping product no. 16 sku: A3CA2BE0A16BB6GS review done
# ...

# %%
df_review = pd.DataFrame(review_list)
df_review
# Out:
#            id customer_display_name  rating     sales_order_date  \
# 0    34303879                 Hersa       5  2022-11-13 06:07:29
# 1    29369494             Khoiriyah       5  2022-08-05 11:12:42
# 2    31899745                 H***a       5  2022-09-29 01:05:27
# 3    16506177         Ika marthalia       5  2021-12-17 16:17:34
# 4    17284951       Annisa Aurellia       5  2022-01-01 11:43:23
# ..        ...                   ...     ...                  ...
# 862  28555754               •*****a       5  2022-07-19 11:08:35
# 863  23663109                g****a       5  2022-04-21 14:11:19
# 864  30108839                 S***i       5  2022-08-21 09:44:51
# 865  32565889                 Sinta       3  2022-10-10 08:59:10
# 866  30849015                Soleha       5  2022-09-04 05:47:27
#
#                                                   tags         submitted_at  \
# 0    [{'id': 2149, 'label': 'Melembapkan'}, {'id': ...  2022-11-20 05:53:04
# ...

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
localhost = "mongodb://localhost:27017"

# %%
client = MongoClient(localhost)
db = client['zalora'] 
collection = db['somethinc']

# %%
collection.insert_many(review_list)
