# %%
import requests
import pandas as pd
from pymongo import MongoClient
from seleniumwire import webdriver
from seleniumwire.utils import decode
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import json
import time

# %% [markdown]
# SCRAPING DATA PRODUK BERDASARKAN PENCARIAN BRAND

# %%
driver = webdriver.Chrome()
product_list = []
driver.get(f'https://shopee.co.id/buyer/login?next=https%3A%2F%2Fshopee.co.id%2F')
username = driver.find_element(By.NAME, 'loginKey')
password = driver.find_element(By.NAME, 'password')
username.send_keys('dipawiartha')
password.send_keys('Wiartha2001')
time.sleep(5)
driver.find_element(By.XPATH, '//button[text()="Log in"]').click()
time.sleep(8)
driver.find_element(By.CLASS_NAME, 'E62KYV').click()
time.sleep(2)
driver.find_element(By.XPATH, '//button[text()="OK"]').click()
time.sleep(20)

for page in range(0, 10):
  driver.get(f'https://shopee.co.id/search?keyword=rexus&page={page}&skipShuffle=true&sortBy=sales')

  # Access requests via the `requests` attribute
  for request in driver.requests:
      if request.response:
        if request.url.startswith('https://shopee.co.id/api/v4/search/search_items?by=sales&keyword='):
          response = request.response
          body = decode(response.body, response.headers.get('Content-Encoding', 'Identity'))
          decode_body = body.decode('utf8')
          json_data = json.loads(decode_body)
          for item in json_data['items']:
            product_list.append(item)
  print('scrapped page: '+str(page))
# Out:
# scrapped page: 0
# scrapped page: 1
# scrapped page: 2
# scrapped page: 3
# scrapped page: 4
# scrapped page: 5
# scrapped page: 6
# scrapped page: 7
# scrapped page: 8
# scrapped page: 9

# %%
df = pd.json_normalize(product_list)
df
# Out:
#             adsid  campaignid distance  match_type     ads_keyword  \
# 0     120799763.0  75794902.0     None         1.0  audio wireless
# 1       2751651.0   2751651.0     None         1.0  wireless mouse
# 2       2751686.0   2751686.0     None         1.0   mouse wireles
# 3      78542420.0  48741066.0     None         1.0          baseus
# 4     119792131.0  84779877.0     None         1.0  headset gaming
# ...           ...         ...      ...         ...             ...
# 2835          NaN         NaN     None         NaN            None
# 2836          NaN         NaN     None         NaN            None
# 2837          NaN         NaN     None         NaN            None
# 2838          NaN         NaN     None         NaN            None
# 2839          NaN         NaN     None         NaN            None
#
#                                          deduction_info collection_id  \
# 0     SXdNMVpBQUFBQUJrUm5KRwtV3mQ+iFiJeTeWtpuzqddfCA...          None
# ...

# %%
produk_duplikat = df[df.duplicated(['itemid'], keep=False)]
produk_duplikat
# Out:
#             adsid  campaignid distance  match_type     ads_keyword  \
# 0     120799763.0  75794902.0     None         1.0  audio wireless
# 1       2751651.0   2751651.0     None         1.0  wireless mouse
# 2       2751686.0   2751686.0     None         1.0   mouse wireles
# 3      78542420.0  48741066.0     None         1.0          baseus
# 4     119792131.0  84779877.0     None         1.0  headset gaming
# ...           ...         ...      ...         ...             ...
# 2815          NaN         NaN     None         NaN            None
# 2816          NaN         NaN     None         NaN            None
# 2817          NaN         NaN     None         NaN            None
# 2818          NaN         NaN     None         NaN            None
# 2819          NaN         NaN     None         NaN            None
#
#                                          deduction_info collection_id  \
# 0     SXdNMVpBQUFBQUJrUm5KRwtV3mQ+iFiJeTeWtpuzqddfCA...          None
# ...

# %%
df_produk2 = df.drop_duplicates(subset=['itemid'], keep="first")
df_produk2
# Out:
#             adsid  campaignid distance  match_type     ads_keyword  \
# 0     120799763.0  75794902.0     None         1.0  audio wireless
# 1       2751651.0   2751651.0     None         1.0  wireless mouse
# 2       2751686.0   2751686.0     None         1.0   mouse wireles
# 3      78542420.0  48741066.0     None         1.0          baseus
# 4     119792131.0  84779877.0     None         1.0  headset gaming
# ...           ...         ...      ...         ...             ...
# 2835          NaN         NaN     None         NaN            None
# 2836          NaN         NaN     None         NaN            None
# 2837          NaN         NaN     None         NaN            None
# 2838          NaN         NaN     None         NaN            None
# 2839          NaN         NaN     None         NaN            None
#
#                                          deduction_info collection_id  \
# 0     SXdNMVpBQUFBQUJrUm5KRwtV3mQ+iFiJeTeWtpuzqddfCA...          None
# ...

# %%
df_produk3 = df_produk2[df_produk2["item_basic.name"].str.contains("REXUS|Rexus|rexus")]
df_produk3
# Out:
#       adsid  campaignid distance  match_type ads_keyword deduction_info  \
# 5       NaN         NaN     None         NaN        None           None
# 6       NaN         NaN     None         NaN        None           None
# 7       NaN         NaN     None         NaN        None           None
# 8       NaN         NaN     None         NaN        None           None
# 9       NaN         NaN     None         NaN        None           None
# ...     ...         ...      ...         ...         ...            ...
# 2835    NaN         NaN     None         NaN        None           None
# 2836    NaN         NaN     None         NaN        None           None
# 2837    NaN         NaN     None         NaN        None           None
# 2838    NaN         NaN     None         NaN        None           None
# 2839    NaN         NaN     None         NaN        None           None
#
#      collection_id display_name campaign_stock  \
# 5             None         None           None
# ...

# %%
result_review = []

# %%
url_review = "https://shopee.co.id/api/v2/item/get_ratings"

for i in range(0, len(product_list)):
    querystring_review = {
        "filter":"0",
        "flag":"1",
        "itemid":f"{product_list[i]['itemid']}",
        "limit":"50",
        "offset":"0",
        "shopid":f"{product_list[i]['shopid']}",
        "type":"0"
    }
    headers_review = {
        'authority': 'shopee.co.id',
        'accept': '*/*',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language':'en-US,en;q=0.9,id;q=0.8,ja;q=0.7',
        'if-none-match-': '55b03-5d3a1cd914f17cf4a6796de72977d3ba',
        'cookie': '__LOCALE__null=ID; csrftoken=8Qs3cIItKMOm32ijJfpHIQsyhuB16wXF; REC_T_ID=2c5bbe52-2db9-11ed-a70a-b47af1499c50; SPC_F=S6e8zBu7JvGYL9fRdFwNdSnTqTyIZDbX; REC_T_ID=2c5e81b4-2db9-11ed-8680-7ec556a0edb3; _fbp=fb.2.1662450886480.1740229127; _QPWSDCXHZQA=e658f935-658f-4916-a174-98f35939b136; _tt_enable_cookie=1; _ttp=
4Shkw98gCpW3cEYBL0=; SPC_T_IV=QUxjU3BMb01kY0RPa2doTg==; SPC_SI=IAM1ZAAAAABYeTlCcEVDc+vdRwAAAAAATlVaeFJrSTM=; _gid=GA1.3.1555358899.1681632200; shopee_webUnique_ccd=NrZLtuUXvz44Zbx5eUQJog==|05QcjaX+zqX61vQ23iVtqUtV4zY8O0mAA+VE+c3oBNyWfL2//ZnvNSm4JsOZVFX2Tn3PvZvaFkmhuZXjYfADAieYzjDee+Sc9hGH|X4VTKfzSV+xKpt9b|06|3; ds=5fb3d86a4bf2d414d6bb1ed47e8be73f; AMP_TOKEN=$NOT_FOUND; _ga=GA1.3.1338607349.1662450890; _dc_gtm_UA-61904553-8=1; _ga_SW6D8G0HXK=GS1.1.1681762355.159.1.1681762426.58.0.0; SPC_EC=UXc4dkNjNzhsVjQ5M0h1QsujxIitlKIkBgnE/qu58p+lsIxPJVQ8mDkY44MJiRoGRqtHNEuQwli/YAuKkYeOGxZKUlY7E1sqCGEvN3keaL9B/VDboztj30Wn6A3AILVc8xA9Dyo6aUQvKmn3SVazyPuvz8Uy77Gha6qOWLiQY2A=',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36 Edg/112.0.1722.48'
    }
    response_review = requests.request("GET", url=url_review, headers=headers_review, params=querystring_review,verify=False).json()

    for offset in range(0, response_review["data"]["item_rating_summary"]['rating_total'], 50):
        querystring_review2 = {
            "filter":"0",
            "flag":"1",
            "itemid":f"{product_list[i]['itemid']}",
            "limit":"50",
            "offset":f"{offset}",
            "shopid":f"{product_list[i]['shopid']}",
            "type":"0"
        }

        response_review2 = requests.request("GET", url=url_review, headers=headers_review, params=querystring_review2,verify=False)
        
        data_review = response_review2.json()
        try:
            for review in data_review['data']['ratings']:
                result_review.append(review)
            print("scraped review product no. "+str(i)+" id: " + str(product_list[i]['itemid']) + " offset: "+str(offset))
        except:
            print(data_review)
        if offset == 3000:
            break
    print("Scraping product no. "+str(i)+" id: " + str(product_list[i]['itemid']) + " review done")
# Out:
# c:\Users\wiart\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'shopee.co.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\wiart\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'shopee.co.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# scraped review product no. 0 id: 15391405550 offset: 0
# ...

# %%
df_review = pd.json_normalize(result_review)
df_review
# Out:
#                 orderid       itemid        cmtid       ctime  rating  \
# 0       129291894253256  15391405550  10739615937  1675919104       1
# 1       129099865233059  15391405550  10719198120  1675692768       1
# 2       124611968294324  15391405550  10328873364  1671195680       1
# 3       130086564224267  15391405550  10802491140  1676621583       1
# 4       128799035277066  15391405550  10680417604  1675314699       1
# ...                 ...          ...          ...         ...     ...
# 131601   97730840217449    465611741   7423925146  1644238804       1
# 131602   49718145060273    465611741   2797343030  1596728344      -1
# 131603  121165267139227    465611741  10103494987  1668863383       1
# 131604   95241376017219    465611741   7160334206  1641631503       1
# 131605   53181271300321    465611741   2971092081  1599648846       1
#
#            userid     shopid  \
# 0       267392362  619272912
# 1        78598945  619272912
# 2        29806758  619272912
# ...

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productreviewecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
localhost = "mongodb://localhost:27017"

# %%
client = MongoClient(localhost)
db = client['shopee'] 
collection = db['erigo2']

# %%
collection.insert_many(result_review)

# %%
data = collection.find()

data
