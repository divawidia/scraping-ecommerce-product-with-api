# %%
import requests
import pandas as pd
from pymongo import MongoClient

# %%
seller_id = 9198

# %%
product_list = []

url = "https://www.zalora.co.id/_c/v1/desktop/zis_list_catalog_products"

query_params = {
    "sort":"popularity",
    "dir":"desc",
    "offset":"0",
    "limit":"300",
    "seller_id":f"{seller_id}",
    "special_price":"false",
    "all_products":"true",
    "new_products":"false",
    "top_sellers":"false",
    "catalogtype":"Main",
    "lang":"id",
    "is_brunei":"false",
    "search_suggest":"false",
    "enable_visual_sort":"true",
    "enable_filter_ads":"true",
    "compact_catalog_desktop":"false",
    "name_search":"false",
    "solr7_support":"false",
    "pick_for_you":"false",
    "learn_to_sort_catalog":"false",
    "enable_similar_term":"true",
    "enable_relevance_classifier":"true",
    "auto_correct":"true"
}

headers = {
    'authority': 'www.zalora.co.id',
    'accept': 'application/json, text/plain, */*',
    'cookie': 'userLanguage=id; PHPSESSID_83d0767d2f534a23f21399428e28c076=1f00ae8006799b60f99753474279dee8; zid=478411372.1668672968; rrCookie=zItAGRRlnEuTeo5cEP2K22oCti81zcKo; ANONYMOUS_TRACKING_ID=06318d2b-9591-4f33-bb10-5da92ab4bb4c; is_guest_with_empty_cart=true; 905125419dc9d3c8f422452a786673ba=-; optimizelyEndUserId=oeu1668672970006r0.89856154814837; ajs_anonymous_id=06318d2b-9591-4f33-bb10-5da92ab4bb4c; ab.storage.deviceId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1={"g":"9611eb88-9412-89ef-10ed-e225abefde5e","c":1668672972721,"l":1668672972721}; _fbp=fb.2.1668672973096.849720760; _gcl_au=1.1.1251577912.1668672973; __rtbh.sid={"eventType":"sid","id":"478411372.1668672968"}; __rtbh.lid={"eventType":"lid","id":"iSbKqsW4cEccbmMlfS4d"}; _tt_enable_cookie=1; _ttp=b6ca33dd-fe7d-40a2-b110-b591d4618095; _vz=viz_6375edd01e73b; _vz=; rr_rcs=eF5jYSlN9jAxTTOwsEw10zU3NUzVNTEzTtG1TEk20jU2NjM0MjI0STQxNuPKLSvJTBEwtLA00TXUNQQAgRcNgQ; browserDetection=eyJ0eXBlIjoiYnJvd3NlciIsIm5hbWUiOiJDaHJvbWUiLCJjc3NDbGFzcyI6ImNocm9tZSIsInZlcnNpb24iOiIxMDcifQ==; _gid=GA1.3.39363069.1669796693; wpn_https={"status":"denied","last_shown":"Wed, 30 Nov 2022 08:25:13 GMT","shown_count":1}; viz_sent=1; _abck=3405F0D98681418EEB0DC15FEC1B1121~0~...~-1~-1~-1; bm_sz=486AFBD725D8C39814029A918F47A805~~4408376~3617347; zalora_referer={"hubb.link":["https:\/\/hubb.link\/"]}; sessionCount=17; ak_bmsc=0D1B38B10DE93F247FEDB9C1DEBE7CE1~000000000000000000000000000000~...; userSegment=men; bm_sv=DB7A56B4E9ACB0ACAF44BAC20C9DF15D~~1; pageCount=46; ab.storage.sessionId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1={"g":"ee0c3641-1965-ed32-cc3b-487630d551cb","e":1669821119003,"c":1669816384262,"l":1669819319003}; _ga_T53WSL6JBT=GS1.1.1669816381.17.1.1669819320.3.0.0; _ga=GA1.1.1421552235.1668672972; cto_bundle=mZBwTV82dSUyQmtZdFNpMll4WHYlMkJNWFVQSkxJOWtnS1dhTXMxcm10UVdaeEpkJTJCdFJCcGJQQm5CUzElMkJOMlE1Sk5iZyUyQmVkWFlVUTdWUm9aTiUyQno1bWlvMGtLa21tbiUyQjFhZWJ2bXUyQUNBSjRCaUlRUnFkRmJFNXglMkJKT1F4VTVYZjhOMSUyRmFLSjA0UzRqZCUyRmJ0aFQweldHaTlnMmdZdyUzRCUzRA; _gat=1; RT="dm=zalora.co.id&si=0fc6470b-0f82-45c7-8969-28c6666ca231&ss=1669818753069&sl=6&tt=18671&obo=0&sh=1669819319466=6:0:18671,1669819309783=5:0:15263,1669819305669=4:0:12008,1669819287020=3:0:9508,1669819262166=2:0:6270&bcn=//684d0d46.akstat.io/&rl=1"',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
}

data = requests.request("GET", url, headers=headers, params=query_params).json()

for offset in range(0, data['response']['numFound'], 300):
    query_params_productlist = {
        "sort":"popularity",
        "dir":"desc",
        "offset":f"{offset}",
        "limit":"300",
        "seller_id":f"{seller_id}",
        "special_price":"false",
        "all_products":"true",
        "new_products":"false",
        "top_sellers":"false",
        "catalogtype":"Main",
        "lang":"id",
        "is_brunei":"false",
        "search_suggest":"false",
        "enable_visual_sort":"true",
        "enable_filter_ads":"true",
        "compact_catalog_desktop":"false",
        "name_search":"false",
        "solr7_support":"false",
        "pick_for_you":"false",
        "learn_to_sort_catalog":"false",
        "enable_similar_term":"true",
        "enable_relevance_classifier":"true",
        "auto_correct":"true"
    }

    productlist = requests.request("GET", url, headers=headers, params=query_params_productlist).json()
    for product in productlist['response']['docs']:
        product_list.append(product)

# %%
df = pd.json_normalize(product_list)
df
# Out:
#                                                    link  \
# 0     geoff-max-athletica-official-shop-larryflow-bl...
# 1     geoff-max-athletica-official-shop-larryflow-da...
# 2     geoff-max-athletica-official-shop-flash-ghost-...
# 3     geoff-max-athletica-official-shop-rx-king-blac...
# 4     geoff-max-athletica-official-shop-rx-king-blue...
# ...                                                 ...
# 1245  geoff-max-geoff-max-x-pacman-inky-white-slippe...
# 1246  geoff-max-athletica-official-shop-argon-all-bl...
# 1247  geoff-max-geoff-max-official-boston-brown-gum-...
# 1248  geoff-max-geoff-max-official-timeless-brown-wh...
# 1249  geoff-max-geoff-max-official-timeless-hi-light...
#
#                                                   image  \
# 0     https://dynamic.zacdn.com/KOvDlNN1Ji54T2h2jrgx...
# 1     https://dynamic.zacdn.com/gSDSFKOa-zH7U2LxyHyJ...
# 2     https://dynamic.zacdn.com/h_IXm7lBM6-WBk9USiyk...
# 3     https://dynamic.zacdn.com/MQFXMAOCfAEuw8NOh2jn...
# ...

# %%
url_review = 'https://www.zalora.co.id/productreviews/reviews/'
review_list = []

for index in range(0, len(product_list)):
    query_params_review = {
        'sku':f'{product_list[index]["meta"]["sku"]}',
        'token':'',
        'per_page':'40'
    }

    headers_review = {
        'authority': 'www.zalora.co.id',
        'accept': '*/*',
        'cookie': 'userLanguage=id; PHPSESSID_83d0767d2f534a23f21399428e28c076=1f00ae8006799b60f99753474279dee8; zid=478411372.1668672968; rrCookie=zItAGRRlnEuTeo5cEP2K22oCti81zcKo; ANONYMOUS_TRACKING_ID=06318d2b-9591-4f33-bb10-5da92ab4bb4c; is_guest_with_empty_cart=true; 905125419dc9d3c8f422452a786673ba=-; optimizelyEndUserId=oeu1668672970006r0.89856154814837; ajs_anonymous_id=06318d2b-9591-4f33-bb10-5da92ab4bb4c; ab.storage.deviceId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1={"g":"9611eb88-9412-89ef-10ed-e225abefde5e","c":1668672972721,"l":1668672972721}; _fbp=fb.2.1668672973096.849720760; _gcl_au=1.1.1251577912.1668672973; __rtbh.sid={"eventType":"sid","id":"478411372.1668672968"}; __rtbh.lid={"eventType":"lid","id":"iSbKqsW4cEccbmMlfS4d"}; _tt_enable_cookie=1; _ttp=b6ca33dd-fe7d-40a2-b110-b591d4618095; _vz=viz_6375edd01e73b; _vz=; rr_rcs=eF5jYSlN9jAxTTOwsEw10zU3NUzVNTEzTtG1TEk20jU2NjM0MjI0STQxNuPKLSvJTBEwtLA00TXUNQQAgRcNgQ; browserDetection=eyJ0eXBlIjoiYnJvd3NlciIsIm5hbWUiOiJDaHJvbWUiLCJjc3NDbGFzcyI6ImNocm9tZSIsInZlcnNpb24iOiIxMDcifQ==; _gid=GA1.3.39363069.1669796693; wpn_https={"status":"denied","last_shown":"Wed, 30 Nov 2022 08:25:13 GMT","shown_count":1}; viz_sent=1; _abck=3405F0D98681418EEB0DC15FEC1B1121~0~...~-1~-1~-1; bm_sz=486AFBD725D8C39814029A918F47A805~~4408376~3617347; zalora_referer={"hubb.link":["https:\/\/hubb.link\/"]}; sessionCount=17; ak_bmsc=0D1B38B10DE93F247FEDB9C1DEBE7CE1~000000000000000000000000000000~...; userSegment=men; _gat=1; cto_bundle=ESFFxV9nUnprRmFueEFDaTB4JTJCS3NUdzR3djZsbWhxcWR0MlQyJTJCRWtSVVdrNmJmRXVXTjNKUUp4YmE1bXdUTHBkeHFhNXJGTXdXV21lRVdhVlR0MGNjbEh3S3JaZEJzcER5V3NuRm1LJTJCN004eWZ0TmV1S1d1MWlvRlZpdXpON2d2ajJtM2l0amIzWU8zMFIwZ0FVOVRYJTJCRW1lUSUzRCUzRA; _gali=6C82DSHC89FF02GS; _ga_T53WSL6JBT=GS1.1.1669816381.17.1.1669819487.33.0.0; pageCount=56; _ga=GA1.3.1421552235.1668672972; bm_sv=DB7A56B4E9ACB0ACAF44BAC20C9DF15D~~1; ab.storage.sessionId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1={"g":"ee0c3641-1965-ed32-cc3b-487630d551cb","e":1669821289999,"c":1669816384262,"l":1669819489999}; RT="dm=zalora.co.id&si=0fc6470b-0f82-45c7-8969-28c6666ca231&ss=1669818753069&sl=15&tt=51398&obo=0&sh=1669819482211=15:0:51398,1669819478407=14:0:47545,1669819474392=13:0:44213,1669819470159=12:0:39982,1669819466328=11:0:36763&bcn=//684d0d46.akstat.io/&rl=1&nu=https://www.zalora.co.id/&cl=1669819490492"',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    }

    response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
    product = product_list[index]
    try:
        for review in response_review['reviews']:
            review.update({"product":product})
            review_list.append(review)

        try:
            while response_review['cursor']['has_next']:
                query_params_review = {
                    'sku':f'{product_list[index]["meta"]["sku"]}',
                    'token':f'{response_review["cursor"]["next"]}',
                    'per_page':'40'
                }

                response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
                
                for review in response_review['reviews']:
                    review.update({"product":product})
                    review_list.append(review)
        except KeyError as e:
            print("Scraping product no. "+str(index)+" sku: " + product_list[index]["meta"]["sku"] + " review done")
    except KeyError as e:
        print("Product no. "+str(index)+" sku :" + product_list[index]["meta"]["sku"] + " has no review")
# Out:
# Product no. 0 sku :BEDCCSHCCFC076GS has no review
# Product no. 1 sku :20A10SH4376431GS has no review
# Product no. 2 sku :6404BSHBC061B0GS has no review
# Product no. 3 sku :FCED9SH1B7567FGS has no review
# Scraping product no. 4 sku: 6C82DSHC89FF02GS review done
# Product no. 5 sku :3CC25SHFA08A54GS has no review
# Product no. 6 sku :F1192SHF07328FGS has no review
# Product no. 7 sku :82883SH488F427GS has no review
# Product no. 8 sku :D4DC4SH7AED659GS has no review
# Scraping product no. 9 sku: 30257SH184B799GS review done
# Scraping product no. 10 sku: 37B84SH62DD601GS review done
# Product no. 11 sku :08183SH2FCE405GS has no review
# Product no. 12 sku :39B75SHDA750A5GS has no review
# Product no. 13 sku :BC5BFSHE64F757GS has no review
# Product no. 14 sku :FDEDESH57F6DF8GS has no review
# Product no. 15 sku :15CC5SHC37F66EGS has no review
# Product no. 16 sku :AEEB1SH86D2B1DGS has no review
# Product no. 17 sku :CE48CSH21E5139GS has no review
# ...

# %%
df_review = pd.json_normalize(review_list)
df_review
# Out:
#            id customer_display_name  rating     sales_order_date  \
# 0    17796540                 Endha       4  2022-01-08 03:10:19
# 1    22326960                E****A       5  2022-04-02 13:08:47
# 2    30555941                 A***i       5  2022-09-02 01:59:13
# 3    25651224              Antonius       5  2022-05-24 03:17:39
# 4    11380903             Mey Yacob       5  2021-10-15 14:33:58
# ..        ...                   ...     ...                  ...
# 166  16959960                 M***i       5  2021-12-25 15:12:44
# 167  14583899                  Desy       4  2021-11-28 10:09:15
# 168  16302702                 Faldy       5  2021-12-15 06:39:06
# 169  19926184                 D***h       4  2022-02-17 16:48:08
# 170  26281921                   a*n       5  2022-06-04 08:25:22
#
#                                                   tags         submitted_at  \
# 0    [{'id': 2044, 'label': 'Kualitas sangat baik'}...  2022-05-21 13:06:05
# ...

# %%
df_review = pd.json_normalize(
    review_list[16],
    record_path = ['tags'])
df_review
# Out:
#      id                 label
# 0  2074  Kualitas sangat baik
# 1  2075            Ukuran pas
# 2  2076   Harga sangat sesuai
# 3  2077      Sesuai deskripsi
# 4  2078      Bagus dan nyaman

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['zaloraProductReview'] 
collection = db['geoffMax']

# %%
collection.insert_many(review_list)
