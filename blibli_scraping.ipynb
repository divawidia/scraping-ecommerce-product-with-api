# %%
import requests
import pandas as pd

# %%
id_merchant = "PON-00045"
url = "https://www.blibli.com/backend/search/merchant/"+id_merchant

querystring = {
    "promoTab": "false", 
    "excludeProductList": 
    "false", 
    "page": "1",
    "start":"0", 
    "intent": "false", 
    "multiCategory": "true", 
    "showFacet": "false"}

payload = ""
headers = {
        'authority': 'www.blibli.com',
        'accept': 'application/json, text/plain, */*',
        'accept-encoding':'gzip, deflate, br',
        'accept-language':'en-US,en;q=0.9,id;q=0.8,ja;q=0.7',
        'cache-control':'no-cache',
        'channelid':'mobile-web',
        'cookie': 'Blibli-Device-Id=U.cb41c6ad-3ec3-413b-839f-6ccc5cef84d0; Blibli-Device-Id-Signature=a3add4c1e749d43595ebfc088de7674634e06db5; _gcl_au=1.1.119481478.1662825687; __gtm_med=popads_cpc; __gtm_src=propeller_ads; __bwa_user_id=657116261.U.6479625894511464.1662825687; _vwo_uuid_v2=D2BADB50769B5030869041F9800073B9B|8d3132207c7774ddf328c43ecacd82b4; _fbp=fb.1.1662825687909.1013520868; _tt_enable_cookie=1; _ttp=d7e905ff-7712-4c32-b238-de66f8387bf5; _vis_opt_s=1%7C; _vis_opt_test_cookie=1; _vwo_uuid=D2BADB50769B5030869041F9800073B9B; __gtm_cam=homepage_smartcpm; cebs=1; Blibli-Is-Member=false; Blibli-Is-Remember=false; Blibli-User-Id=c285e445-8329-48d9-9eff-3b3927c4f96a; Blibli-Session-Id=3325b78c-a3a3-4e67-ba44-c09d9b0b4859; Blibli-Signature=bd1048ea8813b09047c5d789a234b1abaff6ddcc; moe_uuid=34b40e3a-d664-4d16-9fb7-79544db6c0d4; _gid=GA1.2.541906859.1668823463; _vis_opt_exp_223_exclude=1; _abck=9438609A1CC0C976A7C5F0965FDCF94B~0~...~-1~-1~-1; bm_sz=B91F0F27BC7162436DE4407627FB075D~~3556421~3425844; JSESSIONID=5060F37504A97929A092B5C6364B6B60; __bwa_session_id=657116261.S.4379639144583437.1668845209; __bwa_user_session_sequence=44; ak_bmsc=9B97AA717A261A472DFA6920F586DF25~000000000000000000000000000000~...; _vwo_ds=3%3Aa_0%2Ct_0%3A0%241662825685%3A50.27817927%3A%3A7_0%2C6_0%2C5_0%2C4_0%2C3_0%2C2_0%3A215_0%2C214_0%2C213_0%2C211_0%2C210_0%2C209_0%2C208_0%2C139_0%2C3_0%2C2_0%3A0; __bwa_session_action_sequence=10; _vwo_sn=6019524%3A16; _ga_G3ZP2F3MW9=GS1.1.1668845209.24.1.1668845434.57.0.0; _ga=GA1.2.1032891258.1662825687; bm_sv=F4E24BCA7ABFE0EF531D570148505CF4~~1; cebsp=69; cto_bundle=A0wXPF9TSlpLc1NpbDh4cU92cTFEN2ZQd2FxaWw5bHhuZ3RrNWtCUWRFeThDZDclMkJhTTV0WURmZENGUHQ3JTJCaXQ1aUJObkNtQW9ldGlsM0M2RnlmUEtqVEpnOWU0bkclMkJyYVFsbHZXVFl3YzQwZ1QzRjdsSW5zS3Y1MXljY3hPQlJOOUJDckQzRDlzNFQ4dnNEVjlIZkI5ZCUyRlBDUSUzRCUzRA; _dc_gtm_UA-21718848-13=1; _ce.s=v~b7660bf9a491e6fb6dc76f40c3afc212ddedcda9~vpv~0~v11.rlc~1668845211666~gtrk.la~lannul2y',
        'params': '[object Object]',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
        'x-b3-traceid': '50415d66c8693372'
    }
response = requests.request(
    "GET", url, headers=headers, params=querystring)

data = response.json()
product_list = []

for index in range(0, data['data']['paging']['total_item'], 40):
    querystring_product = {"promoTab": "false", "excludeProductList": "false",
                   "start":f"{index}", "intent": "false", "multiCategory": "true", "showFacet": "false"}
    response_product = requests.request("GET", url, data=payload, headers=headers, params=querystring_product)
    data_product = response_product.json()

    for product in data_product["data"]["products"]:
        product_list.append(product)

# %%
df = pd.json_normalize(product_list)
df
# Out:
#                   id              sku merchantCode        status  \
# 0    PON-00045-01951  PON-00045-01951    PON-00045     AVAILABLE
# 1    PON-00045-02229  PON-00045-02229    PON-00045     AVAILABLE
# 2    PON-00045-01930  PON-00045-01930    PON-00045     AVAILABLE
# 3    PON-00045-02035  PON-00045-02035    PON-00045     AVAILABLE
# 4    PON-00045-01916  PON-00045-01916    PON-00045     AVAILABLE
# ..               ...              ...          ...           ...
# 370  PON-00045-02253  PON-00045-02253    PON-00045  OUT_OF_STOCK
# 371  PON-00045-02277  PON-00045-02277    PON-00045  OUT_OF_STOCK
# 372  PON-00045-02137  PON-00045-02137    PON-00045  OUT_OF_STOCK
# 373  PON-00045-02133  PON-00045-02133    PON-00045  OUT_OF_STOCK
# 374  PON-00045-02132  PON-00045-02132    PON-00045  OUT_OF_STOCK
#
#                                                   name  \
# 0    POLYTRON Hydra Bottom Loading Gallon Hybrid Di...
# 1            Set Top Box Digital DVB - T2 [ PDV 700T2]
# ...

# %%
url_review = "https://www.blibli.com/backend/product-review/public-reviews"

result_review = []

for i in range(0, len(product_list)):
    query_params_review = {
        "page":"1",
        "itemPerPage":"30",
        "productSku":f"{product_list[i]['sku']}"
    }
    headers_review = {
        'authority': 'www.blibli.com',
        'accept': 'application/json, text/plain, */*',
        'accept-language':'en-US,en;q=0.9,id;q=0.8,ja;q=0.7',
        'cache-control':'no-cache',
        'cookie': 'Blibli-Device-Id=U.cb41c6ad-3ec3-413b-839f-6ccc5cef84d0; Blibli-Device-Id-Signature=a3add4c1e749d43595ebfc088de7674634e06db5; _gcl_au=1.1.119481478.1662825687; __gtm_med=popads_cpc; __gtm_src=propeller_ads; __bwa_user_id=657116261.U.6479625894511464.1662825687; _vwo_uuid_v2=D2BADB50769B5030869041F9800073B9B|8d3132207c7774ddf328c43ecacd82b4; _fbp=fb.1.1662825687909.1013520868; _tt_enable_cookie=1; _ttp=d7e905ff-7712-4c32-b238-de66f8387bf5; _vis_opt_s=1%7C; _vis_opt_test_cookie=1; _vwo_uuid=D2BADB50769B5030869041F9800073B9B; __gtm_cam=homepage_smartcpm; cebs=1; Blibli-Is-Member=false; Blibli-Is-Remember=false; Blibli-User-Id=c285e445-8329-48d9-9eff-3b3927c4f96a; Blibli-Session-Id=3325b78c-a3a3-4e67-ba44-c09d9b0b4859; Blibli-Signature=bd1048ea8813b09047c5d789a234b1abaff6ddcc; moe_uuid=34b40e3a-d664-4d16-9fb7-79544db6c0d4; _gid=GA1.2.541906859.1668823463; _vis_opt_exp_223_exclude=1; _abck=9438609A1CC0C976A7C5F0965FDCF94B~0~...~-1~-1~-1; bm_sz=B91F0F27BC7162436DE4407627FB075D~~3556421~3425844; JSESSIONID=5060F37504A97929A092B5C6364B6B60; ak_bmsc=9B97AA717A261A472DFA6920F586DF25~000000000000000000000000000000~...; _vwo_ds=3%3Aa_0%2Ct_0%3A0%241662825685%3A50.27817927%3A%3A7_0%2C6_0%2C5_0%2C4_0%2C3_0%2C2_0%3A215_0%2C214_0%2C213_0%2C211_0%2C210_0%2C209_0%2C208_0%2C139_0%2C3_0%2C2_0%3A0; _ga=GA1.2.1032891258.1662825687; cto_bundle=A0wXPF9TSlpLc1NpbDh4cU92cTFEN2ZQd2FxaWw5bHhuZ3RrNWtCUWRFeThDZDclMkJhTTV0WURmZENGUHQ3JTJCaXQ1aUJObkNtQW9ldGlsM0M2RnlmUEtqVEpnOWU0bkclMkJyYVFsbHZXVFl3YzQwZ1QzRjdsSW5zS3Y1MXljY3hPQlJOOUJDckQzRDlzNFQ4dnNEVjlIZkI5ZCUyRlBDUSUzRCUzRA; _dc_gtm_UA-21718848-13=1; __bwa_session_utm_campaign=; __bwa_session_utm_medium=; __bwa_session_utm_source=MERCHANT_PAGE; __bwa_session_utm_content=; __bwa_session_utm_term=; __bwa_session_campaign_type=campaign-tags; __bwa_session_id=723337755.S.4985487813186561.1668846429; __bwa_user_session_sequence=45; _ce.s=v~b7660bf9a491e6fb6dc76f40c3afc212ddedcda9~vpv~0~v11.rlc~1668845211666~gtrk.la~lano2vw8; bm_sv=F4E24BCA7ABFE0EF531D570148505CF4~~1; __bwa_session_action_sequence=3; _vwo_sn=6019524%3A24; cebsp=71; _ga_G3ZP2F3MW9=GS1.1.1668845209.24.1.1668846439.51.0.0',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    }
    response_review = requests.request("GET", url=url_review, headers=headers_review, params=query_params_review).json()

    # result_review = []

    if response_review["paging"]["total_page"] > 1:
        for page in range(1, response_review["paging"]["total_page"]+1):
            querystring_review2 = {"page":f"{page}","itemPerPage":"30","productSku":f"{product_list[i]['sku']}"}

            response_review2 = requests.request("GET", url=url_review, headers=headers_review, params=querystring_review2)
            
            data_review2 = response_review2.json()

            for a in data_review2["data"]:
                product = product_list[i]
                a.update({"product":product})
                result_review.append(a)
            
        # product = product_list[i]
        # product.update({"review_detail" : result_review})
        # data_products.append(product)
    else:
        for a in response_review["data"]:
            product = product_list[i]
            a.update({"product":product})
            result_review.append(a)
        
        # product = product_list[i]
        # product.update({"review_detail" : result_review})
        # data_products.append(product)

    print("Scraping product no. "+str(i)+" sku: " + product_list[i]['sku'] + " review done")
# Out:
# Scraping product no. 0 sku: PON-00045-01951 review done
# Scraping product no. 1 sku: PON-00045-02229 review done
# Scraping product no. 2 sku: PON-00045-01930 review done
# Scraping product no. 3 sku: PON-00045-02035 review done
# Scraping product no. 4 sku: PON-00045-01916 review done
# Scraping product no. 5 sku: PON-00045-01959 review done
# Scraping product no. 6 sku: PON-00045-02040 review done
# Scraping product no. 7 sku: PON-00045-01931 review done
# Scraping product no. 8 sku: PON-00045-02042 review done
# Scraping product no. 9 sku: PON-00045-01956 review done
# Scraping product no. 10 sku: PON-00045-01915 review done
# Scraping product no. 11 sku: PON-00045-01918 review done
# Scraping product no. 12 sku: PON-00045-02064 review done
# Scraping product no. 13 sku: PON-00045-02043 review done
# Scraping product no. 14 sku: PON-00045-02080 review done
# Scraping product no. 15 sku: PON-00045-02195 review done
# Scraping product no. 16 sku: PON-00045-02041 review done
# ...

# %%
df_review = pd.json_normalize(result_review)
df_review
# Out:
#                                       id             name  rating  \
# 0   138df764-b212-48a5-9a48-c5871c503abb            Henry       4
# 1   68e85446-d166-4b89-bdfd-029b4b0e90dc  dh***@gmail.com       5
# 2   5cdcbcbb-bacf-4f5d-9412-e639ce4352c6            Mazda       5
# 3   46af9b29-1663-43d5-9091-07b270f3f7cd            B***i       4
# 4   31fc5372-bdf4-4770-b1b4-764bb4cd4106             Rona       5
# 5   56aa97ec-bb39-4258-8a5c-b8164f65ebea            S***a       5
# 6   b18ac7cc-ead1-40b6-97a3-b18460d13bf3            E***k       4
# 7   ad7e3a14-4920-4e32-bb9e-e278ae7d306e          Muhamad       5
# 8   7ef11b65-1b27-4c45-88c3-aae81105e7b6            Y***a       3
# 9   b518b507-a75b-4854-8bc3-92c18b18e378           Ridwan       4
# 10  073f04db-e32b-4e30-8f40-2c8aa6fda977             Eric       5
# 11  42cb77f9-d5ab-4e4d-8be8-c11ea29b14ce            Tulus       5
# 12  8b17963e-494d-428b-b83e-b04ecba48550           Nathan       5
# ...

# %%
from pymongo import MongoClient

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['blibliProductReview'] 
collection = db['polytron']

# %%
collection.insert_many(result_review)

# %%
data = collection.find()

df = pd.json_normalize(data)
df
# Out:
#                           _id               id              sku merchantCode  \
# 0    6378961cc79f463edd8f25e1  PON-00045-01951  PON-00045-01951    PON-00045
# 1    6378961cc79f463edd8f25e2  PON-00045-02229  PON-00045-02229    PON-00045
# 2    6378961cc79f463edd8f25e3  PON-00045-01930  PON-00045-01930    PON-00045
# 3    6378961cc79f463edd8f25e4  PON-00045-02035  PON-00045-02035    PON-00045
# 4    6378961cc79f463edd8f25e5  PON-00045-01916  PON-00045-01916    PON-00045
# ..                        ...              ...              ...          ...
# 370  6378961cc79f463edd8f2753  PON-00045-02253  PON-00045-02253    PON-00045
# 371  6378961cc79f463edd8f2754  PON-00045-02277  PON-00045-02277    PON-00045
# 372  6378961cc79f463edd8f2755  PON-00045-02137  PON-00045-02137    PON-00045
# 373  6378961cc79f463edd8f2756  PON-00045-02133  PON-00045-02133    PON-00045
# 374  6378961cc79f463edd8f2757  PON-00045-02132  PON-00045-02132    PON-00045
#
# ...
