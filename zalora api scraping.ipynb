# %%
import requests
import pandas as pd
from pymongo import MongoClient

# %%
seller_id = 8828

# %%
product_list = []

url = "https://www.zalora.co.id/_c/v1/desktop/zis_list_catalog_products"

query_params = {
    "sort":"popularity",
    "dir":"desc",
    "offset":"0",
    "limit":"300",
    "seller_id":f"{seller_id}",
    "special_price":"false",
    "all_products":"true",
    "new_products":"false",
    "top_sellers":"false",
    "catalogtype":"Main",
    "lang":"id",
    "is_brunei":"false",
    "search_suggest":"false",
    "enable_visual_sort":"true",
    "enable_filter_ads":"true",
    "compact_catalog_desktop":"false",
    "name_search":"false",
    "solr7_support":"false",
    "pick_for_you":"false",
    "learn_to_sort_catalog":"false",
    "enable_similar_term":"true",
    "enable_relevance_classifier":"true",
    "auto_correct":"true"
}

headers = {
    'authority': 'www.zalora.co.id',
    'accept': 'application/json, text/plain, */*',
    'cookie': 'userLanguage=id; browserDetection=eyJ0eXBlIjoiYnJvd3NlciIsIm5hbWUiOiJDaHJvbWUiLCJjc3NDbGFzcyI6ImNocm9tZSIsInZlcnNpb24iOiIxMDcifQ==; PHPSESSID_83d0767d2f534a23f21399428e28c076=1f00ae8006799b60f99753474279dee8; zid=478411372.1668672968; rrCookie=zItAGRRlnEuTeo5cEP2K22oCti81zcKo; ANONYMOUS_TRACKING_ID=06318d2b-9591-4f33-bb10-5da92ab4bb4c; is_guest_with_empty_cart=true; 905125419dc9d3c8f422452a786673ba=-; zalora_referer={"search.brave.com":["https:\/\/search.brave.com\/"]}; optimizelyEndUserId=oeu1668672970006r0.89856154814837; ajs_anonymous_id=06318d2b-9591-4f33-bb10-5da92ab4bb4c; ab.storage.deviceId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1={"g":"9611eb88-9412-89ef-10ed-e225abefde5e","c":1668672972721,"l":1668672972721}; _fbp=fb.2.1668672973096.849720760; _gcl_au=1.1.1251577912.1668672973; __rtbh.sid={"eventType":"sid","id":"478411372.1668672968"}; __rtbh.lid={"eventType":"lid","id":"iSbKqsW4cEccbmMlfS4d"}; _tt_enable_cookie=1; _ttp=b6ca33dd-fe7d-40a2-b110-b591d4618095; _vz=viz_6375edd01e73b; _vz=; userSegment=men; rr_rcs=eF5jYSlN9jAxTTOwsEw10zU3NUzVNTEzTtG1TEk20jU2NjM0MjI0STQxNuPKLSvJTBEwtLA00TXUNQQAgRcNgQ; wpn_https={"status":"denied","last_shown":"Fri, 18 Nov 2022 02:15:41 GMT","shown_count":2}; last_clicked_promotion_name=SBR|Men|w45bbcmplayboyseventy|All|NA; _abck=3405F0D98681418EEB0DC15FEC1B1121~0~...~-1~-1~-1; bm_sz=F22032832F68C7063BD06D10632A6CCF~~3225905~3748404; _gid=GA1.3.2031190255.1669209785; sessionCount=13; ak_bmsc=F66F24B36C4D04030DD425755D6C9B05~000000000000000000000000000000~...; viz_sent=1; bm_sv=4D098CE470D7B740AA52B864C9FB3115~~1; pageCount=25; ab.storage.sessionId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1={"g":"d510747f-cecf-1cf1-3e5a-8a4b987b50d1","e":1669220819334,"c":1669218088044,"l":1669219019334}; _ga_T53WSL6JBT=GS1.1.1669218086.13.1.1669219020.14.0.0; _ga=GA1.1.1421552235.1668672972; cto_bundle=gzMJQl9VMlJpbDFkcUxKSEpzQyUyRldsVUQ1QVBFTUVqUkpKYXJZekhDT3lkdnglMkJObFJLaUtsVGxWbWhoRWQ5WW9paHBTayUyRjA4ZGk2MUxxblp2VXRyZXZUaERPN2hGUjBvSFJuUjlnYXl0OE9YbFFMMUdHcFNQNUZxdXZLSFdHN1JNdHdkJTJGOUhtTVhIUkRjckhjbzZiVmFkNHJJdyUzRCUzRA; _gat=1; RT="dm=zalora.co.id&si=0fc6470b-0f82-45c7-8969-28c6666ca231&ss=1669218085971&sl=26&tt=92302&obo=2&sh=1669219019748=26:2:92302,1669219015748=25:2:88295,1669219003748=24:2:84510,1669218999173=23:2:79993,1669218993193=22:2:75709&bcn=//684d0d47.akstat.io/&rl=1&ld=1669219019748&nu=https://www.zalora.co.id/&cl=1669219076960"',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
}

data = requests.request("GET", url, headers=headers, params=query_params).json()

for offset in range(0, data['response']['numFound'], 300):
    query_params_productlist = {
        "sort":"popularity",
        "dir":"desc",
        "offset":f"{offset}",
        "limit":"300",
        "seller_id":f"{seller_id}",
        "special_price":"false",
        "all_products":"true",
        "new_products":"false",
        "top_sellers":"false",
        "catalogtype":"Main",
        "lang":"id",
        "is_brunei":"false",
        "search_suggest":"false",
        "enable_visual_sort":"true",
        "enable_filter_ads":"true",
        "compact_catalog_desktop":"false",
        "name_search":"false",
        "solr7_support":"false",
        "pick_for_you":"false",
        "learn_to_sort_catalog":"false",
        "enable_similar_term":"true",
        "enable_relevance_classifier":"true",
        "auto_correct":"true"
    }

    productlist = requests.request("GET", url, headers=headers, params=query_params_productlist).json()
    for product in productlist['response']['docs']:
        product_list.append(product)

# %%
df = pd.json_normalize(product_list)
df
# Out:
#                                                  link  \
# 0   910-910-nineten-geist-ekiden-se-sepatu-lari-pu...
# 1   910-910-nineten-geist-ekiden-se-sepatu-lari-na...
# 2   910-910-nineten-ryu-swift-sepatu-training-hita...
# 3   910-910-nineten-yuza-riot-sepatu-trail-running...
# 4   910-910-nineten-osaka-arch-fix-sepatu-lari-pri...
# ..                                                ...
# 58  910-910-nineten-polo-jersey-lari-910-x-pb-pasi...
# 59  910-910-nineten-jersey-lari-910-x-pb-pasi-biru...
# 60  910-910-nineten-haze-1-5-sepatu-lari-burgundy-...
# 61  910-910-nineten-haze-1-5-sepatu-lari-hitam-ung...
# 62  910-910-nineten-jersey-lari-910-x-pb-pasi-hita...
#
#                                                 image  \
# 0   https://dynamic.zacdn.com/ZnWiXZIkQC4gIhfOB4A0...
# 1   https://dynamic.zacdn.com/6bLOoY1HF8FsZGL2t4WD...
# 2   https://dynamic.zacdn.com/VJO-V91aQzauMz5H9Ljb...
# 3   https://dynamic.zacdn.com/omXY9vHyJ2zvycAuaPnt...
# ...

# %%
url_review = 'https://www.zalora.co.id/productreviews/reviews/'
review_list = []

for index in range(0, len(product_list)):
    query_params_review = {
        'sku':f'{product_list[index]["meta"]["sku"]}',
        'token':'',
        'per_page':'40'
    }

    headers_review = {
        'authority': 'www.zalora.co.id',
        'accept': '*/*',
        'cookie': 'userLanguage=id; browserDetection=eyJ0eXBlIjoiYnJvd3NlciIsIm5hbWUiOiJDaHJvbWUiLCJjc3NDbGFzcyI6ImNocm9tZSIsInZlcnNpb24iOiIxMDcifQ==; PHPSESSID_83d0767d2f534a23f21399428e28c076=1f00ae8006799b60f99753474279dee8; zid=478411372.1668672968; rrCookie=zItAGRRlnEuTeo5cEP2K22oCti81zcKo; ANONYMOUS_TRACKING_ID=06318d2b-9591-4f33-bb10-5da92ab4bb4c; is_guest_with_empty_cart=true; 905125419dc9d3c8f422452a786673ba=-; zalora_referer={"search.brave.com":["https:\/\/search.brave.com\/"]}; optimizelyEndUserId=oeu1668672970006r0.89856154814837; ajs_anonymous_id=06318d2b-9591-4f33-bb10-5da92ab4bb4c; ab.storage.deviceId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1={"g":"9611eb88-9412-89ef-10ed-e225abefde5e","c":1668672972721,"l":1668672972721}; _fbp=fb.2.1668672973096.849720760; _gcl_au=1.1.1251577912.1668672973; __rtbh.sid={"eventType":"sid","id":"478411372.1668672968"}; __rtbh.lid={"eventType":"lid","id":"iSbKqsW4cEccbmMlfS4d"}; _tt_enable_cookie=1; _ttp=b6ca33dd-fe7d-40a2-b110-b591d4618095; _vz=viz_6375edd01e73b; _vz=; userSegment=men; rr_rcs=eF5jYSlN9jAxTTOwsEw10zU3NUzVNTEzTtG1TEk20jU2NjM0MjI0STQxNuPKLSvJTBEwtLA00TXUNQQAgRcNgQ; wpn_https={"status":"denied","last_shown":"Fri, 18 Nov 2022 02:15:41 GMT","shown_count":2}; last_clicked_promotion_name=SBR|Men|w45bbcmplayboyseventy|All|NA; _abck=3405F0D98681418EEB0DC15FEC1B1121~0~...~-1~-1~-1; bm_sz=F22032832F68C7063BD06D10632A6CCF~~3225905~3748404; _gid=GA1.3.2031190255.1669209785; sessionCount=13; ak_bmsc=F66F24B36C4D04030DD425755D6C9B05~000000000000000000000000000000~...; viz_sent=1; cto_bundle=gzMJQl9VMlJpbDFkcUxKSEpzQyUyRldsVUQ1QVBFTUVqUkpKYXJZekhDT3lkdnglMkJObFJLaUtsVGxWbWhoRWQ5WW9paHBTayUyRjA4ZGk2MUxxblp2VXRyZXZUaERPN2hGUjBvSFJuUjlnYXl0OE9YbFFMMUdHcFNQNUZxdXZLSFdHN1JNdHdkJTJGOUhtTVhIUkRjckhjbzZiVmFkNHJJdyUzRCUzRA; _gat=1; _gali=E7604SHA95F1A4GS_; _ga_T53WSL6JBT=GS1.1.1669218086.13.1.1669219126.11.0.0; pageCount=26; _ga=GA1.3.1421552235.1668672972; ab.storage.sessionId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1={"g":"d510747f-cecf-1cf1-3e5a-8a4b987b50d1","e":1669220929988,"c":1669218088044,"l":1669219129988}; bm_sv=4D098CE470D7B740AA52B864C9FB3115~~1; RT="dm=zalora.co.id&si=0fc6470b-0f82-45c7-8969-28c6666ca231&ss=1669218085971&sl=27&tt=98746&obo=2&sh=1669219130916=27:2:98746,1669219019748=26:2:92302,1669219015748=25:2:88295,1669219003748=24:2:84510,1669218999173=23:2:79993&bcn=//684d0d47.akstat.io/&rl=1&ld=1669219130916&nu=https://www.zalora.co.id/&cl=1669219131391"',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    }

    response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
    product = product_list[index]
    try:
        for review in response_review['reviews']:
            review.update({"product":product})
            review_list.append(review)

        try:
            while response_review['cursor']['has_next']:
                query_params_review = {
                    'sku':f'{product_list[index]["meta"]["sku"]}',
                    'token':f'{response_review["cursor"]["next"]}',
                    'per_page':'40'
                }

                response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
                
                for review in response_review['reviews']:
                    review.update({"product":product})
                    review_list.append(review)
        except KeyError as e:
            print("Scraping product no. "+str(index)+" sku: " + product_list[index]["meta"]["sku"] + " review done")
    except KeyError as e:
        print("Product no. "+str(index)+" sku :" + product_list[index]["meta"]["sku"] + " has no review")
# Out:
# Product no. 0 sku :47DB2SHCE39A56GS has no review
# Product no. 1 sku :C4AC0SHFBA9D1CGS has no review
# Product no. 2 sku :C07ECSH655C15BGS has no review
# Product no. 3 sku :09ABESHF54625AGS has no review
# Product no. 4 sku :92A92SH3ED2F54GS has no review
# Product no. 5 sku :932B8SHCFB94BEGS has no review
# Scraping product no. 6 sku: 5CA50SH6249D46GS review done
# Product no. 7 sku :90FC7SHD15B990GS has no review
# Scraping product no. 8 sku: FC952SH13B81D1GS review done
# Scraping product no. 9 sku: 9B7E9SH198C399GS review done
# Scraping product no. 10 sku: 75B5DSHD5D7534GS review done
# Product no. 11 sku :6E2F5SH5A452BEGS has no review
# Scraping product no. 12 sku: DB419SHFCB104EGS review done
# Scraping product no. 13 sku: A509DSH1FBA810GS review done
# Product no. 14 sku :77F76SH6CA6D6AGS has no review
# Scraping product no. 15 sku: E2691SH360A2C2GS review done
# Product no. 16 sku :8A1CFSH6E8DEEDGS has no review
# Product no. 17 sku :1492ASH013D194GS has no review
# ...

# %%
df_review = pd.json_normalize(
    review_list)
df_review
# Out:
#           id customer_display_name  rating     sales_order_date  \
# 0   10514086                 J***n       5  2021-10-01 13:39:24
# 1   11162266            I********s       5  2021-10-13 02:07:19
# 2    5339249              abdulloh       5  2021-07-01 22:09:13
# 3   20841702              kharisma       5  2022-03-08 12:18:49
# 4   29119689              kharisma       5  2022-07-31 03:12:40
# ..       ...                   ...     ...                  ...
# 76   4450625                Sahata       5  2021-06-25 16:17:15
# 77  23685006              C******a       5  2022-04-22 07:11:13
# 78  22252472                  agus       5  2022-03-30 01:58:53
# 79  21666490            Nur Rahman       5  2022-03-23 08:46:01
# 80  19765059         Aditya Aristo       5  2022-02-13 17:48:17
#
#                                                  tags         submitted_at  \
# 0   [{'id': 2049, 'label': 'Kualitas sangat baik'}...  2021-11-09 03:40:37
# ...

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['zaloraProductReview'] 
collection = db['910']

# %%
collection.insert_many(review_list)
