# %%
import requests
import pandas as pd

# %%
store = "910"
url = 'https://www.lazada.co.id/'+store+'/'

query_params = {
    'ajax':'true',
    'from':'wangpu',
    'langFlag':'id',
    'page':'1',
    'pageTypeId':'2',
    'q':'All-Products'
}

headers = {
    'authority': 'www.lazada.co.id',
    'accept': 'application/json, text/plain, */*',
    'cookie': 'miidlaz=miidgi499a1gcf8kjp9cn3j; t_fv=1662664726435; t_uid=Br1Uy7Lfc7KMdFzYA514tADQx66FD0nE; lzd_cid=a360fd78-3649-423d-b46a-75b9ebea8e2c; _tb_token_=fa9e5eb358e5b; cna=FS6hGwn853YCAbb9hCYYob4b; lzd_sid=101ae28026be828dd07d0b40a2652fbe; exlaz=c_lzd_byr:mm_150030223_51150528_2010300519!id1256005:clkgi4c2i1gfghfhhc57f8::; lzd_click_id=clkgi4c2i1gfghfhhc57f8; _bl_uid=26lj5a5z18OuzX4FFtqy8hLtUeUX; _gcl_au=1.1.1060732676.1667526349; _fbp=fb.2.1667526370430.628345689; hng=ID|id-ID|IDR|360; hng.sig=to18pG508Hzz7EPB_okhuQu8kDUP3TDmLlnu4IbIOY8; cto_axid=Bs29sS62NxbyiAGA_4cJjK7HzJmmqpNW; AMCVS_126E248D54200F960A4C98C6%40AdobeOrg=1; _ga=GA1.3.1291115222.1668214893; pdp_login=false; xlly_s=1; AMCV_126E248D54200F960A4C98C6%40AdobeOrg=-1124106680%7CMCIDTS%7C19314%7CMCMID%7C02304393368715373353663002851187300535%7CMCAAMLH-1669299119%7C3%7CMCAAMB-1669299119%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-1668701519s%7CNONE%7CMCSYNCSOP%7C411-19316%7CvVersion%7C5.2.0; EGG_SESS=S_Gs1wHo9OvRHCMp98md7MykiOsZpKXsWGNnIG-w9KAQLUmod9k4cHSKOrAZ3bgpn9sgiOigTWvSN2bc97ZM6oKo2IsUx_EAhwJap8noflefckcjXSDCh5dztpF-l0-_PevDXgFQpb9hEnpCfB5hKHcYlK4Nb4JElDkM_8-_vTw=; _gid=GA1.3.1768280202.1668694385; __wpkreporterwid_=2280956e-9961-4ab4-baae-02b566e582a3; t_sid=shtKdXjZXJw004PThKnb20aV0saEmJ2x; utm_channel=NA; _m_h5_tk=c7a81b587a3a0151fda81baf88d0ec12_1668744321616; _m_h5_tk_enc=9075bcabecaa037245e5a05d05f5c921; cto_bundle=8qu6rV82QSUyRjhGYkZtNkJXMnJyVGhmd1FJJTJCdWFISFVUUzBVc3o2RXFya3pudHZCcENFcGFiT3c5ajhxNUt1aWVocjZSdU9LU1FrY2JnWWNybllmSUNqVG92RFl3N2c2RE51UE5WYlJ6Zkt6d1FiQiUyQnR6TGY3YSUyRkpQZzRJNTlHJTJGUHhRdWxhJTJCZ1lCWnJ2eTEzQXpZeFQ3WVJJWGclM0QlM0Q; _uetsid=cc05d490668111edbde78f8c25c3644d; _uetvid=74edc1a05be211ed8e3e8582a563d421; tfstk=cMqhBu1l2yuBTQw4UkiCcMuK6K_OZ6pEOq3abObuxZ97xlqNicLwuEjeOf5fTU1..; l=eBgcOsoITPk65Xl6BOfwourza77OSIRAguPzaNbMiOCPOiCp5d7GW6zP38L9C3GNhsOwR3z0a8okBeYBqI0QOKUnGL26Qdkmn; isg=BAgI5tf7_10a3BO1Mr4VLYXp2XYasWy7QCAFK8K5VAN2nagHasE8S56bFX3trSST',
    'referer': 'https://www.lazada.co.id/910/?q=All-Products&from=wangpu&langFlag=id&pageTypeId=2',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    'x-csrf-token': 'fa9e5eb358e5b',
    'x-requested-with': 'XMLHttpRequest'
}

product_list = []

data = requests.request("GET", url, headers=headers, params=query_params).json()

for page in range(1, round(int(data['mainInfo']['totalResults'])/40)+2):
    query_params_productlist = {
        'ajax':'true',
        'from':'wangpu',
        'langFlag':'id',
        'page':f'{page}',
        'pageTypeId':'2',
        'q':'All-Products'
    }

    productlist = requests.request("GET", url, headers=headers, params=query_params_productlist).json()
    for product in productlist['mods']['listItems']:
        product_list.append(product)

# %%
df = pd.DataFrame(product_list)
df
# Out:
#                                                  name         nid  \
# 0   910 Nineten Haze 1.5 Sepatu Lari -Hitam/Abu/Merah  5494558167
# 1   910 Nineten Fuuto Accel Sepatu Lari - Merah Fi...  4632954299
# 2   910 Nineten Ryu Swift Sepatu Training - Hitam/...  7048872250
# 3   910 Nineten Geist Ekiden SE Sepatu Lari - Navy...  7057528167
# 4   910 Nineten Haze Vision Sepatu Lari - Biru Tua...  6080196658
# ..                                                ...         ...
# 90        910 Nineten Haze Go Run Jersey Lari - Hitam  2668466274
# 91          910 Nineten Haze Go Run Jersey Lari - Abu  2668032992
# 92   910 Nineten Bundling Kaos Kaki Abu/Orange- 3 PCS  5920220367
# 93      910 Nineten Tama Polo Jersey Lari - Hijau Tua  5620848026
# 94              910 Nineten Senko Jersey Lari - Merah  6878210066
#
#                                                 icons  \
# 0   [{'domClass': 'VZbE7j', 'alias': 'VZbE7j', 'ty...
# 1   [{'domClass': 'VZbE7j', 'alias': 'VZbE7j', 'ty...
# ...

# %%
review_list = []

# %%
url_review = 'https://my.lazada.co.id/pdp/review/getReviewList'
index = 39

query_params_review = {
    'itemId':f'{product_list[index]["itemId"]}',
    'pageSize':'50',
    'filter':'0',
    'sort':'1',
    'pageNo':'1'
}

headers_review = {
    'authority': 'my.lazada.co.id',
    'accept': 'application/json, text/plain, */*',
    'cookie': 'client_type=desktop; miidlaz=miidgi499a1gcf8kjp9cn3j; t_fv=1662664726435; t_uid=Br1Uy7Lfc7KMdFzYA514tADQx66FD0nE; lzd_cid=a360fd78-3649-423d-b46a-75b9ebea8e2c; _tb_token_=fa9e5eb358e5b; cna=FS6hGwn853YCAbb9hCYYob4b; lzd_sid=101ae28026be828dd07d0b40a2652fbe; exlaz=c_lzd_byr:mm_150030223_51150528_2010300519!id1256005:clkgi4c2i1gfghfhhc57f8::; lzd_click_id=clkgi4c2i1gfghfhhc57f8; _gcl_au=1.1.1060732676.1667526349; _fbp=fb.2.1667526370430.628345689; hng=ID|id-ID|IDR|360; hng.sig=to18pG508Hzz7EPB_okhuQu8kDUP3TDmLlnu4IbIOY8; cto_axid=Bs29sS62NxbyiAGA_4cJjK7HzJmmqpNW; AMCVS_126E248D54200F960A4C98C6%40AdobeOrg=1; _ga=GA1.3.1291115222.1668214893; pdp_login=false; xlly_s=1; AMCV_126E248D54200F960A4C98C6%40AdobeOrg=-1124106680%7CMCIDTS%7C19314%7CMCMID%7C02304393368715373353663002851187300535%7CMCAAMLH-1669299119%7C3%7CMCAAMB-1669299119%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-1668701519s%7CNONE%7CMCSYNCSOP%7C411-19316%7CvVersion%7C5.2.0; _gid=GA1.3.1768280202.1668694385; t_sid=shtKdXjZXJw004PThKnb20aV0saEmJ2x; utm_channel=NA; _m_h5_tk=c7a81b587a3a0151fda81baf88d0ec12_1668744321616; _m_h5_tk_enc=9075bcabecaa037245e5a05d05f5c921; cto_bundle=8qu6rV82QSUyRjhGYkZtNkJXMnJyVGhmd1FJJTJCdWFISFVUUzBVc3o2RXFya3pudHZCcENFcGFiT3c5ajhxNUt1aWVocjZSdU9LU1FrY2JnWWNybllmSUNqVG92RFl3N2c2RE51UE5WYlJ6Zkt6d1FiQiUyQnR6TGY3YSUyRkpQZzRJNTlHJTJGUHhRdWxhJTJCZ1lCWnJ2eTEzQXpZeFQ3WVJJWGclM0QlM0Q; _uetsid=cc05d490668111edbde78f8c25c3644d; _uetvid=74edc1a05be211ed8e3e8582a563d421; x5sec=7b22617365727665722d6c617a6164613b32223a223963383538333736393633363161343538613464643439633565646361623063434e7a4e323573474550753373614b4878704c576741457769706d5a392f762f2f2f2f2f41554144227d; tfstk=ckTcBsDiWnSbcRg9FK_jRqlT0KmdZiFVhMIyzbmipUXd_aLPiaEzYk04hTkI3l1..; l=eBgcOsoITPk65zTQBO5Cnurza77TVIRbzsPzaNbMiInca1SftLJlTNCUz9BpSdtj_t5xcetzo7yrqdEW-maU-KOZO_yxO0RIVBp6Re1..; isg=BL6-xq3JUR-uIoVX2CBLL48fD9QA_4J5GvZzSWjHgYGGC1zl0I7IiCPpg9_HM3qR',
    'origin': 'https://www.lazada.co.id',
    'referer': 'https://www.lazada.co.id/',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    'x-csrf-token': 'fa9e5eb358e5b',
    'x-requested-with': 'XMLHttpRequest'
}

response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()

for page in range(1, response_review['model']['paging']['totalPages']+1):
    query_params_review = {
        'itemId':f'{product_list[index]["itemId"]}',
        'pageSize':'50',
        'filter':'0',
        'sort':'1',
        'pageNo':f'{page}'
    }

    response_reviews = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
    for review in response_reviews['model']['items']:
        product = product_list[index]
        review.update({"product" : product})
        review_list.append(review)

print("Scraping product no. "+str(index)+" id: " + product_list[index]['itemId'] + " review done")

# %%
df_review = pd.DataFrame(review_list)
df_review
# Out:
#                                                 name         nid  \
# 0  910 Nineten Haze 1.5 Sepatu Lari -Hitam/Abu/Merah  5494558167
# 1           910 Nineten Kaos Kaki Socks - Abu Oranye  2972432269
#
#                                                icons  \
# 0  [{'domClass': 'VZbE7j', 'alias': 'VZbE7j', 'ty...
# 1  [{'domClass': 'VZbE7j', 'alias': 'VZbE7j', 'ty...
#
#                                             utLogMap  \
# 0  {'srp_name': 'lazadaInShopSrp', 'x_object_type...
# 1  {'srp_name': 'lazadaInShopSrp', 'x_object_type...
#
#                                                image originalPrice  \
# 0  https://id-test-11.slatic.net/p/7a5134292830dd...     449900.00
# 1  https://id-test-11.slatic.net/p/f405eea6dea6cf...      50000.00
#
#   originalPriceShow     price promotionId  priceShow  ...        skuId  \
# 0         Rp449.900    359900        null  Rp359.900  ...  10949942338
# 1          Rp50.000  18900.00        null   Rp18.900  ...   5274704678
#
# ...
