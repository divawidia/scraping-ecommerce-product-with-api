# %%
import requests
import pandas as pd
from pymongo import MongoClient

# %%
product_list = []

url = "https://www.zalora.co.id/_c/v1/desktop/zis_list_catalog_products"
seller_id = 8828

query_params = {
    "sort":"popularity",
    "dir":"desc",
    "offset":"0",
    "limit":"300",
    "seller_id":f"{seller_id}",
    "special_price":"false",
    "all_products":"true",
    "new_products":"false",
    "top_sellers":"false",
    "catalogtype":"Main",
    "lang":"id",
    "is_brunei":"false",
    "search_suggest":"false",
    "enable_visual_sort":"true",
    "enable_filter_ads":"true",
    "compact_catalog_desktop":"false",
    "name_search":"false",
    "solr7_support":"false",
    "pick_for_you":"false",
    "learn_to_sort_catalog":"false",
    "enable_similar_term":"true",
    "enable_relevance_classifier":"true",
    "auto_correct":"true"
}

headers = {
    'authority': 'www.zalora.co.id',
    'accept': 'application/json, text/plain, */*',
    'cookie': 'userLanguage=id; browserDetection=eyJ0eXBlIjoiYnJvd3NlciIsIm5hbWUiOiJDaHJvbWUiLCJjc3NDbGFzcyI6ImNocm9tZSIsInZlcnNpb24iOiIxMDcifQ%3D%3D; PHPSESSID_83d0767d2f534a23f21399428e28c076=1f00ae8006799b60f99753474279dee8; zid=478411372.1668672968; rrCookie=zItAGRRlnEuTeo5cEP2K22oCti81zcKo; ANONYMOUS_TRACKING_ID=06318d2b-9591-4f33-bb10-5da92ab4bb4c; is_guest_with_empty_cart=true; 905125419dc9d3c8f422452a786673ba=-; zalora_referer=%7B%22search.brave.com%22%3A%5B%22https%3A%5C%2F%5C%2Fsearch.brave.com%5C%2F%22%5D%7D; optimizelyEndUserId=oeu1668672970006r0.89856154814837; _gid=GA1.3.1877399038.1668672972; ajs_anonymous_id=06318d2b-9591-4f33-bb10-5da92ab4bb4c; ab.storage.deviceId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1=%7B%22g%22%3A%229611eb88-9412-89ef-10ed-e225abefde5e%22%2C%22c%22%3A1668672972721%2C%22l%22%3A1668672972721%7D; _fbp=fb.2.1668672973096.849720760; _gcl_au=1.1.1251577912.1668672973; __rtbh.sid=%7B%22eventType%22%3A%22sid%22%2C%22id%22%3A%22478411372.1668672968%22%7D; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%22iSbKqsW4cEccbmMlfS4d%22%7D; _tt_enable_cookie=1; _ttp=b6ca33dd-fe7d-40a2-b110-b591d4618095; _vz=viz_6375edd01e73b; _vz=; userSegment=men; rr_rcs=eF5jYSlN9jAxTTOwsEw10zU3NUzVNTEzTtG1TEk20jU2NjM0MjI0STQxNuPKLSvJTBEwtLA00TXUNQQAgRcNgQ; wpn_https={"status":"denied","last_shown":"Fri, 18 Nov 2022 02:15:41 GMT","shown_count":2}; last_clicked_promotion_name=SBR%7CMen%7Cw45bbcmplayboyseventy%7CAll%7CNA; _abck=3405F0D98681418EEB0DC15FEC1B1121~0~...~-1~-1~-1; bm_sz=A8F4F4CC756CD10C3758FDC72FCDDF20~~4470082~4601409; bm_mi=6765075D10BA3421B22D2E369A3197A1~~1; sessionCount=10; ak_bmsc=9133B964396A9042CDF04F47A33DBF6E~000000000000000000000000000000~...; viz_sent=1; _gat=1; _gali=09ABESHF54625AGS_; bm_sv=7E6345C5C9F32275D6E7E40EF79A19CA~~1; pageCount=13; ab.storage.sessionId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1=%7B%22g%22%3A%22f60a25a1-5826-9c40-891a-3e4e3206a3c6%22%2C%22e%22%3A1668865894403%2C%22c%22%3A1668863913268%2C%22l%22%3A1668864094403%7D; _ga_T53WSL6JBT=GS1.1.1668863914.10.1.1668864095.53.0.0; _ga=GA1.1.1421552235.1668672972; cto_bundle=t4QMDV9EYmFTQ0Q0NzZjcG05V1lEZDZ0bTU4WlYxSk1hdWRQdXVLZEVNYTZoY2xoZFNBTlp1OFVQRHdFTDk4eG1va0glMkJXSTc1b2NNSVdQY0dVeE5wWnR3T0pHa2RONzl5SCUyQnBvWWFhQXhZZGtaeVp0JTJCdXFiN1BpeFJGYmt3VE1GNlREaVNkWkVsJTJCN25rd3hIZGhaSVhnV0hhQSUzRCUzRA; RT="dm=zalora.co.id&si=0fc6470b-0f82-45c7-8969-28c6666ca231&ss=1668863909929&sl=13&tt=37757&obo=0&sh=1668864094672%3D13%3A0%3A37757%2C1668864091790%3D12%3A0%3A34802%2C1668864019993%3D11%3A0%3A30873%2C1668864005807%3D10%3A0%3A22692%2C1668864000236%3D9%3A0%3A20801&bcn=%2F%2F684d0d46.akstat.io%2F&rl=1&ld=1668864094673&nu=https%3A%2F%2Fwww.zalora.co.id%2F&cl=1668864100053"',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
}

data = requests.request("GET", url, headers=headers, params=query_params).json()

for offset in range(0, data['response']['numFound'], 300):
    query_params_productlist = {
        "sort":"popularity",
        "dir":"desc",
        "offset":f"{offset}",
        "limit":"300",
        "seller_id":f"{seller_id}",
        "special_price":"false",
        "all_products":"true",
        "new_products":"false",
        "top_sellers":"false",
        "catalogtype":"Main",
        "lang":"id",
        "is_brunei":"false",
        "search_suggest":"false",
        "enable_visual_sort":"true",
        "enable_filter_ads":"true",
        "compact_catalog_desktop":"false",
        "name_search":"false",
        "solr7_support":"false",
        "pick_for_you":"false",
        "learn_to_sort_catalog":"false",
        "enable_similar_term":"true",
        "enable_relevance_classifier":"true",
        "auto_correct":"true"
    }

    productlist = requests.request("GET", url, headers=headers, params=query_params_productlist).json()
    for product in productlist['response']['docs']:
        product_list.append(product)

# %%
df = pd.json_normalize(product_list)
df
# Out:
#                                                  link  \
# 0   910-910-nineten-geist-ekiden-se-sepatu-lari-na...
# 1   910-910-nineten-ryu-swift-sepatu-training-hita...
# 2   910-910-nineten-yuza-riot-sepatu-trail-running...
# 3   910-910-nineten-kiva-sepatu-training-abu-kunin...
# 4   910-910-nineten-osaka-arch-fix-sepatu-lari-pri...
# 5   910-910-nineten-kiva-sepatu-training-hitam-abu...
# 6   910-910-nineten-fuuto-accel-sepatu-lari-merah-...
# 7   910-910-nineten-yuka-accel-rapid-sepatu-traini...
# 8   910-910-nineten-haze-vision-sepatu-lari-biru-t...
# 9   910-910-nineten-ryu-swift-sepatu-lari-biru-ora...
# 10  910-910-nineten-fuuto-accel-sepatu-lari-biru-p...
# 11  910-910-nineten-fuuto-accel-sepatu-lari-abu-ku...
# 12  910-910-nineten-takashi-run-sepatu-lari-jingga...
# 13  910-910-nineten-yuza-sepatu-trail-running-hija...
# 14  910-910-nineten-haze-metaspeed-sepatu-lari-jin...
# 15  910-910-nineten-yuza-matterhorn-sepatu-trail-r...
# ...

# %%
url_review = 'https://www.zalora.co.id/productreviews/reviews/'
review_list = []

for index in range(0, len(product_list)):
    query_params_review = {
        'sku':f'{product_list[index]["meta"]["sku"]}',
        'token':'',
        'per_page':'40'
    }

    headers_review = {
        'authority': 'www.zalora.co.id',
        'accept': '*/*',
        'cookie': 'userLanguage=id; browserDetection=eyJ0eXBlIjoiYnJvd3NlciIsIm5hbWUiOiJDaHJvbWUiLCJjc3NDbGFzcyI6ImNocm9tZSIsInZlcnNpb24iOiIxMDcifQ%3D%3D; PHPSESSID_83d0767d2f534a23f21399428e28c076=1f00ae8006799b60f99753474279dee8; zid=478411372.1668672968; rrCookie=zItAGRRlnEuTeo5cEP2K22oCti81zcKo; ANONYMOUS_TRACKING_ID=06318d2b-9591-4f33-bb10-5da92ab4bb4c; is_guest_with_empty_cart=true; 905125419dc9d3c8f422452a786673ba=-; zalora_referer=%7B%22search.brave.com%22%3A%5B%22https%3A%5C%2F%5C%2Fsearch.brave.com%5C%2F%22%5D%7D; optimizelyEndUserId=oeu1668672970006r0.89856154814837; _gid=GA1.3.1877399038.1668672972; ajs_anonymous_id=06318d2b-9591-4f33-bb10-5da92ab4bb4c; ab.storage.deviceId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1=%7B%22g%22%3A%229611eb88-9412-89ef-10ed-e225abefde5e%22%2C%22c%22%3A1668672972721%2C%22l%22%3A1668672972721%7D; _fbp=fb.2.1668672973096.849720760; _gcl_au=1.1.1251577912.1668672973; __rtbh.sid=%7B%22eventType%22%3A%22sid%22%2C%22id%22%3A%22478411372.1668672968%22%7D; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%22iSbKqsW4cEccbmMlfS4d%22%7D; _tt_enable_cookie=1; _ttp=b6ca33dd-fe7d-40a2-b110-b591d4618095; _vz=viz_6375edd01e73b; _vz=; userSegment=men; rr_rcs=eF5jYSlN9jAxTTOwsEw10zU3NUzVNTEzTtG1TEk20jU2NjM0MjI0STQxNuPKLSvJTBEwtLA00TXUNQQAgRcNgQ; wpn_https={"status":"denied","last_shown":"Fri, 18 Nov 2022 02:15:41 GMT","shown_count":2}; last_clicked_promotion_name=SBR%7CMen%7Cw45bbcmplayboyseventy%7CAll%7CNA; _abck=3405F0D98681418EEB0DC15FEC1B1121~0~...~-1~-1~-1; bm_sz=A8F4F4CC756CD10C3758FDC72FCDDF20~~4470082~4601409; bm_mi=6765075D10BA3421B22D2E369A3197A1~~1; sessionCount=10; ak_bmsc=9133B964396A9042CDF04F47A33DBF6E~000000000000000000000000000000~...; viz_sent=1; cto_bundle=t4QMDV9EYmFTQ0Q0NzZjcG05V1lEZDZ0bTU4WlYxSk1hdWRQdXVLZEVNYTZoY2xoZFNBTlp1OFVQRHdFTDk4eG1va0glMkJXSTc1b2NNSVdQY0dVeE5wWnR3T0pHa2RONzl5SCUyQnBvWWFhQXhZZGtaeVp0JTJCdXFiN1BpeFJGYmt3VE1GNlREaVNkWkVsJTJCN25rd3hIZGhaSVhnV0hhQSUzRCUzRA; _gat=1; _gali=64D6BSHDA79ACDGS_; _ga_T53WSL6JBT=GS1.1.1668863914.10.1.1668864222.60.0.0; _ga=GA1.3.1421552235.1668672972; pageCount=14; ab.storage.sessionId.0ac28e08-db3a-4792-8c49-5a8b6a0521a1=%7B%22g%22%3A%22f60a25a1-5826-9c40-891a-3e4e3206a3c6%22%2C%22e%22%3A1668866024559%2C%22c%22%3A1668863913268%2C%22l%22%3A1668864224559%7D; bm_sv=7E6345C5C9F32275D6E7E40EF79A19CA~~1; _gat_UA-28869185-1=1; RT="dm=zalora.co.id&si=0fc6470b-0f82-45c7-8969-28c6666ca231&ss=1668863909929&sl=14&tt=41877&obo=0&sh=1668864225092%3D14%3A0%3A41877%2C1668864094672%3D13%3A0%3A37757%2C1668864091790%3D12%3A0%3A34802%2C1668864019993%3D11%3A0%3A30873%2C1668864005807%3D10%3A0%3A22692&bcn=%2F%2F684d0d46.akstat.io%2F&rl=1&ld=1668864225092&nu=https%3A%2F%2Fwww.zalora.co.id%2F&cl=1668864225932',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    }

    response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
    product = product_list[index]
    try:
        for review in response_review['reviews']:
            review.update({"product":product})
            review_list.append(review)

        try:
            while response_review['cursor']['has_next']:
                query_params_review = {
                    'sku':f'{product_list[index]["meta"]["sku"]}',
                    'token':f'{response_review["cursor"]["next"]}',
                    'per_page':'40'
                }

                response_review = requests.request("GET", url_review, headers=headers_review, params=query_params_review).json()
                
                for review in response_review['reviews']:
                    review.update({"product":product})
                    review_list.append(review)
        except KeyError as e:
            review.update({"product":product})
            review_list.append(review)
            print("Scraping product no. "+str(index)+" sku: " + product_list[index]["meta"]["sku"] + " review done")
    except KeyError as e:
        print("Product no. "+str(index)+" sku :" + product_list[index]["meta"]["sku"] + " has no review")
# Out:
# Product no. 0 sku :C4AC0SHFBA9D1CGS has no review
# Product no. 1 sku :C07ECSH655C15BGS has no review
# Product no. 2 sku :09ABESHF54625AGS has no review
# Scraping product no. 3 sku: 5CA50SH6249D46GS review done
# Product no. 4 sku :92A92SH3ED2F54GS has no review
# Product no. 5 sku :90FC7SHD15B990GS has no review
# Scraping product no. 6 sku: FC952SH13B81D1GS review done
# Product no. 7 sku :DB419SHFCB104EGS has no review
# Scraping product no. 8 sku: 75B5DSHD5D7534GS review done
# Product no. 9 sku :6E2F5SH5A452BEGS has no review
# Scraping product no. 10 sku: A509DSH1FBA810GS review done
# Product no. 11 sku :8A1CFSH6E8DEEDGS has no review
# Product no. 12 sku :1492ASH013D194GS has no review
# Scraping product no. 13 sku: E2691SH360A2C2GS review done
# Product no. 14 sku :77F76SH6CA6D6AGS has no review
# Product no. 15 sku :DF639SH4B044DAGS has no review
# Scraping product no. 16 sku: 1B74ASHF0C8B49GS review done
# Product no. 17 sku :633DASH9DB3CAEGS has no review
# ...

# %%
df_review = pd.DataFrame(
    review_list)
df_review
# Out:
#           id customer_display_name  rating     sales_order_date  \
# 0   10514086                 J***n       5  2021-10-01 13:39:24
# 1   10514086                 J***n       5  2021-10-01 13:39:24
# 2   11162266            I********s       5  2021-10-13 02:07:19
# 3    5339249              abdulloh       5  2021-07-01 22:09:13
# 4    5339249              abdulloh       5  2021-07-01 22:09:13
# ..       ...                   ...     ...                  ...
# 88  23685006              C******a       5  2022-04-22 07:11:13
# 89  22252472                  agus       5  2022-03-30 01:58:53
# 90  21666490            Nur Rahman       5  2022-03-23 08:46:01
# 91  19765059         Aditya Aristo       5  2022-02-13 17:48:17
# 92  19765059         Aditya Aristo       5  2022-02-13 17:48:17
#
#                                                  tags         submitted_at  \
# 0   [{'id': 2049, 'label': 'Kualitas sangat baik'}...  2021-11-09 03:40:37
# ...

# %%
dict_df_review = df_review.to_dict('records')
dict_df_review
# Out:
# [{'id': 10514086,
#   'customer_display_name': 'J***n',
#   'rating': 5,
#   'sales_order_date': '2021-10-01 13:39:24',
#   'tags': [{'id': 2049, 'label': 'Kualitas sangat baik'},
#    {'id': 2050, 'label': 'Ukuran pas'},
#    {'id': 2051, 'label': 'Nyaman'},
#    {'id': 2052, 'label': 'Harga sangat sesuai'}],
#   'submitted_at': '2021-11-09 03:40:37',
#   'product_size': '40',
#   'product_size_system': 'EU',
#   'product': {'meta': {'sku': '5CA50SH6249D46GS',
#     'max_saving_percentage': '25',
#     'brand': '910',
#     'name': '910 Nineten Kiva Sepatu Training - Abu Kuning',
#     'special_price': 'Rp 299.900',
#     'price': 'Rp 399.900',
#     'activated_at': '2021-09-13 17:37:45',
#     'max_price': '399.900',
#     'grouped_products': '',
#     'sizesystembrand': 'EU',
#     'sizesystembrand_position': '0',
#     'id_catalog_config': '3068548',
#     'sub_cat_type_id': '222',
#     'gender_id': '5',
#     'gender': 'Unisex',
#     'attribute_set_id': '4',
# ...

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['zaloraProductReview'] 
collection = db['910']

# %%
collection.insert_many(dict_df_review)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16792/3205404234.py in <module>
# ----> 1 collection.insert_many(dict_df_review)
#
# c:\Users\wiart\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     587         blk = _Bulk(self, ordered, bypass_document_validation)
#     588         blk.ops = [doc for doc in gen()]
# --> 589         blk.execute(write_concern, session=session)
#     590         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     591
#
# c:\Users\wiart\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\bulk.py in execute(self, write_concern, session)
#     446                 self.execute_no_results(sock_info, generator)
#     447         else:
# ...
