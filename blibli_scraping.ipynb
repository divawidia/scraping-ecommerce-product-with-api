# %%
import requests
import pandas as pd

# %%
id_merchant = "frisian-flag-official-store"

# %%
url = "https://www.blibli.com/backend/search/brand/"+id_merchant

querystring = {
    "promoTab": "false", 
    "excludeProductList": "false", 
    "page": "1",
    "start":"0", 
    "intent": "false", 
    "multiCategory": "true", 
    "showFacet": "false"}

payload = ""
headers = {
        'authority': 'www.blibli.com',
        'accept': 'application/json, text/plain, */*',
        'accept-encoding':'gzip, deflate, br',
        'accept-language':'en-US,en;q=0.9,id;q=0.8,ja;q=0.7',
        'cache-control':'no-cache',
        'channelid':'mobile-web',
        'cookie': 'Blibli-Device-Id=U.cb41c6ad-3ec3-413b-839f-6ccc5cef84d0; Blibli-Device-Id-Signature=a3add4c1e749d43595ebfc088de7674634e06db5; _gcl_au=1.1.119481478.1662825687; __gtm_med=popads_cpc; __gtm_src=propeller_ads; __bwa_user_id=657116261.U.6479625894511464.1662825687; _vwo_uuid_v2=D2BADB50769B5030869041F9800073B9B|8d3132207c7774ddf328c43ecacd82b4; _fbp=fb.1.1662825687909.1013520868; _tt_enable_cookie=1; _ttp=d7e905ff-7712-4c32-b238-de66f8387bf5; _vis_opt_s=1%7C; _vis_opt_test_cookie=1; _vwo_uuid=D2BADB50769B5030869041F9800073B9B; __gtm_cam=homepage_smartcpm; cebs=1; Blibli-Is-Member=false; Blibli-Is-Remember=false; Blibli-User-Id=c285e445-8329-48d9-9eff-3b3927c4f96a; Blibli-Session-Id=3325b78c-a3a3-4e67-ba44-c09d9b0b4859; Blibli-Signature=bd1048ea8813b09047c5d789a234b1abaff6ddcc; moe_uuid=34b40e3a-d664-4d16-9fb7-79544db6c0d4; _vis_opt_exp_223_exclude=1; JSESSIONID=0C4BE506C57C87DC083457F68DE0388D; _gid=GA1.2.542517985.1669123993; _abck=9438609A1CC0C976A7C5F0965FDCF94B~0~...~-1~-1~-1; bm_sz=0DB30F1D5CE267D687AC0DDC89F6831B~~3425858~3162434; ak_bmsc=236B0A7E53E55C11F8DE574748D3F755~000000000000000000000000000000~...; __bwa_session_id=657116261.S.8918323070550215.1669176817; __bwa_user_session_sequence=58; _vwo_ds=3%3Aa_0%2Ct_0%3A0%241662825685%3A50.27817927%3A%3A7_0%2C6_0%2C5_0%2C4_0%2C3_0%2C2_0%3A215_0%2C214_0%2C213_0%2C211_0%2C210_0%2C209_0%2C208_0%2C139_0%2C3_0%2C2_0%3A0; _ga=GA1.2.1032891258.1662825687; _dc_gtm_UA-21718848-13=1; cebsp=114; cto_bundle=SifeW19QcDBQSWpuaEN2YzJnS2p5S3BoVWhvSHdIenBzUTg0eFdKM1NQRXRFWnM3RW1ic3A0U3Rpb1lmSFFYbmdKZ2VYM3RBZ1R6alpSNmVXM2ZFNzVtNUtVWjlETW41N0U4Uk4xVUk0SXVXYWNaaXd4akUxVzR0SE8lMkZMMFVwSmtCQUdGODc2ZyUyRlRpc2UlMkJ2VVVsYlF6YyUyQlMzZyUzRCUzRA; _ce.s=v~b7660bf9a491e6fb6dc76f40c3afc212ddedcda9~vpv~0~v11.rlc~1669176823921~ir~1~gtrk.la~lat4vwqm; _ga_G3ZP2F3MW9=GS1.1.1669176819.31.1.1669176996.20.0.0; __bwa_session_action_sequence=4; _vwo_sn=6351129%3A7; bm_sv=4F0715554568C1D9C5E39D58AB7CA037~~1',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    }
response = requests.request(
    "GET", url, headers=headers, params=querystring)

data = response.json()
product_list = []
# data

for index in range(0, data['data']['paging']['total_item'], 40):
    querystring_product = {"promoTab": "false", "excludeProductList": "false",
                   "start":f"{index}", "intent": "false", "multiCategory": "true", "showFacet": "false"}
    response_product = requests.request("GET", url, data=payload, headers=headers, params=querystring_product)
    data_product = response_product.json()

    for product in data_product["data"]["products"]:
        product_list.append(product)

# %%
df = pd.json_normalize(product_list)
df
# Out:
#                   id              sku merchantCode        status  \
# 0    BLD-60037-00204  BLD-60037-00204    BLD-60037     AVAILABLE
# 1    BLD-60037-00010  BLD-60037-00010    BLD-60037     AVAILABLE
# 2    BLD-60037-00025  BLD-60037-00025    BLD-60037     AVAILABLE
# 3    BLD-60037-00179  BLD-60037-00179    BLD-60037     AVAILABLE
# 4    BLD-60037-00196  BLD-60037-00196    BLD-60037     AVAILABLE
# ..               ...              ...          ...           ...
# 127  BLI-60053-00130  BLI-60053-00130    BLI-60053  OUT_OF_STOCK
# 128  BLI-60053-00042  BLI-60053-00042    BLI-60053  OUT_OF_STOCK
# 129  BLI-60053-00041  BLI-60053-00041    BLI-60053  OUT_OF_STOCK
# 130  BLD-60037-00219  BLD-60037-00219    BLD-60037  OUT_OF_STOCK
# 131  BLD-60037-00232  BLD-60037-00232    BLD-60037  OUT_OF_STOCK
#
#                                                   name  \
# 0              Frisian Flag Kental Manis Pouch [545 g]
# 1            Frisian Flag Full Cream Susu UHT [225 mL]
# ...

# %%
url_review = "https://www.blibli.com/backend/product-review/public-reviews"

result_review = []

for i in range(0, len(product_list)):
    query_params_review = {
        "page":"1",
        "itemPerPage":"30",
        "productSku":f"{product_list[i]['sku']}"
    }
    headers_review = {
        'authority': 'www.blibli.com',
        'accept': 'application/json, text/plain, */*',
        'accept-language':'en-US,en;q=0.9,id;q=0.8,ja;q=0.7',
        'cache-control':'no-cache',
        'cookie': 'Blibli-Device-Id=U.cb41c6ad-3ec3-413b-839f-6ccc5cef84d0; Blibli-Device-Id-Signature=a3add4c1e749d43595ebfc088de7674634e06db5; _gcl_au=1.1.119481478.1662825687; __gtm_med=popads_cpc; __gtm_src=propeller_ads; __bwa_user_id=657116261.U.6479625894511464.1662825687; _vwo_uuid_v2=D2BADB50769B5030869041F9800073B9B|8d3132207c7774ddf328c43ecacd82b4; _fbp=fb.1.1662825687909.1013520868; _tt_enable_cookie=1; _ttp=d7e905ff-7712-4c32-b238-de66f8387bf5; _vis_opt_s=1%7C; _vis_opt_test_cookie=1; _vwo_uuid=D2BADB50769B5030869041F9800073B9B; __gtm_cam=homepage_smartcpm; cebs=1; Blibli-Is-Member=false; Blibli-Is-Remember=false; Blibli-User-Id=c285e445-8329-48d9-9eff-3b3927c4f96a; Blibli-Session-Id=3325b78c-a3a3-4e67-ba44-c09d9b0b4859; Blibli-Signature=bd1048ea8813b09047c5d789a234b1abaff6ddcc; moe_uuid=34b40e3a-d664-4d16-9fb7-79544db6c0d4; _vis_opt_exp_223_exclude=1; JSESSIONID=0C4BE506C57C87DC083457F68DE0388D; _gid=GA1.2.542517985.1669123993; _abck=9438609A1CC0C976A7C5F0965FDCF94B~0~...~-1~-1~-1; bm_sz=0DB30F1D5CE267D687AC0DDC89F6831B~~3425858~3162434; ak_bmsc=236B0A7E53E55C11F8DE574748D3F755~000000000000000000000000000000~...; _vwo_ds=3%3Aa_0%2Ct_0%3A0%241662825685%3A50.27817927%3A%3A7_0%2C6_0%2C5_0%2C4_0%2C3_0%2C2_0%3A215_0%2C214_0%2C213_0%2C211_0%2C210_0%2C209_0%2C208_0%2C139_0%2C3_0%2C2_0%3A0; _ga=GA1.2.1032891258.1662825687; cto_bundle=yZqhRl9TeXRZMzhRbWp3Tk9iRXNwZENpcnFYbkl1UiUyRlFtTXdBalV1Q3dVc05ldlpBemtJaHYlMkJoNkZNY2xBek1SMUwwbnFJTzNDdlZ4TjJ5dmtkMm1EcjJpSjQlMkY2UXJ4RnRFYWlCbzJzUjlHeThDRzRxYno5cWVMJTJCZWdQc2hYaSUyRllVbE5IRyUyQjVXc3JERlN1SzhoYWNST1FuOHclM0QlM0Q; _dc_gtm_UA-21718848-13=1; __bwa_session_utm_campaign=; __bwa_session_utm_medium=; __bwa_session_utm_source=BRAND_PAGE; __bwa_session_utm_content=; __bwa_session_utm_term=; __bwa_session_campaign_type=campaign-tags; __bwa_session_id=723337755.S.1450413421181787.1669177102; __bwa_user_session_sequence=59; _ga_G3ZP2F3MW9=GS1.1.1669176819.31.1.1669177110.52.0.0; bm_sv=4F0715554568C1D9C5E39D58AB7CA037~~1; _ce.s=v~b7660bf9a491e6fb6dc76f40c3afc212ddedcda9~vpv~0~v11.rlc~1669176823921~ir~1~gtrk.la~lat4yhgr; __bwa_session_action_sequence=3; _vwo_sn=6351129%3A15; cebsp=117',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    }
    response_review = requests.request("GET", url=url_review, headers=headers_review, params=query_params_review).json()

    product = product_list[i]

    try:
        if response_review["paging"]["total_page"] > 1:
            for page in range(1, response_review["paging"]["total_page"]+1):
                querystring_review2 = {"page":f"{page}","itemPerPage":"30","productSku":f"{product_list[i]['sku']}"}

                response_review2 = requests.request("GET", url=url_review, headers=headers_review, params=querystring_review2)
                
                data_review2 = response_review2.json()

                for a in data_review2["data"]:
                    a.update({"product":product})
                    result_review.append(a)
        else:
            for a in response_review["data"]:
                a.update({"product":product})
                result_review.append(a)

        print("Scraping product no. "+str(i)+" sku: " + product_list[i]['sku'] + " review done")
    except Exception as e:
        print(response_review)
        print(e)
# Out:
# Scraping product no. 0 sku: BLD-60037-00204 review done
# Scraping product no. 1 sku: BLD-60037-00010 review done
# Scraping product no. 2 sku: BLD-60037-00025 review done
# Scraping product no. 3 sku: BLD-60037-00179 review done
# Scraping product no. 4 sku: BLD-60037-00196 review done
# Scraping product no. 5 sku: BLD-60037-00187 review done
# Scraping product no. 6 sku: BLD-60037-00005 review done
# Scraping product no. 7 sku: BLI-60053-00117 review done
# Scraping product no. 8 sku: BLD-60037-00029 review done
# Scraping product no. 9 sku: BLD-60037-00023 review done
# Scraping product no. 10 sku: BLD-60037-00192 review done
# Scraping product no. 11 sku: BLD-60037-00206 review done
# Scraping product no. 12 sku: BLD-60037-00194 review done
# Scraping product no. 13 sku: BLD-60037-00027 review done
# Scraping product no. 14 sku: BLD-60037-00035 review done
# Scraping product no. 15 sku: BLD-60037-00037 review done
# Scraping product no. 16 sku: BLD-60037-00021 review done
# ...

# %%
url_review = "https://www.blibli.com/backend/product-review/public-reviews"
query_params_review = {
    "page":"1",
    "itemPerPage":"30",
    "productSku":"91S-60022-00641"
}
headers_review = {
    'authority': 'www.blibli.com',
    'accept': 'application/json, text/plain, */*',
    'accept-language':'en-US,en;q=0.9,id;q=0.8,ja;q=0.7',
    'cache-control':'no-cache',
    'cookie': 'Blibli-Device-Id=U.cb41c6ad-3ec3-413b-839f-6ccc5cef84d0; Blibli-Device-Id-Signature=a3add4c1e749d43595ebfc088de7674634e06db5; _gcl_au=1.1.119481478.1662825687; __gtm_med=popads_cpc; __gtm_src=propeller_ads; __bwa_user_id=657116261.U.6479625894511464.1662825687; _vwo_uuid_v2=D2BADB50769B5030869041F9800073B9B|8d3132207c7774ddf328c43ecacd82b4; _fbp=fb.1.1662825687909.1013520868; _tt_enable_cookie=1; _ttp=d7e905ff-7712-4c32-b238-de66f8387bf5; _vis_opt_s=1%7C; _vis_opt_test_cookie=1; _vwo_uuid=D2BADB50769B5030869041F9800073B9B; __gtm_cam=homepage_smartcpm; cebs=1; Blibli-Is-Member=false; Blibli-Is-Remember=false; Blibli-User-Id=c285e445-8329-48d9-9eff-3b3927c4f96a; Blibli-Session-Id=3325b78c-a3a3-4e67-ba44-c09d9b0b4859; Blibli-Signature=bd1048ea8813b09047c5d789a234b1abaff6ddcc; moe_uuid=34b40e3a-d664-4d16-9fb7-79544db6c0d4; _vis_opt_exp_223_exclude=1; _abck=9438609A1CC0C976A7C5F0965FDCF94B~0~...~-1~-1~-1; bm_sz=6C49DC0353EBCF35EFC34DCBD73EFE7D~~4535876~4337716; JSESSIONID=0C4BE506C57C87DC083457F68DE0388D; ak_bmsc=68995E329202A145F591E914BD3D7223~000000000000000000000000000000~...; _gid=GA1.2.542517985.1669123993; _vwo_ds=3%3Aa_0%2Ct_0%3A0%241662825685%3A50.27817927%3A%3A7_0%2C6_0%2C5_0%2C4_0%2C3_0%2C2_0%3A215_0%2C214_0%2C213_0%2C211_0%2C210_0%2C209_0%2C208_0%2C139_0%2C3_0%2C2_0%3A0; cto_bundle=yM3ubV9OR1RZaE8lMkJzNGVyVVE3UEd3MjFKZXlMelUyRWtDd2lyS0Nxam9TQ2ttUjVvNldkTDQlMkZaNHQ2TGpSZlBvaWlXM2d0R3haN1plMTRiOXdWcU03MHpwTHc2TXgzTnR4JTJGSjZIelByck93eFZuNTJobGVCZUZRTDhPdWhyM3glMkZyc2dpdnBIcGJRM0VmQWozOVN5b0hzeUgydyUzRCUzRA; _ga=GA1.2.1032891258.1662825687; _dc_gtm_UA-21718848-13=1; __bwa_session_utm_campaign=; __bwa_session_utm_medium=; __bwa_session_utm_source=MERCHANT_PAGE; __bwa_session_utm_content=; __bwa_session_utm_term=; __bwa_session_campaign_type=campaign-tags; __bwa_session_id=723337755.S.8328705692739494.1669125735; __bwa_user_session_sequence=50; __bwa_session_action_sequence=3; _vwo_sn=6298315%3A20; cebsp=86; _ga_G3ZP2F3MW9=GS1.1.1669123995.27.1.1669125757.38.0.0; bm_sv=EF3C6E4667E589D9F533595D55BBC73B~~1; _ce.s=v~b7660bf9a491e6fb6dc76f40c3afc212ddedcda9~vpv~0~v11.rlc~1669124010383~gtrk.la~lasadpjo',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
}
response_review = requests.request("GET", url=url_review, headers=headers_review, params=query_params_review).json()

product = product_list[i]

try:
    if response_review["paging"]["total_page"] > 1:
        for page in range(1, response_review["paging"]["total_page"]+1):
            querystring_review2 = {"page":f"{page}","itemPerPage":"30","productSku":"91S-60022-00641"}

            response_review2 = requests.request("GET", url=url_review, headers=headers_review, params=querystring_review2)
            
            data_review2 = response_review2.json()

            for a in data_review2["data"]:
                a.update({"product":product})
                result_review.append(a)
    else:
        for a in response_review["data"]:
            a.update({"product":product})
            result_review.append(a)

    print("Scraping product sku: 91S-60022-00641 review done")
except Exception as e:
    print(response_review)
    print(e)
# Out:
# Scraping product sku: 91S-60022-00641 review done

# %%
df_review = pd.json_normalize(result_review)
df_review
# Out:
#                                         id     name  rating  \
# 0     170ba96d-af89-4acc-90bd-9e9ec42e1bd0  jessica       5
# 1     aa46e455-f0c9-4a0a-b2b0-505d0d14e729     janu       5
# 2     1b76d80a-84f5-43a4-be5e-661c38596553    L***n       4
# 3     89129333-4d37-4b72-b0d6-566f091620d4    S***i       5
# 4     2792d9bc-7316-4476-91ec-ad5205796659  BAMBANG       5
# ...                                    ...      ...     ...
# 9335  aef7988e-1eb0-429c-b021-80030011dbce     Dika       5
# 9336  89f03236-48aa-42bf-b7be-66b3e0eabf4a     mama       5
# 9337  a38bf198-2433-45c3-80a3-cee868515466  Pininta       5
# 9338  38100dcc-6218-40fd-b26d-d178e5dc564a     Ivan       5
# 9339  515c0398-69c6-4afb-9436-76965fe8115a    M***c       5
#
#                                                 content    createdDate  \
# 0                                                        1669038077491
# 1                                                        1669037969428
# ...

# %%
from pymongo import MongoClient

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['blibliProductReview'] 
collection = db['frisian_flag']

# %%
collection.insert_many(result_review)

# %%
data = collection.find()

df = pd.json_normalize(data)
df
# Out:
#                            _id                                    id     name  \
# 0     637da7b1a3544c828525076d  170ba96d-af89-4acc-90bd-9e9ec42e1bd0  jessica
# 1     637da7b1a3544c828525076e  aa46e455-f0c9-4a0a-b2b0-505d0d14e729     janu
# 2     637da7b1a3544c828525076f  1b76d80a-84f5-43a4-be5e-661c38596553    L***n
# 3     637da7b1a3544c8285250770  89129333-4d37-4b72-b0d6-566f091620d4    S***i
# 4     637da7b1a3544c8285250771  2792d9bc-7316-4476-91ec-ad5205796659  BAMBANG
# ...                        ...                                   ...      ...
# 9335  637da7b1a3544c8285252be4  aef7988e-1eb0-429c-b021-80030011dbce     Dika
# 9336  637da7b1a3544c8285252be5  89f03236-48aa-42bf-b7be-66b3e0eabf4a     mama
# 9337  637da7b1a3544c8285252be6  a38bf198-2433-45c3-80a3-cee868515466  Pininta
# 9338  637da7b1a3544c8285252be7  38100dcc-6218-40fd-b26d-d178e5dc564a     Ivan
# 9339  637da7b1a3544c8285252be8  515c0398-69c6-4afb-9436-76965fe8115a    M***c
#
# ...
