# %%
from pymongo import MongoClient
import pandas as pd
import nltk
import string
import re
import numpy as np

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['blibliProductReview'] 
collection = db['somethinc']

# %%
data = collection.find()

df = pd.json_normalize(data)
df
# Out:
#                            _id                                    id  \
# 0     637e18d68ccf7446afd010e3  73a68739-1237-49f1-821f-6261cb90c5fc
# 1     637e18d68ccf7446afd010e4  75702197-fba0-4200-a0f0-52dd7c8c332c
# 2     637e18d68ccf7446afd010e5  2a91401f-8e11-4b90-8027-7605a8b89ba3
# 3     637e18d68ccf7446afd010e6  5c94e856-63aa-40c5-be9d-8931160c049d
# 4     637e18d68ccf7446afd010e7  3d98c992-e2c9-454c-aa1a-a957f7ac5764
# ...                        ...                                   ...
# 8348  637e18d68ccf7446afd0317f  c5025d0d-a0d3-48ed-827e-11ce51f6cacc
# 8349  637e18d68ccf7446afd03180  40b76884-0c7b-4f71-ad22-93d237b1ad45
# 8350  637e18d68ccf7446afd03181  236dc7b3-5a93-43fb-8e1f-2bac06cfcc46
# 8351  637e18d68ccf7446afd03182  86009efb-3533-476f-bfdc-fba46fe8f399
# 8352  637e18d68ccf7446afd03183  893e13a5-337b-4856-b471-4f292ad587df
#
#                  name  rating    createdDate    updatedDate  likes  \
# 0                 Aro       5  1668487909680  1668487909680      0
# ...

# %%
df_content = pd.DataFrame(df[['rating', 'content', 'createdDate', 'product.name']])
df_content
# Out:
#       rating                                            content  \
# 0          5                                                NaN
# 1          5
# 2          5
# 3          5
# 4          5
# ...      ...                                                ...
# 8348       5                                     Very pigmented
# 8349       5
# 8350       5  so pretty... warnanya pigmented banget, hargan...
# 8351       5    good seller. trusted. barang sampai dengan aman
# 8352       5            Bagus bgt. Pigmented dan warnanya ok ok
#
#         createdDate                                       product.name
# 0     1668487909680        Somethinc AHA BHA PHA Peeling Solution 20ml
# 1     1668437644933        Somethinc AHA BHA PHA Peeling Solution 20ml
# 2     1668379161516        Somethinc AHA BHA PHA Peeling Solution 20ml
# 3     1668228006469        Somethinc AHA BHA PHA Peeling Solution 20ml
# 4     1668162659023        Somethinc AHA BHA PHA Peeling Solution 20ml
# ...

# %%
df_content = df_content.dropna(how='all',subset=['content'])
df_content
# Out:
#       rating                                            content  \
# 1          5
# 2          5
# 3          5
# 4          5
# 6          5                                      bagus bangett
# ...      ...                                                ...
# 8348       5                                     Very pigmented
# 8349       5
# 8350       5  so pretty... warnanya pigmented banget, hargan...
# 8351       5    good seller. trusted. barang sampai dengan aman
# 8352       5            Bagus bgt. Pigmented dan warnanya ok ok
#
#         createdDate                                       product.name
# 1     1668437644933        Somethinc AHA BHA PHA Peeling Solution 20ml
# 2     1668379161516        Somethinc AHA BHA PHA Peeling Solution 20ml
# 3     1668228006469        Somethinc AHA BHA PHA Peeling Solution 20ml
# 4     1668162659023        Somethinc AHA BHA PHA Peeling Solution 20ml
# 6     1666909187978        Somethinc AHA BHA PHA Peeling Solution 20ml
# ...

# %%
df_content = df_content[df_content.content != ""]
df_content
# Out:
#       rating                                            content  \
# 6          5                                      bagus bangett
# 16         5  selalu puas kalau belanja di blibli official. ...
# 20         5  packing aman, 1 hari sampai, baru pertama nyob...
# 23         5      peeling andalan.. ga bikin iritasi.. cinttaaa
# 25         5  Pesanan sudah diterima dengan baik, sesuai des...
# ...      ...                                                ...
# 8347       5                                         bagusnyaaa
# 8348       5                                     Very pigmented
# 8350       5  so pretty... warnanya pigmented banget, hargan...
# 8351       5    good seller. trusted. barang sampai dengan aman
# 8352       5            Bagus bgt. Pigmented dan warnanya ok ok
#
#         createdDate                                       product.name
# 6     1666909187978        Somethinc AHA BHA PHA Peeling Solution 20ml
# ...

# %%
duplicates = df_content[df_content.duplicated(['content', 'product.name'])]
duplicates
# Out:
#       rating                                            content  \
# 439        5                                               good
# 1051       5                                                 ok
# 1053       4                         baru mau coba semoga cocok
# 1344       5                                              bagus
# 1365       5                                               nice
# 1594       5                                        Sangat baik
# 1724       5                                                 ok
# 1764       5                                                 ok
# 1794       5                                               good
# 2110       5                                               good
# 2455       5                                              Bagus
# 2506       5  barang nya cepat datang sesuai pesanan...senan...
# 2520       5  sesuai deskripsi, proses pesanan cepat, produk...
# 2601       5                                              bagus
# ...

# %%
df_nonduplicate = df_content.drop_duplicates(subset=['content', 'product.name'])
df_nonduplicate
# Out:
#       rating                                            content  \
# 6          5                                      bagus bangett
# 16         5  selalu puas kalau belanja di blibli official. ...
# 20         5  packing aman, 1 hari sampai, baru pertama nyob...
# 23         5      peeling andalan.. ga bikin iritasi.. cinttaaa
# 25         5  Pesanan sudah diterima dengan baik, sesuai des...
# ...      ...                                                ...
# 8347       5                                         bagusnyaaa
# 8348       5                                     Very pigmented
# 8350       5  so pretty... warnanya pigmented banget, hargan...
# 8351       5    good seller. trusted. barang sampai dengan aman
# 8352       5            Bagus bgt. Pigmented dan warnanya ok ok
#
#         createdDate                                       product.name
# 6     1666909187978        Somethinc AHA BHA PHA Peeling Solution 20ml
# ...
