# %%
import requests
import pandas as pd
from pymongo import MongoClient

# %%
vender_id = "47912"
token = "5f1fa63293091314122dec2466e65dd6"

# %%
url = 'https://color.jd.id/shop_decoration_ina/search/2.0'

query_params = {
    'pageSize':'50',
    'mergeSku':'true', 
    'venderId':f'{vender_id}',
    'pageNo':'1',
    'orderBy':'1',
    'catLevel':'-1',
    'filters':'{}',
    '_token':f'{token}'
}

headers = {
    'authority': 'color.jd.id',
    'accept': '*/*',
    'cookie': 'mba_muid=166860068555036447537; _deviceId=cbeb6b66-d448-4b21-aab0-611c512b955d; eptCountry=%7B%22id%22%3A%2262%22%7D; _gcl_au=1.1.799070587.1668600687; GarudaShop=Other Page; _fbp=fb.1.1668600717483.1200734578; address_flag=true; stateId=10100000; cityId=10100004; areaId=10100033; townId=10100209; regional_full=10100000:DKI%20Jakarta|10100004:Kota%20Jakarta%20Selatan|10100033:Setia%20Budi|10100209:Karet%20Kuningan; moe_uuid=ea3dfb1c-f3b2-4cf7-bf83-a9b39eac502a; USER_DATA=%7B%22attributes%22%3A%5B%5D%2C%22subscribedToOldSdk%22%3Afalse%2C%22deviceUuid%22%3A%22ea3dfb1c-f3b2-4cf7-bf83-a9b39eac502a%22%2C%22deviceAdded%22%3Atrue%7D; shshshfpa=a7fce101-466d-8ca7-109c-9b3d3a896bc0-1668672773; site=undefined; shshshfpb=iyCjL7701bdt0nv0hai9Xjg; x_api_device_token=38e0fb2e-3091-4227-883f-a1f9a0dc17e3; _gia_s_local_fingerprint=6465bf402a49e4ecc47d679c1b8c8438; _gia_s_e_joint={"eid":"FK2TYVRWIWHAB363FQW42A3QEJI4YCS3VSHNIR5IH6ZE7WLUAXZSH2ALRJOCGX64HCHW5X2OESC2VIW6WGNMRI43ZU","ma":"","im":"","os":"Android 6.x","ip":"182.253.132.113","ia":"","uu":"","at":"6"}; TrackID=1thqAgyJR7lnAMleDW1k0d4xCVQr13iO1iaLtj9v3CmOgkTquX4CkYwNmLZmvMubaoFq_yg7TzPOm2Ck_bN3s3Q; pinId=2l-AJG5YkWyr6ERWVo1rrbKS7MJkIcs6; pin=jdid_deglekwqxwlc; unick=jdid_eqtGCmjycoit; me=05429cefa54876c1fac907b8fde611ef; jmp=5b1dbe1e2e8d757935d0ef70227f6cc1e9e5294b5fef3506fd199b439ac6992f; _tp=""; logining=1; _pst=jdid_deglekwqxwlc; __jdv=63461492|accounts.google.com|-|organic|notset|1668674909535; regional_pin=jdid_deglekwqxwlc; _gid=GA1.2.1340604156.1668861183; vc=8861187672; __jda=63461492.166860068555036447537.1668600685.1668701149.1668861187.10; __jdc=63461492; __jd_ab=10; _searchHistory=official%2520store%2Cpolytton%2Caerostreet%2Cset%2520top%2520box%2CAdvan%2Csanken%2Cnike; _gat_UA-69994851-3=1; _dc_gtm_UA-69994851-3=1; shshshfp=65c1eef4af192a35c9cfea0224cd40b2; shshshsID=9b9527a912ec2b799fd3581ebac1d4cd_4_1668861499325; _dc_gtm_UA-69994851-1=1; 3AB9D23F7A4B3C9B=FK2TYVRWIWHAB363FQW42A3QEJI4YCS3VSHNIR5IH6ZE7WLUAXZSH2ALRJOCGX64HCHW5X2OESC2VIW6WGNMRI43ZU; lighting-id=...; RT="z=1&dm=jd.id&si=cwt9r2ru0yo&ss=lanwv15e&sl=b&tt=mnr&ld=6r18&ul=6s27&hd=6s9f"; _tk=U1gi7ubab111h41vv5lsfjrm5l90; m-search-ab=idsearchrevision-new-10_100; _browser_id=58823322-0e98-4a26-9e83-4d227f09c5f7; cto_bundle=vKSIFl9KRSUyQmVJMTFKazF5T3ltSURMQkdMdDEzbTVJek5vY0JBd1B3cUVmUDhGUFdhbmRjODNYSlV4aXYwN3VNeUZrTWlndjZaNjc4TEh6V1QlMkZkSFh0MnQzSEs5RnNRR3NpNWRMYW5IRktuaDNpdVdQME1SNzRRQiUyQnBhTGpTdktpSXpMNQ; __jdb=63461492.23.166860068555036447537|10.1668861187; mba_sid=16688611875602784285884544071.7; _ga_VZMC86167F=GS1.1.1668861183.10.1.1668861537.45.0.0; _ga=GA1.2.221065702.1668600688',
    'lang': 'id',
    'origin': 'https://www.jd.id',
    'referer': 'https://www.jd.id/',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    'x-api-timestamp': '1668679359139'
}

product_list = []

data = requests.request("POST", url, headers=headers, params=query_params).json()

for i in range(1, data['data']['pageCount']+1):
    query_params_productlist = {
        'pageSize':'50',
        'mergeSku':'true', 
        'venderId':f'{vender_id}',
        'pageNo':f'{i}',
        'orderBy':'1',
        'catLevel':'-1',
        'filters':'{}',
        '_token':f'{token}'
    }

    product_response = requests.request("POST", url, headers=headers, params=query_params_productlist).json()
    for product in product_response['data']['skuList']:
        product_list.append(product)

# %%
df = pd.json_normalize(product_list)
df
# Out:
#     commentNum goodComment                                           imageUrl  \
# 0           16           5  https://img12.jd.id/zhipu/amZzL3Q4NS83MC80OTk5...
# 1           11           5  https://img12.jd.id/zhipu/amZzL3Q3My8zOC80OTI2...
# 2           39           5  https://img12.jd.id/zhipu/amZzL3Q4Mi8xNzcvNDI3...
# 3           12           5  https://img12.jd.id/zhipu/amZzL3Q3OS8yODkvNDk3...
# 4            0         5.0  https://img12.jd.id/zhipu/amZzL3Q4NS8yOTEvMjQ3...
# ..         ...         ...                                                ...
# 94           0         5.0  https://img12.jd.id/zhipu/amZzL3Q5NC8xNTEvMTUz...
# 95           0           5  https://img12.jd.id/zhipu/amZzL3QxMDYvMTAwLzk4...
# 96           1           5  https://img12.jd.id/zhipu/amZzL3Q4NS8xNDYvMTU2...
# 97           0           5  https://img12.jd.id/zhipu/amZzL3QxMDkvNzMvOTg1...
# 98           0         5.0  https://img12.jd.id/zhipu/amZzL3Q5NC8zMjcvMTU1...
#
#     promoStatus      skuId                                            skuName  \
# 0             0  659846226  910 Nineten Hatomi Kaos Kaki Pendek Socks Ankl...
# 1             0  629067218  910 Nineten Fuka Kaos Kaki Panjang Socks Quart...
# 2             0  627505081  910 Nineten Nichirin Kaos Kaki Pendek Socks An...
# 3             0  629066321  910 Nineten Fuka Kaos Kaki Panjang Socks Quart...
# 4             0  653721348  910 Nineten Haze 1.5 Sepatu Lari - Biru Dongke...
# ..          ...        ...                                                ...
# 94            0  686593738           910 Nineten Senko Jersey Lari - Hitam  S
# 95            0  694731597  910 Nineten Bundling Kaos Kaki Hatomi Ankle Ab...
# 96            0  694730133  910 Nineten Bundling Kaos Kaki Hatomi Ankle Hi...
# 97            0  694736581  910 Nineten Bundling Kaos Kaki Hatomi Ankle Mi...
# 98            0  686594414       910 Nineten Yuza Riot Jersey Lari - Hijau  M
#
#         spuId
# 0   659846225
# 1   629067217
# 2   627505080
# 3   629066320
# 4   653722110
# ..        ...
# 94  686593737
# 95  694731596
# 96  694730132
# 97  694736580
# 98  686594413
#
# [99 rows x 7 columns]

# %%
url_review = 'https://color.jd.id/jdid_pc_website/comment_product_page/1.0'

review_list = []
for index in range(0, len(product_list)):
    query_params_review = {
        'spuId':f'{product_list[index]["spuId"]}',
        'skuId':f'{product_list[index]["skuId"]}',
        'storeId':'',
        'pageSize':'50',
        'pageIndex':'1',
        'tagId':'',
        'commentType':''
    }

    headers_review = {
        'authority': 'color.jd.id',
        'accept': '*/*',
        'cookie': 'mba_muid=166860068555036447537; _deviceId=cbeb6b66-d448-4b21-aab0-611c512b955d; eptCountry={"id":"62"}; _gcl_au=1.1.799070587.1668600687; GarudaShop=Other Page; _fbp=fb.1.1668600717483.1200734578; address_flag=true; stateId=10100000; cityId=10100004; areaId=10100033; townId=10100209; regional_full=10100000:DKI Jakarta|10100004:Kota Jakarta Selatan|10100033:Setia Budi|10100209:Karet Kuningan; moe_uuid=ea3dfb1c-f3b2-4cf7-bf83-a9b39eac502a; USER_DATA={"attributes":[],"subscribedToOldSdk":false,"deviceUuid":"ea3dfb1c-f3b2-4cf7-bf83-a9b39eac502a","deviceAdded":true}; shshshfpa=a7fce101-466d-8ca7-109c-9b3d3a896bc0-1668672773; site=undefined; shshshfpb=iyCjL7701bdt0nv0hai9Xjg; x_api_device_token=38e0fb2e-3091-4227-883f-a1f9a0dc17e3; _gia_s_local_fingerprint=6465bf402a49e4ecc47d679c1b8c8438; _gia_s_e_joint={"eid":"FK2TYVRWIWHAB363FQW42A3QEJI4YCS3VSHNIR5IH6ZE7WLUAXZSH2ALRJOCGX64HCHW5X2OESC2VIW6WGNMRI43ZU","ma":"","im":"","os":"Android 6.x","ip":"182.253.132.113","ia":"","uu":"","at":"6"}; _tp=""; logining=1; regional_pin=jdid_deglekwqxwlc; vc=0398590495; _gid=GA1.2.678183130.1670398593; __jd_ab=15; _searchHistory=910; cto_bundle=MMeRTl83MVRSWHgwZklWYlp2VE9ETzBhN1lYTVVWdmw3N0FDa3JFcWtsZEtTakpkaGo0TW4wNkx2MTlvT0lhUmF2NkxqJTJGUUFPJTJCWkM0UEhzMjR4REpSNFdsNUx4SjcxMmg5ZHBmSksxMjBrZFMxZlZPZGNxZWVpcTJueTlRQ1Z0OGc4eTI; shshshfp=5dd83b1ac7975da99b4babe22f2b3d29; mba_sid=16703985906249333596767135208.2; TrackID=1PS7Zdov6S1YEOBCRoW_hA_yzJg7rb09rFwYRTAlEbcacM8fPXzik5ZJB9Hvlp5Xtyud7k1jtEXpm12HZu-VGLA; lighting-id=...; pinId=F75_dAMyEJadIkMtq60ob9lOVL4SJJY8; pin=jdid_zzqpaghwqnyn; unick=jdid_f15kcDHcvizz; me=96240b55f0991d7beba877ce24869687; jmp=be905eb086eb3c36122773d3995fa483917793b2178e1d68a9cfef3f209b7653; _pst=jdid_zzqpaghwqnyn; __jdc=63461492; __jda=63461492.166860068555036447537.1668600685.1670398591.1670398869.16; __jdv=63461492|accounts.google.com|-|organic|notset|1670398869260; shshshsID=524fd5b552e05c64ebd3b2d1ae136709_5_1670398880536; _ga=GA1.2.221065702.1668600688; 3AB9D23F7A4B3C9B=FK2TYVRWIWHAB363FQW42A3QEJI4YCS3VSHNIR5IH6ZE7WLUAXZSH2ALRJOCGX64HCHW5X2OESC2VIW6WGNMRI43ZU; _ga_VZMC86167F=GS1.1.1670398592.16.1.1670399000.60.0.0; RT="z=1&dm=jd.id&si=zg9036csei&ss=lbdc6fth&sl=b&tt=15ub&ld=6vfw&nu=6277b638b01049e58dfacbd65896d302&cl=98pi&ul=98rs&hd=99zk"; _browser_id=1670399001387; __jdb=63461492.4.166860068555036447537|16.1670398869',
        'lang': 'id',
        'origin': 'https://www.jd.id',
        'referer': 'https://www.jd.id/',
        'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-site',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
        'x-api-platform': 'PC',
        'x-api-timestamp': '1668680185752'
    }

    response_review = requests.request("POST", url_review, headers=headers_review, params=query_params_review).json()
    product = product_list[index]
    for page in range(1, round(response_review['data']['total']/50)+2):
        query_params_review = {
            'spuId':f'{product_list[index]["spuId"]}',
            'skuId':f'{product_list[index]["skuId"]}',
            'storeId':'',
            'pageSize':'50',
            'pageIndex':f'{page}',
            'tagId':'',
            'commentType':''
        }

        response_reviews = requests.request("POST", url_review, headers=headers_review, params=query_params_review).json()
        for review in response_reviews['data']['items']:
            review.update({"product":product})
            review_list.append(review)
    print("Scraping product no. "+str(index)+" id: " + str(product_list[index]["spuId"]) + " review done")
# Out:
# Scraping product no. 0 id: 659846225 review done
# Scraping product no. 1 id: 629067217 review done
# Scraping product no. 2 id: 627505080 review done
# Scraping product no. 3 id: 629066320 review done
# Scraping product no. 4 id: 653722110 review done
# Scraping product no. 5 id: 654882691 review done
# Scraping product no. 6 id: 624935344 review done
# Scraping product no. 7 id: 654879047 review done
# Scraping product no. 8 id: 668974826 review done
# Scraping product no. 9 id: 654876840 review done
# Scraping product no. 10 id: 609867427 review done
# Scraping product no. 11 id: 701430786 review done
# Scraping product no. 12 id: 628560048 review done
# Scraping product no. 13 id: 693861312 review done
# Scraping product no. 14 id: 624914163 review done
# Scraping product no. 15 id: 654883274 review done
# Scraping product no. 16 id: 674613154 review done
# Scraping product no. 17 id: 693871778 review done
# Scraping product no. 18 id: 702329410 review done
# Scraping product no. 19 id: 644390156 review done
# Scraping product no. 20 id: 686594329 review done
# Scraping product no. 21 id: 674611469 review done
# Scraping product no. 22 id: 609123724 review done
# Scraping product no. 23 id: 702329977 review done
# Scraping product no. 24 id: 674583780 review done
# Scraping product no. 25 id: 642876865 review done
# Scraping product no. 26 id: 609123571 review done
# Scraping product no. 27 id: 702329879 review done
# Scraping product no. 28 id: 702329336 review done
# Scraping product no. 29 id: 624913348 review done
# Scraping product no. 30 id: 642589734 review done
# Scraping product no. 31 id: 674718377 review done
# Scraping product no. 32 id: 691262238 review done
# Scraping product no. 33 id: 702329915 review done
# Scraping product no. 34 id: 697032825 review done
# Scraping product no. 35 id: 609866703 review done
# Scraping product no. 36 id: 658830032 review done
# Scraping product no. 37 id: 698107592 review done
# Scraping product no. 38 id: 698065193 review done
# Scraping product no. 39 id: 694764143 review done
# Scraping product no. 40 id: 627101927 review done
# Scraping product no. 41 id: 643639856 review done
# Scraping product no. 42 id: 704237293 review done
# Scraping product no. 43 id: 686972613 review done
# Scraping product no. 44 id: 675107593 review done
# Scraping product no. 45 id: 671061284 review done
# Scraping product no. 46 id: 692904496 review done
# Scraping product no. 47 id: 670013256 review done
# Scraping product no. 48 id: 701430248 review done
# Scraping product no. 49 id: 609125803 review done
# Scraping product no. 50 id: 692908425 review done
# Scraping product no. 51 id: 679908134 review done
# Scraping product no. 52 id: 698199087 review done
# Scraping product no. 53 id: 684761754 review done
# Scraping product no. 54 id: 609867809 review done
# Scraping product no. 55 id: 698106834 review done
# Scraping product no. 56 id: 630141342 review done
# Scraping product no. 57 id: 628996646 review done
# Scraping product no. 58 id: 629242893 review done
# Scraping product no. 59 id: 694730940 review done
# Scraping product no. 60 id: 633187905 review done
# Scraping product no. 61 id: 694730402 review done
# Scraping product no. 62 id: 658829296 review done
# Scraping product no. 63 id: 654881847 review done
# Scraping product no. 64 id: 694765526 review done
# Scraping product no. 65 id: 646048617 review done
# Scraping product no. 66 id: 694195433 review done
# Scraping product no. 67 id: 686970436 review done
# Scraping product no. 68 id: 654876480 review done
# Scraping product no. 69 id: 694729631 review done
# Scraping product no. 70 id: 704236478 review done
# Scraping product no. 71 id: 686589158 review done
# Scraping product no. 72 id: 624464117 review done
# Scraping product no. 73 id: 654880272 review done
# Scraping product no. 74 id: 694728715 review done
# Scraping product no. 75 id: 621640377 review done
# Scraping product no. 76 id: 654879204 review done
# Scraping product no. 77 id: 674947513 review done
# Scraping product no. 78 id: 654883160 review done
# Scraping product no. 79 id: 694620128 review done
# Scraping product no. 80 id: 690968807 review done
# Scraping product no. 81 id: 698065453 review done
# Scraping product no. 82 id: 694737378 review done
# Scraping product no. 83 id: 674156558 review done
# Scraping product no. 84 id: 675702211 review done
# Scraping product no. 85 id: 686593640 review done
# Scraping product no. 86 id: 694764771 review done
# Scraping product no. 87 id: 694731877 review done
# Scraping product no. 88 id: 694043859 review done
# Scraping product no. 89 id: 670013573 review done
# Scraping product no. 90 id: 641551743 review done
# Scraping product no. 91 id: 654878639 review done
# Scraping product no. 92 id: 702330322 review done
# Scraping product no. 93 id: 674580905 review done
# Scraping product no. 94 id: 686593737 review done
# Scraping product no. 95 id: 694731596 review done
# Scraping product no. 96 id: 694730132 review done
# Scraping product no. 97 id: 694736580 review done
# Scraping product no. 98 id: 686594413 review done

# %%
df_review = pd.json_normalize(review_list)
df_review
# Out:
#     userNickName                                          userImage country  \
# 0         R****i  amZzL3Q3Ni8xMzQvMTkwNDc4NjY0NzEvNzAzODI3L2RiZW...    None
# 1         j****0                                               None    None
# 2         j****l                                               None    None
# 3         t****8                    nHBfsgAACgAAAAQAJYa1UgAAYTA.jpg    None
# 4         j****Q  amZzL3Q4OC81OC83NzcwODEyMjA5LzI2Njg2LzRiODg3Ym...    None
# ..           ...                                                ...     ...
# 325       d****o                                               None    None
# 326       g****h  amZzL3QxMDkvMjIvMTE0MDY5MTM5Mi8yMzUwMC9jNTJiMW...    None
# 327       R****i  amZzL3Q3Ni8xMzQvMTkwNDc4NjY0NzEvNzAzODI3L2RiZW...    None
# 328       m****8                                               None    None
# 329       h****t                                               None    None
#
#      commentType      skuId venderId userPin  \
# 0              5  659846226    47912  r****i
# 1              5  659846226    47912  j****0
# 2              5  659846226    47912  j****l
# 3              5  659846226    47912  t****8
# 4              5  659846226    47912  j****w
# ..           ...        ...      ...     ...
# 325            5  694737379    47912  j****b
# 326            5  694765601    47912  j****t
# 327            5  654878640    47912  r****i
# 328            5  654878640    47912  j****p
# 329            5  686594415    47912  j****t
#
#                                       commentChildrens wareCommStatus  \
# 0    [{'commentId': '546746382', 'commentDate': 165...           None
# 1    [{'commentId': '549141971', 'commentDate': 166...           None
# 2    [{'commentId': '549120235', 'commentDate': 166...           None
# 3    [{'commentId': '549096939', 'commentDate': 166...           None
# 4    [{'commentId': '546659137', 'commentDate': 165...           None
# ..                                                 ...            ...
# 325  [{'commentId': '548988743', 'commentDate': 166...           None
# 326  [{'commentId': '548978369', 'commentDate': 166...           None
# 327  [{'commentId': '546746379', 'commentDate': 165...           None
# 328  [{'commentId': '546941091', 'commentDate': 165...           None
# 329  [{'commentId': '548578554', 'commentDate': 166...           None
#
#          spuId wareWarrStatus skuAttributes  product.commentNum  \
# 0    659846225           None                                16
# 1    659846225           None                                16
# 2    659846225           None                                16
# 3    659846225           None                                16
# 4    659846225           None                                16
# ..         ...            ...           ...                 ...
# 325  694737378           None                                 1
# 326  694764771           None                                 1
# 327  654878639           None                                 2
# 328  654878639           None                                 2
# 329  686594413           None                                 0
#
#     product.goodComment                                   product.imageUrl  \
# 0                     5  https://img12.jd.id/zhipu/amZzL3Q4NS83MC80OTk5...
# 1                     5  https://img12.jd.id/zhipu/amZzL3Q4NS83MC80OTk5...
# 2                     5  https://img12.jd.id/zhipu/amZzL3Q4NS83MC80OTk5...
# 3                     5  https://img12.jd.id/zhipu/amZzL3Q4NS83MC80OTk5...
# 4                     5  https://img12.jd.id/zhipu/amZzL3Q4NS83MC80OTk5...
# ..                  ...                                                ...
# 325                   5  https://img12.jd.id/zhipu/amZzL3QxMzAvNTcvOTMz...
# 326                   5  https://img12.jd.id/zhipu/amZzL3QxNDIvMjk1Lzk1...
# 327                   5  https://img12.jd.id/zhipu/amZzL3QxMDAvMTkzLzMz...
# 328                   5  https://img12.jd.id/zhipu/amZzL3QxMDAvMTkzLzMz...
# 329                 5.0  https://img12.jd.id/zhipu/amZzL3Q5NC8zMjcvMTU1...
#
#      product.promoStatus  product.skuId  \
# 0                      0      659846226
# 1                      0      659846226
# 2                      0      659846226
# 3                      0      659846226
# 4                      0      659846226
# ..                   ...            ...
# 325                    0      694737379
# 326                    0      694765601
# 327                    0      654878640
# 328                    0      654878640
# 329                    0      686594414
#
#                                        product.skuName  product.spuId
# 0    910 Nineten Hatomi Kaos Kaki Pendek Socks Ankl...      659846225
# 1    910 Nineten Hatomi Kaos Kaki Pendek Socks Ankl...      659846225
# 2    910 Nineten Hatomi Kaos Kaki Pendek Socks Ankl...      659846225
# 3    910 Nineten Hatomi Kaos Kaki Pendek Socks Ankl...      659846225
# 4    910 Nineten Hatomi Kaos Kaki Pendek Socks Ankl...      659846225
# ..                                                 ...            ...
# 325  910 Nineten Bundling Kaos Kaki Hatomi Ankle Ab...      694737378
# 326  910 Nineten Bundling Hatomi Quarter Hitam Sock...      694764771
# 327  910 Nineten Raku Kaos Kaki Pendek Socks Ankle ...      654878639
# 328  910 Nineten Raku Kaos Kaki Pendek Socks Ankle ...      654878639
# 329       910 Nineten Yuza Riot Jersey Lari - Hijau  M      686594413
#
# [330 rows x 19 columns]

# %%
df_review = pd.json_normalize(
    review_list, 
    record_path = ['commentChildrens'], 
    meta=[
        'userNickName', 
        'userImage', 
        'country', 
        'venderId', 
        'userPin', 
        'wareCommStatus', 
        'wareWarrStatus', 
        'skuAttributes', 
        ['product', 'commentNum'],
        ['product', 'goodComment'],
        ['product', 'imageUrl'],
        ['product', 'skuId'],
        ['product', 'skuName'],
        ['product', 'spuId']
        ]
    )
df_review
# Out:
#       commentId    commentDate  \
# 0     548368176  1662802514000
# 1     548279461  1662256672000
# 2     536999225  1613182573000
# 3     546762806  1652790365000
# 4     543393019  1636586934000
# ...         ...            ...
# 4094  538347272  1617623126000
# 4095  534221255  1605220587000
# 4096  535798700  1609244007000
# 4097  539616468  1622273600000
# 4098  534489877  1605960298000
#
#                                                 content  \
# 0     sepatunya keren, mengganti sepatu anak yg udah...
# 1     paket nya sudah datang dengan selamat, bahan n...
# 2                 sepatunya keren bgt,thanks aerostreet
# 3     wah ini bagus bangt sih.walapun hampir sama ka...
# 4     Saya suka model sepatunya, keren. Cuman agak s...
# ...                                                 ...
# 4094                                       sangat bagus
# 4095                                              bagus
# 4096                     terima kasih.. sepatunya bagus
# 4097                                             kereen
# 4098  Terimakasih sudah menjadi market place terbaik...
#
#                                                 imgList         state  \
# 0     [amZzL3Q5Ny8yNTgvMTU3Mjg3MDg2MDYvOTc1Mzg1L2UwN...  AUDIT_PASSED
# 1     [amZzL3Q5MS8zMTEvMTU2MjAwMzExODUvOTIxMjgxL2JhZ...  AUDIT_PASSED
# 2     [amZzL3Q3My8yNjQvMzQxMTA0OTIyOS8xMDE3MzQ2LzY4N...  AUDIT_PASSED
# 3     [amZzL3Q5NC8xNTcvMTA5NjcwNTYyNzcvMTg5NTU1NS8zM...  AUDIT_PASSED
# 4     [amZzL3Q5NC80LzI5NDYyMjgzMDIvNjQ0NTA4LzE2OGYzM...  AUDIT_PASSED
# ...                                                 ...           ...
# 4094                                                 []  AUDIT_PASSED
# 4095  [amZzL3Q3OS8yODgvMjM1ODYwNDg1MS8xMzMzODU0LzljZ...  AUDIT_PASSED
# 4096  [amZzL3Q3Ni8zMDUvMjY3MDcwNDYxNy8xMzk1NDUwL2Q2N...  AUDIT_PASSED
# 4097                                                 []  AUDIT_PASSED
# 4098                                                 []  AUDIT_PASSED
#
#       replyYn               ip  commentAgain  commentType  venderReply  ...  \
# 0           0   112.215.235.64             0            5            0  ...
# 1           0     114.10.30.70             0            5            0  ...
# 2           0  114.124.173.171             0            5            0  ...
# 3           0     182.0.172.28             0            5            0  ...
# 4           0    120.188.72.58             0            5            0  ...
# ...       ...              ...           ...          ...          ...  ...
# 4094        0  114.124.238.172             0            5            0  ...
# 4095        0    114.5.144.217             0            5            0  ...
# 4096        0  110.139.200.157             0            5            0  ...
# 4097        0   202.59.162.210             0            5            0  ...
# 4098        0    180.248.58.29             0            5            0  ...
#
#       userPin wareCommStatus  wareWarrStatus skuAttributes  \
# 0      j****y           None            None
# 1      j****h           None            None
# 2      w****l           None            None
# 3      j****j           None            None
# 4      c****0           None            None
# ...       ...            ...             ...           ...
# 4094   h****2           None            None
# 4095   j****x           None            None
# 4096   n****8           None            None
# 4097   j****i           None            None
# 4098   s****9           None            None
#
#       product.commentNum product.goodComment  \
# 0                     75                   5
# 1                     75                   5
# 2                     75                   5
# 3                     75                   5
# 4                     75                   5
# ...                  ...                 ...
# 4094                   0                 5.0
# 4095                   0                 5.0
# 4096                   0                 5.0
# 4097                   0                 5.0
# 4098                   0                 5.0
#
#                                        product.imageUrl product.skuId  \
# 0     https://img12.jd.id/zhipu/amZzL3Q5MS8yMjgvMTEz...     625499074
# 1     https://img12.jd.id/zhipu/amZzL3Q5MS8yMjgvMTEz...     625499074
# 2     https://img12.jd.id/zhipu/amZzL3Q5MS8yMjgvMTEz...     625499074
# 3     https://img12.jd.id/zhipu/amZzL3Q5MS8yMjgvMTEz...     625499074
# 4     https://img12.jd.id/zhipu/amZzL3Q5MS8yMjgvMTEz...     625499074
# ...                                                 ...           ...
# 4094  https://img12.jd.id/zhipu/amZzL3Q3OS81NC8zNDMy...     610930809
# 4095  https://img12.jd.id/zhipu/amZzL3QzNC8xMTQvNTE0...     610930872
# 4096  https://img12.jd.id/zhipu/amZzL3Q3My8zMjMvMzQz...     610930892
# 4097  https://img12.jd.id/zhipu/amZzL3Q3OS8yMDEvMzQ1...     610931793
# 4098  https://img12.jd.id/zhipu/amZzL3QyOC8yNC8zMTk1...     610931917
#
#                                         product.skuName product.spuId
# 0     Aerostreet 36-45 Massive Low Hitam - Sepatu Sn...     625499071
# 1     Aerostreet 36-45 Massive Low Hitam - Sepatu Sn...     625499071
# 2     Aerostreet 36-45 Massive Low Hitam - Sepatu Sn...     625499071
# 3     Aerostreet 36-45 Massive Low Hitam - Sepatu Sn...     625499071
# 4     Aerostreet 36-45 Massive Low Hitam - Sepatu Sn...     625499071
# ...                                                 ...           ...
# 4094  Aerostreet 39-42 Orious Black Grey - Sepatu Sn...     610930806
# 4095  Aerostreet 39-42 Absender Black Grey - Sepatu ...     610931376
# 4096  Aerostreet 39-42 Evogree Black Red - Sepatu Sn...     610930891
# 4097  Aerostreet 35-38 Cosmix Navy - Sepatu Sneakers...     610931788
# 4098  Aerostreet 35-38 Fit  Hitam - Sepatu Sneakers ...     610932458
#
# [4099 rows x 39 columns]

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@productrevieecommerce.r81yr95.mongodb.net/?retryWrites=true&w=majority"

# %%
localhost = "mongodb://localhost:27017"

# %%
client = MongoClient(localhost)
db = client['jdid'] 
collection = db['910']

# %%
collection.insert_many(review_list)
