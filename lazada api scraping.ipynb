# %%
import requests
import pandas as pd

# %%
url = 'https://www.lazada.co.id/aerostreet/'

query_params = {
    'ajax':'true',
    'from':'wangpu',
    'langFlag':'id',
    'page':'1',
    'pageTypeId':'2',
    'q':'All-Products'
}

headers = {
    'authority': 'www.lazada.co.id',
    'accept': 'application/json, text/plain, */*',
    'cookie': '__wpkreporterwid_=23aa6269-808e-4b2f-8c30-c64a120823d1; miidlaz=miidgi499a1gcf8kjp9cn3j; t_fv=1662664726435; t_uid=Br1Uy7Lfc7KMdFzYA514tADQx66FD0nE; lzd_cid=a360fd78-3649-423d-b46a-75b9ebea8e2c; _tb_token_=fa9e5eb358e5b; cna=FS6hGwn853YCAbb9hCYYob4b; lzd_sid=101ae28026be828dd07d0b40a2652fbe; exlaz=c_lzd_byr:mm_150030223_51150528_2010300519!id1256005:clkgi4c2i1gfghfhhc57f8::; lzd_click_id=clkgi4c2i1gfghfhhc57f8; _bl_uid=26lj5a5z18OuzX4FFtqy8hLtUeUX; _gcl_au=1.1.1060732676.1667526349; _fbp=fb.2.1667526370430.628345689; hng=ID|id-ID|IDR|360; hng.sig=to18pG508Hzz7EPB_okhuQu8kDUP3TDmLlnu4IbIOY8; cto_axid=Bs29sS62NxbyiAGA_4cJjK7HzJmmqpNW; AMCVS_126E248D54200F960A4C98C6%40AdobeOrg=1; _ga=GA1.3.1291115222.1668214893; pdp_login=false; xlly_s=1; t_sid=tMUBGKBJynQ2Hbov3jErp59Kfn9DLzwf; utm_channel=NA; _m_h5_tk=97cfbf3b33f03a5d46485794d49783ba_1668704377638; _m_h5_tk_enc=100113a0180689b014a6b3faeecdd011; cto_bundle=pItnpF9UNVVTYVFJZlBJdllyOW1PMTJKUXVCandzalVVS3lOS3VYNDBYYTRPbFdzNXFOWTdacnhGbFduNnNXRXcwMFI0YTJXNGhqN0lzcWREemRzVW9BWWx4QlJ3eW52cXMzRFU5aUN0NDc0JTJCaUpwWkh6dnhHUWJBZXNGczhsYkdGN0NQNHMxbCUyRlpDZmlSZTBxQ0IlMkZoaXpXZXclM0QlM0Q; AMCV_126E248D54200F960A4C98C6%40AdobeOrg=-1124106680%7CMCIDTS%7C19314%7CMCMID%7C02304393368715373353663002851187300535%7CMCAAMLH-1669299119%7C3%7CMCAAMB-1669299119%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-1668701519s%7CNONE%7CMCSYNCSOP%7C411-19316%7CvVersion%7C5.2.0; EGG_SESS=S_Gs1wHo9OvRHCMp98md7MykiOsZpKXsWGNnIG-w9KAQLUmod9k4cHSKOrAZ3bgpn9sgiOigTWvSN2bc97ZM6oKo2IsUx_EAhwJap8noflefckcjXSDCh5dztpF-l0-_PevDXgFQpb9hEnpCfB5hKHcYlK4Nb4JElDkM_8-_vTw=; _uetsid=cc05d490668111edbde78f8c25c3644d; _uetvid=74edc1a05be211ed8e3e8582a563d421; _gid=GA1.3.1768280202.1668694385; tfstk=cF2ABg4DwabDRChI1oCobd-ZlohOaiCxSa0eBJpXHc3RkGvvhs2TKJ3oGLmK8qIR.; l=eBgcOsoITPk65PGUBOfwlurza77tDIRfguPzaNbMiOB1tE5mwpaaxHZmFBvDE3QQKtfYOetzo7yrqd3MWYzLRxiOWh5ycvGOpxv9-; isg=BMzMihAVw2lgs9f5lmqZuWnFnSr-BXCvfJzBZyaNr3ahsW27TheEPzJHUbGJ-agH',
    'referer': 'https://www.lazada.co.id/aerostreet/?from=wangpu&langFlag=id&page=23&pageTypeId=2&q=All-Products',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    'x-csrf-token': 'fa9e5eb358e5b',
    'x-requested-with': 'XMLHttpRequest',
    'x-ua': '140#...',
    'x-umidtoken': 'T2gAs1rluSsWa7sOxMvxS6lOJXxgt_LV22ZunYdGaEHh5BvutAA-kaqjOgYTWQv7OCs='
}

result_product = []

data = requests.request("GET", url, headers=headers, params=query_params).json()

# %%
df = pd.DataFrame(data['mods']['listItems'])
df
# Out:
#                                                  name         nid  \
# 0   Aerostreet 39-44 Xenon Hitam Hitam - Sandal Se...  7045236399
# 1   Aerostreet 37-44 Massive All Black - Sepatu Sn...  6978080936
# 2   Aerostreet 36-45 Massive Low Hitam - Sepatu Sn...  4766732812
# 3   Aerostreet 36-40 Rose Putih Natural Pink - Sep...  5847820181
# 4   Aerostreet 37-44 Jhosse Low Hitam - Sepatu Sne...  4531244640
# 5   Aerostreet 39-44 Xenon Hitam Putih - Sandal Sl...  7045308503
# 6   Aerostreet 37-44 Dunk Putih Abu Muda - Sepatu ...  6605202092
# 7   Aerostreet 36-45 Massive Low Putih - Sepatu Sn...  4959894771
# 8   Aerostreet T Shirt Surrealizem Krem Kaos T-Shi...  6685612991
# 9   Aerostreet 37-44 Classic Putih Navy - Sepatu S...  6330488120
# 10  Aerostreet 36-40 Jisoo Putih Abu Muda Putih - ...  6138078988
# 11  Aerostreet 36-40 Rose Putih Abu Muda Putih - S...  6138098387
# 12  Aerostreet 36-40 Rose Putih Natural Hijau - Se...  5847776637
# ...
